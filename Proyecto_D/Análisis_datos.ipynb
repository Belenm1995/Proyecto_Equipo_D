# %% [markdown]
# # Cargamos las librerías

# %%
import requests
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Carga de los datos extraídos por ciudades entre 2021 y 2025:

# %% [markdown]
# ## Pontevedra

# %%
df_ponte_21 = pd.read_csv("pontevedra_2021-11-15_2022-11-15.csv")
df_ponte_22 = pd.read_csv("pontevedra_2022-11-15_2023-11-15.csv")
df_ponte_23 = pd.read_csv("pontevedra_2023-11-15_2024-11-15.csv")
df_ponte_24 = pd.read_csv("pontevedra_2024-11-15_2025-11-15.csv")
df_ponte = pd.concat([df_ponte_21, df_ponte_22, df_ponte_23, df_ponte_24], axis = 0, ignore_index = True)
df_ponte = df_ponte.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## A Coruña

# %%
df_coruna_21 = pd.read_csv("Csv_por_ciudades_y_años/coruña_2021_11_15_2022_11_15-checkpoint.csv")
df_coruna_22 = pd.read_csv("Csv_por_ciudades_y_años/coruña_2022_11_15_2023_11_15.csv")
df_coruna_23 = pd.read_csv("Csv_por_ciudades_y_años/coruña_2023_11_15_2024_11_15-checkpoint.csv")
df_coruna_24 = pd.read_csv("Csv_por_ciudades_y_años/coruña_2024_11_15_2025_11_15-checkpoint.csv")
df_coruna = pd.concat([df_coruna_21, df_coruna_22, df_coruna_23, df_coruna_24], axis = 0, ignore_index = True)
df_coruna = df_coruna.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Caldes de Montbui

# %%
df_caldes_21 = pd.read_csv("caldes_2021_11_15_2022_11_15.csv")
df_caldes_22 = pd.read_csv("caldes_2022_11_15_2023_11_15.csv")
df_caldes_23 = pd.read_csv("caldes_2023_11_15_2024_11_15.csv")
df_caldes_24 = pd.read_csv("caldes_2024_11_15_2025_11_15.csv")
df_caldes = pd.concat([df_caldes_21, df_caldes_22, df_caldes_23, df_caldes_24], axis = 0, ignore_index = True)
df_caldes = df_caldes.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Palma del Río

# %%
df_palmadr_21 = pd.read_csv("palmadr_2021_11_15_2022_11_15.csv")
df_palmadr_22 = pd.read_csv("palmadr_2022_11_15_2023_11_15.csv")
df_palmadr_23 = pd.read_csv("palmadr_2023_11_15_2024_11_15.csv")
df_palmadr_24 = pd.read_csv("palmadr_2024_11_15_2025_11_15.csv")
df_palmadr = pd.concat([df_palmadr_21, df_palmadr_22, df_palmadr_23, df_palmadr_24], axis = 0, ignore_index = True)
df_palmadr = df_palmadr.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Paiporta

# %%
df_paiporta_21 = pd.read_csv("paiporta_2021_11_15_2022_11_15.csv")
df_paiporta_22 = pd.read_csv("paiporta_2022_11_15_2023_11_15.csv")
df_paiporta_23 = pd.read_csv("paiporta_2023_11_15_2024_11_15.csv")
df_paiporta_24 = pd.read_csv("paiporta_2024_11_15_2025_11_15.csv")
df_paiporta = pd.concat([df_paiporta_21, df_paiporta_22, df_paiporta_23, df_paiporta_24], axis = 0, ignore_index = True)
df_paiporta = df_paiporta.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Guatire

# %%
df_guatire_21 = pd.read_csv("guatire_2021-11-15_2022-11-15.csv")
df_guatire_22 = pd.read_csv("guatire_2022-11-15_2023-11-15.csv")
df_guatire_23 = pd.read_csv("guatire_2023-11-15_2024-11-15.csv")
df_guatire_24 = pd.read_csv("guatire_2024-11-15_2025-11-15.csv")
df_guatire = pd.concat([df_guatire_21, df_guatire_22, df_guatire_23, df_guatire_24], axis = 0, ignore_index = True)
df_guatire = df_guatire.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Sidney

# %%
df_sidney_21 = pd.read_csv("sidney_2021-11-15_2022-11-15.csv")
df_sidney_22 = pd.read_csv("sidney_2022-11-15_2023-11-15.csv")
df_sidney_23 = pd.read_csv("sidney_2023-11-15_2024-11-15.csv")
df_sidney_24 = pd.read_csv("sidney_2024-11-15_2025-11-15.csv")
df_sidney = pd.concat([df_sidney_21, df_sidney_22, df_sidney_23, df_sidney_24], axis = 0, ignore_index = True)
df_sidney = df_sidney.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Ushuaia

# %%
df_ushuaia_21 = pd.read_csv("ushuaia_2021-11-15_2022-11-15.csv")
df_ushuaia_22 = pd.read_csv("ushuaia_2022-11-15_2023-11-15.csv")
df_ushuaia_23 = pd.read_csv("ushuaia_2023-11-15_2024-11-15.csv")
df_ushuaia_24 = pd.read_csv("ushuaia_2024-11-15_2025-11-15.csv")
df_ushuaia = pd.concat([df_ushuaia_21, df_ushuaia_22, df_ushuaia_23, df_ushuaia_24], axis = 0, ignore_index = True)
df_ushuaia = df_ushuaia.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Oslo

# %%
df_oslo_21 = pd.read_csv("oslo_2021-11-15_2022-11-15.csv")
df_oslo_22 = pd.read_csv("oslo_2022-11-15_2023-11-15.csv")
df_oslo_23 = pd.read_csv("oslo_2023-11-15_2024-11-15.csv")
df_oslo_24 = pd.read_csv("oslo_2024-11-15_2025-11-15.csv")
df_oslo = pd.concat([df_oslo_21, df_oslo_22, df_oslo_23, df_oslo_24], axis = 0, ignore_index = True)
df_oslo = df_oslo.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# # Hacemos un DataFrame con todo concatenándolos

# %%
df = pd.concat([df_ponte, df_coruna, df_caldes, df_palmadr, df_paiporta, df_guatire, df_sidney, df_ushuaia, df_oslo], axis = 0, ignore_index = True)

# %% [markdown]
# # Preguntas

# %% [markdown]
# 1. ¿Hace más viento en el norte o en el sur de Galicia?
# 2. Temperaturas máxima y mínima alcanzadas en ese período de tiempo.
# 3. Temperaturas máxima y mínima en España
