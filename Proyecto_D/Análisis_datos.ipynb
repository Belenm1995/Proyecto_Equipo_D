# %% [markdown]
# # Cargamos las librerías

# %%
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.axes as ax
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Carga de los datos extraídos por ciudades entre 2021 y 2025:

# %% [markdown]
# ## Pontevedra

# %%
import os
from datetime import datetime

df_ponte = pd.concat(objs = [pd.read_csv(x) for x in os.listdir() if x.startswith("ponte") and x.endswith(".csv")],
                     ignore_index = True)

df_ponte = df_ponte.drop(labels = "Unnamed: 0", axis = 1)

df_ponte["Fecha"] = df_ponte["Fecha"].apply(lambda x : datetime.strptime(x, "%Y-%m-%d"))

df_ponte["Year"] = df_ponte["Fecha"].apply(lambda x : x.year)

rename_columns = {"Momento (UNIX) de la vel. máx. del veinto" : "Momento (UNIX) de la vel. máx. del viento",
                  "Profundidad de la neive" : "Profundidad de la nieve"}

df_ponte = df_ponte.rename(columns = rename_columns)

df_ponte
# Out:
#           Ciudad      Fecha  Fecha (UNIX)  Presión atmosférica  \
# 0     Pontevedra 2021-11-15    1636930800                 1008
# 1     Pontevedra 2021-11-16    1637017200                 1008
# 2     Pontevedra 2021-11-17    1637103600                 1010
# 3     Pontevedra 2021-11-18    1637190000                 1011
# 4     Pontevedra 2021-11-19    1637276400                 1008
# ...          ...        ...           ...                  ...
# 1456  Pontevedra 2025-11-10    1762729200                 1005
# 1457  Pontevedra 2025-11-11    1762815600                  997
# 1458  Pontevedra 2025-11-12    1762902000                  991
# 1459  Pontevedra 2025-11-13    1762988400                  988
# 1460  Pontevedra 2025-11-14    1763074800                  988
#
#       Presión Atm. sobre Nvl. del mar  Media de la vel. del viento (m/s)  \
# 0                                1021                                1.8
# ...

# %% [markdown]
# ## A Coruña

# %%
import os
from datetime import datetime

df_coruna = pd.concat(objs = [pd.read_csv(x) for x in os.listdir() if x.startswith("coru") and x.endswith(".csv")],
                     ignore_index = True)

df_coruna = df_coruna.drop(labels = "Unnamed: 0", axis = 1)

df_coruna["Fecha"] = df_coruna["Fecha"].apply(lambda x : datetime.strptime(x, "%Y-%m-%d"))

df_coruna["Year"] = df_coruna["Fecha"].apply(lambda x : x.year)

df_coruna = df_coruna.rename(columns = rename_columns)

df_coruna
# Out:
#         Ciudad      Fecha  Fecha (UNIX)  Presión atmosférica  \
# 0     A Coruña 2021-11-15    1636930800                 1016
# 1     A Coruña 2021-11-16    1637017200                 1016
# 2     A Coruña 2021-11-17    1637103600                 1018
# 3     A Coruña 2021-11-18    1637190000                 1018
# 4     A Coruña 2021-11-19    1637276400                 1015
# ...        ...        ...           ...                  ...
# 1456  A Coruña 2025-11-10    1762729200                 1004
# 1457  A Coruña 2025-11-11    1762815600                  995
# 1458  A Coruña 2025-11-12    1762902000                  989
# 1459  A Coruña 2025-11-13    1762988400                  987
# 1460  A Coruña 2025-11-14    1763074800                  986
#
#       Presión Atm. sobre Nvl. del mar  Media de la vel. del viento (m/s)  \
# 0                                1025                                4.8
# 1                                1024                                4.6
# ...

# %% [markdown]
# ## Caldes de Montbui

# %%
import os
from datetime import datetime

df_caldes = pd.concat(objs = [pd.read_csv(x) for x in os.listdir() if x.startswith("caldes") and x.endswith(".csv")],
                     ignore_index = True)

df_caldes = df_caldes.drop(labels = "Unnamed: 0", axis = 1)

df_caldes["Fecha"] = df_caldes["Fecha"].apply(lambda x : datetime.strptime(x, "%Y-%m-%d"))

df_caldes["Year"] = df_caldes["Fecha"].apply(lambda x : x.year)

df_caldes = df_caldes.rename(columns = rename_columns)

df_caldes
# Out:
#                  Ciudad      Fecha  Fecha (UNIX)  Presión atmosférica  \
# 0     Caldes de Montbui 2021-11-15    1636930800                  987
# 1     Caldes de Montbui 2021-11-16    1637017200                  989
# 2     Caldes de Montbui 2021-11-17    1637103600                  992
# 3     Caldes de Montbui 2021-11-18    1637190000                  998
# 4     Caldes de Montbui 2021-11-19    1637276400                 1001
# ...                 ...        ...           ...                  ...
# 1456  Caldes de Montbui 2025-11-10    1762729200                  989
# 1457  Caldes de Montbui 2025-11-11    1762815600                  991
# 1458  Caldes de Montbui 2025-11-12    1762902000                  990
# 1459  Caldes de Montbui 2025-11-13    1762988400                  990
# 1460  Caldes de Montbui 2025-11-14    1763074800                  983
#
#       Presión Atm. sobre Nvl. del mar  Media de la vel. del viento (m/s)  \
# ...

# %% [markdown]
# ## Palma del Río

# %%
import os
from datetime import datetime

df_palmadr = pd.concat(objs = [pd.read_csv(x) for x in os.listdir() if x.startswith("palma") and x.endswith(".csv")],
                     ignore_index = True)

df_palmadr = df_palmadr.drop(labels = "Unnamed: 0", axis = 1)

df_palmadr["Fecha"] = df_palmadr["Fecha"].apply(lambda x : datetime.strptime(x, "%Y-%m-%d"))

df_palmadr["Year"] = df_palmadr["Fecha"].apply(lambda x : x.year)

df_palmadr = df_palmadr.rename(columns = rename_columns)

df_palmadr
# Out:
#              Ciudad      Fecha  Fecha (UNIX)  Presión atmosférica  \
# 0     Palma del Río 2021-11-15    1636930800                 1011
# 1     Palma del Río 2021-11-16    1637017200                 1011
# 2     Palma del Río 2021-11-17    1637103600                 1012
# 3     Palma del Río 2021-11-18    1637190000                 1014
# 4     Palma del Río 2021-11-19    1637276400                 1013
# ...             ...        ...           ...                  ...
# 1456  Palma del Río 2025-11-10    1762729200                 1018
# 1457  Palma del Río 2025-11-11    1762815600                 1015
# 1458  Palma del Río 2025-11-12    1762902000                 1010
# 1459  Palma del Río 2025-11-13    1762988400                 1008
# 1460  Palma del Río 2025-11-14    1763074800                 1009
#
#       Presión Atm. sobre Nvl. del mar  Media de la vel. del viento (m/s)  \
# 0                                1018                                2.6
# ...

# %% [markdown]
# # Hacemos un DataFrame con todo concatenándolos

# %%
df = pd.concat([df_caldes, df_coruna, df_palmadr, df_ponte],
               axis = 0, ignore_index = True)

df
# Out:
#                  Ciudad      Fecha  Fecha (UNIX)  Presión atmosférica  \
# 0     Caldes de Montbui 2021-11-15    1636930800                  987
# 1     Caldes de Montbui 2021-11-16    1637017200                  989
# 2     Caldes de Montbui 2021-11-17    1637103600                  992
# 3     Caldes de Montbui 2021-11-18    1637190000                  998
# 4     Caldes de Montbui 2021-11-19    1637276400                 1001
# ...                 ...        ...           ...                  ...
# 5839         Pontevedra 2025-11-10    1762729200                 1005
# 5840         Pontevedra 2025-11-11    1762815600                  997
# 5841         Pontevedra 2025-11-12    1762902000                  991
# 5842         Pontevedra 2025-11-13    1762988400                  988
# 5843         Pontevedra 2025-11-14    1763074800                  988
#
#       Presión Atm. sobre Nvl. del mar  Media de la vel. del viento (m/s)  \
# ...

# %% [markdown]
# # Preguntas

# %% [markdown]
# 1. ¿Hace más viento en el norte o en el sur de Galicia?
# 2. Temperaturas máxima y mínima alcanzadas en ese período de tiempo.
# 3. Temperaturas máxima y mínima en España.

# %% [markdown]
# # Gráficas

# %% [markdown]
# ### 1. Comparación temperaturas máxima, media y mínima entre 2021 y 2025 por ciudades

# %%
X = df_ponte["Fecha"]
Y1 = df_ponte["Media de la temperatura"]
Y2 = df_ponte["Temperatura máxima"]
Y3 = df_ponte["Temperatura mínima"]

colores = ["red", "blue", "green"]

plt.figure(figsize = (15, 8))

plt.plot(X,
         Y1, 
         color       = "red",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temperatura ℃") 

plt.plot(X,
         Y2, 
         color       = "blue",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. máxima ℃") 

plt.plot(X,
         Y3, 
         color       = "green",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. mínima ℃") 



plt.legend()
plt.xticks([])
plt.grid()
plt.show()

# %%
X = df_coruna["Fecha"]
Y1 = df_coruna["Media de la temperatura"]
Y2 = df_coruna["Temperatura máxima"]
Y3 = df_coruna["Temperatura mínima"]

colores = ["red", "blue", "green"]

plt.figure(figsize = (15, 8))

plt.plot(X,
         Y1, 
         color       = "red",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temperatura ℃") 

plt.plot(X,
         Y2, 
         color       = "blue",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. máxima ℃") 

plt.plot(X,
         Y3, 
         color       = "green",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. mínima ℃") 



plt.legend()
plt.xticks([])
plt.grid()
plt.show()

# %%
X = df_caldes["Fecha"]
Y1 = df_caldes["Media de la temperatura"]
Y2 = df_caldes["Temperatura máxima"]
Y3 = df_caldes["Temperatura mínima"]

colores = ["red", "blue", "green"]

plt.figure(figsize = (15, 8))

plt.plot(X,
         Y1, 
         color       = "red",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temperatura ℃") 

plt.plot(X,
         Y2, 
         color       = "blue",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. máxima ℃") 

plt.plot(X,
         Y3, 
         color       = "green",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. mínima ℃") 



plt.legend()
plt.xticks([])
plt.grid()
#plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1000))
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
#plt.gcf().autofmt_xdate()
#ax.xaxis.set_major_locator(mdates.FixedLocator([pd.to_datetime("2021-11-15"), pd.to_datetime("2025-11-15")]))
plt.show()

# %%
X = df_palmadr["Fecha"]
Y1 = df_palmadr["Media de la temperatura"]
Y2 = df_palmadr["Temperatura máxima"]
Y3 = df_palmadr["Temperatura mínima"]

colores = ["red", "blue", "green"]

plt.figure(figsize = (15, 8))

plt.plot(X,
         Y1, 
         color       = "red",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temperatura ℃") 

plt.plot(X,
         Y2, 
         color       = "blue",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. máxima ℃") 

plt.plot(X,
         Y3, 
         color       = "green",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. mínima ℃") 



plt.legend()
plt.xticks([])
plt.grid()
plt.show()

# %%
X = df_guatire["Fecha"]
Y1 = df_guatire["Media de la temperatura"]
Y2 = df_guatire["Temperatura máxima"]
Y3 = df_guatire["Temperatura mínima"]

colores = ["red", "blue", "green"]

plt.figure(figsize = (15, 8))

plt.plot(X,
         Y1, 
         color       = "red",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temperatura ℃") 

plt.plot(X,
         Y2, 
         color       = "blue",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. máxima ℃") 

plt.plot(X,
         Y3, 
         color       = "green",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. mínima ℃") 



plt.legend()
plt.xticks([])
plt.grid()
plt.show()

# %% [markdown]
# ### 2. Evolución de la temperatura media, máxima y mínima en este periodo

# %%
plt.figure(figsize = (10,20))

plt.subplot(3, 1, 1) 
sns.barplot(x = "Year", 
            y = "Media de la temperatura", 
            hue = "Ciudad", 
            data = df.groupby(by = ["Year","Ciudad"]).agg({"Media de la temperatura": "mean"}), 
            palette = "rainbow")

plt.legend([])

plt.subplot(3, 1, 2)
sns.barplot(x = "Year", 
            y = "Temperatura máxima", 
            hue = "Ciudad", 
            data = df.groupby(by = ["Year","Ciudad"]).agg({"Temperatura máxima": "max"}), 
            palette = "rainbow")

plt.legend([])

plt.subplot(3,1, 3)
sns.barplot(x = "Year", 
            y = "Temperatura mínima", 
            hue = "Ciudad", 
            data = df.groupby(by = ["Year","Ciudad"]).agg({"Temperatura mínima": "min"}), 
            palette = "rainbow")

plt.legend(ncol=2, loc="lower left", fontsize=12)

plt.show()

# %%
plt.figure(figsize = (6, 4))

sns.countplot(x = "Year", hue = "Ciudad", data = df.groupby(by = ["Year","Ciudad"]).agg({"Temperatura máxima": "max"}), palette = "Reds")
plt.xticks(rotation = 90)

plt.show()

# %% [markdown]
# 3.

# %%
X = np.linspace(-5, 5, 1_000)
Y = X

plt.figure(figsize = (15, 8))

plt.subplot(2, 3, 1)  
sns.histplot(df_palmadr["Índice máximo de rayos ultravioleta"], color = "red", bins = 50, kde = True) 

plt.subplot(2, 3, 2)  
sns.histplot(df_caldes["Índice máximo de rayos ultravioleta"], color = "green", bins = 50, kde = True) 

plt.subplot(2, 3, 3)  
sns.histplot(df_ponte["Índice máximo de rayos ultravioleta"], color = "blue", bins = 50, kde = True)

plt.subplot(2, 3, 4)
sns.histplot(df_oslo["Índice máximo de rayos ultravioleta"], color = "magenta", bins = 50, kde = True)

plt.subplot(2, 3, 5)  
sns.histplot(df_coruna["Índice máximo de rayos ultravioleta"], color = "orange", bins = 50, kde = True)

plt.subplot(2, 3, 6)  
sns.histplot(df_guatire["Índice máximo de rayos ultravioleta"], color = "yellow", bins = 50, kde = True)

plt.show()

# %%
X = np.linspace(-5, 5, 1_000)
Y = X

plt.figure(figsize = (15, 8))

plt.subplot(2, 3, 1)  
plt.boxplot(x = df_palmadr["Presión atmosférica"], labels = ["Palma del Río"])

plt.subplot(2, 3, 2) 
plt.boxplot(x = df_caldes["Presión atmosférica"], labels = ["Caldes de Montbui"])

plt.subplot(2, 3, 3) 
plt.boxplot(x = df_ponte["Presión atmosférica"], labels = ["Pontevedra"])

plt.subplot(2, 3, 4)
plt.boxplot(x = df_oslo["Presión atmosférica"], labels = ["Oslo"])

plt.subplot(2, 3, 5)  
plt.boxplot(x = df_coruna["Presión atmosférica"], labels = ["A Coruña"])

plt.subplot(2, 3, 6)  
plt.boxplot(x = df_guatire["Presión atmosférica"], labels = ["Guatire"])



plt.show()
# Out:
# /var/folders/61/713tbj6n3456mfmkb75f3j8r0000gn/T/ipykernel_87600/3551316975.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x = df_palmadr["Presión atmosférica"], labels = ["Palma del Río"])
# /var/folders/61/713tbj6n3456mfmkb75f3j8r0000gn/T/ipykernel_87600/3551316975.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x = df_caldes["Presión atmosférica"], labels = ["Caldes de Montbui"])
# /var/folders/61/713tbj6n3456mfmkb75f3j8r0000gn/T/ipykernel_87600/3551316975.py:13: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
# ...
