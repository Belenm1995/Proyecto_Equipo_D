# %%
import requests
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data = {}

url = "https://api.weatherbit.io/v2.0/geocode?&city=pontevedra&country=ES&key=ac89c8c428e94ce68180c1a3a65dec3f"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'ES',
#  'geo_id': 'PONTEVEDRA--ES',
#  'lat': 42.431,
#  'lon': -8.64435,
#  'name': 'Pontevedra',
#  'state_code': '58',
#  'timezone': 'Europe/Madrid'}

# %%
# Datos Pontevedra 2024/2025
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=42.431&lon=-8.64435&start_date=2024-11-15&end_date=2025-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
data.update(response.json())

# %%
pprint(data)
# Out:
# {'city_id': '3113209',
#  'city_name': 'Pontevedra',
#  'country_code': 'ES',
#  'data': [{'clouds': 90,
#            'datetime': '2024-11-15',
#            'dewpt': 12.2,
#            'dhi': 29,
#            'dni': 246,
#            'ghi': 114,
#            'max_dhi': 94,
#            'max_dni': 789,
#            'max_ghi': 467,
#            'max_temp': 19,
#            'max_temp_ts': 1731682800,
#            'max_uv': 2.2,
#            'max_wind_dir': 62,
#            'max_wind_spd': 2,
#            'max_wind_spd_ts': 1731625200,
#            'min_temp': 14.5,
#            'min_temp_ts': 1731639600,
#            'precip': 28.8,
#            'precip_gpm': 28.8,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 78,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 60,
#            't_dhi': 691,
#            't_dni': 5892,
#            't_ghi': 2733,
#            't_solar_rad': 1438,
#            'temp': 16.1,
#            'ts': 1731625200,
#            'wind_dir': 62,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.4},
#           {'clouds': 67,
#            'datetime': '2024-11-16',
#            'dewpt': 11.9,
#            'dhi': 29,
#            'dni': 244,
#            'ghi': 112,
#            'max_dhi': 94,
#            'max_dni': 787,
#            'max_ghi': 463,
#            'max_temp': 19.4,
#            'max_temp_ts': 1731769200,
#            'max_uv': 1.4,
#            'max_wind_dir': 79,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1731726000,
#            'min_temp': 14.8,
#            'min_temp_ts': 1731794400,
#            'precip': 2.3,
#            'precip_gpm': 2.3,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 73,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 61,
#            't_dhi': 686,
#            't_dni': 5848,
#            't_ghi': 2698,
#            't_solar_rad': 1460,
#            'temp': 16.7,
#            'ts': 1731711600,
#            'wind_dir': 79,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.5},
#           {'clouds': 9,
#            'datetime': '2024-11-17',
#            'dewpt': 11.2,
#            'dhi': 28,
#            'dni': 242,
#            'ghi': 111,
#            'max_dhi': 94,
#            'max_dni': 785,
#            'max_ghi': 459,
#            'max_temp': 20.1,
#            'max_temp_ts': 1731880800,
#            'max_uv': 3.1,
#            'max_wind_dir': 118,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1731880800,
#            'min_temp': 12.9,
#            'min_temp_ts': 1731812400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 77,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 111,
#            't_dhi': 681,
#            't_dni': 5806,
#            't_ghi': 2663,
#            't_solar_rad': 2663,
#            'temp': 15.3,
#            'ts': 1731798000,
#            'wind_dir': 118,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.5},
#           {'clouds': 30,
#            'datetime': '2024-11-18',
#            'dewpt': 11.9,
#            'dhi': 28,
#            'dni': 240,
#            'ghi': 110,
#            'max_dhi': 93,
#            'max_dni': 783,
#            'max_ghi': 454,
#            'max_temp': 18.1,
#            'max_temp_ts': 1731909600,
#            'max_uv': 2.6,
#            'max_wind_dir': 150,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1731906000,
#            'min_temp': 11.1,
#            'min_temp_ts': 1731913200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 107,
#            't_dhi': 676,
#            't_dni': 5763,
#            't_ghi': 2630,
#            't_solar_rad': 2576,
#            'temp': 14,
#            'ts': 1731884400,
#            'wind_dir': 150,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.4},
#           {'clouds': 90,
#            'datetime': '2024-11-19',
#            'dewpt': 10.8,
#            'dhi': 28,
#            'dni': 238,
#            'ghi': 108,
#            'max_dhi': 93,
#            'max_dni': 781,
#            'max_ghi': 450,
#            'max_temp': 14.4,
#            'max_temp_ts': 1731970800,
#            'max_uv': 1,
#            'max_wind_dir': 147,
#            'max_wind_spd': 4,
#            'max_wind_spd_ts': 1731970800,
#            'min_temp': 11.5,
#            'min_temp_ts': 1731970800,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1020,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 42,
#            't_dhi': 671,
#            't_dni': 5722,
#            't_ghi': 2598,
#            't_solar_rad': 997,
#            'temp': 13,
#            'ts': 1731970800,
#            'wind_dir': 147,
#            'wind_gust_spd': 7.2,
#            'wind_spd': 2.1},
#           {'clouds': 85,
#            'datetime': '2024-11-20',
#            'dewpt': 12.2,
#            'dhi': 28,
#            'dni': 237,
#            'ghi': 107,
#            'max_dhi': 93,
#            'max_dni': 779,
#            'max_ghi': 446,
#            'max_temp': 15.2,
#            'max_temp_ts': 1732122000,
#            'max_uv': 1.2,
#            'max_wind_dir': 252,
#            'max_wind_spd': 6,
#            'max_wind_spd_ts': 1732122000,
#            'min_temp': 13.3,
#            'min_temp_ts': 1732122000,
#            'precip': 2.3,
#            'precip_gpm': 2.3,
#            'pres': 1021,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 41,
#            't_dhi': 666,
#            't_dni': 5682,
#            't_ghi': 2566,
#            't_solar_rad': 996,
#            'temp': 14.1,
#            'ts': 1732057200,
#            'wind_dir': 252,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 4.2},
#           {'clouds': 90,
#            'datetime': '2024-11-21',
#            'dewpt': 12.6,
#            'dhi': 28,
#            'dni': 235,
#            'ghi': 106,
#            'max_dhi': 92,
#            'max_dni': 777,
#            'max_ghi': 442,
#            'max_temp': 15.6,
#            'max_temp_ts': 1732143600,
#            'max_uv': 1.2,
#            'max_wind_dir': 245,
#            'max_wind_spd': 9.6,
#            'max_wind_spd_ts': 1732143600,
#            'min_temp': 12.6,
#            'min_temp_ts': 1732143600,
#            'precip': 9.3,
#            'precip_gpm': 9.3,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 43,
#            't_dhi': 661,
#            't_dni': 5642,
#            't_ghi': 2536,
#            't_solar_rad': 1028,
#            'temp': 14.5,
#            'ts': 1732143600,
#            'wind_dir': 245,
#            'wind_gust_spd': 18,
#            'wind_spd': 7.4},
#           {'clouds': 81,
#            'datetime': '2024-11-22',
#            'dewpt': 7.7,
#            'dhi': 27,
#            'dni': 233,
#            'ghi': 104,
#            'max_dhi': 92,
#            'max_dni': 775,
#            'max_ghi': 439,
#            'max_temp': 13.3,
#            'max_temp_ts': 1732230000,
#            'max_uv': 1.4,
#            'max_wind_dir': 146,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1732230000,
#            'min_temp': 7.4,
#            'min_temp_ts': 1732262400,
#            'precip': 1.3,
#            'precip_gpm': 1.3,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 43,
#            't_dhi': 656,
#            't_dni': 5604,
#            't_ghi': 2506,
#            't_solar_rad': 1022,
#            'temp': 10.9,
#            'ts': 1732230000,
#            'wind_dir': 146,
#            'wind_gust_spd': 10,
#            'wind_spd': 1.9},
#           {'clouds': 91,
#            'datetime': '2024-11-23',
#            'dewpt': 11.4,
#            'dhi': 27,
#            'dni': 232,
#            'ghi': 103,
#            'max_dhi': 92,
#            'max_dni': 774,
#            'max_ghi': 435,
#            'max_temp': 20.7,
#            'max_temp_ts': 1732366800,
#            'max_uv': 0.9,
#            'max_wind_dir': 179,
#            'max_wind_spd': 6,
#            'max_wind_spd_ts': 1732395600,
#            'min_temp': 12.3,
#            'min_temp_ts': 1732316400,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 999,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 71,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 27,
#            't_dhi': 651,
#            't_dni': 5566,
#            't_ghi': 2478,
#            't_solar_rad': 649,
#            'temp': 17.2,
#            'ts': 1732316400,
#            'wind_dir': 179,
#            'wind_gust_spd': 19.6,
#            'wind_spd': 3.9},
#           {'clouds': 82,
#            'datetime': '2024-11-24',
#            'dewpt': 10.4,
#            'dhi': 27,
#            'dni': 230,
#            'ghi': 102,
#            'max_dhi': 91,
#            'max_dni': 772,
#            'max_ghi': 431,
#            'max_temp': 21.7,
#            'max_temp_ts': 1732442400,
#            'max_uv': 1.1,
#            'max_wind_dir': 176,
#            'max_wind_spd': 7.2,
#            'max_wind_spd_ts': 1732456800,
#            'min_temp': 13.7,
#            'min_temp_ts': 1732485600,
#            'precip': 56,
#            'precip_gpm': 56,
#            'pres': 991,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 58,
#            'slp': 1003,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 42,
#            't_dhi': 646,
#            't_dni': 5530,
#            't_ghi': 2450,
#            't_solar_rad': 1012,
#            'temp': 19.4,
#            'ts': 1732402800,
#            'wind_dir': 176,
#            'wind_gust_spd': 26,
#            'wind_spd': 4.7},
#           {'clouds': 59,
#            'datetime': '2024-11-25',
#            'dewpt': 9.8,
#            'dhi': 27,
#            'dni': 229,
#            'ghi': 101,
#            'max_dhi': 91,
#            'max_dni': 770,
#            'max_ghi': 428,
#            'max_temp': 14.2,
#            'max_temp_ts': 1732539600,
#            'max_uv': 2.3,
#            'max_wind_dir': 186,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1732528800,
#            'min_temp': 9.2,
#            'min_temp_ts': 1732510800,
#            'precip': 9,
#            'precip_gpm': 9,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 94,
#            't_dhi': 642,
#            't_dni': 5495,
#            't_ghi': 2423,
#            't_solar_rad': 2264,
#            'temp': 11.2,
#            'ts': 1732489200,
#            'wind_dir': 186,
#            'wind_gust_spd': 12.4,
#            'wind_spd': 1.4},
#           {'clouds': 85,
#            'datetime': '2024-11-26',
#            'dewpt': 10.1,
#            'dhi': 27,
#            'dni': 228,
#            'ghi': 100,
#            'max_dhi': 91,
#            'max_dni': 768,
#            'max_ghi': 425,
#            'max_temp': 13.9,
#            'max_temp_ts': 1732636800,
#            'max_uv': 1.3,
#            'max_wind_dir': 146,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1732618800,
#            'min_temp': 10.2,
#            'min_temp_ts': 1732575600,
#            'precip': 4.5,
#            'precip_gpm': 4.5,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 53,
#            't_dhi': 637,
#            't_dni': 5461,
#            't_ghi': 2397,
#            't_solar_rad': 1273,
#            'temp': 12.1,
#            'ts': 1732575600,
#            'wind_dir': 146,
#            'wind_gust_spd': 12,
#            'wind_spd': 1.3},
#           {'clouds': 62,
#            'datetime': '2024-11-27',
#            'dewpt': 9.3,
#            'dhi': 26,
#            'dni': 226,
#            'ghi': 99,
#            'max_dhi': 91,
#            'max_dni': 767,
#            'max_ghi': 421,
#            'max_temp': 17.9,
#            'max_temp_ts': 1732708800,
#            'max_uv': 1.5,
#            'max_wind_dir': 148,
#            'max_wind_spd': 2,
#            'max_wind_spd_ts': 1732744800,
#            'min_temp': 10.4,
#            'min_temp_ts': 1732744800,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 65,
#            't_dhi': 633,
#            't_dni': 5428,
#            't_ghi': 2373,
#            't_solar_rad': 1562,
#            'temp': 13.4,
#            'ts': 1732662000,
#            'wind_dir': 148,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 1.2},
#           {'clouds': 42,
#            'datetime': '2024-11-28',
#            'dewpt': 8,
#            'dhi': 26,
#            'dni': 225,
#            'ghi': 98,
#            'max_dhi': 90,
#            'max_dni': 765,
#            'max_ghi': 418,
#            'max_temp': 18.4,
#            'max_temp_ts': 1732806000,
#            'max_uv': 2.3,
#            'max_wind_dir': 149,
#            'max_wind_spd': 3.8,
#            'max_wind_spd_ts': 1732748400,
#            'min_temp': 8.2,
#            'min_temp_ts': 1732780800,
#            'precip': 1,
#            'precip_gpm': 1,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 72,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 91,
#            't_dhi': 629,
#            't_dni': 5397,
#            't_ghi': 2349,
#            't_solar_rad': 2194,
#            'temp': 13.2,
#            'ts': 1732748400,
#            'wind_dir': 149,
#            'wind_gust_spd': 9.6,
#            'wind_spd': 1.3},
#           {'clouds': 77,
#            'datetime': '2024-11-29',
#            'dewpt': 13.9,
#            'dhi': 26,
#            'dni': 224,
#            'ghi': 97,
#            'max_dhi': 90,
#            'max_dni': 764,
#            'max_ghi': 415,
#            'max_temp': 20.5,
#            'max_temp_ts': 1732881600,
#            'max_uv': 1.9,
#            'max_wind_dir': 175,
#            'max_wind_spd': 3.8,
#            'max_wind_spd_ts': 1732849200,
#            'min_temp': 15,
#            'min_temp_ts': 1732906800,
#            'precip': 2.8,
#            'precip_gpm': 2.8,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 624,
#            't_dni': 5366,
#            't_ghi': 2326,
#            't_solar_rad': 1979,
#            'temp': 17.3,
#            'ts': 1732834800,
#            'wind_dir': 175,
#            'wind_gust_spd': 14.8,
#            'wind_spd': 2.1},
#           {'clouds': 88,
#            'datetime': '2024-11-30',
#            'dewpt': 14.9,
#            'dhi': 26,
#            'dni': 222,
#            'ghi': 96,
#            'max_dhi': 90,
#            'max_dni': 762,
#            'max_ghi': 412,
#            'max_temp': 18.2,
#            'max_temp_ts': 1733004000,
#            'max_uv': 0.9,
#            'max_wind_dir': 171,
#            'max_wind_spd': 6.8,
#            'max_wind_spd_ts': 1733004000,
#            'min_temp': 15.4,
#            'min_temp_ts': 1732924800,
#            'precip': 8.8,
#            'precip_gpm': 8.8,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 27,
#            't_dhi': 620,
#            't_dni': 5336,
#            't_ghi': 2304,
#            't_solar_rad': 656,
#            'temp': 17,
#            'ts': 1732921200,
#            'wind_dir': 171,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 2.1},
#           {'clouds': 94,
#            'datetime': '2024-12-01',
#            'dewpt': 14,
#            'dhi': 26,
#            'dni': 221,
#            'ghi': 95,
#            'max_dhi': 90,
#            'max_dni': 761,
#            'max_ghi': 409,
#            'max_temp': 16.7,
#            'max_temp_ts': 1733086800,
#            'max_uv': 0.7,
#            'max_wind_dir': 180,
#            'max_wind_spd': 6.4,
#            'max_wind_spd_ts': 1733086800,
#            'min_temp': 13.1,
#            'min_temp_ts': 1733090400,
#            'precip': 34,
#            'precip_gpm': 34,
#            'pres': 1020,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 13,
#            't_dhi': 617,
#            't_dni': 5307,
#            't_ghi': 2283,
#            't_solar_rad': 303,
#            'temp': 15.1,
#            'ts': 1733007600,
#            'wind_dir': 180,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 3.2},
#           {'clouds': 41,
#            'datetime': '2024-12-02',
#            'dewpt': 10.6,
#            'dhi': 26,
#            'dni': 220,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 759,
#            'max_ghi': 407,
#            'max_temp': 16.4,
#            'max_temp_ts': 1733144400,
#            'max_uv': 1.6,
#            'max_wind_dir': 198,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1733144400,
#            'min_temp': 9.5,
#            'min_temp_ts': 1733176800,
#            'precip': 1.8,
#            'precip_gpm': 1.8,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 67,
#            't_dhi': 613,
#            't_dni': 5279,
#            't_ghi': 2264,
#            't_solar_rad': 1599,
#            'temp': 12.6,
#            'ts': 1733094000,
#            'wind_dir': 198,
#            'wind_gust_spd': 8.4,
#            'wind_spd': 1.5},
#           {'clouds': 93,
#            'datetime': '2024-12-03',
#            'dewpt': 8.8,
#            'dhi': 25,
#            'dni': 219,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 758,
#            'max_ghi': 404,
#            'max_temp': 11.7,
#            'max_temp_ts': 1733234400,
#            'max_uv': 0.7,
#            'max_wind_dir': 163,
#            'max_wind_spd': 1.9,
#            'max_wind_spd_ts': 1733209200,
#            'min_temp': 6.5,
#            'min_temp_ts': 1733205600,
#            'precip': 7.5,
#            'precip_gpm': 7.5,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 18,
#            't_dhi': 609,
#            't_dni': 5253,
#            't_ghi': 2245,
#            't_solar_rad': 434,
#            'temp': 9.6,
#            'ts': 1733180400,
#            'wind_dir': 163,
#            'wind_gust_spd': 8.8,
#            'wind_spd': 1},
#           {'clouds': 83,
#            'datetime': '2024-12-04',
#            'dewpt': 11.2,
#            'dhi': 25,
#            'dni': 218,
#            'ghi': 93,
#            'max_dhi': 89,
#            'max_dni': 756,
#            'max_ghi': 402,
#            'max_temp': 14.1,
#            'max_temp_ts': 1733320800,
#            'max_uv': 0.7,
#            'max_wind_dir': 129,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1733317200,
#            'min_temp': 10.4,
#            'min_temp_ts': 1733292000,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 19,
#            't_dhi': 606,
#            't_dni': 5227,
#            't_ghi': 2227,
#            't_solar_rad': 454,
#            'temp': 12,
#            'ts': 1733266800,
#            'wind_dir': 129,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.2},
#           {'clouds': 96,
#            'datetime': '2024-12-05',
#            'dewpt': 12.5,
#            'dhi': 25,
#            'dni': 217,
#            'ghi': 92,
#            'max_dhi': 89,
#            'max_dni': 755,
#            'max_ghi': 399,
#            'max_temp': 14.5,
#            'max_temp_ts': 1733414400,
#            'max_uv': 0.7,
#            'max_wind_dir': 146,
#            'max_wind_spd': 1.5,
#            'max_wind_spd_ts': 1733360400,
#            'min_temp': 11,
#            'min_temp_ts': 1733353200,
#            'precip': 11.5,
#            'precip_gpm': 11.5,
#            'pres': 1017,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 99,
#            'slp': 1030,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 14,
#            't_dhi': 603,
#            't_dni': 5202,
#            't_ghi': 2210,
#            't_solar_rad': 337,
#            'temp': 12.7,
#            'ts': 1733353200,
#            'wind_dir': 146,
#            'wind_gust_spd': 10,
#            'wind_spd': 0.8},
#           {'clouds': 86,
#            'datetime': '2024-12-06',
#            'dewpt': 13.8,
#            'dhi': 25,
#            'dni': 216,
#            'ghi': 91,
#            'max_dhi': 89,
#            'max_dni': 754,
#            'max_ghi': 397,
#            'max_temp': 16.3,
#            'max_temp_ts': 1733493600,
#            'max_uv': 1.2,
#            'max_wind_dir': 140,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1733493600,
#            'min_temp': 13.5,
#            'min_temp_ts': 1733450400,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1017,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1030,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 52,
#            't_dhi': 600,
#            't_dni': 5178,
#            't_ghi': 2194,
#            't_solar_rad': 1251,
#            'temp': 14.6,
#            'ts': 1733439600,
#            'wind_dir': 140,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.1},
#           {'clouds': 63,
#            'datetime': '2024-12-07',
#            'dewpt': 9.1,
#            'dhi': 25,
#            'dni': 215,
#            'ghi': 91,
#            'max_dhi': 88,
#            'max_dni': 753,
#            'max_ghi': 395,
#            'max_temp': 14.5,
#            'max_temp_ts': 1733544000,
#            'max_uv': 1.5,
#            'max_wind_dir': 264,
#            'max_wind_spd': 4.9,
#            'max_wind_spd_ts': 1733580000,
#            'min_temp': 9.5,
#            'min_temp_ts': 1733608800,
#            'precip': 1.8,
#            'precip_gpm': 1.8,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1031,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 597,
#            't_dni': 5156,
#            't_ghi': 2180,
#            't_solar_rad': 1974,
#            'temp': 12.7,
#            'ts': 1733526000,
#            'wind_dir': 264,
#            'wind_gust_spd': 14,
#            'wind_spd': 2.7},
#           {'clouds': 58,
#            'datetime': '2024-12-08',
#            'dewpt': 6,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 393,
#            'max_temp': 12.1,
#            'max_temp_ts': 1733662800,
#            'max_uv': 1.4,
#            'max_wind_dir': 265,
#            'max_wind_spd': 4.5,
#            'max_wind_spd_ts': 1733666400,
#            'min_temp': 7.6,
#            'min_temp_ts': 1733637600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1019,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1032,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 79,
#            't_dhi': 595,
#            't_dni': 5136,
#            't_ghi': 2166,
#            't_solar_rad': 1887,
#            'temp': 9.2,
#            'ts': 1733612400,
#            'wind_dir': 265,
#            'wind_gust_spd': 14.8,
#            'wind_spd': 1.9},
#           {'clouds': 35,
#            'datetime': '2024-12-09',
#            'dewpt': 6.3,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 391,
#            'max_temp': 12.3,
#            'max_temp_ts': 1733752800,
#            'max_uv': 1.6,
#            'max_wind_dir': 150,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1733749200,
#            'min_temp': 6.1,
#            'min_temp_ts': 1733727600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 85,
#            't_dhi': 592,
#            't_dni': 5117,
#            't_ghi': 2153,
#            't_solar_rad': 2033,
#            'temp': 8.3,
#            'ts': 1733698800,
#            'wind_dir': 150,
#            'wind_gust_spd': 12.4,
#            'wind_spd': 1.4},
#           {'clouds': 17,
#            'datetime': '2024-12-10',
#            'dewpt': 4.8,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 390,
#            'max_temp': 12.4,
#            'max_temp_ts': 1733835600,
#            'max_uv': 2.1,
#            'max_wind_dir': 117,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1733842800,
#            'min_temp': 4.4,
#            'min_temp_ts': 1733817600,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 89,
#            't_dhi': 590,
#            't_dni': 5100,
#            't_ghi': 2142,
#            't_solar_rad': 2141,
#            'temp': 7.7,
#            'ts': 1733785200,
#            'wind_dir': 117,
#            'wind_gust_spd': 10,
#            'wind_spd': 1.7},
#           {'clouds': 7,
#            'datetime': '2024-12-11',
#            'dewpt': 3.8,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 388,
#            'max_temp': 11.8,
#            'max_temp_ts': 1733925600,
#            'max_uv': 2.1,
#            'max_wind_dir': 146,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1733875200,
#            'min_temp': 2.9,
#            'min_temp_ts': 1733904000,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 89,
#            't_dhi': 587,
#            't_dni': 5085,
#            't_ghi': 2131,
#            't_solar_rad': 2131,
#            'temp': 7.1,
#            'ts': 1733871600,
#            'wind_dir': 146,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.2},
#           {'clouds': 25,
#            'datetime': '2024-12-12',
#            'dewpt': 4,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 386,
#            'max_temp': 12.3,
#            'max_temp_ts': 1734012000,
#            'max_uv': 1.9,
#            'max_wind_dir': 107,
#            'max_wind_spd': 3,
#            'max_wind_spd_ts': 1734040800,
#            'min_temp': 6,
#            'min_temp_ts': 1733986800,
#            'precip': 1.5,
#            'precip_gpm': 1.5,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 75,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 88,
#            't_dhi': 585,
#            't_dni': 5072,
#            't_ghi': 2122,
#            't_solar_rad': 2112,
#            'temp': 8.2,
#            'ts': 1733958000,
#            'wind_dir': 107,
#            'wind_gust_spd': 6.4,
#            'wind_spd': 1.4},
#           {'clouds': 68,
#            'datetime': '2024-12-13',
#            'dewpt': 3.6,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 385,
#            'max_temp': 12.4,
#            'max_temp_ts': 1734102000,
#            'max_uv': 1.4,
#            'max_wind_dir': 85,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1734127200,
#            'min_temp': 5.2,
#            'min_temp_ts': 1734073200,
#            'precip': 2,
#            'precip_gpm': 2,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 75,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 70,
#            't_dhi': 583,
#            't_dni': 5061,
#            't_ghi': 2113,
#            't_solar_rad': 1687,
#            'temp': 7.8,
#            'ts': 1734044400,
#            'wind_dir': 85,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.8},
#           {'clouds': 19,
#            'datetime': '2024-12-14',
#            'dewpt': 4,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 384,
#            'max_temp': 12.9,
#            'max_temp_ts': 1734184800,
#            'max_uv': 2.1,
#            'max_wind_dir': 133,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1734213600,
#            'min_temp': 4.6,
#            'min_temp_ts': 1734152400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1017,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 77,
#            'slp': 1030,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 88,
#            't_dhi': 581,
#            't_dni': 5053,
#            't_ghi': 2106,
#            't_solar_rad': 2106,
#            'temp': 8,
#            'ts': 1734130800,
#            'wind_dir': 133,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.7},
#           {'clouds': 30,
#            'datetime': '2024-12-15',
#            'dewpt': 3.4,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 383,
#            'max_temp': 12.3,
#            'max_temp_ts': 1734271200,
#            'max_uv': 2.1,
#            'max_wind_dir': 102,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1734217200,
#            'min_temp': 3.7,
#            'min_temp_ts': 1734238800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1021,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 77,
#            'slp': 1035,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 85,
#            't_dhi': 580,
#            't_dni': 5046,
#            't_ghi': 2100,
#            't_solar_rad': 2036,
#            'temp': 7.2,
#            'ts': 1734217200,
#            'wind_dir': 102,
#            'wind_gust_spd': 7.6,
#            'wind_spd': 1.1},
#           {'clouds': 75,
#            'datetime': '2024-12-16',
#            'dewpt': 4.9,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 14,
#            'max_temp_ts': 1734354000,
#            'max_uv': 1.6,
#            'max_wind_dir': 135,
#            'max_wind_spd': 2.2,
#            'max_wind_spd_ts': 1734343200,
#            'min_temp': 4.9,
#            'min_temp_ts': 1734332400,
#            'precip': 3,
#            'precip_gpm': 3,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1032,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 66,
#            't_dhi': 579,
#            't_dni': 5041,
#            't_ghi': 2095,
#            't_solar_rad': 1579,
#            'temp': 9,
#            'ts': 1734303600,
#            'wind_dir': 135,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.3},
#           {'clouds': 81,
#            'datetime': '2024-12-17',
#            'dewpt': 6.9,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 19.1,
#            'max_temp_ts': 1734440400,
#            'max_uv': 1.7,
#            'max_wind_dir': 169,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1734462000,
#            'min_temp': 9.5,
#            'min_temp_ts': 1734390000,
#            'precip': 11.5,
#            'precip_gpm': 11.5,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 68,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 68,
#            't_dhi': 578,
#            't_dni': 5038,
#            't_ghi': 2091,
#            't_solar_rad': 1631,
#            'temp': 13.1,
#            'ts': 1734390000,
#            'wind_dir': 169,
#            'wind_gust_spd': 17.6,
#            'wind_spd': 1.8},
#           {'clouds': 94,
#            'datetime': '2024-12-18',
#            'dewpt': 14.2,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 16.2,
#            'max_temp_ts': 1734544800,
#            'max_uv': 0.6,
#            'max_wind_dir': 170,
#            'max_wind_spd': 4.8,
#            'max_wind_spd_ts': 1734534000,
#            'min_temp': 14.4,
#            'min_temp_ts': 1734476400,
#            'precip': 39.8,
#            'precip_gpm': 39.8,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 9,
#            't_dhi': 579,
#            't_dni': 5035,
#            't_ghi': 2088,
#            't_solar_rad': 209,
#            'temp': 15.2,
#            'ts': 1734476400,
#            'wind_dir': 170,
#            'wind_gust_spd': 20.8,
#            'wind_spd': 4},
#           {'clouds': 46,
#            'datetime': '2024-12-19',
#            'dewpt': 9.5,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 15.2,
#            'max_temp_ts': 1734562800,
#            'max_uv': 1.5,
#            'max_wind_dir': 211,
#            'max_wind_spd': 3.4,
#            'max_wind_spd_ts': 1734591600,
#            'min_temp': 6.4,
#            'min_temp_ts': 1734645600,
#            'precip': 2.3,
#            'precip_gpm': 2.3,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 81,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2085,
#            't_solar_rad': 1951,
#            'temp': 12.1,
#            'ts': 1734562800,
#            'wind_dir': 211,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 2.4},
#           {'clouds': 29,
#            'datetime': '2024-12-20',
#            'dewpt': 4.8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 12.3,
#            'max_temp_ts': 1734703200,
#            'max_uv': 1.7,
#            'max_wind_dir': 138,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1734703200,
#            'min_temp': 3.4,
#            'min_temp_ts': 1734674400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1020,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 82,
#            'slp': 1033,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 80,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2084,
#            't_solar_rad': 1917,
#            'temp': 7.9,
#            'ts': 1734649200,
#            'wind_dir': 138,
#            'wind_gust_spd': 7.2,
#            'wind_spd': 1.7},
#           {'clouds': 81,
#            'datetime': '2024-12-21',
#            'dewpt': 8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 13.8,
#            'max_temp_ts': 1734789600,
#            'max_uv': 0.6,
#            'max_wind_dir': 125,
#            'max_wind_spd': 2.3,
#            'max_wind_spd_ts': 1734764400,
#            'min_temp': 6.4,
#            'min_temp_ts': 1734753600,
#            'precip': 1.3,
#            'precip_gpm': 1.3,
#            'pres': 1021,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1034,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 20,
#            't_dhi': 580,
#            't_dni': 5035,
#            't_ghi': 2084,
#            't_solar_rad': 468,
#            'temp': 9.8,
#            'ts': 1734735600,
#            'wind_dir': 125,
#            'wind_gust_spd': 4,
#            'wind_spd': 1.1},
#           {'clouds': 88,
#            'datetime': '2024-12-22',
#            'dewpt': 10.7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 14.4,
#            'max_temp_ts': 1734872400,
#            'max_uv': 0.7,
#            'max_wind_dir': 217,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1734890400,
#            'min_temp': 10.4,
#            'min_temp_ts': 1734854400,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1020,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1034,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 27,
#            't_dhi': 581,
#            't_dni': 5038,
#            't_ghi': 2085,
#            't_solar_rad': 652,
#            'temp': 11.7,
#            'ts': 1734822000,
#            'wind_dir': 217,
#            'wind_gust_spd': 9.6,
#            'wind_spd': 1.3},
#           {'clouds': 33,
#            'datetime': '2024-12-23',
#            'dewpt': 6.7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 13.3,
#            'max_temp_ts': 1734976800,
#            'max_uv': 1.7,
#            'max_wind_dir': 105,
#            'max_wind_spd': 6,
#            'max_wind_spd_ts': 1734987600,
#            'min_temp': 7.9,
#            'min_temp_ts': 1734940800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 78,
#            'slp': 1033,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 71,
#            't_dhi': 582,
#            't_dni': 5043,
#            't_ghi': 2087,
#            't_solar_rad': 1710,
#            'temp': 10.4,
#            'ts': 1734908400,
#            'wind_dir': 105,
#            'wind_gust_spd': 14,
#            'wind_spd': 2.6},
#           {'clouds': 0,
#            'datetime': '2024-12-24',
#            'dewpt': 7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 15.6,
#            'max_temp_ts': 1735063200,
#            'max_uv': 2.1,
#            'max_wind_dir': 59,
#            'max_wind_spd': 4.8,
#            'max_wind_spd_ts': 1735059600,
#            'min_temp': 7.4,
#            'min_temp_ts': 1735066800,
#            'precip': 5.5,
#            'precip_gpm': 5.5,
#            'pres': 1029,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1030,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 583,
#            't_dni': 5050,
#            't_ghi': 2091,
#            't_solar_rad': 2091,
#            'temp': 10.6,
#            'ts': 1734994800,
#            'wind_dir': 59,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 3.7},
#           {'clouds': 0,
#            'datetime': '2024-12-25',
#            'dewpt': 8.6,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 748,
#            'max_ghi': 384,
#            'max_temp': 15.9,
#            'max_temp_ts': 1735081200,
#            'max_uv': 2.1,
#            'max_wind_dir': 122,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1735081200,
#            'min_temp': 7.4,
#            'min_temp_ts': 1735081200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1026,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 584,
#            't_dni': 5058,
#            't_ghi': 2095,
#            't_solar_rad': 2095,
#            'temp': 10.8,
#            'ts': 1735081200,
#            'wind_dir': 122,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.8},
#           {'clouds': 20,
#            'datetime': '2024-12-26',
#            'dewpt': 7.7,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 385,
#            'max_temp': 14.8,
#            'max_temp_ts': 1735189200,
#            'max_uv': 2.1,
#            'max_wind_dir': 129,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1735189200,
#            'min_temp': 5.9,
#            'min_temp_ts': 1735189200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1026,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 586,
#            't_dni': 5068,
#            't_ghi': 2100,
#            't_solar_rad': 2100,
#            'temp': 9.6,
#            'ts': 1735167600,
#            'wind_dir': 129,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.5},
#           {'clouds': 46,
#            'datetime': '2024-12-27',
#            'dewpt': 7.6,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 386,
#            'max_temp': 12.5,
#            'max_temp_ts': 1735279200,
#            'max_uv': 1.8,
#            'max_wind_dir': 139,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1735261200,
#            'min_temp': 5.9,
#            'min_temp_ts': 1735282800,
#            'precip': 4,
#            'precip_gpm': 4,
#            'pres': 1017,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 84,
#            't_dhi': 588,
#            't_dni': 5080,
#            't_ghi': 2106,
#            't_solar_rad': 2009,
#            'temp': 8.7,
#            'ts': 1735254000,
#            'wind_dir': 139,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.6},
#           {'clouds': 75,
#            'datetime': '2024-12-28',
#            'dewpt': 7.5,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 387,
#            'max_temp': 12.1,
#            'max_temp_ts': 1735398000,
#            'max_uv': 1.4,
#            'max_wind_dir': 148,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1735340400,
#            'min_temp': 6.2,
#            'min_temp_ts': 1735351200,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1029,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 75,
#            't_dhi': 589,
#            't_dni': 5094,
#            't_ghi': 2113,
#            't_solar_rad': 1791,
#            'temp': 8.8,
#            'ts': 1735340400,
#            'wind_dir': 148,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.1},
#           {'clouds': 49,
#            'datetime': '2024-12-29',
#            'dewpt': 5.9,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 388,
#            'max_temp': 12.7,
#            'max_temp_ts': 1735477200,
#            'max_uv': 1.5,
#            'max_wind_dir': 134,
#            'max_wind_spd': 2.3,
#            'max_wind_spd_ts': 1735484400,
#            'min_temp': 6.2,
#            'min_temp_ts': 1735509600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 78,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 79,
#            't_dhi': 591,
#            't_dni': 5109,
#            't_ghi': 2122,
#            't_solar_rad': 1896,
#            'temp': 9.6,
#            'ts': 1735426800,
#            'wind_dir': 134,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.5},
#           {'clouds': 31,
#            'datetime': '2024-12-30',
#            'dewpt': 5,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 390,
#            'max_temp': 11.7,
#            'max_temp_ts': 1735567200,
#            'max_uv': 1.9,
#            'max_wind_dir': 122,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1735596000,
#            'min_temp': 4,
#            'min_temp_ts': 1735542000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1029,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 85,
#            't_dhi': 593,
#            't_dni': 5125,
#            't_ghi': 2131,
#            't_solar_rad': 2039,
#            'temp': 7.1,
#            'ts': 1735513200,
#            'wind_dir': 122,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 1.7},
#           {'clouds': 14,
#            'datetime': '2024-12-31',
#            'dewpt': 4,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 391,
#            'max_temp': 11.6,
#            'max_temp_ts': 1735657200,
#            'max_uv': 2.1,
#            'max_wind_dir': 119,
#            'max_wind_spd': 2.7,
#            'max_wind_spd_ts': 1735678800,
#            'min_temp': 3.1,
#            'min_temp_ts': 1735632000,
#            'precip': 0,
# ...
#            't_dhi': 779,
#            't_dni': 6607,
#            't_ghi': 3396,
#            't_solar_rad': 664,
#            'temp': 14.2,
#            'ts': 1761778800,
#            'wind_dir': 163,
#            'wind_gust_spd': 16.5,
#            'wind_spd': 4.5},
#           {'clouds': 85,
#            'datetime': '2025-10-31',
#            'dewpt': 15,
#            'dhi': 32,
#            'dni': 273,
#            'ghi': 140,
#            'max_dhi': 100,
#            'max_dni': 819,
#            'max_ghi': 540,
#            'max_temp': 17.5,
#            'max_temp_ts': 1761922800,
#            'max_uv': 1.3,
#            'max_wind_dir': 188,
#            'max_wind_spd': 5.6,
#            'max_wind_spd_ts': 1761876000,
#            'min_temp': 15.4,
#            'min_temp_ts': 1761865200,
#            'precip': 37.3,
#            'precip_gpm': 37.3,
#            'pres': 996,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1007,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 34,
#            't_dhi': 773,
#            't_dni': 6564,
#            't_ghi': 3350,
#            't_solar_rad': 813,
#            'temp': 16.5,
#            'ts': 1761865200,
#            'wind_dir': 188,
#            'wind_gust_spd': 13.4,
#            'wind_spd': 4.8},
#           {'clouds': 77,
#            'datetime': '2025-11-01',
#            'dewpt': 12.1,
#            'dhi': 32,
#            'dni': 272,
#            'ghi': 138,
#            'max_dhi': 99,
#            'max_dni': 817,
#            'max_ghi': 535,
#            'max_temp': 16.2,
#            'max_temp_ts': 1761951600,
#            'max_uv': 1.1,
#            'max_wind_dir': 207,
#            'max_wind_spd': 4.1,
#            'max_wind_spd_ts': 1761951600,
#            'min_temp': 11.7,
#            'min_temp_ts': 1762030800,
#            'precip': 12.8,
#            'precip_gpm': 12.8,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 35,
#            't_dhi': 768,
#            't_dni': 6520,
#            't_ghi': 3304,
#            't_solar_rad': 839,
#            'temp': 14.1,
#            'ts': 1761951600,
#            'wind_dir': 207,
#            'wind_gust_spd': 12.7,
#            'wind_spd': 1.8},
#           {'clouds': 53,
#            'datetime': '2025-11-02',
#            'dewpt': 11.2,
#            'dhi': 32,
#            'dni': 270,
#            'ghi': 136,
#            'max_dhi': 99,
#            'max_dni': 815,
#            'max_ghi': 530,
#            'max_temp': 15.5,
#            'max_temp_ts': 1762084800,
#            'max_uv': 1.3,
#            'max_wind_dir': 161,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1762088400,
#            'min_temp': 10.3,
#            'min_temp_ts': 1762120800,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 46,
#            't_dhi': 762,
#            't_dni': 6476,
#            't_ghi': 3259,
#            't_solar_rad': 1095,
#            'temp': 12.7,
#            'ts': 1762038000,
#            'wind_dir': 161,
#            'wind_gust_spd': 6.2,
#            'wind_spd': 1.4},
#           {'clouds': 39,
#            'datetime': '2025-11-03',
#            'dewpt': 9.8,
#            'dhi': 32,
#            'dni': 268,
#            'ghi': 134,
#            'max_dhi': 99,
#            'max_dni': 813,
#            'max_ghi': 524,
#            'max_temp': 17.3,
#            'max_temp_ts': 1762178400,
#            'max_uv': 1.9,
#            'max_wind_dir': 142,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1762174800,
#            'min_temp': 8,
#            'min_temp_ts': 1762138800,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 93,
#            't_dhi': 757,
#            't_dni': 6432,
#            't_ghi': 3214,
#            't_solar_rad': 2225,
#            'temp': 12.5,
#            'ts': 1762124400,
#            'wind_dir': 142,
#            'wind_gust_spd': 6.3,
#            'wind_spd': 1.5},
#           {'clouds': 59,
#            'datetime': '2025-11-04',
#            'dewpt': 10.8,
#            'dhi': 31,
#            'dni': 266,
#            'ghi': 132,
#            'max_dhi': 98,
#            'max_dni': 811,
#            'max_ghi': 519,
#            'max_temp': 19.2,
#            'max_temp_ts': 1762264800,
#            'max_uv': 1.1,
#            'max_wind_dir': 162,
#            'max_wind_spd': 7.2,
#            'max_wind_spd_ts': 1762293600,
#            'min_temp': 13.5,
#            'min_temp_ts': 1762210800,
#            'precip': 15.3,
#            'precip_gpm': 15.3,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 68,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 33,
#            't_dhi': 751,
#            't_dni': 6387,
#            't_ghi': 3170,
#            't_solar_rad': 793,
#            'temp': 16.7,
#            'ts': 1762210800,
#            'wind_dir': 162,
#            'wind_gust_spd': 17.5,
#            'wind_spd': 4.8},
#           {'clouds': 81,
#            'datetime': '2025-11-05',
#            'dewpt': 12.8,
#            'dhi': 31,
#            'dni': 264,
#            'ghi': 130,
#            'max_dhi': 98,
#            'max_dni': 809,
#            'max_ghi': 514,
#            'max_temp': 18.6,
#            'max_temp_ts': 1762297200,
#            'max_uv': 1.3,
#            'max_wind_dir': 184,
#            'max_wind_spd': 7.1,
#            'max_wind_spd_ts': 1762315200,
#            'min_temp': 12.3,
#            'min_temp_ts': 1762380000,
#            'precip': 76.6,
#            'precip_gpm': 76.6,
#            'pres': 993,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1004,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 45,
#            't_dhi': 746,
#            't_dni': 6342,
#            't_ghi': 3127,
#            't_solar_rad': 1070,
#            'temp': 15.1,
#            'ts': 1762297200,
#            'wind_dir': 184,
#            'wind_gust_spd': 16.6,
#            'wind_spd': 5},
#           {'clouds': 37,
#            'datetime': '2025-11-06',
#            'dewpt': 11,
#            'dhi': 31,
#            'dni': 262,
#            'ghi': 128,
#            'max_dhi': 97,
#            'max_dni': 807,
#            'max_ghi': 509,
#            'max_temp': 14.9,
#            'max_temp_ts': 1762434000,
#            'max_uv': 2.2,
#            'max_wind_dir': 216,
#            'max_wind_spd': 4.6,
#            'max_wind_spd_ts': 1762401600,
#            'min_temp': 12.3,
#            'min_temp_ts': 1762383600,
#            'precip': 24.3,
#            'precip_gpm': 24.3,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 99,
#            't_dhi': 740,
#            't_dni': 6297,
#            't_ghi': 3084,
#            't_solar_rad': 2380,
#            'temp': 13.2,
#            'ts': 1762383600,
#            'wind_dir': 216,
#            'wind_gust_spd': 12.1,
#            'wind_spd': 2.8},
#           {'clouds': 43,
#            'datetime': '2025-11-07',
#            'dewpt': 12.8,
#            'dhi': 31,
#            'dni': 260,
#            'ghi': 127,
#            'max_dhi': 97,
#            'max_dni': 805,
#            'max_ghi': 504,
#            'max_temp': 16.6,
#            'max_temp_ts': 1762516800,
#            'max_uv': 2.1,
#            'max_wind_dir': 210,
#            'max_wind_spd': 3.7,
#            'max_wind_spd_ts': 1762480800,
#            'min_temp': 10.5,
#            'min_temp_ts': 1762549200,
#            'precip': 35.3,
#            'precip_gpm': 35.3,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 95,
#            't_dhi': 735,
#            't_dni': 6252,
#            't_ghi': 3042,
#            't_solar_rad': 2287,
#            'temp': 14.1,
#            'ts': 1762470000,
#            'wind_dir': 210,
#            'wind_gust_spd': 9.7,
#            'wind_spd': 2.1},
#           {'clouds': 20,
#            'datetime': '2025-11-08',
#            'dewpt': 9.6,
#            'dhi': 30,
#            'dni': 259,
#            'ghi': 125,
#            'max_dhi': 97,
#            'max_dni': 803,
#            'max_ghi': 499,
#            'max_temp': 15.1,
#            'max_temp_ts': 1762610400,
#            'max_uv': 2.4,
#            'max_wind_dir': 153,
#            'max_wind_spd': 1.1,
#            'max_wind_spd_ts': 1762632000,
#            'min_temp': 6.7,
#            'min_temp_ts': 1762639200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 117,
#            't_dhi': 729,
#            't_dni': 6206,
#            't_ghi': 3001,
#            't_solar_rad': 2818,
#            'temp': 11.3,
#            'ts': 1762556400,
#            'wind_dir': 153,
#            'wind_gust_spd': 2.7,
#            'wind_spd': 0.9},
#           {'clouds': 52,
#            'datetime': '2025-11-09',
#            'dewpt': 8.6,
#            'dhi': 30,
#            'dni': 257,
#            'ghi': 123,
#            'max_dhi': 96,
#            'max_dni': 801,
#            'max_ghi': 495,
#            'max_temp': 14.6,
#            'max_temp_ts': 1762686000,
#            'max_uv': 1.1,
#            'max_wind_dir': 140,
#            'max_wind_spd': 3.3,
#            'max_wind_spd_ts': 1762689600,
#            'min_temp': 6.4,
#            'min_temp_ts': 1762650000,
#            'precip': 2.5,
#            'precip_gpm': 2.5,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 43,
#            't_dhi': 724,
#            't_dni': 6161,
#            't_ghi': 2960,
#            't_solar_rad': 1036,
#            'temp': 11,
#            'ts': 1762642800,
#            'wind_dir': 140,
#            'wind_gust_spd': 7.9,
#            'wind_spd': 2.1},
#           {'clouds': 61,
#            'datetime': '2025-11-10',
#            'dewpt': 12.6,
#            'dhi': 30,
#            'dni': 255,
#            'ghi': 122,
#            'max_dhi': 96,
#            'max_dni': 799,
#            'max_ghi': 490,
#            'max_temp': 15.6,
#            'max_temp_ts': 1762783200,
#            'max_uv': 1,
#            'max_wind_dir': 178,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1762776000,
#            'min_temp': 12.8,
#            'min_temp_ts': 1762740000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1005,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 92,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 16,
#            't_dhi': 718,
#            't_dni': 6116,
#            't_ghi': 2920,
#            't_solar_rad': 378,
#            'temp': 13.9,
#            'ts': 1762729200,
#            'wind_dir': 178,
#            'wind_gust_spd': 7.2,
#            'wind_spd': 2},
#           {'clouds': 57,
#            'datetime': '2025-11-11',
#            'dewpt': 12.7,
#            'dhi': 30,
#            'dni': 253,
#            'ghi': 120,
#            'max_dhi': 96,
#            'max_dni': 797,
#            'max_ghi': 485,
#            'max_temp': 16.9,
#            'max_temp_ts': 1762866000,
#            'max_uv': 2.5,
#            'max_wind_dir': 170,
#            'max_wind_spd': 7.3,
#            'max_wind_spd_ts': 1762858800,
#            'min_temp': 13.5,
#            'min_temp_ts': 1762815600,
#            'precip': 36.5,
#            'precip_gpm': 36.5,
#            'pres': 997,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 83,
#            'slp': 1008,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 115,
#            't_dhi': 713,
#            't_dni': 6070,
#            't_ghi': 2881,
#            't_solar_rad': 2752,
#            'temp': 15.6,
#            'ts': 1762815600,
#            'wind_dir': 170,
#            'wind_gust_spd': 17.5,
#            'wind_spd': 5.5},
#           {'clouds': 74,
#            'datetime': '2025-11-12',
#            'dewpt': 12,
#            'dhi': 29,
#            'dni': 251,
#            'ghi': 118,
#            'max_dhi': 95,
#            'max_dni': 795,
#            'max_ghi': 480,
#            'max_temp': 16.6,
#            'max_temp_ts': 1762909200,
#            'max_uv': 1.1,
#            'max_wind_dir': 166,
#            'max_wind_spd': 7.1,
#            'max_wind_spd_ts': 1762927200,
#            'min_temp': 13.3,
#            'min_temp_ts': 1762977600,
#            'precip': 66.7,
#            'precip_gpm': 66.7,
#            'pres': 991,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 83,
#            'slp': 1002,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 27,
#            't_dhi': 707,
#            't_dni': 6025,
#            't_ghi': 2843,
#            't_solar_rad': 643,
#            'temp': 15,
#            'ts': 1762902000,
#            'wind_dir': 166,
#            'wind_gust_spd': 16.9,
#            'wind_spd': 4.9},
#           {'clouds': 95,
#            'datetime': '2025-11-13',
#            'dewpt': 13.4,
#            'dhi': 29,
#            'dni': 249,
#            'ghi': 117,
#            'max_dhi': 95,
#            'max_dni': 793,
#            'max_ghi': 476,
#            'max_temp': 16.4,
#            'max_temp_ts': 1763024400,
#            'max_uv': 1,
#            'max_wind_dir': 144,
#            'max_wind_spd': 3.9,
#            'max_wind_spd_ts': 1763024400,
#            'min_temp': 13.3,
#            'min_temp_ts': 1762988400,
#            'precip': 70.5,
#            'precip_gpm': 70.5,
#            'pres': 988,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 90,
#            'slp': 998,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 21,
#            't_dhi': 702,
#            't_dni': 5981,
#            't_ghi': 2805,
#            't_solar_rad': 493,
#            'temp': 15,
#            'ts': 1762988400,
#            'wind_dir': 144,
#            'wind_gust_spd': 13.4,
#            'wind_spd': 2.2},
#           {'clouds': 84,
#            'datetime': '2025-11-14',
#            'dewpt': 11.4,
#            'dhi': 29,
#            'dni': 247,
#            'ghi': 115,
#            'max_dhi': 95,
#            'max_dni': 791,
#            'max_ghi': 471,
#            'max_temp': 14.7,
#            'max_temp_ts': 1763074800,
#            'max_uv': 1.2,
#            'max_wind_dir': 170,
#            'max_wind_spd': 5.5,
#            'max_wind_spd_ts': 1763118000,
#            'min_temp': 11.9,
#            'min_temp_ts': 1763157600,
#            'precip': 46.8,
#            'precip_gpm': 46.8,
#            'pres': 988,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 998,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 32,
#            't_dhi': 697,
#            't_dni': 5936,
#            't_ghi': 2768,
#            't_solar_rad': 760,
#            'temp': 13.4,
#            'ts': 1763074800,
#            'wind_dir': 170,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 3.8}],
#  'lat': 42.431,
#  'lon': -8.64435,
#  'sources': ['080440-99999', 'imerg', 'era5', 'sat', 'radar', 'snodas'],
#  'state_code': '58',
#  'station_id': '080440-99999',
#  'timezone': 'Europe/Madrid'}

# %%
ciudad = data["city_name"]
ciudad
# Out:
# 'Pontevedra'

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

pontevedra =  pd.DataFrame(datos)

pontevedra.head()

pontevedra.to_csv("pontevedra_2024-11-15_2025-11-15.csv")

# %%
# Datos Pontevedra 2023/2024
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=42.431&lon=-8.64435&start_date=2023-11-15&end_date=2024-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
data.update(response.json())

# %%
pprint(data)
# Out:
# {'city_id': '3113209',
#  'city_name': 'Pontevedra',
#  'country_code': 'ES',
#  'data': [{'clouds': 87,
#            'datetime': '2023-11-15',
#            'dewpt': 15.4,
#            'dhi': 29,
#            'dni': 246,
#            'ghi': 114,
#            'max_dhi': 94,
#            'max_dni': 789,
#            'max_ghi': 467,
#            'max_temp': 18.1,
#            'max_temp_ts': 1700053200,
#            'max_uv': 1,
#            'max_wind_dir': 150,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1700085600,
#            'min_temp': 13.1,
#            'min_temp_ts': 1700031600,
#            'precip': 7,
#            'precip_gpm': 7,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 26,
#            't_dhi': 691,
#            't_dni': 5892,
#            't_ghi': 2733,
#            't_solar_rad': 627,
#            'temp': 15.7,
#            'ts': 1700002800,
#            'wind_dir': 150,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 1.3},
#           {'clouds': 68,
#            'datetime': '2023-11-16',
#            'dewpt': 15.3,
#            'dhi': 29,
#            'dni': 244,
#            'ghi': 112,
#            'max_dhi': 94,
#            'max_dni': 787,
#            'max_ghi': 463,
#            'max_temp': 18.2,
#            'max_temp_ts': 1700132400,
#            'max_uv': 2.1,
#            'max_wind_dir': 193,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1700089200,
#            'min_temp': 12.2,
#            'min_temp_ts': 1700172000,
#            'precip': 3.5,
#            'precip_gpm': 3.5,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 97,
#            't_dhi': 686,
#            't_dni': 5848,
#            't_ghi': 2698,
#            't_solar_rad': 2331,
#            'temp': 16,
#            'ts': 1700089200,
#            'wind_dir': 193,
#            'wind_gust_spd': 12.4,
#            'wind_spd': 1.5},
#           {'clouds': 78,
#            'datetime': '2023-11-17',
#            'dewpt': 12.2,
#            'dhi': 28,
#            'dni': 242,
#            'ghi': 111,
#            'max_dhi': 94,
#            'max_dni': 785,
#            'max_ghi': 459,
#            'max_temp': 18.5,
#            'max_temp_ts': 1700222400,
#            'max_uv': 1.3,
#            'max_wind_dir': 158,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1700204400,
#            'min_temp': 9.8,
#            'min_temp_ts': 1700204400,
#            'precip': 1.3,
#            'precip_gpm': 1.3,
#            'pres': 1012,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 46,
#            't_dhi': 681,
#            't_dni': 5806,
#            't_ghi': 2663,
#            't_solar_rad': 1094,
#            'temp': 13.6,
#            'ts': 1700175600,
#            'wind_dir': 158,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.2},
#           {'clouds': 75,
#            'datetime': '2023-11-18',
#            'dewpt': 14,
#            'dhi': 28,
#            'dni': 240,
#            'ghi': 110,
#            'max_dhi': 93,
#            'max_dni': 783,
#            'max_ghi': 454,
#            'max_temp': 20.7,
#            'max_temp_ts': 1700312400,
#            'max_uv': 1.7,
#            'max_wind_dir': 153,
#            'max_wind_spd': 1.9,
#            'max_wind_spd_ts': 1700319600,
#            'min_temp': 13.1,
#            'min_temp_ts': 1700276400,
#            'precip': 1,
#            'precip_gpm': 1,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 80,
#            't_dhi': 676,
#            't_dni': 5763,
#            't_ghi': 2630,
#            't_solar_rad': 1926,
#            'temp': 15.5,
#            'ts': 1700262000,
#            'wind_dir': 153,
#            'wind_gust_spd': 9.6,
#            'wind_spd': 1},
#           {'clouds': 58,
#            'datetime': '2023-11-19',
#            'dewpt': 13.8,
#            'dhi': 28,
#            'dni': 238,
#            'ghi': 108,
#            'max_dhi': 93,
#            'max_dni': 781,
#            'max_ghi': 450,
#            'max_temp': 19.7,
#            'max_temp_ts': 1700395200,
#            'max_uv': 2.2,
#            'max_wind_dir': 168,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1700402400,
#            'min_temp': 12.1,
#            'min_temp_ts': 1700355600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 96,
#            't_dhi': 671,
#            't_dni': 5722,
#            't_ghi': 2598,
#            't_solar_rad': 2299,
#            'temp': 15,
#            'ts': 1700348400,
#            'wind_dir': 168,
#            'wind_gust_spd': 5.6,
#            'wind_spd': 1},
#           {'clouds': 61,
#            'datetime': '2023-11-20',
#            'dewpt': 10.6,
#            'dhi': 28,
#            'dni': 237,
#            'ghi': 107,
#            'max_dhi': 93,
#            'max_dni': 779,
#            'max_ghi': 446,
#            'max_temp': 16.5,
#            'max_temp_ts': 1700485200,
#            'max_uv': 1.3,
#            'max_wind_dir': 172,
#            'max_wind_spd': 3.9,
#            'max_wind_spd_ts': 1700499600,
#            'min_temp': 8.7,
#            'min_temp_ts': 1700517600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 47,
#            't_dhi': 666,
#            't_dni': 5682,
#            't_ghi': 2566,
#            't_solar_rad': 1126,
#            'temp': 12.7,
#            'ts': 1700434800,
#            'wind_dir': 172,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 1.8},
#           {'clouds': 28,
#            'datetime': '2023-11-21',
#            'dewpt': 7,
#            'dhi': 28,
#            'dni': 235,
#            'ghi': 106,
#            'max_dhi': 92,
#            'max_dni': 777,
#            'max_ghi': 442,
#            'max_temp': 13.9,
#            'max_temp_ts': 1700575200,
#            'max_uv': 1.8,
#            'max_wind_dir': 230,
#            'max_wind_spd': 5.1,
#            'max_wind_spd_ts': 1700568000,
#            'min_temp': 7.6,
#            'min_temp_ts': 1700535600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 91,
#            't_dhi': 661,
#            't_dni': 5642,
#            't_ghi': 2536,
#            't_solar_rad': 2173,
#            'temp': 10.5,
#            'ts': 1700521200,
#            'wind_dir': 230,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 2.1},
#           {'clouds': 36,
#            'datetime': '2023-11-22',
#            'dewpt': 7,
#            'dhi': 27,
#            'dni': 233,
#            'ghi': 104,
#            'max_dhi': 92,
#            'max_dni': 775,
#            'max_ghi': 439,
#            'max_temp': 15.6,
#            'max_temp_ts': 1700658000,
#            'max_uv': 2.3,
#            'max_wind_dir': 107,
#            'max_wind_spd': 4.1,
#            'max_wind_spd_ts': 1700679600,
#            'min_temp': 5.9,
#            'min_temp_ts': 1700625600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 102,
#            't_dhi': 656,
#            't_dni': 5604,
#            't_ghi': 2506,
#            't_solar_rad': 2451,
#            'temp': 10.8,
#            'ts': 1700607600,
#            'wind_dir': 107,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 1.7},
#           {'clouds': 5,
#            'datetime': '2023-11-23',
#            'dewpt': 6.4,
#            'dhi': 27,
#            'dni': 232,
#            'ghi': 103,
#            'max_dhi': 92,
#            'max_dni': 774,
#            'max_ghi': 435,
#            'max_temp': 18.2,
#            'max_temp_ts': 1700744400,
#            'max_uv': 2.7,
#            'max_wind_dir': 143,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1700722800,
#            'min_temp': 7.7,
#            'min_temp_ts': 1700715600,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1012,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 69,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 103,
#            't_dhi': 651,
#            't_dni': 5566,
#            't_ghi': 2478,
#            't_solar_rad': 2477,
#            'temp': 12.1,
#            'ts': 1700694000,
#            'wind_dir': 143,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 1.6},
#           {'clouds': 13,
#            'datetime': '2023-11-24',
#            'dewpt': 6.7,
#            'dhi': 27,
#            'dni': 230,
#            'ghi': 102,
#            'max_dhi': 91,
#            'max_dni': 772,
#            'max_ghi': 431,
#            'max_temp': 16.8,
#            'max_temp_ts': 1700830800,
#            'max_uv': 2.9,
#            'max_wind_dir': 108,
#            'max_wind_spd': 3,
#            'max_wind_spd_ts': 1700856000,
#            'min_temp': 6.8,
#            'min_temp_ts': 1700809200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 99,
#            't_dhi': 646,
#            't_dni': 5530,
#            't_ghi': 2450,
#            't_solar_rad': 2376,
#            'temp': 10.8,
#            'ts': 1700780400,
#            'wind_dir': 108,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.9},
#           {'clouds': 59,
#            'datetime': '2023-11-25',
#            'dewpt': 7.1,
#            'dhi': 27,
#            'dni': 229,
#            'ghi': 101,
#            'max_dhi': 91,
#            'max_dni': 770,
#            'max_ghi': 428,
#            'max_temp': 14.9,
#            'max_temp_ts': 1700917200,
#            'max_uv': 2.8,
#            'max_wind_dir': 131,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1700877600,
#            'min_temp': 5,
#            'min_temp_ts': 1700895600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 94,
#            't_dhi': 642,
#            't_dni': 5495,
#            't_ghi': 2423,
#            't_solar_rad': 2245,
#            'temp': 9.4,
#            'ts': 1700866800,
#            'wind_dir': 131,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.8},
#           {'clouds': 99,
#            'datetime': '2023-11-26',
#            'dewpt': 9.3,
#            'dhi': 27,
#            'dni': 228,
#            'ghi': 100,
#            'max_dhi': 91,
#            'max_dni': 768,
#            'max_ghi': 425,
#            'max_temp': 14.1,
#            'max_temp_ts': 1701010800,
#            'max_uv': 0.9,
#            'max_wind_dir': 99,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1700964000,
#            'min_temp': 8,
#            'min_temp_ts': 1700964000,
#            'precip': 1.5,
#            'precip_gpm': 1.5,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 18,
#            't_dhi': 637,
#            't_dni': 5461,
#            't_ghi': 2397,
#            't_solar_rad': 437,
#            'temp': 10.4,
#            'ts': 1700953200,
#            'wind_dir': 99,
#            'wind_gust_spd': 4,
#            'wind_spd': 1.7},
#           {'clouds': 96,
#            'datetime': '2023-11-27',
#            'dewpt': 11.8,
#            'dhi': 26,
#            'dni': 226,
#            'ghi': 99,
#            'max_dhi': 91,
#            'max_dni': 767,
#            'max_ghi': 421,
#            'max_temp': 13.7,
#            'max_temp_ts': 1701097200,
#            'max_uv': 1,
#            'max_wind_dir': 198,
#            'max_wind_spd': 1.1,
#            'max_wind_spd_ts': 1701039600,
#            'min_temp': 10.8,
#            'min_temp_ts': 1701039600,
#            'precip': 4.8,
#            'precip_gpm': 4.8,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 97,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 26,
#            't_dhi': 633,
#            't_dni': 5428,
#            't_ghi': 2373,
#            't_solar_rad': 624,
#            'temp': 12.3,
#            'ts': 1701039600,
#            'wind_dir': 198,
#            'wind_gust_spd': 8.8,
#            'wind_spd': 0.7},
#           {'clouds': 97,
#            'datetime': '2023-11-28',
#            'dewpt': 13.5,
#            'dhi': 26,
#            'dni': 225,
#            'ghi': 98,
#            'max_dhi': 90,
#            'max_dni': 765,
#            'max_ghi': 418,
#            'max_temp': 14.6,
#            'max_temp_ts': 1701205200,
#            'max_uv': 0.9,
#            'max_wind_dir': 153,
#            'max_wind_spd': 2,
#            'max_wind_spd_ts': 1701201600,
#            'min_temp': 12.8,
#            'min_temp_ts': 1701158400,
#            'precip': 19,
#            'precip_gpm': 19,
#            'pres': 999,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 99,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 10,
#            't_dhi': 629,
#            't_dni': 5397,
#            't_ghi': 2349,
#            't_solar_rad': 235,
#            'temp': 13.7,
#            'ts': 1701126000,
#            'wind_dir': 153,
#            'wind_gust_spd': 10,
#            'wind_spd': 1},
#           {'clouds': 97,
#            'datetime': '2023-11-29',
#            'dewpt': 15.1,
#            'dhi': 26,
#            'dni': 224,
#            'ghi': 97,
#            'max_dhi': 90,
#            'max_dni': 764,
#            'max_ghi': 415,
#            'max_temp': 16.1,
#            'max_temp_ts': 1701255600,
#            'max_uv': 0.9,
#            'max_wind_dir': 195,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1701241200,
#            'min_temp': 13.5,
#            'min_temp_ts': 1701295200,
#            'precip': 16.3,
#            'precip_gpm': 16.3,
#            'pres': 990,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 100,
#            'slp': 1003,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 10,
#            't_dhi': 624,
#            't_dni': 5366,
#            't_ghi': 2326,
#            't_solar_rad': 240,
#            'temp': 15.1,
#            'ts': 1701212400,
#            'wind_dir': 195,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 1.8},
#           {'clouds': 90,
#            'datetime': '2023-11-30',
#            'dewpt': 9.4,
#            'dhi': 26,
#            'dni': 222,
#            'ghi': 96,
#            'max_dhi': 90,
#            'max_dni': 762,
#            'max_ghi': 412,
#            'max_temp': 13.4,
#            'max_temp_ts': 1701298800,
#            'max_uv': 0.9,
#            'max_wind_dir': 174,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1701324000,
#            'min_temp': 7.3,
#            'min_temp_ts': 1701381600,
#            'precip': 53.8,
#            'precip_gpm': 53.8,
#            'pres': 989,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1002,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 29,
#            't_dhi': 620,
#            't_dni': 5336,
#            't_ghi': 2304,
#            't_solar_rad': 705,
#            'temp': 10.1,
#            'ts': 1701298800,
#            'wind_dir': 174,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.1},
#           {'clouds': 54,
#            'datetime': '2023-12-01',
#            'dewpt': 7.5,
#            'dhi': 26,
#            'dni': 221,
#            'ghi': 95,
#            'max_dhi': 90,
#            'max_dni': 761,
#            'max_ghi': 409,
#            'max_temp': 12.4,
#            'max_temp_ts': 1701439200,
#            'max_uv': 1.1,
#            'max_wind_dir': 142,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1701442800,
#            'min_temp': 6.3,
#            'min_temp_ts': 1701417600,
#            'precip': 2.8,
#            'precip_gpm': 2.8,
#            'pres': 993,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1006,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 76,
#            't_dhi': 617,
#            't_dni': 5307,
#            't_ghi': 2283,
#            't_solar_rad': 1826,
#            'temp': 8.4,
#            'ts': 1701385200,
#            'wind_dir': 142,
#            'wind_gust_spd': 8.8,
#            'wind_spd': 1.2},
#           {'clouds': 48,
#            'datetime': '2023-12-02',
#            'dewpt': 6.3,
#            'dhi': 26,
#            'dni': 220,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 759,
#            'max_ghi': 407,
#            'max_temp': 12.5,
#            'max_temp_ts': 1701525600,
#            'max_uv': 1.7,
#            'max_wind_dir': 124,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1701547200,
#            'min_temp': 4.5,
#            'min_temp_ts': 1701500400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 84,
#            't_dhi': 613,
#            't_dni': 5279,
#            't_ghi': 2264,
#            't_solar_rad': 2017,
#            'temp': 7.9,
#            'ts': 1701471600,
#            'wind_dir': 124,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.4},
#           {'clouds': 87,
#            'datetime': '2023-12-03',
#            'dewpt': 8.1,
#            'dhi': 25,
#            'dni': 219,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 758,
#            'max_ghi': 404,
#            'max_temp': 12,
#            'max_temp_ts': 1701640800,
#            'max_uv': 0.7,
#            'max_wind_dir': 148,
#            'max_wind_spd': 6.2,
#            'max_wind_spd_ts': 1701626400,
#            'min_temp': 6.9,
#            'min_temp_ts': 1701561600,
#            'precip': 37,
#            'precip_gpm': 37,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 609,
#            't_dni': 5253,
#            't_ghi': 2245,
#            't_solar_rad': 532,
#            'temp': 9.7,
#            'ts': 1701558000,
#            'wind_dir': 148,
#            'wind_gust_spd': 20.8,
#            'wind_spd': 2.9},
#           {'clouds': 49,
#            'datetime': '2023-12-04',
#            'dewpt': 9.1,
#            'dhi': 25,
#            'dni': 218,
#            'ghi': 93,
#            'max_dhi': 89,
#            'max_dni': 756,
#            'max_ghi': 402,
#            'max_temp': 12.5,
#            'max_temp_ts': 1701694800,
#            'max_uv': 1.5,
#            'max_wind_dir': 200,
#            'max_wind_spd': 4.9,
#            'max_wind_spd_ts': 1701694800,
#            'min_temp': 6.8,
#            'min_temp_ts': 1701727200,
#            'precip': 2,
#            'precip_gpm': 2,
#            'pres': 1003,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 89,
#            't_dhi': 606,
#            't_dni': 5227,
#            't_ghi': 2227,
#            't_solar_rad': 2138,
#            'temp': 10.9,
#            'ts': 1701644400,
#            'wind_dir': 200,
#            'wind_gust_spd': 13.6,
#            'wind_spd': 2.6},
#           {'clouds': 77,
#            'datetime': '2023-12-05',
#            'dewpt': 5.1,
#            'dhi': 25,
#            'dni': 217,
#            'ghi': 92,
#            'max_dhi': 89,
#            'max_dni': 755,
#            'max_ghi': 399,
#            'max_temp': 11.7,
#            'max_temp_ts': 1701781200,
#            'max_uv': 0.7,
#            'max_wind_dir': 107,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1701734400,
#            'min_temp': 4.4,
#            'min_temp_ts': 1701813600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 20,
#            't_dhi': 603,
#            't_dni': 5202,
#            't_ghi': 2210,
#            't_solar_rad': 490,
#            'temp': 7.1,
#            'ts': 1701730800,
#            'wind_dir': 107,
#            'wind_gust_spd': 8,
#            'wind_spd': 1.6},
#           {'clouds': 95,
#            'datetime': '2023-12-06',
#            'dewpt': 3.3,
#            'dhi': 25,
#            'dni': 216,
#            'ghi': 91,
#            'max_dhi': 89,
#            'max_dni': 754,
#            'max_ghi': 397,
#            'max_temp': 10.5,
#            'max_temp_ts': 1701892800,
#            'max_uv': 0.7,
#            'max_wind_dir': 154,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1701831600,
#            'min_temp': 3.2,
#            'min_temp_ts': 1701835200,
#            'precip': 14.3,
#            'precip_gpm': 14.3,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 600,
#            't_dni': 5178,
#            't_ghi': 2194,
#            't_solar_rad': 528,
#            'temp': 6.5,
#            'ts': 1701817200,
#            'wind_dir': 154,
#            'wind_gust_spd': 15.2,
#            'wind_spd': 1.6},
#           {'clouds': 93,
#            'datetime': '2023-12-07',
#            'dewpt': 12.4,
#            'dhi': 25,
#            'dni': 215,
#            'ghi': 91,
#            'max_dhi': 88,
#            'max_dni': 753,
#            'max_ghi': 395,
#            'max_temp': 15.8,
#            'max_temp_ts': 1701954000,
#            'max_uv': 0.7,
#            'max_wind_dir': 208,
#            'max_wind_spd': 3.3,
#            'max_wind_spd_ts': 1701957600,
#            'min_temp': 8.5,
#            'min_temp_ts': 1701903600,
#            'precip': 47.3,
#            'precip_gpm': 47.3,
#            'pres': 1000,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 9,
#            't_dhi': 597,
#            't_dni': 5156,
#            't_ghi': 2180,
#            't_solar_rad': 227,
#            'temp': 12.7,
#            'ts': 1701903600,
#            'wind_dir': 208,
#            'wind_gust_spd': 18,
#            'wind_spd': 1.8},
#           {'clouds': 84,
#            'datetime': '2023-12-08',
#            'dewpt': 10.2,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 393,
#            'max_temp': 14.4,
#            'max_temp_ts': 1702044000,
#            'max_uv': 0.7,
#            'max_wind_dir': 163,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1702069200,
#            'min_temp': 8.7,
#            'min_temp_ts': 1702022400,
#            'precip': 8,
#            'precip_gpm': 8,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 30,
#            't_dhi': 595,
#            't_dni': 5136,
#            't_ghi': 2166,
#            't_solar_rad': 716,
#            'temp': 11.3,
#            'ts': 1701990000,
#            'wind_dir': 163,
#            'wind_gust_spd': 14.8,
#            'wind_spd': 1.8},
#           {'clouds': 100,
#            'datetime': '2023-12-09',
#            'dewpt': 15.4,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 391,
#            'max_temp': 16.9,
#            'max_temp_ts': 1702119600,
#            'max_uv': 0.7,
#            'max_wind_dir': 189,
#            'max_wind_spd': 4,
#            'max_wind_spd_ts': 1702090800,
#            'min_temp': 12.1,
#            'min_temp_ts': 1702076400,
#            'precip': 23.5,
#            'precip_gpm': 23.5,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 99,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 11,
#            't_dhi': 592,
#            't_dni': 5117,
#            't_ghi': 2153,
#            't_solar_rad': 272,
#            'temp': 15.6,
#            'ts': 1702076400,
#            'wind_dir': 189,
#            'wind_gust_spd': 16.4,
#            'wind_spd': 2.1},
#           {'clouds': 100,
#            'datetime': '2023-12-10',
#            'dewpt': 15.6,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 390,
#            'max_temp': 17.4,
#            'max_temp_ts': 1702213200,
#            'max_uv': 0.7,
#            'max_wind_dir': 171,
#            'max_wind_spd': 4.3,
#            'max_wind_spd_ts': 1702195200,
#            'min_temp': 15.5,
#            'min_temp_ts': 1702245600,
#            'precip': 4.8,
#            'precip_gpm': 4.8,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 10,
#            't_dhi': 590,
#            't_dni': 5100,
#            't_ghi': 2142,
#            't_solar_rad': 251,
#            'temp': 16.3,
#            'ts': 1702162800,
#            'wind_dir': 171,
#            'wind_gust_spd': 15.2,
#            'wind_spd': 2.8},
#           {'clouds': 100,
#            'datetime': '2023-12-11',
#            'dewpt': 14.6,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 388,
#            'max_temp': 17.2,
#            'max_temp_ts': 1702288800,
#            'max_uv': 0.7,
#            'max_wind_dir': 164,
#            'max_wind_spd': 4.3,
#            'max_wind_spd_ts': 1702296000,
#            'min_temp': 14.7,
#            'min_temp_ts': 1702321200,
#            'precip': 3.3,
#            'precip_gpm': 3.3,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 13,
#            't_dhi': 587,
#            't_dni': 5085,
#            't_ghi': 2131,
#            't_solar_rad': 318,
#            'temp': 15.9,
#            'ts': 1702249200,
#            'wind_dir': 164,
#            'wind_gust_spd': 15.6,
#            'wind_spd': 3.3},
#           {'clouds': 97,
#            'datetime': '2023-12-12',
#            'dewpt': 12.8,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 386,
#            'max_temp': 15.9,
#            'max_temp_ts': 1702342800,
#            'max_uv': 0.7,
#            'max_wind_dir': 201,
#            'max_wind_spd': 3.8,
#            'max_wind_spd_ts': 1702335600,
#            'min_temp': 10.5,
#            'min_temp_ts': 1702418400,
#            'precip': 38.5,
#            'precip_gpm': 38.5,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 97,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 15,
#            't_dhi': 585,
#            't_dni': 5072,
#            't_ghi': 2122,
#            't_solar_rad': 358,
#            'temp': 13.3,
#            'ts': 1702335600,
#            'wind_dir': 201,
#            'wind_gust_spd': 14,
#            'wind_spd': 2.1},
#           {'clouds': 49,
#            'datetime': '2023-12-13',
#            'dewpt': 8.9,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 385,
#            'max_temp': 13.1,
#            'max_temp_ts': 1702468800,
#            'max_uv': 1.3,
#            'max_wind_dir': 180,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1702483200,
#            'min_temp': 7.8,
#            'min_temp_ts': 1702450800,
#            'precip': 8.8,
#            'precip_gpm': 8.8,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 81,
#            't_dhi': 583,
#            't_dni': 5061,
#            't_ghi': 2113,
#            't_solar_rad': 1950,
#            'temp': 9.8,
#            'ts': 1702422000,
#            'wind_dir': 180,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 1.3},
#           {'clouds': 42,
#            'datetime': '2023-12-14',
#            'dewpt': 7.3,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 384,
#            'max_temp': 13.3,
#            'max_temp_ts': 1702558800,
#            'max_uv': 1.6,
#            'max_wind_dir': 146,
#            'max_wind_spd': 2.7,
#            'max_wind_spd_ts': 1702540800,
#            'min_temp': 6,
#            'min_temp_ts': 1702537200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1031,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 68,
#            't_dhi': 581,
#            't_dni': 5053,
#            't_ghi': 2106,
#            't_solar_rad': 1634,
#            'temp': 9.1,
#            'ts': 1702508400,
#            'wind_dir': 146,
#            'wind_gust_spd': 7.2,
#            'wind_spd': 1.3},
#           {'clouds': 5,
#            'datetime': '2023-12-15',
#            'dewpt': 7.7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 383,
#            'max_temp': 15.2,
#            'max_temp_ts': 1702648800,
#            'max_uv': 2.1,
#            'max_wind_dir': 121,
#            'max_wind_spd': 1.7,
#            'max_wind_spd_ts': 1702594800,
#            'min_temp': 6,
#            'min_temp_ts': 1702627200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1035,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 580,
#            't_dni': 5046,
#            't_ghi': 2100,
#            't_solar_rad': 2100,
#            'temp': 9.7,
#            'ts': 1702594800,
#            'wind_dir': 121,
#            'wind_gust_spd': 8.4,
#            'wind_spd': 0.9},
#           {'clouds': 21,
#            'datetime': '2023-12-16',
#            'dewpt': 6.3,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 13.9,
#            'max_temp_ts': 1702735200,
#            'max_uv': 2.1,
#            'max_wind_dir': 135,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1702760400,
#            'min_temp': 4.7,
#            'min_temp_ts': 1702713600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 85,
#            'slp': 1035,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 84,
#            't_dhi': 579,
#            't_dni': 5041,
#            't_ghi': 2095,
#            't_solar_rad': 2018,
#            'temp': 8.7,
#            'ts': 1702681200,
#            'wind_dir': 135,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.2},
#           {'clouds': 30,
#            'datetime': '2023-12-17',
#            'dewpt': 3,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 12,
#            'max_temp_ts': 1702821600,
#            'max_uv': 2.1,
#            'max_wind_dir': 107,
#            'max_wind_spd': 3.5,
#            'max_wind_spd_ts': 1702792800,
#            'min_temp': 2.7,
#            'min_temp_ts': 1702800000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 77,
#            'slp': 1035,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 578,
#            't_dni': 5038,
#            't_ghi': 2091,
#            't_solar_rad': 2088,
#            'temp': 6.8,
#            'ts': 1702767600,
#            'wind_dir': 107,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.8},
#           {'clouds': 46,
#            'datetime': '2023-12-18',
#            'dewpt': 2.9,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 10.3,
#            'max_temp_ts': 1702908000,
#            'max_uv': 1.8,
#            'max_wind_dir': 126,
#            'max_wind_spd': 3.5,
#            'max_wind_spd_ts': 1702861200,
#            'min_temp': 1.2,
#            'min_temp_ts': 1702882800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1035,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 579,
#            't_dni': 5035,
#            't_ghi': 2088,
#            't_solar_rad': 1979,
#            'temp': 5.4,
#            'ts': 1702854000,
#            'wind_dir': 126,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.7},
#           {'clouds': 85,
#            'datetime': '2023-12-19',
#            'dewpt': 5.4,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 11.8,
#            'max_temp_ts': 1702998000,
#            'max_uv': 1.6,
#            'max_wind_dir': 144,
#            'max_wind_spd': 3.4,
#            'max_wind_spd_ts': 1702944000,
#            'min_temp': 1.8,
#            'min_temp_ts': 1702962000,
#            'precip': 1,
#            'precip_gpm': 1,
#            'pres': 1020,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1034,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 67,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2085,
#            't_solar_rad': 1608,
#            'temp': 6.7,
#            'ts': 1702940400,
#            'wind_dir': 144,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.3},
#           {'clouds': 56,
#            'datetime': '2023-12-20',
#            'dewpt': 7.6,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 13.3,
#            'max_temp_ts': 1703073600,
#            'max_uv': 1.7,
#            'max_wind_dir': 267,
#            'max_wind_spd': 4.1,
#            'max_wind_spd_ts': 1703084400,
#            'min_temp': 8.8,
#            'min_temp_ts': 1703026800,
#            'precip': 1.3,
#            'precip_gpm': 1.3,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 82,
#            'slp': 1035,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 68,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2084,
#            't_solar_rad': 1639,
#            'temp': 10.6,
#            'ts': 1703026800,
#            'wind_dir': 267,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 2.3},
#           {'clouds': 70,
#            'datetime': '2023-12-21',
#            'dewpt': 8.8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 14.1,
#            'max_temp_ts': 1703167200,
#            'max_uv': 1,
#            'max_wind_dir': 213,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1703178000,
#            'min_temp': 8.4,
#            'min_temp_ts': 1703196000,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1020,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1034,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 45,
#            't_dhi': 580,
#            't_dni': 5035,
#            't_ghi': 2084,
#            't_solar_rad': 1089,
#            'temp': 10.5,
#            'ts': 1703113200,
#            'wind_dir': 213,
#            'wind_gust_spd': 10,
#            'wind_spd': 1.1},
#           {'clouds': 13,
#            'datetime': '2023-12-22',
#            'dewpt': 6.9,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 14.6,
#            'max_temp_ts': 1703253600,
#            'max_uv': 2.1,
#            'max_wind_dir': 253,
#            'max_wind_spd': 3.4,
#            'max_wind_spd_ts': 1703250000,
#            'min_temp': 7.4,
#            'min_temp_ts': 1703282400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 77,
#            'slp': 1031,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 581,
#            't_dni': 5038,
#            't_ghi': 2085,
#            't_solar_rad': 2085,
#            'temp': 10.8,
#            'ts': 1703199600,
#            'wind_dir': 253,
#            'wind_gust_spd': 11.6,
#            'wind_spd': 1.8},
#           {'clouds': 0,
#            'datetime': '2023-12-23',
#            'dewpt': 6.1,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 13.7,
#            'max_temp_ts': 1703340000,
#            'max_uv': 2.1,
#            'max_wind_dir': 160,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1703311200,
#            'min_temp': 5.6,
#            'min_temp_ts': 1703322000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 82,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 582,
#            't_dni': 5043,
#            't_ghi': 2087,
#            't_solar_rad': 2087,
#            'temp': 9,
#            'ts': 1703286000,
#            'wind_dir': 160,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.2},
#           {'clouds': 30,
#            'datetime': '2023-12-24',
#            'dewpt': 6.2,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 13.2,
#            'max_temp_ts': 1703426400,
#            'max_uv': 1.8,
#            'max_wind_dir': 145,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1703444400,
#            'min_temp': 5,
#            'min_temp_ts': 1703404800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1012,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 85,
#            't_dhi': 583,
#            't_dni': 5050,
#            't_ghi': 2091,
#            't_solar_rad': 2048,
#            'temp': 8.4,
#            'ts': 1703372400,
#            'wind_dir': 145,
#            'wind_gust_spd': 5.6,
#            'wind_spd': 1.1},
#           {'clouds': 31,
#            'datetime': '2023-12-25',
#            'dewpt': 5,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 748,
#            'max_ghi': 384,
#            'max_temp': 12.4,
#            'max_temp_ts': 1703512800,
#            'max_uv': 2,
#            'max_wind_dir': 115,
#            'max_wind_spd': 2.3,
#            'max_wind_spd_ts': 1703484000,
#            'min_temp': 3.6,
#            'min_temp_ts': 1703487600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 85,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 584,
#            't_dni': 5058,
#            't_ghi': 2095,
#            't_solar_rad': 2088,
#            'temp': 7.5,
#            'ts': 1703458800,
#            'wind_dir': 115,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.4},
#           {'clouds': 90,
#            'datetime': '2023-12-26',
#            'dewpt': 8,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 385,
#            'max_temp': 13.6,
#            'max_temp_ts': 1703602800,
#            'max_uv': 0.7,
#            'max_wind_dir': 155,
#            'max_wind_spd': 3.5,
#            'max_wind_spd_ts': 1703628000,
#            'min_temp': 7.9,
#            'min_temp_ts': 1703545200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 27,
#            't_dhi': 586,
#            't_dni': 5068,
#            't_ghi': 2100,
#            't_solar_rad': 657,
#            'temp': 10.7,
#            'ts': 1703545200,
#            'wind_dir': 155,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 1.8},
#           {'clouds': 95,
#            'datetime': '2023-12-27',
#            'dewpt': 9.4,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 386,
#            'max_temp': 14.2,
#            'max_temp_ts': 1703678400,
#            'max_uv': 0.7,
#            'max_wind_dir': 151,
#            'max_wind_spd': 4.9,
#            'max_wind_spd_ts': 1703656800,
#            'min_temp': 12.2,
#            'min_temp_ts': 1703714400,
#            'precip': 16.5,
#            'precip_gpm': 16.5,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 21,
#            't_dhi': 588,
#            't_dni': 5080,
#            't_ghi': 2106,
#            't_solar_rad': 505,
#            'temp': 12.8,
#            'ts': 1703631600,
#            'wind_dir': 151,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 3.7},
#           {'clouds': 97,
#            'datetime': '2023-12-28',
#            'dewpt': 11.8,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 387,
#            'max_temp': 12.6,
#            'max_temp_ts': 1703761200,
#            'max_uv': 0.7,
#            'max_wind_dir': 206,
#            'max_wind_spd': 3.8,
#            'max_wind_spd_ts': 1703746800,
#            'min_temp': 10.8,
#            'min_temp_ts': 1703793600,
#            'precip': 41.5,
#            'precip_gpm': 41.5,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 99,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 10,
#            't_dhi': 589,
#            't_dni': 5094,
#            't_ghi': 2113,
#            't_solar_rad': 242,
#            'temp': 12,
#            'ts': 1703718000,
#            'wind_dir': 206,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 1.4},
#           {'clouds': 82,
#            'datetime': '2023-12-29',
#            'dewpt': 10.5,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 388,
#            'max_temp': 11.9,
#            'max_temp_ts': 1703815200,
#            'max_uv': 1,
#            'max_wind_dir': 201,
#            'max_wind_spd': 2.7,
#            'max_wind_spd_ts': 1703887200,
#            'min_temp': 8.2,
#            'min_temp_ts': 1703887200,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 34,
#            't_dhi': 591,
#            't_dni': 5109,
#            't_ghi': 2122,
#            't_solar_rad': 821,
#            'temp': 10.8,
#            'ts': 1703804400,
#            'wind_dir': 201,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 0.9},
#           {'clouds': 79,
#            'datetime': '2023-12-30',
#            'dewpt': 9.4,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 390,
#            'max_temp': 13,
#            'max_temp_ts': 1703944800,
#            'max_uv': 1,
#            'max_wind_dir': 143,
#            'max_wind_spd': 5.3,
#            'max_wind_spd_ts': 1703970000,
#            'min_temp': 7.3,
#            'min_temp_ts': 1703901600,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 45,
#            't_dhi': 593,
#            't_dni': 5125,
#            't_ghi': 2131,
#            't_solar_rad': 1090,
#            'temp': 10.2,
#            'ts': 1703890800,
#            'wind_dir': 143,
#            'wind_gust_spd': 19.2,
#            'wind_spd': 2.7},
#           {'clouds': 87,
#            'datetime': '2023-12-31',
#            'dewpt': 7.5,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 391,
#            'max_temp': 12,
#            'max_temp_ts': 1704027600,
#            'max_uv': 1.1,
#            'max_wind_dir': 196,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1704020400,
#            'min_temp': 7.7,
#            'min_temp_ts': 1704060000,
#            'precip': 3.8,
# ...
#            'snow_depth': 0,
#            'solar_rad': 127,
#            't_dhi': 779,
#            't_dni': 6607,
#            't_ghi': 3396,
#            't_solar_rad': 3044,
#            'temp': 18.1,
#            'ts': 1730242800,
#            'wind_dir': 190,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 1.8},
#           {'clouds': 42,
#            'datetime': '2024-10-31',
#            'dewpt': 12.5,
#            'dhi': 32,
#            'dni': 273,
#            'ghi': 140,
#            'max_dhi': 100,
#            'max_dni': 819,
#            'max_ghi': 540,
#            'max_temp': 22.1,
#            'max_temp_ts': 1730379600,
#            'max_uv': 2.9,
#            'max_wind_dir': 91,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1730383200,
#            'min_temp': 13.9,
#            'min_temp_ts': 1730347200,
#            'precip': 14.8,
#            'precip_gpm': 14.8,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 72,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 131,
#            't_dhi': 773,
#            't_dni': 6564,
#            't_ghi': 3350,
#            't_solar_rad': 3145,
#            'temp': 17.6,
#            'ts': 1730329200,
#            'wind_dir': 91,
#            'wind_gust_spd': 8.8,
#            'wind_spd': 1.8},
#           {'clouds': 47,
#            'datetime': '2024-11-01',
#            'dewpt': 13.5,
#            'dhi': 32,
#            'dni': 272,
#            'ghi': 138,
#            'max_dhi': 99,
#            'max_dni': 817,
#            'max_ghi': 535,
#            'max_temp': 22.9,
#            'max_temp_ts': 1730462400,
#            'max_uv': 2.9,
#            'max_wind_dir': 144,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1730426400,
#            'min_temp': 15.3,
#            'min_temp_ts': 1730498400,
#            'precip': 1.5,
#            'precip_gpm': 1.5,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 74,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 133,
#            't_dhi': 768,
#            't_dni': 6520,
#            't_ghi': 3304,
#            't_solar_rad': 3194,
#            'temp': 18.3,
#            'ts': 1730415600,
#            'wind_dir': 144,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 1.3},
#           {'clouds': 9,
#            'datetime': '2024-11-02',
#            'dewpt': 13.2,
#            'dhi': 32,
#            'dni': 270,
#            'ghi': 136,
#            'max_dhi': 99,
#            'max_dni': 815,
#            'max_ghi': 530,
#            'max_temp': 24.2,
#            'max_temp_ts': 1730552400,
#            'max_uv': 3.1,
#            'max_wind_dir': 141,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1730577600,
#            'min_temp': 13.1,
#            'min_temp_ts': 1730520000,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 78,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 135,
#            't_dhi': 762,
#            't_dni': 6476,
#            't_ghi': 3259,
#            't_solar_rad': 3236,
#            'temp': 17.2,
#            'ts': 1730502000,
#            'wind_dir': 141,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 1.5},
#           {'clouds': 5,
#            'datetime': '2024-11-03',
#            'dewpt': 12.6,
#            'dhi': 32,
#            'dni': 268,
#            'ghi': 134,
#            'max_dhi': 99,
#            'max_dni': 813,
#            'max_ghi': 524,
#            'max_temp': 23.4,
#            'max_temp_ts': 1730638800,
#            'max_uv': 3.5,
#            'max_wind_dir': 138,
#            'max_wind_spd': 2.3,
#            'max_wind_spd_ts': 1730592000,
#            'min_temp': 13.2,
#            'min_temp_ts': 1730617200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 75,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 134,
#            't_dhi': 757,
#            't_dni': 6432,
#            't_ghi': 3214,
#            't_solar_rad': 3214,
#            'temp': 17.4,
#            'ts': 1730588400,
#            'wind_dir': 138,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.1},
#           {'clouds': 84,
#            'datetime': '2024-11-04',
#            'dewpt': 13,
#            'dhi': 31,
#            'dni': 266,
#            'ghi': 132,
#            'max_dhi': 98,
#            'max_dni': 811,
#            'max_ghi': 519,
#            'max_temp': 18.1,
#            'max_temp_ts': 1730736000,
#            'max_uv': 1.1,
#            'max_wind_dir': 99,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1730700000,
#            'min_temp': 14.6,
#            'min_temp_ts': 1730689200,
#            'precip': 10.3,
#            'precip_gpm': 10.3,
#            'pres': 1003,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 32,
#            't_dhi': 751,
#            't_dni': 6387,
#            't_ghi': 3170,
#            't_solar_rad': 767,
#            'temp': 16.5,
#            'ts': 1730674800,
#            'wind_dir': 99,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.4},
#           {'clouds': 71,
#            'datetime': '2024-11-05',
#            'dewpt': 15.6,
#            'dhi': 31,
#            'dni': 264,
#            'ghi': 130,
#            'max_dhi': 98,
#            'max_dni': 809,
#            'max_ghi': 514,
#            'max_temp': 23.2,
#            'max_temp_ts': 1730811600,
#            'max_uv': 1.4,
#            'max_wind_dir': 116,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1730779200,
#            'min_temp': 16,
#            'min_temp_ts': 1730772000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 48,
#            't_dhi': 746,
#            't_dni': 6342,
#            't_ghi': 3127,
#            't_solar_rad': 1144,
#            'temp': 18.5,
#            'ts': 1730761200,
#            'wind_dir': 116,
#            'wind_gust_spd': 6,
#            'wind_spd': 1.3},
#           {'clouds': 60,
#            'datetime': '2024-11-06',
#            'dewpt': 16.2,
#            'dhi': 31,
#            'dni': 262,
#            'ghi': 128,
#            'max_dhi': 97,
#            'max_dni': 807,
#            'max_ghi': 509,
#            'max_temp': 22.7,
#            'max_temp_ts': 1730894400,
#            'max_uv': 2.4,
#            'max_wind_dir': 167,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1730930400,
#            'min_temp': 15.9,
#            'min_temp_ts': 1730930400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 114,
#            't_dhi': 740,
#            't_dni': 6297,
#            't_ghi': 3084,
#            't_solar_rad': 2724,
#            'temp': 18.4,
#            'ts': 1730847600,
#            'wind_dir': 167,
#            'wind_gust_spd': 6.4,
#            'wind_spd': 1.1},
#           {'clouds': 87,
#            'datetime': '2024-11-07',
#            'dewpt': 13.9,
#            'dhi': 31,
#            'dni': 260,
#            'ghi': 127,
#            'max_dhi': 97,
#            'max_dni': 805,
#            'max_ghi': 504,
#            'max_temp': 22.4,
#            'max_temp_ts': 1730988000,
#            'max_uv': 1.2,
#            'max_wind_dir': 152,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1730934000,
#            'min_temp': 14.4,
#            'min_temp_ts': 1730959200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 39,
#            't_dhi': 735,
#            't_dni': 6252,
#            't_ghi': 3042,
#            't_solar_rad': 935,
#            'temp': 17.5,
#            'ts': 1730934000,
#            'wind_dir': 152,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.3},
#           {'clouds': 75,
#            'datetime': '2024-11-08',
#            'dewpt': 14.3,
#            'dhi': 30,
#            'dni': 259,
#            'ghi': 125,
#            'max_dhi': 97,
#            'max_dni': 803,
#            'max_ghi': 499,
#            'max_temp': 18.6,
#            'max_temp_ts': 1731063600,
#            'max_uv': 1.7,
#            'max_wind_dir': 135,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1731042000,
#            'min_temp': 12.4,
#            'min_temp_ts': 1731103200,
#            'precip': 3.5,
#            'precip_gpm': 3.5,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 73,
#            't_dhi': 729,
#            't_dni': 6206,
#            't_ghi': 3001,
#            't_solar_rad': 1760,
#            'temp': 15.8,
#            'ts': 1731020400,
#            'wind_dir': 135,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 1.2},
#           {'clouds': 80,
#            'datetime': '2024-11-09',
#            'dewpt': 12.4,
#            'dhi': 30,
#            'dni': 257,
#            'ghi': 123,
#            'max_dhi': 96,
#            'max_dni': 801,
#            'max_ghi': 495,
#            'max_temp': 18.6,
#            'max_temp_ts': 1731157200,
#            'max_uv': 1.5,
#            'max_wind_dir': 138,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1731114000,
#            'min_temp': 10.4,
#            'min_temp_ts': 1731135600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 59,
#            't_dhi': 724,
#            't_dni': 6161,
#            't_ghi': 2960,
#            't_solar_rad': 1420,
#            'temp': 14,
#            'ts': 1731106800,
#            'wind_dir': 138,
#            'wind_gust_spd': 8,
#            'wind_spd': 1.1},
#           {'clouds': 97,
#            'datetime': '2024-11-10',
#            'dewpt': 16.3,
#            'dhi': 30,
#            'dni': 255,
#            'ghi': 122,
#            'max_dhi': 96,
#            'max_dni': 799,
#            'max_ghi': 490,
#            'max_temp': 18.9,
#            'max_temp_ts': 1731247200,
#            'max_uv': 1,
#            'max_wind_dir': 184,
#            'max_wind_spd': 1.8,
#            'max_wind_spd_ts': 1731258000,
#            'min_temp': 14.9,
#            'min_temp_ts': 1731193200,
#            'precip': 3.5,
#            'precip_gpm': 3.5,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 14,
#            't_dhi': 718,
#            't_dni': 6116,
#            't_ghi': 2920,
#            't_solar_rad': 334,
#            'temp': 16.7,
#            'ts': 1731193200,
#            'wind_dir': 184,
#            'wind_gust_spd': 5.6,
#            'wind_spd': 0.9},
#           {'clouds': 21,
#            'datetime': '2024-11-11',
#            'dewpt': 12.1,
#            'dhi': 30,
#            'dni': 253,
#            'ghi': 120,
#            'max_dhi': 96,
#            'max_dni': 797,
#            'max_ghi': 485,
#            'max_temp': 21,
#            'max_temp_ts': 1731330000,
#            'max_uv': 3.2,
#            'max_wind_dir': 130,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1731362400,
#            'min_temp': 12.7,
#            'min_temp_ts': 1731308400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 120,
#            't_dhi': 713,
#            't_dni': 6070,
#            't_ghi': 2881,
#            't_solar_rad': 2879,
#            'temp': 15.9,
#            'ts': 1731279600,
#            'wind_dir': 130,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 1.7},
#           {'clouds': 21,
#            'datetime': '2024-11-12',
#            'dewpt': 7.5,
#            'dhi': 29,
#            'dni': 251,
#            'ghi': 118,
#            'max_dhi': 95,
#            'max_dni': 795,
#            'max_ghi': 480,
#            'max_temp': 19.2,
#            'max_temp_ts': 1731416400,
#            'max_uv': 3.2,
#            'max_wind_dir': 57,
#            'max_wind_spd': 3.4,
#            'max_wind_spd_ts': 1731412800,
#            'min_temp': 10.2,
#            'min_temp_ts': 1731448800,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 67,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 117,
#            't_dhi': 707,
#            't_dni': 6025,
#            't_ghi': 2843,
#            't_solar_rad': 2817,
#            'temp': 13.7,
#            'ts': 1731366000,
#            'wind_dir': 57,
#            'wind_gust_spd': 14.8,
#            'wind_spd': 2.1},
#           {'clouds': 28,
#            'datetime': '2024-11-13',
#            'dewpt': 4.6,
#            'dhi': 29,
#            'dni': 249,
#            'ghi': 117,
#            'max_dhi': 95,
#            'max_dni': 793,
#            'max_ghi': 476,
#            'max_temp': 14.7,
#            'max_temp_ts': 1731510000,
#            'max_uv': 3,
#            'max_wind_dir': 136,
#            'max_wind_spd': 4.1,
#            'max_wind_spd_ts': 1731520800,
#            'min_temp': 9.3,
#            'min_temp_ts': 1731466800,
#            'precip': 1.5,
#            'precip_gpm': 1.5,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 65,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 115,
#            't_dhi': 702,
#            't_dni': 5981,
#            't_ghi': 2805,
#            't_solar_rad': 2768,
#            'temp': 11.3,
#            'ts': 1731452400,
#            'wind_dir': 136,
#            'wind_gust_spd': 14.8,
#            'wind_spd': 2.1},
#           {'clouds': 32,
#            'datetime': '2024-11-14',
#            'dewpt': 8.3,
#            'dhi': 29,
#            'dni': 247,
#            'ghi': 115,
#            'max_dhi': 95,
#            'max_dni': 791,
#            'max_ghi': 471,
#            'max_temp': 18.3,
#            'max_temp_ts': 1731596400,
#            'max_uv': 3.1,
#            'max_wind_dir': 47,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1731538800,
#            'min_temp': 11.8,
#            'min_temp_ts': 1731538800,
#            'precip': 2,
#            'precip_gpm': 2,
#            'pres': 1003,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 67,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 114,
#            't_dhi': 697,
#            't_dni': 5936,
#            't_ghi': 2768,
#            't_solar_rad': 2738,
#            'temp': 14.2,
#            'ts': 1731538800,
#            'wind_dir': 47,
#            'wind_gust_spd': 12.4,
#            'wind_spd': 1.9}],
#  'lat': 42.431,
#  'lon': -8.64435,
#  'sources': ['080440-99999', 'imerg', 'era5', 'sat', 'radar', 'snodas'],
#  'state_code': '58',
#  'station_id': '080440-99999',
#  'timezone': 'Europe/Madrid'}

# %%
ciudad = data["city_name"]
ciudad
# Out:
# 'Pontevedra'

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

pontevedra =  pd.DataFrame(datos)

pontevedra.head()

pontevedra.to_csv("pontevedra_2023-11-15_2024-11-15.csv")

# %%
# Datos Pontevedra 2022/2023
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=42.431&lon=-8.64435&start_date=2022-11-15&end_date=2023-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
data.update(response.json())

# %%
pprint(data)
# Out:
# {'city_id': '3113209',
#  'city_name': 'Pontevedra',
#  'country_code': 'ES',
#  'data': [{'clouds': 84,
#            'datetime': '2022-11-15',
#            'dewpt': 12.9,
#            'dhi': 29,
#            'dni': 246,
#            'ghi': 114,
#            'max_dhi': 94,
#            'max_dni': 789,
#            'max_ghi': 467,
#            'max_temp': 15.4,
#            'max_temp_ts': 1668549600,
#            'max_uv': 2,
#            'max_wind_dir': 186,
#            'max_wind_spd': 5.6,
#            'max_wind_spd_ts': 1668549600,
#            'min_temp': 12.9,
#            'min_temp_ts': 1668546000,
#            'precip': 38.5,
#            'precip_gpm': 38.5,
#            'pres': 996,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1008,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 89,
#            't_dhi': 691,
#            't_dni': 5892,
#            't_ghi': 2733,
#            't_solar_rad': 2139,
#            'temp': 14.2,
#            'ts': 1668466800,
#            'wind_dir': 186,
#            'wind_gust_spd': 23.2,
#            'wind_spd': 2.4},
#           {'clouds': 93,
#            'datetime': '2022-11-16',
#            'dewpt': 13.7,
#            'dhi': 29,
#            'dni': 244,
#            'ghi': 112,
#            'max_dhi': 94,
#            'max_dni': 787,
#            'max_ghi': 463,
#            'max_temp': 16.7,
#            'max_temp_ts': 1668564000,
#            'max_uv': 1,
#            'max_wind_dir': 206,
#            'max_wind_spd': 7.6,
#            'max_wind_spd_ts': 1668556800,
#            'min_temp': 13.7,
#            'min_temp_ts': 1668589200,
#            'precip': 16.8,
#            'precip_gpm': 16.8,
#            'pres': 993,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1006,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 15,
#            't_dhi': 686,
#            't_dni': 5848,
#            't_ghi': 2698,
#            't_solar_rad': 367,
#            'temp': 14.9,
#            'ts': 1668553200,
#            'wind_dir': 206,
#            'wind_gust_spd': 19.6,
#            'wind_spd': 4.5},
#           {'clouds': 59,
#            'datetime': '2022-11-17',
#            'dewpt': 12.7,
#            'dhi': 28,
#            'dni': 242,
#            'ghi': 111,
#            'max_dhi': 94,
#            'max_dni': 785,
#            'max_ghi': 459,
#            'max_temp': 15,
#            'max_temp_ts': 1668639600,
#            'max_uv': 1.7,
#            'max_wind_dir': 172,
#            'max_wind_spd': 3,
#            'max_wind_spd_ts': 1668675600,
#            'min_temp': 11,
#            'min_temp_ts': 1668722400,
#            'precip': 1.8,
#            'precip_gpm': 1.8,
#            'pres': 995,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1008,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 79,
#            't_dhi': 681,
#            't_dni': 5806,
#            't_ghi': 2663,
#            't_solar_rad': 1904,
#            'temp': 13.4,
#            'ts': 1668639600,
#            'wind_dir': 172,
#            'wind_gust_spd': 14,
#            'wind_spd': 1.6},
#           {'clouds': 44,
#            'datetime': '2022-11-18',
#            'dewpt': 8.9,
#            'dhi': 28,
#            'dni': 240,
#            'ghi': 110,
#            'max_dhi': 93,
#            'max_dni': 783,
#            'max_ghi': 454,
#            'max_temp': 12.8,
#            'max_temp_ts': 1668776400,
#            'max_uv': 1.9,
#            'max_wind_dir': 125,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1668758400,
#            'min_temp': 7.2,
#            'min_temp_ts': 1668754800,
#            'precip': 19,
#            'precip_gpm': 19,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 85,
#            't_dhi': 676,
#            't_dni': 5763,
#            't_ghi': 2630,
#            't_solar_rad': 2047,
#            'temp': 9.7,
#            'ts': 1668726000,
#            'wind_dir': 125,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 1.1},
#           {'clouds': 97,
#            'datetime': '2022-11-19',
#            'dewpt': 8.7,
#            'dhi': 28,
#            'dni': 238,
#            'ghi': 108,
#            'max_dhi': 93,
#            'max_dni': 781,
#            'max_ghi': 450,
#            'max_temp': 10.8,
#            'max_temp_ts': 1668895200,
#            'max_uv': 0.9,
#            'max_wind_dir': 157,
#            'max_wind_spd': 1.8,
#            'max_wind_spd_ts': 1668844800,
#            'min_temp': 6.6,
#            'min_temp_ts': 1668841200,
#            'precip': 13.5,
#            'precip_gpm': 13.5,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 671,
#            't_dni': 5722,
#            't_ghi': 2598,
#            't_solar_rad': 532,
#            'temp': 9,
#            'ts': 1668812400,
#            'wind_dir': 157,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 0.9},
#           {'clouds': 97,
#            'datetime': '2022-11-20',
#            'dewpt': 13.8,
#            'dhi': 28,
#            'dni': 237,
#            'ghi': 107,
#            'max_dhi': 93,
#            'max_dni': 779,
#            'max_ghi': 446,
#            'max_temp': 17,
#            'max_temp_ts': 1668949200,
#            'max_uv': 1.3,
#            'max_wind_dir': 164,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1668981600,
#            'min_temp': 10.8,
#            'min_temp_ts': 1668898800,
#            'precip': 20.8,
#            'precip_gpm': 20.8,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 41,
#            't_dhi': 666,
#            't_dni': 5682,
#            't_ghi': 2566,
#            't_solar_rad': 973,
#            'temp': 14.1,
#            'ts': 1668898800,
#            'wind_dir': 164,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 1.1},
#           {'clouds': 77,
#            'datetime': '2022-11-21',
#            'dewpt': 10.8,
#            'dhi': 28,
#            'dni': 235,
#            'ghi': 106,
#            'max_dhi': 92,
#            'max_dni': 777,
#            'max_ghi': 442,
#            'max_temp': 16.3,
#            'max_temp_ts': 1668985200,
#            'max_uv': 1.8,
#            'max_wind_dir': 241,
#            'max_wind_spd': 6.9,
#            'max_wind_spd_ts': 1669042800,
#            'min_temp': 8.6,
#            'min_temp_ts': 1669068000,
#            'precip': 24.5,
#            'precip_gpm': 24.5,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 73,
#            't_dhi': 661,
#            't_dni': 5642,
#            't_ghi': 2536,
#            't_solar_rad': 1759,
#            'temp': 13.1,
#            'ts': 1668985200,
#            'wind_dir': 241,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 4.5},
#           {'clouds': 93,
#            'datetime': '2022-11-22',
#            'dewpt': 12.4,
#            'dhi': 27,
#            'dni': 233,
#            'ghi': 104,
#            'max_dhi': 92,
#            'max_dni': 775,
#            'max_ghi': 439,
#            'max_temp': 16.3,
#            'max_temp_ts': 1669150800,
#            'max_uv': 0.9,
#            'max_wind_dir': 188,
#            'max_wind_spd': 4.6,
#            'max_wind_spd_ts': 1669136400,
#            'min_temp': 8.3,
#            'min_temp_ts': 1669075200,
#            'precip': 36.5,
#            'precip_gpm': 36.5,
#            'pres': 999,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 11,
#            't_dhi': 656,
#            't_dni': 5604,
#            't_ghi': 2506,
#            't_solar_rad': 253,
#            'temp': 12.6,
#            'ts': 1669071600,
#            'wind_dir': 188,
#            'wind_gust_spd': 17.6,
#            'wind_spd': 2.7},
#           {'clouds': 79,
#            'datetime': '2022-11-23',
#            'dewpt': 12.6,
#            'dhi': 27,
#            'dni': 232,
#            'ghi': 103,
#            'max_dhi': 92,
#            'max_dni': 774,
#            'max_ghi': 435,
#            'max_temp': 16.3,
#            'max_temp_ts': 1669158000,
#            'max_uv': 1.6,
#            'max_wind_dir': 201,
#            'max_wind_spd': 5.5,
#            'max_wind_spd_ts': 1669172400,
#            'min_temp': 12.7,
#            'min_temp_ts': 1669240800,
#            'precip': 23.3,
#            'precip_gpm': 23.3,
#            'pres': 1000,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 74,
#            't_dhi': 651,
#            't_dni': 5566,
#            't_ghi': 2478,
#            't_solar_rad': 1774,
#            'temp': 14.3,
#            'ts': 1669158000,
#            'wind_dir': 201,
#            'wind_gust_spd': 19.6,
#            'wind_spd': 2.6},
#           {'clouds': 75,
#            'datetime': '2022-11-24',
#            'dewpt': 12,
#            'dhi': 27,
#            'dni': 230,
#            'ghi': 102,
#            'max_dhi': 91,
#            'max_dni': 772,
#            'max_ghi': 431,
#            'max_temp': 16.1,
#            'max_temp_ts': 1669298400,
#            'max_uv': 0.9,
#            'max_wind_dir': 168,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1669294800,
#            'min_temp': 11,
#            'min_temp_ts': 1669327200,
#            'precip': 32.3,
#            'precip_gpm': 32.3,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 24,
#            't_dhi': 646,
#            't_dni': 5530,
#            't_ghi': 2450,
#            't_solar_rad': 578,
#            'temp': 13.1,
#            'ts': 1669244400,
#            'wind_dir': 168,
#            'wind_gust_spd': 11.6,
#            'wind_spd': 1.4},
#           {'clouds': 38,
#            'datetime': '2022-11-25',
#            'dewpt': 9,
#            'dhi': 27,
#            'dni': 229,
#            'ghi': 101,
#            'max_dhi': 91,
#            'max_dni': 770,
#            'max_ghi': 428,
#            'max_temp': 15.8,
#            'max_temp_ts': 1669381200,
#            'max_uv': 2.5,
#            'max_wind_dir': 105,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1669410000,
#            'min_temp': 8.1,
#            'min_temp_ts': 1669356000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1012,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 76,
#            't_dhi': 642,
#            't_dni': 5495,
#            't_ghi': 2423,
#            't_solar_rad': 1832,
#            'temp': 10.9,
#            'ts': 1669330800,
#            'wind_dir': 105,
#            'wind_gust_spd': 7.2,
#            'wind_spd': 1.3},
#           {'clouds': 74,
#            'datetime': '2022-11-26',
#            'dewpt': 7.3,
#            'dhi': 27,
#            'dni': 228,
#            'ghi': 100,
#            'max_dhi': 91,
#            'max_dni': 768,
#            'max_ghi': 425,
#            'max_temp': 16.6,
#            'max_temp_ts': 1669467600,
#            'max_uv': 2.4,
#            'max_wind_dir': 135,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1669424400,
#            'min_temp': 7.5,
#            'min_temp_ts': 1669417200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 77,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 68,
#            't_dhi': 637,
#            't_dni': 5461,
#            't_ghi': 2397,
#            't_solar_rad': 1643,
#            'temp': 11.3,
#            'ts': 1669417200,
#            'wind_dir': 135,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 1.5},
#           {'clouds': 77,
#            'datetime': '2022-11-27',
#            'dewpt': 9.1,
#            'dhi': 26,
#            'dni': 226,
#            'ghi': 99,
#            'max_dhi': 91,
#            'max_dni': 767,
#            'max_ghi': 421,
#            'max_temp': 13.2,
#            'max_temp_ts': 1669561200,
#            'max_uv': 1.1,
#            'max_wind_dir': 183,
#            'max_wind_spd': 3,
#            'max_wind_spd_ts': 1669536000,
#            'min_temp': 8.3,
#            'min_temp_ts': 1669586400,
#            'precip': 33,
#            'precip_gpm': 33,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 27,
#            't_dhi': 633,
#            't_dni': 5428,
#            't_ghi': 2373,
#            't_solar_rad': 638,
#            'temp': 11.5,
#            'ts': 1669503600,
#            'wind_dir': 183,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 1.4},
#           {'clouds': 55,
#            'datetime': '2022-11-28',
#            'dewpt': 8.7,
#            'dhi': 26,
#            'dni': 225,
#            'ghi': 98,
#            'max_dhi': 90,
#            'max_dni': 765,
#            'max_ghi': 418,
#            'max_temp': 14,
#            'max_temp_ts': 1669636800,
#            'max_uv': 1.7,
#            'max_wind_dir': 135,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1669608000,
#            'min_temp': 7.1,
#            'min_temp_ts': 1669615200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1012,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 80,
#            't_dhi': 629,
#            't_dni': 5397,
#            't_ghi': 2349,
#            't_solar_rad': 1926,
#            'temp': 9.7,
#            'ts': 1669590000,
#            'wind_dir': 135,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.4},
#           {'clouds': 71,
#            'datetime': '2022-11-29',
#            'dewpt': 8.8,
#            'dhi': 26,
#            'dni': 224,
#            'ghi': 97,
#            'max_dhi': 90,
#            'max_dni': 764,
#            'max_ghi': 415,
#            'max_temp': 13.7,
#            'max_temp_ts': 1669734000,
#            'max_uv': 0.9,
#            'max_wind_dir': 131,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1669698000,
#            'min_temp': 8,
#            'min_temp_ts': 1669708800,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 624,
#            't_dni': 5366,
#            't_ghi': 2326,
#            't_solar_rad': 520,
#            'temp': 10.5,
#            'ts': 1669676400,
#            'wind_dir': 131,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.3},
#           {'clouds': 83,
#            'datetime': '2022-11-30',
#            'dewpt': 8.9,
#            'dhi': 26,
#            'dni': 222,
#            'ghi': 96,
#            'max_dhi': 90,
#            'max_dni': 762,
#            'max_ghi': 412,
#            'max_temp': 11.7,
#            'max_temp_ts': 1669820400,
#            'max_uv': 0.9,
#            'max_wind_dir': 100,
#            'max_wind_spd': 3.7,
#            'max_wind_spd_ts': 1669770000,
#            'min_temp': 9.2,
#            'min_temp_ts': 1669845600,
#            'precip': 34.3,
#            'precip_gpm': 34.3,
#            'pres': 1000,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 20,
#            't_dhi': 620,
#            't_dni': 5336,
#            't_ghi': 2304,
#            't_solar_rad': 469,
#            'temp': 10.6,
#            'ts': 1669762800,
#            'wind_dir': 100,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 1.5},
#           {'clouds': 2,
#            'datetime': '2022-12-01',
#            'dewpt': 6.5,
#            'dhi': 26,
#            'dni': 221,
#            'ghi': 95,
#            'max_dhi': 90,
#            'max_dni': 761,
#            'max_ghi': 409,
#            'max_temp': 15.6,
#            'max_temp_ts': 1669903200,
#            'max_uv': 2.2,
#            'max_wind_dir': 134,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1669932000,
#            'min_temp': 5.5,
#            'min_temp_ts': 1669881600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 91,
#            't_dhi': 617,
#            't_dni': 5307,
#            't_ghi': 2283,
#            't_solar_rad': 2194,
#            'temp': 9.7,
#            'ts': 1669849200,
#            'wind_dir': 134,
#            'wind_gust_spd': 7.6,
#            'wind_spd': 1.6},
#           {'clouds': 3,
#            'datetime': '2022-12-02',
#            'dewpt': 3.8,
#            'dhi': 26,
#            'dni': 220,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 759,
#            'max_ghi': 407,
#            'max_temp': 13.3,
#            'max_temp_ts': 1669989600,
#            'max_uv': 2.2,
#            'max_wind_dir': 132,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1670018400,
#            'min_temp': 2.5,
#            'min_temp_ts': 1669968000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 998,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 93,
#            't_dhi': 613,
#            't_dni': 5279,
#            't_ghi': 2264,
#            't_solar_rad': 2235,
#            'temp': 7.3,
#            'ts': 1669935600,
#            'wind_dir': 132,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 1.3},
#           {'clouds': 2,
#            'datetime': '2022-12-03',
#            'dewpt': 1.6,
#            'dhi': 25,
#            'dni': 219,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 758,
#            'max_ghi': 404,
#            'max_temp': 12.2,
#            'max_temp_ts': 1670072400,
#            'max_uv': 2.1,
#            'max_wind_dir': 107,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1670022000,
#            'min_temp': 2.4,
#            'min_temp_ts': 1670054400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 995,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 71,
#            'slp': 1008,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 94,
#            't_dhi': 609,
#            't_dni': 5253,
#            't_ghi': 2245,
#            't_solar_rad': 2245,
#            'temp': 6.8,
#            'ts': 1670022000,
#            'wind_dir': 107,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 1.8},
#           {'clouds': 47,
#            'datetime': '2022-12-04',
#            'dewpt': 3,
#            'dhi': 25,
#            'dni': 218,
#            'ghi': 93,
#            'max_dhi': 89,
#            'max_dni': 756,
#            'max_ghi': 402,
#            'max_temp': 12.2,
#            'max_temp_ts': 1670162400,
#            'max_uv': 1.7,
#            'max_wind_dir': 151,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1670108400,
#            'min_temp': 1.8,
#            'min_temp_ts': 1670137200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 994,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 78,
#            'slp': 1007,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 78,
#            't_dhi': 606,
#            't_dni': 5227,
#            't_ghi': 2227,
#            't_solar_rad': 1878,
#            'temp': 6.6,
#            'ts': 1670108400,
#            'wind_dir': 151,
#            'wind_gust_spd': 7.6,
#            'wind_spd': 1.1},
#           {'clouds': 60,
#            'datetime': '2022-12-05',
#            'dewpt': 6.8,
#            'dhi': 25,
#            'dni': 217,
#            'ghi': 92,
#            'max_dhi': 89,
#            'max_dni': 755,
#            'max_ghi': 399,
#            'max_temp': 16.9,
#            'max_temp_ts': 1670248800,
#            'max_uv': 1.7,
#            'max_wind_dir': 74,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1670212800,
#            'min_temp': 7.5,
#            'min_temp_ts': 1670212800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 995,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 74,
#            'slp': 1008,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 78,
#            't_dhi': 603,
#            't_dni': 5202,
#            't_ghi': 2210,
#            't_solar_rad': 1879,
#            'temp': 11.4,
#            'ts': 1670194800,
#            'wind_dir': 74,
#            'wind_gust_spd': 7.2,
#            'wind_spd': 1.7},
#           {'clouds': 68,
#            'datetime': '2022-12-06',
#            'dewpt': 8.6,
#            'dhi': 25,
#            'dni': 216,
#            'ghi': 91,
#            'max_dhi': 89,
#            'max_dni': 754,
#            'max_ghi': 397,
#            'max_temp': 15.4,
#            'max_temp_ts': 1670335200,
#            'max_uv': 1.4,
#            'max_wind_dir': 104,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1670306400,
#            'min_temp': 9.9,
#            'min_temp_ts': 1670299200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 62,
#            't_dhi': 600,
#            't_dni': 5178,
#            't_ghi': 2194,
#            't_solar_rad': 1480,
#            'temp': 11.8,
#            'ts': 1670281200,
#            'wind_dir': 104,
#            'wind_gust_spd': 3.6,
#            'wind_spd': 1.4},
#           {'clouds': 44,
#            'datetime': '2022-12-07',
#            'dewpt': 8.5,
#            'dhi': 25,
#            'dni': 215,
#            'ghi': 91,
#            'max_dhi': 88,
#            'max_dni': 753,
#            'max_ghi': 395,
#            'max_temp': 16.9,
#            'max_temp_ts': 1670418000,
#            'max_uv': 1.9,
#            'max_wind_dir': 114,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1670450400,
#            'min_temp': 8.2,
#            'min_temp_ts': 1670400000,
#            'precip': 2,
#            'precip_gpm': 2,
#            'pres': 997,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1010,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 63,
#            't_dhi': 597,
#            't_dni': 5156,
#            't_ghi': 2180,
#            't_solar_rad': 1502,
#            'temp': 12,
#            'ts': 1670367600,
#            'wind_dir': 114,
#            'wind_gust_spd': 7.6,
#            'wind_spd': 1.3},
#           {'clouds': 87,
#            'datetime': '2022-12-08',
#            'dewpt': 10.4,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 393,
#            'max_temp': 17.7,
#            'max_temp_ts': 1670500800,
#            'max_uv': 1.3,
#            'max_wind_dir': 129,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1670511600,
#            'min_temp': 11.2,
#            'min_temp_ts': 1670468400,
#            'precip': 24,
#            'precip_gpm': 24,
#            'pres': 984,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 997,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 58,
#            't_dhi': 595,
#            't_dni': 5136,
#            't_ghi': 2166,
#            't_solar_rad': 1391,
#            'temp': 13.2,
#            'ts': 1670454000,
#            'wind_dir': 129,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.7},
#           {'clouds': 44,
#            'datetime': '2022-12-09',
#            'dewpt': 8.5,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 391,
#            'max_temp': 15.5,
#            'max_temp_ts': 1670587200,
#            'max_uv': 1.8,
#            'max_wind_dir': 204,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1670594400,
#            'min_temp': 9.8,
#            'min_temp_ts': 1670623200,
#            'precip': 1.8,
#            'precip_gpm': 1.8,
#            'pres': 986,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 999,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 592,
#            't_dni': 5117,
#            't_ghi': 2153,
#            't_solar_rad': 2090,
#            'temp': 11.8,
#            'ts': 1670540400,
#            'wind_dir': 204,
#            'wind_gust_spd': 13.6,
#            'wind_spd': 2.3},
#           {'clouds': 67,
#            'datetime': '2022-12-10',
#            'dewpt': 4.3,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 390,
#            'max_temp': 11.4,
#            'max_temp_ts': 1670680800,
#            'max_uv': 2,
#            'max_wind_dir': 150,
#            'max_wind_spd': 2,
#            'max_wind_spd_ts': 1670702400,
#            'min_temp': 5.4,
#            'min_temp_ts': 1670655600,
#            'precip': 8.5,
#            'precip_gpm': 8.5,
#            'pres': 997,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1010,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 60,
#            't_dhi': 590,
#            't_dni': 5100,
#            't_ghi': 2142,
#            't_solar_rad': 1429,
#            'temp': 8.4,
#            'ts': 1670626800,
#            'wind_dir': 150,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 1.2},
#           {'clouds': 88,
#            'datetime': '2022-12-11',
#            'dewpt': 6.9,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 388,
#            'max_temp': 12.6,
#            'max_temp_ts': 1670767200,
#            'max_uv': 0.8,
#            'max_wind_dir': 143,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1670720400,
#            'min_temp': 6.6,
#            'min_temp_ts': 1670727600,
#            'precip': 12.3,
#            'precip_gpm': 12.3,
#            'pres': 992,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1005,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 31,
#            't_dhi': 587,
#            't_dni': 5085,
#            't_ghi': 2131,
#            't_solar_rad': 755,
#            'temp': 8.6,
#            'ts': 1670713200,
#            'wind_dir': 143,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.1},
#           {'clouds': 100,
#            'datetime': '2022-12-12',
#            'dewpt': 13.7,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 386,
#            'max_temp': 16.7,
#            'max_temp_ts': 1670832000,
#            'max_uv': 1.1,
#            'max_wind_dir': 196,
#            'max_wind_spd': 6.9,
#            'max_wind_spd_ts': 1670832000,
#            'min_temp': 8.9,
#            'min_temp_ts': 1670799600,
#            'precip': 50.8,
#            'precip_gpm': 50.8,
#            'pres': 987,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1000,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 50,
#            't_dhi': 585,
#            't_dni': 5072,
#            't_ghi': 2122,
#            't_solar_rad': 1206,
#            'temp': 14.4,
#            'ts': 1670799600,
#            'wind_dir': 196,
#            'wind_gust_spd': 24.8,
#            'wind_spd': 3.3},
#           {'clouds': 98,
#            'datetime': '2022-12-13',
#            'dewpt': 15.1,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 385,
#            'max_temp': 16.4,
#            'max_temp_ts': 1670936400,
#            'max_uv': 0.7,
#            'max_wind_dir': 175,
#            'max_wind_spd': 2.2,
#            'max_wind_spd_ts': 1670889600,
#            'min_temp': 13.9,
#            'min_temp_ts': 1670968800,
#            'precip': 11,
#            'precip_gpm': 11,
#            'pres': 986,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 97,
#            'slp': 999,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 9,
#            't_dhi': 583,
#            't_dni': 5061,
#            't_ghi': 2113,
#            't_solar_rad': 211,
#            'temp': 15.5,
#            'ts': 1670886000,
#            'wind_dir': 175,
#            'wind_gust_spd': 12.4,
#            'wind_spd': 1.6},
#           {'clouds': 78,
#            'datetime': '2022-12-14',
#            'dewpt': 11.9,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 384,
#            'max_temp': 17.4,
#            'max_temp_ts': 1671019200,
#            'max_uv': 0.9,
#            'max_wind_dir': 159,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1670986800,
#            'min_temp': 12.1,
#            'min_temp_ts': 1671055200,
#            'precip': 20.5,
#            'precip_gpm': 20.5,
#            'pres': 985,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 997,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 41,
#            't_dhi': 581,
#            't_dni': 5053,
#            't_ghi': 2106,
#            't_solar_rad': 994,
#            'temp': 14,
#            'ts': 1670972400,
#            'wind_dir': 159,
#            'wind_gust_spd': 15.2,
#            'wind_spd': 2.5},
#           {'clouds': 88,
#            'datetime': '2022-12-15',
#            'dewpt': 10.4,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 383,
#            'max_temp': 12.6,
#            'max_temp_ts': 1671116400,
#            'max_uv': 1.1,
#            'max_wind_dir': 125,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1671076800,
#            'min_temp': 10.5,
#            'min_temp_ts': 1671087600,
#            'precip': 5.5,
#            'precip_gpm': 5.5,
#            'pres': 984,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 997,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 62,
#            't_dhi': 580,
#            't_dni': 5046,
#            't_ghi': 2100,
#            't_solar_rad': 1497,
#            'temp': 11.5,
#            'ts': 1671058800,
#            'wind_dir': 125,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 1.4},
#           {'clouds': 68,
#            'datetime': '2022-12-16',
#            'dewpt': 8.6,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 15.5,
#            'max_temp_ts': 1671192000,
#            'max_uv': 2.1,
#            'max_wind_dir': 118,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1671213600,
#            'min_temp': 8.3,
#            'min_temp_ts': 1671177600,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 993,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1006,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 84,
#            't_dhi': 579,
#            't_dni': 5041,
#            't_ghi': 2095,
#            't_solar_rad': 2008,
#            'temp': 11.5,
#            'ts': 1671145200,
#            'wind_dir': 118,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 1.5},
#           {'clouds': 76,
#            'datetime': '2022-12-17',
#            'dewpt': 9.2,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 14,
#            'max_temp_ts': 1671285600,
#            'max_uv': 1.4,
#            'max_wind_dir': 129,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1671307200,
#            'min_temp': 9.8,
#            'min_temp_ts': 1671231600,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 53,
#            't_dhi': 578,
#            't_dni': 5038,
#            't_ghi': 2091,
#            't_solar_rad': 1273,
#            'temp': 11.3,
#            'ts': 1671231600,
#            'wind_dir': 129,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 1.2},
#           {'clouds': 95,
#            'datetime': '2022-12-18',
#            'dewpt': 9.7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 16.3,
#            'max_temp_ts': 1671400800,
#            'max_uv': 0.9,
#            'max_wind_dir': 172,
#            'max_wind_spd': 6.3,
#            'max_wind_spd_ts': 1671354000,
#            'min_temp': 10.8,
#            'min_temp_ts': 1671318000,
#            'precip': 7.3,
#            'precip_gpm': 7.3,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 75,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 35,
#            't_dhi': 579,
#            't_dni': 5035,
#            't_ghi': 2088,
#            't_solar_rad': 850,
#            'temp': 14.2,
#            'ts': 1671318000,
#            'wind_dir': 172,
#            'wind_gust_spd': 20.4,
#            'wind_spd': 3.8},
#           {'clouds': 100,
#            'datetime': '2022-12-19',
#            'dewpt': 12.7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 16.4,
#            'max_temp_ts': 1671404400,
#            'max_uv': 0.6,
#            'max_wind_dir': 156,
#            'max_wind_spd': 7.5,
#            'max_wind_spd_ts': 1671408000,
#            'min_temp': 13.2,
#            'min_temp_ts': 1671418800,
#            'precip': 81.3,
#            'precip_gpm': 81.3,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 16,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2085,
#            't_solar_rad': 387,
#            'temp': 14.5,
#            'ts': 1671404400,
#            'wind_dir': 156,
#            'wind_gust_spd': 23.6,
#            'wind_spd': 5.9},
#           {'clouds': 86,
#            'datetime': '2022-12-20',
#            'dewpt': 13.3,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 15.2,
#            'max_temp_ts': 1671490800,
#            'max_uv': 1.7,
#            'max_wind_dir': 181,
#            'max_wind_spd': 4.6,
#            'max_wind_spd_ts': 1671490800,
#            'min_temp': 13.2,
#            'min_temp_ts': 1671559200,
#            'precip': 51.3,
#            'precip_gpm': 51.3,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 83,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2084,
#            't_solar_rad': 1983,
#            'temp': 14.2,
#            'ts': 1671490800,
#            'wind_dir': 181,
#            'wind_gust_spd': 19.6,
#            'wind_spd': 2.2},
#           {'clouds': 96,
#            'datetime': '2022-12-21',
#            'dewpt': 13.8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 16.2,
#            'max_temp_ts': 1671631200,
#            'max_uv': 0.7,
#            'max_wind_dir': 187,
#            'max_wind_spd': 3.9,
#            'max_wind_spd_ts': 1671598800,
#            'min_temp': 12.8,
#            'min_temp_ts': 1671606000,
#            'precip': 8,
#            'precip_gpm': 8,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 13,
#            't_dhi': 580,
#            't_dni': 5035,
#            't_ghi': 2084,
#            't_solar_rad': 311,
#            'temp': 14.9,
#            'ts': 1671577200,
#            'wind_dir': 187,
#            'wind_gust_spd': 15.6,
#            'wind_spd': 2.5},
#           {'clouds': 89,
#            'datetime': '2022-12-22',
#            'dewpt': 15,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 16.1,
#            'max_temp_ts': 1671710400,
#            'max_uv': 0.7,
#            'max_wind_dir': 180,
#            'max_wind_spd': 4.5,
#            'max_wind_spd_ts': 1671735600,
#            'min_temp': 14.5,
#            'min_temp_ts': 1671742800,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 97,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 13,
#            't_dhi': 581,
#            't_dni': 5038,
#            't_ghi': 2085,
#            't_solar_rad': 301,
#            'temp': 15.5,
#            'ts': 1671663600,
#            'wind_dir': 180,
#            'wind_gust_spd': 16.4,
#            'wind_spd': 2.6},
#           {'clouds': 91,
#            'datetime': '2022-12-23',
#            'dewpt': 14.2,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 16.9,
#            'max_temp_ts': 1671793200,
#            'max_uv': 0.7,
#            'max_wind_dir': 176,
#            'max_wind_spd': 5.5,
#            'max_wind_spd_ts': 1671807600,
#            'min_temp': 13.4,
#            'min_temp_ts': 1671832800,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 16,
#            't_dhi': 582,
#            't_dni': 5043,
#            't_ghi': 2087,
#            't_solar_rad': 391,
#            'temp': 15.5,
#            'ts': 1671750000,
#            'wind_dir': 176,
#            'wind_gust_spd': 20.4,
#            'wind_spd': 4},
#           {'clouds': 99,
#            'datetime': '2022-12-24',
#            'dewpt': 12.9,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 15.2,
#            'max_temp_ts': 1671858000,
#            'max_uv': 0.7,
#            'max_wind_dir': 181,
#            'max_wind_spd': 5.3,
#            'max_wind_spd_ts': 1671858000,
#            'min_temp': 10.9,
#            'min_temp_ts': 1671919200,
#            'precip': 35,
#            'precip_gpm': 35,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 15,
#            't_dhi': 583,
#            't_dni': 5050,
#            't_ghi': 2091,
#            't_solar_rad': 353,
#            'temp': 13.7,
#            'ts': 1671836400,
#            'wind_dir': 181,
#            'wind_gust_spd': 20,
#            'wind_spd': 2.4},
#           {'clouds': 97,
#            'datetime': '2022-12-25',
#            'dewpt': 11.7,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 748,
#            'max_ghi': 384,
#            'max_temp': 13.9,
#            'max_temp_ts': 1671937200,
#            'max_uv': 0.7,
#            'max_wind_dir': 163,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1671980400,
#            'min_temp': 10.9,
#            'min_temp_ts': 1671922800,
#            'precip': 23.8,
#            'precip_gpm': 23.8,
#            'pres': 999,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 16,
#            't_dhi': 584,
#            't_dni': 5058,
#            't_ghi': 2095,
#            't_solar_rad': 381,
#            'temp': 12.7,
#            'ts': 1671922800,
#            'wind_dir': 163,
#            'wind_gust_spd': 19.2,
#            'wind_spd': 2.2},
#           {'clouds': 49,
#            'datetime': '2022-12-26',
#            'dewpt': 10.1,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 385,
#            'max_temp': 14.6,
#            'max_temp_ts': 1672059600,
#            'max_uv': 1.6,
#            'max_wind_dir': 131,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1672063200,
#            'min_temp': 9.2,
#            'min_temp_ts': 1672092000,
#            'precip': 4.5,
#            'precip_gpm': 4.5,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 75,
#            't_dhi': 586,
#            't_dni': 5068,
#            't_ghi': 2100,
#            't_solar_rad': 1797,
#            'temp': 11.5,
#            'ts': 1672009200,
#            'wind_dir': 131,
#            'wind_gust_spd': 8,
#            'wind_spd': 1.6},
#           {'clouds': 19,
#            'datetime': '2022-12-27',
#            'dewpt': 7.8,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 386,
#            'max_temp': 13.9,
#            'max_temp_ts': 1672146000,
#            'max_uv': 1.9,
#            'max_wind_dir': 125,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1672124400,
#            'min_temp': 7.3,
#            'min_temp_ts': 1672117200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1029,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 75,
#            't_dhi': 588,
#            't_dni': 5080,
#            't_ghi': 2106,
#            't_solar_rad': 1807,
#            'temp': 9.8,
#            'ts': 1672095600,
#            'wind_dir': 125,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 1.6},
#           {'clouds': 91,
#            'datetime': '2022-12-28',
#            'dewpt': 11,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 387,
#            'max_temp': 14.3,
#            'max_temp_ts': 1672221600,
#            'max_uv': 0.7,
#            'max_wind_dir': 163,
#            'max_wind_spd': 3.8,
#            'max_wind_spd_ts': 1672210800,
#            'min_temp': 7.2,
#            'min_temp_ts': 1672185600,
#            'precip': 5.3,
#            'precip_gpm': 5.3,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 14,
#            't_dhi': 589,
#            't_dni': 5094,
#            't_ghi': 2113,
#            't_solar_rad': 332,
#            'temp': 11.7,
#            'ts': 1672182000,
#            'wind_dir': 163,
#            'wind_gust_spd': 14.8,
#            'wind_spd': 2.2},
#           {'clouds': 88,
#            'datetime': '2022-12-29',
#            'dewpt': 12.2,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 388,
#            'max_temp': 13.7,
#            'max_temp_ts': 1672351200,
#            'max_uv': 0.7,
#            'max_wind_dir': 183,
#            'max_wind_spd': 3.3,
#            'max_wind_spd_ts': 1672351200,
#            'min_temp': 11.7,
#            'min_temp_ts': 1672300800,
#            'precip': 28.3,
#            'precip_gpm': 28.3,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 99,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 16,
#            't_dhi': 591,
#            't_dni': 5109,
#            't_ghi': 2122,
#            't_solar_rad': 384,
#            'temp': 12.3,
#            'ts': 1672268400,
#            'wind_dir': 183,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 1.7},
#           {'clouds': 93,
#            'datetime': '2022-12-30',
#            'dewpt': 14.1,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 390,
#            'max_temp': 16.4,
#            'max_temp_ts': 1672430400,
#            'max_uv': 0.8,
#            'max_wind_dir': 184,
#            'max_wind_spd': 6.4,
#            'max_wind_spd_ts': 1672434000,
#            'min_temp': 13.7,
#            'min_temp_ts': 1672354800,
#            'precip': 25.3,
#            'precip_gpm': 25.3,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 593,
#            't_dni': 5125,
#            't_ghi': 2131,
#            't_solar_rad': 527,
#            'temp': 15.3,
#            'ts': 1672354800,
#            'wind_dir': 184,
#            'wind_gust_spd': 21.6,
#            'wind_spd': 4.1},
#           {'clouds': 80,
#            'datetime': '2022-12-31',
#            'dewpt': 10.2,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 391,
#            'max_temp': 17.9,
#            'max_temp_ts': 1672491600,
#            'max_uv': 1.4,
#            'max_wind_dir': 164,
#            'max_wind_spd': 8.2,
#            'max_wind_spd_ts': 1672491600,
# ...
#            'solar_rad': 92,
#            't_dhi': 779,
#            't_dni': 6607,
#            't_ghi': 3396,
#            't_solar_rad': 2206,
#            'temp': 12.8,
#            'ts': 1698620400,
#            'wind_dir': 189,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 2},
#           {'clouds': 72,
#            'datetime': '2023-10-31',
#            'dewpt': 12.8,
#            'dhi': 32,
#            'dni': 273,
#            'ghi': 140,
#            'max_dhi': 100,
#            'max_dni': 819,
#            'max_ghi': 540,
#            'max_temp': 18.2,
#            'max_temp_ts': 1698753600,
#            'max_uv': 2.4,
#            'max_wind_dir': 145,
#            'max_wind_spd': 3.9,
#            'max_wind_spd_ts': 1698789600,
#            'min_temp': 11.3,
#            'min_temp_ts': 1698728400,
#            'precip': 14,
#            'precip_gpm': 14,
#            'pres': 998,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1011,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 84,
#            't_dhi': 773,
#            't_dni': 6564,
#            't_ghi': 3350,
#            't_solar_rad': 2021,
#            'temp': 13.8,
#            'ts': 1698706800,
#            'wind_dir': 145,
#            'wind_gust_spd': 20,
#            'wind_spd': 2.1},
#           {'clouds': 92,
#            'datetime': '2023-11-01',
#            'dewpt': 13.1,
#            'dhi': 32,
#            'dni': 272,
#            'ghi': 138,
#            'max_dhi': 99,
#            'max_dni': 817,
#            'max_ghi': 535,
#            'max_temp': 16.9,
#            'max_temp_ts': 1698876000,
#            'max_uv': 1.2,
#            'max_wind_dir': 190,
#            'max_wind_spd': 6.8,
#            'max_wind_spd_ts': 1698876000,
#            'min_temp': 12.2,
#            'min_temp_ts': 1698818400,
#            'precip': 55,
#            'precip_gpm': 55,
#            'pres': 995,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1008,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 38,
#            't_dhi': 768,
#            't_dni': 6520,
#            't_ghi': 3304,
#            't_solar_rad': 902,
#            'temp': 14.5,
#            'ts': 1698793200,
#            'wind_dir': 190,
#            'wind_gust_spd': 29.2,
#            'wind_spd': 3.6},
#           {'clouds': 72,
#            'datetime': '2023-11-02',
#            'dewpt': 9.6,
#            'dhi': 32,
#            'dni': 270,
#            'ghi': 136,
#            'max_dhi': 99,
#            'max_dni': 815,
#            'max_ghi': 530,
#            'max_temp': 17,
#            'max_temp_ts': 1698879600,
#            'max_uv': 2.6,
#            'max_wind_dir': 244,
#            'max_wind_spd': 7.7,
#            'max_wind_spd_ts': 1698912000,
#            'min_temp': 9.2,
#            'min_temp_ts': 1698937200,
#            'precip': 34.8,
#            'precip_gpm': 34.8,
#            'pres': 991,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1003,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 116,
#            't_dhi': 762,
#            't_dni': 6476,
#            't_ghi': 3259,
#            't_solar_rad': 2776,
#            'temp': 11.6,
#            'ts': 1698879600,
#            'wind_dir': 244,
#            'wind_gust_spd': 27.2,
#            'wind_spd': 4.8},
#           {'clouds': 95,
#            'datetime': '2023-11-03',
#            'dewpt': 11.4,
#            'dhi': 32,
#            'dni': 268,
#            'ghi': 134,
#            'max_dhi': 99,
#            'max_dni': 813,
#            'max_ghi': 524,
#            'max_temp': 14.7,
#            'max_temp_ts': 1699048800,
#            'max_uv': 1.1,
#            'max_wind_dir': 223,
#            'max_wind_spd': 6.2,
#            'max_wind_spd_ts': 1698966000,
#            'min_temp': 11.3,
#            'min_temp_ts': 1698966000,
#            'precip': 38,
#            'precip_gpm': 38,
#            'pres': 994,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1007,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 42,
#            't_dhi': 757,
#            't_dni': 6432,
#            't_ghi': 3214,
#            't_solar_rad': 996,
#            'temp': 12.5,
#            'ts': 1698966000,
#            'wind_dir': 223,
#            'wind_gust_spd': 18.8,
#            'wind_spd': 3},
#           {'clouds': 74,
#            'datetime': '2023-11-04',
#            'dewpt': 12,
#            'dhi': 31,
#            'dni': 266,
#            'ghi': 132,
#            'max_dhi': 98,
#            'max_dni': 811,
#            'max_ghi': 519,
#            'max_temp': 16.5,
#            'max_temp_ts': 1699070400,
#            'max_uv': 2.1,
#            'max_wind_dir': 221,
#            'max_wind_spd': 8.4,
#            'max_wind_spd_ts': 1699110000,
#            'min_temp': 11.3,
#            'min_temp_ts': 1699117200,
#            'precip': 44,
#            'precip_gpm': 44,
#            'pres': 984,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 997,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 117,
#            't_dhi': 751,
#            't_dni': 6387,
#            't_ghi': 3170,
#            't_solar_rad': 2801,
#            'temp': 14.2,
#            'ts': 1699052400,
#            'wind_dir': 221,
#            'wind_gust_spd': 28,
#            'wind_spd': 6},
#           {'clouds': 71,
#            'datetime': '2023-11-05',
#            'dewpt': 10.3,
#            'dhi': 31,
#            'dni': 264,
#            'ghi': 130,
#            'max_dhi': 98,
#            'max_dni': 809,
#            'max_ghi': 514,
#            'max_temp': 13.3,
#            'max_temp_ts': 1699192800,
#            'max_uv': 1.8,
#            'max_wind_dir': 205,
#            'max_wind_spd': 4.9,
#            'max_wind_spd_ts': 1699153200,
#            'min_temp': 9.1,
#            'min_temp_ts': 1699221600,
#            'precip': 86.8,
#            'precip_gpm': 86.8,
#            'pres': 995,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1008,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 94,
#            't_dhi': 746,
#            't_dni': 6342,
#            't_ghi': 3127,
#            't_solar_rad': 2258,
#            'temp': 11.5,
#            'ts': 1699138800,
#            'wind_dir': 205,
#            'wind_gust_spd': 19.6,
#            'wind_spd': 3},
#           {'clouds': 44,
#            'datetime': '2023-11-06',
#            'dewpt': 7.8,
#            'dhi': 31,
#            'dni': 262,
#            'ghi': 128,
#            'max_dhi': 97,
#            'max_dni': 807,
#            'max_ghi': 509,
#            'max_temp': 13.7,
#            'max_temp_ts': 1699275600,
#            'max_uv': 2.7,
#            'max_wind_dir': 142,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1699286400,
#            'min_temp': 6.9,
#            'min_temp_ts': 1699254000,
#            'precip': 13.3,
#            'precip_gpm': 13.3,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 123,
#            't_dhi': 740,
#            't_dni': 6297,
#            't_ghi': 3084,
#            't_solar_rad': 2950,
#            'temp': 9.3,
#            'ts': 1699225200,
#            'wind_dir': 142,
#            'wind_gust_spd': 11.6,
#            'wind_spd': 1.5},
#           {'clouds': 83,
#            'datetime': '2023-11-07',
#            'dewpt': 8.8,
#            'dhi': 31,
#            'dni': 260,
#            'ghi': 127,
#            'max_dhi': 97,
#            'max_dni': 805,
#            'max_ghi': 504,
#            'max_temp': 14.9,
#            'max_temp_ts': 1699387200,
#            'max_uv': 1.4,
#            'max_wind_dir': 197,
#            'max_wind_spd': 4.8,
#            'max_wind_spd_ts': 1699383600,
#            'min_temp': 8.1,
#            'min_temp_ts': 1699311600,
#            'precip': 3.8,
#            'precip_gpm': 3.8,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 85,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 45,
#            't_dhi': 735,
#            't_dni': 6252,
#            't_ghi': 3042,
#            't_solar_rad': 1087,
#            'temp': 11.4,
#            'ts': 1699311600,
#            'wind_dir': 197,
#            'wind_gust_spd': 11.6,
#            'wind_spd': 2.1},
#           {'clouds': 96,
#            'datetime': '2023-11-08',
#            'dewpt': 12.4,
#            'dhi': 30,
#            'dni': 259,
#            'ghi': 125,
#            'max_dhi': 97,
#            'max_dni': 803,
#            'max_ghi': 499,
#            'max_temp': 15,
#            'max_temp_ts': 1699401600,
#            'max_uv': 1,
#            'max_wind_dir': 186,
#            'max_wind_spd': 8.4,
#            'max_wind_spd_ts': 1699419600,
#            'min_temp': 11,
#            'min_temp_ts': 1699480800,
#            'precip': 35.5,
#            'precip_gpm': 35.5,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 14,
#            't_dhi': 729,
#            't_dni': 6206,
#            't_ghi': 3001,
#            't_solar_rad': 337,
#            'temp': 13.1,
#            'ts': 1699398000,
#            'wind_dir': 186,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 3.5},
#           {'clouds': 80,
#            'datetime': '2023-11-09',
#            'dewpt': 11,
#            'dhi': 30,
#            'dni': 257,
#            'ghi': 123,
#            'max_dhi': 96,
#            'max_dni': 801,
#            'max_ghi': 495,
#            'max_temp': 16.5,
#            'max_temp_ts': 1699531200,
#            'max_uv': 1.4,
#            'max_wind_dir': 140,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1699534800,
#            'min_temp': 9.2,
#            'min_temp_ts': 1699513200,
#            'precip': 3.5,
#            'precip_gpm': 3.5,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 56,
#            't_dhi': 724,
#            't_dni': 6161,
#            't_ghi': 2960,
#            't_solar_rad': 1349,
#            'temp': 11.8,
#            'ts': 1699484400,
#            'wind_dir': 140,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 1.2},
#           {'clouds': 98,
#            'datetime': '2023-11-10',
#            'dewpt': 13.3,
#            'dhi': 30,
#            'dni': 255,
#            'ghi': 122,
#            'max_dhi': 96,
#            'max_dni': 799,
#            'max_ghi': 490,
#            'max_temp': 16.6,
#            'max_temp_ts': 1699653600,
#            'max_uv': 1,
#            'max_wind_dir': 184,
#            'max_wind_spd': 4.1,
#            'max_wind_spd_ts': 1699642800,
#            'min_temp': 11.1,
#            'min_temp_ts': 1699570800,
#            'precip': 30.5,
#            'precip_gpm': 30.5,
#            'pres': 1003,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 100,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 17,
#            't_dhi': 718,
#            't_dni': 6116,
#            't_ghi': 2920,
#            't_solar_rad': 407,
#            'temp': 13.3,
#            'ts': 1699570800,
#            'wind_dir': 184,
#            'wind_gust_spd': 15.2,
#            'wind_spd': 1.5},
#           {'clouds': 95,
#            'datetime': '2023-11-11',
#            'dewpt': 16.6,
#            'dhi': 30,
#            'dni': 253,
#            'ghi': 120,
#            'max_dhi': 96,
#            'max_dni': 797,
#            'max_ghi': 485,
#            'max_temp': 17.7,
#            'max_temp_ts': 1699711200,
#            'max_uv': 1.4,
#            'max_wind_dir': 196,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1699736400,
#            'min_temp': 16.2,
#            'min_temp_ts': 1699671600,
#            'precip': 6,
#            'precip_gpm': 6,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 99,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 34,
#            't_dhi': 713,
#            't_dni': 6070,
#            't_ghi': 2881,
#            't_solar_rad': 807,
#            'temp': 16.7,
#            'ts': 1699657200,
#            'wind_dir': 196,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 2.5},
#           {'clouds': 90,
#            'datetime': '2023-11-12',
#            'dewpt': 16.2,
#            'dhi': 29,
#            'dni': 251,
#            'ghi': 118,
#            'max_dhi': 95,
#            'max_dni': 795,
#            'max_ghi': 480,
#            'max_temp': 22.3,
#            'max_temp_ts': 1699790400,
#            'max_uv': 1.4,
#            'max_wind_dir': 175,
#            'max_wind_spd': 4,
#            'max_wind_spd_ts': 1699826400,
#            'min_temp': 15.2,
#            'min_temp_ts': 1699765200,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 45,
#            't_dhi': 707,
#            't_dni': 6025,
#            't_ghi': 2843,
#            't_solar_rad': 1079,
#            'temp': 17.5,
#            'ts': 1699743600,
#            'wind_dir': 175,
#            'wind_gust_spd': 15.2,
#            'wind_spd': 2},
#           {'clouds': 98,
#            'datetime': '2023-11-13',
#            'dewpt': 16.9,
#            'dhi': 29,
#            'dni': 249,
#            'ghi': 117,
#            'max_dhi': 95,
#            'max_dni': 793,
#            'max_ghi': 476,
#            'max_temp': 17.9,
#            'max_temp_ts': 1699833600,
#            'max_uv': 1,
#            'max_wind_dir': 174,
#            'max_wind_spd': 4.6,
#            'max_wind_spd_ts': 1699855200,
#            'min_temp': 16.7,
#            'min_temp_ts': 1699905600,
#            'precip': 6.3,
#            'precip_gpm': 6.3,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 98,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 12,
#            't_dhi': 702,
#            't_dni': 5981,
#            't_ghi': 2805,
#            't_solar_rad': 281,
#            'temp': 17.2,
#            'ts': 1699830000,
#            'wind_dir': 174,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 3.3},
#           {'clouds': 95,
#            'datetime': '2023-11-14',
#            'dewpt': 16.5,
#            'dhi': 29,
#            'dni': 247,
#            'ghi': 115,
#            'max_dhi': 95,
#            'max_dni': 791,
#            'max_ghi': 471,
#            'max_temp': 18.2,
#            'max_temp_ts': 1699959600,
#            'max_uv': 1,
#            'max_wind_dir': 185,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1699941600,
#            'min_temp': 15.2,
#            'min_temp_ts': 1699999200,
#            'precip': 3.3,
#            'precip_gpm': 3.3,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 99,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 14,
#            't_dhi': 697,
#            't_dni': 5936,
#            't_ghi': 2768,
#            't_solar_rad': 346,
#            'temp': 16.6,
#            'ts': 1699916400,
#            'wind_dir': 185,
#            'wind_gust_spd': 15.6,
#            'wind_spd': 2.3}],
#  'lat': 42.431,
#  'lon': -8.64435,
#  'sources': ['080440-99999', 'imerg', 'era5', 'sat', 'radar', 'snodas'],
#  'state_code': '58',
#  'station_id': '080440-99999',
#  'timezone': 'Europe/Madrid'}

# %%
ciudad = data["city_name"]
ciudad

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

pontevedra =  pd.DataFrame(datos)

pontevedra.head()

pontevedra.to_csv("pontevedra_2022-11-15_2023-11-15.csv")

# %%
# Datos Pontevedra 2021/2022
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=42.431&lon=-8.64435&start_date=2021-11-15&end_date=2022-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
data.update(response.json())

# %%
pprint(data)
# Out:
# {'city_id': '3113209',
#  'city_name': 'Pontevedra',
#  'country_code': 'ES',
#  'data': [{'clouds': 21,
#            'datetime': '2021-11-15',
#            'dewpt': 7.8,
#            'dhi': 29,
#            'dni': 246,
#            'ghi': 114,
#            'max_dhi': 94,
#            'max_dni': 789,
#            'max_ghi': 467,
#            'max_temp': 18,
#            'max_temp_ts': 1636981200,
#            'max_uv': 2.2,
#            'max_wind_dir': 146,
#            'max_wind_spd': 3.5,
#            'max_wind_spd_ts': 1636981200,
#            'min_temp': 7.8,
#            'min_temp_ts': 1636948800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 104,
#            't_dhi': 691,
#            't_dni': 5892,
#            't_ghi': 2733,
#            't_solar_rad': 2487,
#            'temp': 12.2,
#            'ts': 1636930800,
#            'wind_dir': 146,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 1.8},
#           {'clouds': 27,
#            'datetime': '2021-11-16',
#            'dewpt': 6.9,
#            'dhi': 29,
#            'dni': 244,
#            'ghi': 112,
#            'max_dhi': 94,
#            'max_dni': 787,
#            'max_ghi': 463,
#            'max_temp': 17.4,
#            'max_temp_ts': 1637067600,
#            'max_uv': 2.6,
#            'max_wind_dir': 157,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1637074800,
#            'min_temp': 8.9,
#            'min_temp_ts': 1637046000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 69,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 88,
#            't_dhi': 686,
#            't_dni': 5848,
#            't_ghi': 2698,
#            't_solar_rad': 2114,
#            'temp': 12.7,
#            'ts': 1637017200,
#            'wind_dir': 157,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 2.2},
#           {'clouds': 19,
#            'datetime': '2021-11-17',
#            'dewpt': 6.3,
#            'dhi': 28,
#            'dni': 242,
#            'ghi': 111,
#            'max_dhi': 94,
#            'max_dni': 785,
#            'max_ghi': 459,
#            'max_temp': 17.3,
#            'max_temp_ts': 1637157600,
#            'max_uv': 3,
#            'max_wind_dir': 146,
#            'max_wind_spd': 3.5,
#            'max_wind_spd_ts': 1637168400,
#            'min_temp': 9.6,
#            'min_temp_ts': 1637132400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 65,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 111,
#            't_dhi': 681,
#            't_dni': 5806,
#            't_ghi': 2663,
#            't_solar_rad': 2663,
#            'temp': 12.8,
#            'ts': 1637103600,
#            'wind_dir': 146,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 2.4},
#           {'clouds': 2,
#            'datetime': '2021-11-18',
#            'dewpt': 4.3,
#            'dhi': 28,
#            'dni': 240,
#            'ghi': 110,
#            'max_dhi': 93,
#            'max_dni': 783,
#            'max_ghi': 454,
#            'max_temp': 17.3,
#            'max_temp_ts': 1637244000,
#            'max_uv': 3,
#            'max_wind_dir': 85,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1637193600,
#            'min_temp': 6.2,
#            'min_temp_ts': 1637215200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 63,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 110,
#            't_dhi': 676,
#            't_dni': 5763,
#            't_ghi': 2630,
#            't_solar_rad': 2630,
#            'temp': 11.4,
#            'ts': 1637190000,
#            'wind_dir': 85,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.8},
#           {'clouds': 4,
#            'datetime': '2021-11-19',
#            'dewpt': 5.6,
#            'dhi': 28,
#            'dni': 238,
#            'ghi': 108,
#            'max_dhi': 93,
#            'max_dni': 781,
#            'max_ghi': 450,
#            'max_temp': 20,
#            'max_temp_ts': 1637330400,
#            'max_uv': 3,
#            'max_wind_dir': 123,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1637359200,
#            'min_temp': 9.5,
#            'min_temp_ts': 1637280000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 59,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 108,
#            't_dhi': 671,
#            't_dni': 5722,
#            't_ghi': 2598,
#            't_solar_rad': 2598,
#            'temp': 13.7,
#            'ts': 1637276400,
#            'wind_dir': 123,
#            'wind_gust_spd': 6.4,
#            'wind_spd': 1.4},
#           {'clouds': 20,
#            'datetime': '2021-11-20',
#            'dewpt': 7.6,
#            'dhi': 28,
#            'dni': 237,
#            'ghi': 107,
#            'max_dhi': 93,
#            'max_dni': 779,
#            'max_ghi': 446,
#            'max_temp': 19.9,
#            'max_temp_ts': 1637413200,
#            'max_uv': 2.8,
#            'max_wind_dir': 127,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1637442000,
#            'min_temp': 10.4,
#            'min_temp_ts': 1637395200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 65,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 107,
#            't_dhi': 666,
#            't_dni': 5682,
#            't_ghi': 2566,
#            't_solar_rad': 2561,
#            'temp': 14.1,
#            'ts': 1637362800,
#            'wind_dir': 127,
#            'wind_gust_spd': 5.6,
#            'wind_spd': 1.4},
#           {'clouds': 39,
#            'datetime': '2021-11-21',
#            'dewpt': 7.6,
#            'dhi': 28,
#            'dni': 235,
#            'ghi': 106,
#            'max_dhi': 92,
#            'max_dni': 777,
#            'max_ghi': 442,
#            'max_temp': 16.9,
#            'max_temp_ts': 1637503200,
#            'max_uv': 2.9,
#            'max_wind_dir': 148,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1637514000,
#            'min_temp': 8,
#            'min_temp_ts': 1637478000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1003,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 99,
#            't_dhi': 661,
#            't_dni': 5642,
#            't_ghi': 2536,
#            't_solar_rad': 2365,
#            'temp': 11.7,
#            'ts': 1637449200,
#            'wind_dir': 148,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1.8},
#           {'clouds': 32,
#            'datetime': '2021-11-22',
#            'dewpt': 4.8,
#            'dhi': 27,
#            'dni': 233,
#            'ghi': 104,
#            'max_dhi': 92,
#            'max_dni': 775,
#            'max_ghi': 439,
#            'max_temp': 11.2,
#            'max_temp_ts': 1637582400,
#            'max_uv': 1.9,
#            'max_wind_dir': 248,
#            'max_wind_spd': 5.1,
#            'max_wind_spd_ts': 1637586000,
#            'min_temp': 6.4,
#            'min_temp_ts': 1637564400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 88,
#            't_dhi': 656,
#            't_dni': 5604,
#            't_ghi': 2506,
#            't_solar_rad': 2120,
#            'temp': 8.8,
#            'ts': 1637535600,
#            'wind_dir': 248,
#            'wind_gust_spd': 16,
#            'wind_spd': 2.3},
#           {'clouds': 38,
#            'datetime': '2021-11-23',
#            'dewpt': 5.5,
#            'dhi': 27,
#            'dni': 232,
#            'ghi': 103,
#            'max_dhi': 92,
#            'max_dni': 774,
#            'max_ghi': 435,
#            'max_temp': 14,
#            'max_temp_ts': 1637672400,
#            'max_uv': 1.9,
#            'max_wind_dir': 266,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1637686800,
#            'min_temp': 6.5,
#            'min_temp_ts': 1637625600,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 72,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 75,
#            't_dhi': 651,
#            't_dni': 5566,
#            't_ghi': 2478,
#            't_solar_rad': 1811,
#            'temp': 10.4,
#            'ts': 1637622000,
#            'wind_dir': 266,
#            'wind_gust_spd': 16,
#            'wind_spd': 2.7},
#           {'clouds': 53,
#            'datetime': '2021-11-24',
#            'dewpt': 5.8,
#            'dhi': 27,
#            'dni': 230,
#            'ghi': 102,
#            'max_dhi': 91,
#            'max_dni': 772,
#            'max_ghi': 431,
#            'max_temp': 11.8,
#            'max_temp_ts': 1637766000,
#            'max_uv': 2.1,
#            'max_wind_dir': 260,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1637762400,
#            'min_temp': 7.9,
#            'min_temp_ts': 1637733600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 78,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 79,
#            't_dhi': 646,
#            't_dni': 5530,
#            't_ghi': 2450,
#            't_solar_rad': 1893,
#            'temp': 9.6,
#            'ts': 1637708400,
#            'wind_dir': 260,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 2.1},
#           {'clouds': 41,
#            'datetime': '2021-11-25',
#            'dewpt': 6.1,
#            'dhi': 27,
#            'dni': 229,
#            'ghi': 101,
#            'max_dhi': 91,
#            'max_dni': 770,
#            'max_ghi': 428,
#            'max_temp': 12.9,
#            'max_temp_ts': 1637848800,
#            'max_uv': 2,
#            'max_wind_dir': 172,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1637848800,
#            'min_temp': 6.6,
#            'min_temp_ts': 1637812800,
#            'precip': 16,
#            'precip_gpm': 16,
#            'pres': 1000,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 642,
#            't_dni': 5495,
#            't_ghi': 2423,
#            't_solar_rad': 1977,
#            'temp': 9,
#            'ts': 1637794800,
#            'wind_dir': 172,
#            'wind_gust_spd': 12,
#            'wind_spd': 1.5},
#           {'clouds': 48,
#            'datetime': '2021-11-26',
#            'dewpt': 5.5,
#            'dhi': 27,
#            'dni': 228,
#            'ghi': 100,
#            'max_dhi': 91,
#            'max_dni': 768,
#            'max_ghi': 425,
#            'max_temp': 12.3,
#            'max_temp_ts': 1637931600,
#            'max_uv': 1.7,
#            'max_wind_dir': 230,
#            'max_wind_spd': 4,
#            'max_wind_spd_ts': 1637928000,
#            'min_temp': 6,
#            'min_temp_ts': 1637913600,
#            'precip': 2,
#            'precip_gpm': 2,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 63,
#            't_dhi': 637,
#            't_dni': 5461,
#            't_ghi': 2397,
#            't_solar_rad': 1512,
#            'temp': 9.1,
#            'ts': 1637881200,
#            'wind_dir': 230,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 1.9},
#           {'clouds': 55,
#            'datetime': '2021-11-27',
#            'dewpt': 5.6,
#            'dhi': 26,
#            'dni': 226,
#            'ghi': 99,
#            'max_dhi': 91,
#            'max_dni': 767,
#            'max_ghi': 421,
#            'max_temp': 10.1,
#            'max_temp_ts': 1638025200,
#            'max_uv': 2.1,
#            'max_wind_dir': 254,
#            'max_wind_spd': 5.1,
#            'max_wind_spd_ts': 1637996400,
#            'min_temp': 4.9,
#            'min_temp_ts': 1638050400,
#            'precip': 2.8,
#            'precip_gpm': 2.8,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 94,
#            't_dhi': 633,
#            't_dni': 5428,
#            't_ghi': 2373,
#            't_solar_rad': 2253,
#            'temp': 8.3,
#            'ts': 1637967600,
#            'wind_dir': 254,
#            'wind_gust_spd': 16,
#            'wind_spd': 2.6},
#           {'clouds': 76,
#            'datetime': '2021-11-28',
#            'dewpt': 5.5,
#            'dhi': 26,
#            'dni': 225,
#            'ghi': 98,
#            'max_dhi': 90,
#            'max_dni': 765,
#            'max_ghi': 418,
#            'max_temp': 9.9,
#            'max_temp_ts': 1638133200,
#            'max_uv': 0.9,
#            'max_wind_dir': 161,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1638079200,
#            'min_temp': 2.1,
#            'min_temp_ts': 1638075600,
#            'precip': 7.5,
#            'precip_gpm': 7.5,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 21,
#            't_dhi': 629,
#            't_dni': 5397,
#            't_ghi': 2349,
#            't_solar_rad': 507,
#            'temp': 6.1,
#            'ts': 1638054000,
#            'wind_dir': 161,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 1},
#           {'clouds': 74,
#            'datetime': '2021-11-29',
#            'dewpt': 9.6,
#            'dhi': 26,
#            'dni': 224,
#            'ghi': 97,
#            'max_dhi': 90,
#            'max_dni': 764,
#            'max_ghi': 415,
#            'max_temp': 12.8,
#            'max_temp_ts': 1638187200,
#            'max_uv': 1.3,
#            'max_wind_dir': 165,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1638223200,
#            'min_temp': 7.9,
#            'min_temp_ts': 1638223200,
#            'precip': 7.3,
#            'precip_gpm': 7.3,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 51,
#            't_dhi': 624,
#            't_dni': 5366,
#            't_ghi': 2326,
#            't_solar_rad': 1236,
#            'temp': 10.3,
#            'ts': 1638140400,
#            'wind_dir': 165,
#            'wind_gust_spd': 8,
#            'wind_spd': 1},
#           {'clouds': 52,
#            'datetime': '2021-11-30',
#            'dewpt': 8,
#            'dhi': 26,
#            'dni': 222,
#            'ghi': 96,
#            'max_dhi': 90,
#            'max_dni': 762,
#            'max_ghi': 412,
#            'max_temp': 14.4,
#            'max_temp_ts': 1638277200,
#            'max_uv': 1.4,
#            'max_wind_dir': 133,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1638226800,
#            'min_temp': 7,
#            'min_temp_ts': 1638255600,
#            'precip': 1.5,
#            'precip_gpm': 1.5,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 73,
#            't_dhi': 620,
#            't_dni': 5336,
#            't_ghi': 2304,
#            't_solar_rad': 1753,
#            'temp': 10,
#            'ts': 1638226800,
#            'wind_dir': 133,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.5},
#           {'clouds': 86,
#            'datetime': '2021-12-01',
#            'dewpt': 9.4,
#            'dhi': 26,
#            'dni': 221,
#            'ghi': 95,
#            'max_dhi': 90,
#            'max_dni': 761,
#            'max_ghi': 409,
#            'max_temp': 12.6,
#            'max_temp_ts': 1638360000,
#            'max_uv': 0.8,
#            'max_wind_dir': 179,
#            'max_wind_spd': 2,
#            'max_wind_spd_ts': 1638370800,
#            'min_temp': 8.9,
#            'min_temp_ts': 1638396000,
#            'precip': 4.3,
#            'precip_gpm': 4.3,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 93,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 27,
#            't_dhi': 617,
#            't_dni': 5307,
#            't_ghi': 2283,
#            't_solar_rad': 659,
#            'temp': 10.5,
#            'ts': 1638313200,
#            'wind_dir': 179,
#            'wind_gust_spd': 11.2,
#            'wind_spd': 1},
#           {'clouds': 45,
#            'datetime': '2021-12-02',
#            'dewpt': 6.1,
#            'dhi': 26,
#            'dni': 220,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 759,
#            'max_ghi': 407,
#            'max_temp': 11.6,
#            'max_temp_ts': 1638450000,
#            'max_uv': 1.4,
#            'max_wind_dir': 162,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1638457200,
#            'min_temp': 5.4,
#            'min_temp_ts': 1638482400,
#            'precip': 1.3,
#            'precip_gpm': 1.3,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 613,
#            't_dni': 5279,
#            't_ghi': 2264,
#            't_solar_rad': 2076,
#            'temp': 8.3,
#            'ts': 1638399600,
#            'wind_dir': 162,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 1.5},
#           {'clouds': 88,
#            'datetime': '2021-12-03',
#            'dewpt': 8.2,
#            'dhi': 25,
#            'dni': 219,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 758,
#            'max_ghi': 404,
#            'max_temp': 11.9,
#            'max_temp_ts': 1638568800,
#            'max_uv': 0.7,
#            'max_wind_dir': 155,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1638554400,
#            'min_temp': 5.2,
#            'min_temp_ts': 1638486000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1012,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 18,
#            't_dhi': 609,
#            't_dni': 5253,
#            't_ghi': 2245,
#            't_solar_rad': 423,
#            'temp': 8.7,
#            'ts': 1638486000,
#            'wind_dir': 155,
#            'wind_gust_spd': 10,
#            'wind_spd': 1.2},
#           {'clouds': 75,
#            'datetime': '2021-12-04',
#            'dewpt': 10.8,
#            'dhi': 25,
#            'dni': 218,
#            'ghi': 93,
#            'max_dhi': 89,
#            'max_dni': 756,
#            'max_ghi': 402,
#            'max_temp': 14.6,
#            'max_temp_ts': 1638622800,
#            'max_uv': 1.3,
#            'max_wind_dir': 220,
#            'max_wind_spd': 4.9,
#            'max_wind_spd_ts': 1638594000,
#            'min_temp': 8.9,
#            'min_temp_ts': 1638655200,
#            'precip': 9.8,
#            'precip_gpm': 9.8,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 75,
#            't_dhi': 606,
#            't_dni': 5227,
#            't_ghi': 2227,
#            't_solar_rad': 1790,
#            'temp': 12.5,
#            'ts': 1638572400,
#            'wind_dir': 220,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 2.3},
#           {'clouds': 71,
#            'datetime': '2021-12-05',
#            'dewpt': 8.2,
#            'dhi': 25,
#            'dni': 217,
#            'ghi': 92,
#            'max_dhi': 89,
#            'max_dni': 755,
#            'max_ghi': 399,
#            'max_temp': 12.1,
#            'max_temp_ts': 1638709200,
#            'max_uv': 1,
#            'max_wind_dir': 117,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1638673200,
#            'min_temp': 7.8,
#            'min_temp_ts': 1638673200,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 54,
#            't_dhi': 603,
#            't_dni': 5202,
#            't_ghi': 2210,
#            't_solar_rad': 1285,
#            'temp': 9.7,
#            'ts': 1638658800,
#            'wind_dir': 117,
#            'wind_gust_spd': 11.6,
#            'wind_spd': 1.3},
#           {'clouds': 94,
#            'datetime': '2021-12-06',
#            'dewpt': 10.4,
#            'dhi': 25,
#            'dni': 216,
#            'ghi': 91,
#            'max_dhi': 89,
#            'max_dni': 754,
#            'max_ghi': 397,
#            'max_temp': 12.3,
#            'max_temp_ts': 1638806400,
#            'max_uv': 0.7,
#            'max_wind_dir': 169,
#            'max_wind_spd': 1.3,
#            'max_wind_spd_ts': 1638766800,
#            'min_temp': 9.2,
#            'min_temp_ts': 1638759600,
#            'precip': 10.5,
#            'precip_gpm': 10.5,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 97,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 9,
#            't_dhi': 600,
#            't_dni': 5178,
#            't_ghi': 2194,
#            't_solar_rad': 219,
#            'temp': 10.8,
#            'ts': 1638745200,
#            'wind_dir': 169,
#            'wind_gust_spd': 10,
#            'wind_spd': 0.8},
#           {'clouds': 88,
#            'datetime': '2021-12-07',
#            'dewpt': 11.5,
#            'dhi': 25,
#            'dni': 215,
#            'ghi': 91,
#            'max_dhi': 88,
#            'max_dni': 753,
#            'max_ghi': 395,
#            'max_temp': 14.6,
#            'max_temp_ts': 1638853200,
#            'max_uv': 0.9,
#            'max_wind_dir': 218,
#            'max_wind_spd': 4.9,
#            'max_wind_spd_ts': 1638860400,
#            'min_temp': 8,
#            'min_temp_ts': 1638914400,
#            'precip': 33.3,
#            'precip_gpm': 33.3,
#            'pres': 1002,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 24,
#            't_dhi': 597,
#            't_dni': 5156,
#            't_ghi': 2180,
#            't_solar_rad': 569,
#            'temp': 12.3,
#            'ts': 1638831600,
#            'wind_dir': 218,
#            'wind_gust_spd': 20.4,
#            'wind_spd': 3.2},
#           {'clouds': 67,
#            'datetime': '2021-12-08',
#            'dewpt': 6.5,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 393,
#            'max_temp': 10.8,
#            'max_temp_ts': 1638975600,
#            'max_uv': 0.8,
#            'max_wind_dir': 241,
#            'max_wind_spd': 4.7,
#            'max_wind_spd_ts': 1638975600,
#            'min_temp': 6.7,
#            'min_temp_ts': 1638946800,
#            'precip': 9.8,
#            'precip_gpm': 9.8,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 31,
#            't_dhi': 595,
#            't_dni': 5136,
#            't_ghi': 2166,
#            't_solar_rad': 744,
#            'temp': 8.3,
#            'ts': 1638918000,
#            'wind_dir': 241,
#            'wind_gust_spd': 19.2,
#            'wind_spd': 2.5},
#           {'clouds': 92,
#            'datetime': '2021-12-09',
#            'dewpt': 10.7,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 391,
#            'max_temp': 12.9,
#            'max_temp_ts': 1639058400,
#            'max_uv': 0.7,
#            'max_wind_dir': 210,
#            'max_wind_spd': 3.5,
#            'max_wind_spd_ts': 1639087200,
#            'min_temp': 8,
#            'min_temp_ts': 1639004400,
#            'precip': 1.8,
#            'precip_gpm': 1.8,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 96,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 592,
#            't_dni': 5117,
#            't_ghi': 2153,
#            't_solar_rad': 518,
#            'temp': 11.3,
#            'ts': 1639004400,
#            'wind_dir': 210,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 1.8},
#           {'clouds': 77,
#            'datetime': '2021-12-10',
#            'dewpt': 11.5,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 390,
#            'max_temp': 14.4,
#            'max_temp_ts': 1639134000,
#            'max_uv': 0.8,
#            'max_wind_dir': 232,
#            'max_wind_spd': 4.8,
#            'max_wind_spd_ts': 1639119600,
#            'min_temp': 10.7,
#            'min_temp_ts': 1639170000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 29,
#            't_dhi': 590,
#            't_dni': 5100,
#            't_ghi': 2142,
#            't_solar_rad': 693,
#            'temp': 12.8,
#            'ts': 1639090800,
#            'wind_dir': 232,
#            'wind_gust_spd': 12.4,
#            'wind_spd': 2.7},
#           {'clouds': 89,
#            'datetime': '2021-12-11',
#            'dewpt': 11.2,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 388,
#            'max_temp': 14.9,
#            'max_temp_ts': 1639231200,
#            'max_uv': 1.1,
#            'max_wind_dir': 161,
#            'max_wind_spd': 1.2,
#            'max_wind_spd_ts': 1639227600,
#            'min_temp': 9.7,
#            'min_temp_ts': 1639260000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1013,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 95,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 54,
#            't_dhi': 587,
#            't_dni': 5085,
#            't_ghi': 2131,
#            't_solar_rad': 1291,
#            'temp': 12,
#            'ts': 1639177200,
#            'wind_dir': 161,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 0.7},
#           {'clouds': 47,
#            'datetime': '2021-12-12',
#            'dewpt': 8.2,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 386,
#            'max_temp': 14.4,
#            'max_temp_ts': 1639317600,
#            'max_uv': 1.5,
#            'max_wind_dir': 122,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1639285200,
#            'min_temp': 6.7,
#            'min_temp_ts': 1639296000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 63,
#            't_dhi': 585,
#            't_dni': 5072,
#            't_ghi': 2122,
#            't_solar_rad': 1518,
#            'temp': 9.9,
#            'ts': 1639263600,
#            'wind_dir': 122,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 1.1},
#           {'clouds': 6,
#            'datetime': '2021-12-13',
#            'dewpt': 9.3,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 385,
#            'max_temp': 17.4,
#            'max_temp_ts': 1639400400,
#            'max_uv': 2,
#            'max_wind_dir': 111,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1639429200,
#            'min_temp': 8.3,
#            'min_temp_ts': 1639378800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 88,
#            't_dhi': 583,
#            't_dni': 5061,
#            't_ghi': 2113,
#            't_solar_rad': 2113,
#            'temp': 11.7,
#            'ts': 1639350000,
#            'wind_dir': 111,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.4},
#           {'clouds': 2,
#            'datetime': '2021-12-14',
#            'dewpt': 8,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 88,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 384,
#            'max_temp': 17.2,
#            'max_temp_ts': 1639490400,
#            'max_uv': 2.1,
#            'max_wind_dir': 129,
#            'max_wind_spd': 3.4,
#            'max_wind_spd_ts': 1639443600,
#            'min_temp': 7.6,
#            'min_temp_ts': 1639468800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 88,
#            't_dhi': 581,
#            't_dni': 5053,
#            't_ghi': 2106,
#            't_solar_rad': 2106,
#            'temp': 11.3,
#            'ts': 1639436400,
#            'wind_dir': 129,
#            'wind_gust_spd': 6.4,
#            'wind_spd': 1.7},
#           {'clouds': 12,
#            'datetime': '2021-12-15',
#            'dewpt': 5.7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 383,
#            'max_temp': 16.3,
#            'max_temp_ts': 1639576800,
#            'max_uv': 2.1,
#            'max_wind_dir': 136,
#            'max_wind_spd': 2.9,
#            'max_wind_spd_ts': 1639602000,
#            'min_temp': 6.2,
#            'min_temp_ts': 1639548000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 74,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 580,
#            't_dni': 5046,
#            't_ghi': 2100,
#            't_solar_rad': 2099,
#            'temp': 10.2,
#            'ts': 1639522800,
#            'wind_dir': 136,
#            'wind_gust_spd': 5.6,
#            'wind_spd': 1.3},
#           {'clouds': 13,
#            'datetime': '2021-12-16',
#            'dewpt': 4.8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 16.1,
#            'max_temp_ts': 1639663200,
#            'max_uv': 2.1,
#            'max_wind_dir': 150,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1639612800,
#            'min_temp': 7.1,
#            'min_temp_ts': 1639627200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 69,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 579,
#            't_dni': 5041,
#            't_ghi': 2095,
#            't_solar_rad': 2093,
#            'temp': 10.3,
#            'ts': 1639609200,
#            'wind_dir': 150,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 0.9},
#           {'clouds': 6,
#            'datetime': '2021-12-17',
#            'dewpt': 3.7,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 15.2,
#            'max_temp_ts': 1639749600,
#            'max_uv': 2.1,
#            'max_wind_dir': 132,
#            'max_wind_spd': 2.5,
#            'max_wind_spd_ts': 1639695600,
#            'min_temp': 5.3,
#            'min_temp_ts': 1639728000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 67,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 578,
#            't_dni': 5038,
#            't_ghi': 2091,
#            't_solar_rad': 2090,
#            'temp': 9.6,
#            'ts': 1639695600,
#            'wind_dir': 132,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 1.5},
#           {'clouds': 20,
#            'datetime': '2021-12-18',
#            'dewpt': 3.8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 14.6,
#            'max_temp_ts': 1639836000,
#            'max_uv': 1.5,
#            'max_wind_dir': 122,
#            'max_wind_spd': 2.8,
#            'max_wind_spd_ts': 1639810800,
#            'min_temp': 5.3,
#            'min_temp_ts': 1639789200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 71,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 579,
#            't_dni': 5035,
#            't_ghi': 2088,
#            't_solar_rad': 1978,
#            'temp': 8.8,
#            'ts': 1639782000,
#            'wind_dir': 122,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 1.3},
#           {'clouds': 32,
#            'datetime': '2021-12-19',
#            'dewpt': 4.4,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 15.4,
#            'max_temp_ts': 1639922400,
#            'max_uv': 2.1,
#            'max_wind_dir': 129,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1639947600,
#            'min_temp': 5.7,
#            'min_temp_ts': 1639900800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 68,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 70,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2085,
#            't_solar_rad': 1669,
#            'temp': 10,
#            'ts': 1639868400,
#            'wind_dir': 129,
#            'wind_gust_spd': 6,
#            'wind_spd': 1},
#           {'clouds': 79,
#            'datetime': '2021-12-20',
#            'dewpt': 7.8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 15.9,
#            'max_temp_ts': 1640005200,
#            'max_uv': 0.7,
#            'max_wind_dir': 111,
#            'max_wind_spd': 2.1,
#            'max_wind_spd_ts': 1640023200,
#            'min_temp': 10.8,
#            'min_temp_ts': 1639969200,
#            'precip': 24,
#            'precip_gpm': 24,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 69,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 579,
#            't_dni': 5034,
#            't_ghi': 2084,
#            't_solar_rad': 536,
#            'temp': 13.5,
#            'ts': 1639954800,
#            'wind_dir': 111,
#            'wind_gust_spd': 10,
#            'wind_spd': 1.6},
#           {'clouds': 55,
#            'datetime': '2021-12-21',
#            'dewpt': 11.6,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 19.9,
#            'max_temp_ts': 1640091600,
#            'max_uv': 0.6,
#            'max_wind_dir': 116,
#            'max_wind_spd': 4.5,
#            'max_wind_spd_ts': 1640095200,
#            'min_temp': 12.1,
#            'min_temp_ts': 1640055600,
#            'precip': 18.3,
#            'precip_gpm': 18.3,
#            'pres': 999,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 78,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 21,
#            't_dhi': 580,
#            't_dni': 5035,
#            't_ghi': 2084,
#            't_solar_rad': 510,
#            'temp': 15.7,
#            'ts': 1640041200,
#            'wind_dir': 116,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 2.5},
#           {'clouds': 77,
#            'datetime': '2021-12-22',
#            'dewpt': 10.4,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 746,
#            'max_ghi': 382,
#            'max_temp': 17.7,
#            'max_temp_ts': 1640127600,
#            'max_uv': 1.1,
#            'max_wind_dir': 163,
#            'max_wind_spd': 3.8,
#            'max_wind_spd_ts': 1640210400,
#            'min_temp': 13.7,
#            'min_temp_ts': 1640160000,
#            'precip': 1.3,
#            'precip_gpm': 1.3,
#            'pres': 999,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 72,
#            'slp': 1012,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 57,
#            't_dhi': 581,
#            't_dni': 5038,
#            't_ghi': 2085,
#            't_solar_rad': 1377,
#            'temp': 15.5,
#            'ts': 1640127600,
#            'wind_dir': 163,
#            'wind_gust_spd': 15.6,
#            'wind_spd': 2.5},
#           {'clouds': 72,
#            'datetime': '2021-12-23',
#            'dewpt': 11.8,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 16.5,
#            'max_temp_ts': 1640264400,
#            'max_uv': 1.5,
#            'max_wind_dir': 173,
#            'max_wind_spd': 4.9,
#            'max_wind_spd_ts': 1640296800,
#            'min_temp': 12.9,
#            'min_temp_ts': 1640293200,
#            'precip': 43,
#            'precip_gpm': 43,
#            'pres': 998,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1011,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 73,
#            't_dhi': 582,
#            't_dni': 5043,
#            't_ghi': 2087,
#            't_solar_rad': 1743,
#            'temp': 14,
#            'ts': 1640214000,
#            'wind_dir': 173,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 2.4},
#           {'clouds': 96,
#            'datetime': '2021-12-24',
#            'dewpt': 11,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 747,
#            'max_ghi': 383,
#            'max_temp': 13.8,
#            'max_temp_ts': 1640325600,
#            'max_uv': 0.7,
#            'max_wind_dir': 165,
#            'max_wind_spd': 4.7,
#            'max_wind_spd_ts': 1640311200,
#            'min_temp': 11.4,
#            'min_temp_ts': 1640343600,
#            'precip': 54.5,
#            'precip_gpm': 54.5,
#            'pres': 992,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1005,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 11,
#            't_dhi': 583,
#            't_dni': 5050,
#            't_ghi': 2091,
#            't_solar_rad': 257,
#            'temp': 12.6,
#            'ts': 1640300400,
#            'wind_dir': 165,
#            'wind_gust_spd': 19.2,
#            'wind_spd': 3.5},
#           {'clouds': 99,
#            'datetime': '2021-12-25',
#            'dewpt': 11.5,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 748,
#            'max_ghi': 384,
#            'max_temp': 15.6,
#            'max_temp_ts': 1640433600,
#            'max_uv': 0.7,
#            'max_wind_dir': 153,
#            'max_wind_spd': 2.6,
#            'max_wind_spd_ts': 1640386800,
#            'min_temp': 11.8,
#            'min_temp_ts': 1640412000,
#            'precip': 5.3,
#            'precip_gpm': 5.3,
#            'pres': 990,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1003,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 22,
#            't_dhi': 584,
#            't_dni': 5058,
#            't_ghi': 2095,
#            't_solar_rad': 521,
#            'temp': 13,
#            'ts': 1640386800,
#            'wind_dir': 153,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 1.5},
#           {'clouds': 100,
#            'datetime': '2021-12-26',
#            'dewpt': 13.2,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 87,
#            'max_dhi': 88,
#            'max_dni': 748,
#            'max_ghi': 385,
#            'max_temp': 15.9,
#            'max_temp_ts': 1640527200,
#            'max_uv': 0.7,
#            'max_wind_dir': 167,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1640527200,
#            'min_temp': 12,
#            'min_temp_ts': 1640502000,
#            'precip': 24.8,
#            'precip_gpm': 24.8,
#            'pres': 993,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 97,
#            'slp': 1006,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 9,
#            't_dhi': 586,
#            't_dni': 5068,
#            't_ghi': 2100,
#            't_solar_rad': 210,
#            'temp': 13.7,
#            'ts': 1640473200,
#            'wind_dir': 167,
#            'wind_gust_spd': 19.2,
#            'wind_spd': 2.4},
#           {'clouds': 78,
#            'datetime': '2021-12-27',
#            'dewpt': 12.9,
#            'dhi': 24,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 386,
#            'max_temp': 15.5,
#            'max_temp_ts': 1640610000,
#            'max_uv': 0.7,
#            'max_wind_dir': 192,
#            'max_wind_spd': 5.9,
#            'max_wind_spd_ts': 1640559600,
#            'min_temp': 13.8,
#            'min_temp_ts': 1640592000,
#            'precip': 8.5,
#            'precip_gpm': 8.5,
#            'pres': 998,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1010,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 20,
#            't_dhi': 588,
#            't_dni': 5080,
#            't_ghi': 2106,
#            't_solar_rad': 470,
#            'temp': 14.8,
#            'ts': 1640559600,
#            'wind_dir': 192,
#            'wind_gust_spd': 18,
#            'wind_spd': 4.2},
#           {'clouds': 96,
#            'datetime': '2021-12-28',
#            'dewpt': 14.1,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 387,
#            'max_temp': 17.2,
#            'max_temp_ts': 1640696400,
#            'max_uv': 1.3,
#            'max_wind_dir': 177,
#            'max_wind_spd': 4.5,
#            'max_wind_spd_ts': 1640700000,
#            'min_temp': 14.6,
#            'min_temp_ts': 1640649600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 48,
#            't_dhi': 589,
#            't_dni': 5094,
#            't_ghi': 2113,
#            't_solar_rad': 1151,
#            'temp': 15.5,
#            'ts': 1640646000,
#            'wind_dir': 177,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 2.9},
#           {'clouds': 92,
#            'datetime': '2021-12-29',
#            'dewpt': 14.2,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 388,
#            'max_temp': 15.9,
#            'max_temp_ts': 1640775600,
#            'max_uv': 0.7,
#            'max_wind_dir': 167,
#            'max_wind_spd': 3.3,
#            'max_wind_spd_ts': 1640743200,
#            'min_temp': 14,
#            'min_temp_ts': 1640815200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 23,
#            't_dhi': 591,
#            't_dni': 5109,
#            't_ghi': 2122,
#            't_solar_rad': 540,
#            'temp': 15.2,
#            'ts': 1640732400,
#            'wind_dir': 167,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 2.3},
#           {'clouds': 27,
#            'datetime': '2021-12-30',
#            'dewpt': 11.6,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 751,
#            'max_ghi': 390,
#            'max_temp': 15.6,
#            'max_temp_ts': 1640876400,
#            'max_uv': 2,
#            'max_wind_dir': 159,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1640869200,
#            'min_temp': 11.2,
#            'min_temp_ts': 1640898000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 88,
#            't_dhi': 593,
#            't_dni': 5125,
#            't_ghi': 2131,
#            't_solar_rad': 2105,
#            'temp': 13.2,
#            'ts': 1640818800,
#            'wind_dir': 159,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 1.5},
#           {'clouds': 32,
#            'datetime': '2021-12-31',
#            'dewpt': 9,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 391,
#            'max_temp': 21.4,
#            'max_temp_ts': 1640959200,
#            'max_uv': 1.4,
#            'max_wind_dir': 149,
#            'max_wind_spd': 5.8,
#            'max_wind_spd_ts': 1640984400,
#            'min_temp': 10.4,
#            'min_temp_ts': 1640937600,
#            'precip': 0,
#            'precip_gpm': 0,
# ...
#            'snow_depth': 0,
#            'solar_rad': 80,
#            't_dhi': 779,
#            't_dni': 6607,
#            't_ghi': 3396,
#            't_solar_rad': 2001,
#            'temp': 14.8,
#            'ts': 1667080800,
#            'wind_dir': 148,
#            'wind_gust_spd': 8.8,
#            'wind_spd': 1.1},
#           {'clouds': 79,
#            'datetime': '2022-10-31',
#            'dewpt': 13,
#            'dhi': 32,
#            'dni': 273,
#            'ghi': 140,
#            'max_dhi': 100,
#            'max_dni': 819,
#            'max_ghi': 540,
#            'max_temp': 17.7,
#            'max_temp_ts': 1667224800,
#            'max_uv': 2.8,
#            'max_wind_dir': 192,
#            'max_wind_spd': 4.6,
#            'max_wind_spd_ts': 1667199600,
#            'min_temp': 11.2,
#            'min_temp_ts': 1667253600,
#            'precip': 28.3,
#            'precip_gpm': 28.3,
#            'pres': 1000,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 112,
#            't_dhi': 773,
#            't_dni': 6564,
#            't_ghi': 3350,
#            't_solar_rad': 2682,
#            'temp': 15,
#            'ts': 1667170800,
#            'wind_dir': 192,
#            'wind_gust_spd': 22.8,
#            'wind_spd': 2.4},
#           {'clouds': 70,
#            'datetime': '2022-11-01',
#            'dewpt': 10.6,
#            'dhi': 32,
#            'dni': 272,
#            'ghi': 138,
#            'max_dhi': 99,
#            'max_dni': 817,
#            'max_ghi': 535,
#            'max_temp': 17.5,
#            'max_temp_ts': 1667307600,
#            'max_uv': 2.2,
#            'max_wind_dir': 114,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1667271600,
#            'min_temp': 8.8,
#            'min_temp_ts': 1667282400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 117,
#            't_dhi': 768,
#            't_dni': 6520,
#            't_ghi': 3304,
#            't_solar_rad': 2808,
#            'temp': 12.5,
#            'ts': 1667257200,
#            'wind_dir': 114,
#            'wind_gust_spd': 8.8,
#            'wind_spd': 1.4},
#           {'clouds': 83,
#            'datetime': '2022-11-02',
#            'dewpt': 10.9,
#            'dhi': 32,
#            'dni': 270,
#            'ghi': 136,
#            'max_dhi': 99,
#            'max_dni': 815,
#            'max_ghi': 530,
#            'max_temp': 16.5,
#            'max_temp_ts': 1667397600,
#            'max_uv': 1.1,
#            'max_wind_dir': 130,
#            'max_wind_spd': 3.5,
#            'max_wind_spd_ts': 1667426400,
#            'min_temp': 10.2,
#            'min_temp_ts': 1667372400,
#            'precip': 2,
#            'precip_gpm': 2,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 28,
#            't_dhi': 762,
#            't_dni': 6476,
#            't_ghi': 3259,
#            't_solar_rad': 681,
#            'temp': 13,
#            'ts': 1667343600,
#            'wind_dir': 130,
#            'wind_gust_spd': 12,
#            'wind_spd': 1.7},
#           {'clouds': 78,
#            'datetime': '2022-11-03',
#            'dewpt': 11.1,
#            'dhi': 32,
#            'dni': 268,
#            'ghi': 134,
#            'max_dhi': 99,
#            'max_dni': 813,
#            'max_ghi': 524,
#            'max_temp': 17.3,
#            'max_temp_ts': 1667480400,
#            'max_uv': 2.8,
#            'max_wind_dir': 211,
#            'max_wind_spd': 4,
#            'max_wind_spd_ts': 1667476800,
#            'min_temp': 9,
#            'min_temp_ts': 1667512800,
#            'precip': 14.8,
#            'precip_gpm': 14.8,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 124,
#            't_dhi': 757,
#            't_dni': 6432,
#            't_ghi': 3214,
#            't_solar_rad': 2987,
#            'temp': 13.9,
#            'ts': 1667430000,
#            'wind_dir': 211,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 2.5},
#           {'clouds': 53,
#            'datetime': '2022-11-04',
#            'dewpt': 8.1,
#            'dhi': 31,
#            'dni': 266,
#            'ghi': 132,
#            'max_dhi': 98,
#            'max_dni': 811,
#            'max_ghi': 519,
#            'max_temp': 16.7,
#            'max_temp_ts': 1667574000,
#            'max_uv': 1.1,
#            'max_wind_dir': 109,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1667595600,
#            'min_temp': 8.1,
#            'min_temp_ts': 1667545200,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 45,
#            't_dhi': 751,
#            't_dni': 6387,
#            't_ghi': 3170,
#            't_solar_rad': 1085,
#            'temp': 11.5,
#            'ts': 1667516400,
#            'wind_dir': 109,
#            'wind_gust_spd': 6.4,
#            'wind_spd': 1.6},
#           {'clouds': 34,
#            'datetime': '2022-11-05',
#            'dewpt': 8.5,
#            'dhi': 31,
#            'dni': 264,
#            'ghi': 130,
#            'max_dhi': 98,
#            'max_dni': 809,
#            'max_ghi': 514,
#            'max_temp': 16.9,
#            'max_temp_ts': 1667653200,
#            'max_uv': 2.7,
#            'max_wind_dir': 135,
#            'max_wind_spd': 3.9,
#            'max_wind_spd_ts': 1667617200,
#            'min_temp': 6.2,
#            'min_temp_ts': 1667631600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 125,
#            't_dhi': 746,
#            't_dni': 6342,
#            't_ghi': 3127,
#            't_solar_rad': 2998,
#            'temp': 11.3,
#            'ts': 1667602800,
#            'wind_dir': 135,
#            'wind_gust_spd': 7.6,
#            'wind_spd': 2},
#           {'clouds': 64,
#            'datetime': '2022-11-06',
#            'dewpt': 12.7,
#            'dhi': 31,
#            'dni': 262,
#            'ghi': 128,
#            'max_dhi': 97,
#            'max_dni': 807,
#            'max_ghi': 509,
#            'max_temp': 17.3,
#            'max_temp_ts': 1667761200,
#            'max_uv': 2.2,
#            'max_wind_dir': 191,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1667761200,
#            'min_temp': 12.6,
#            'min_temp_ts': 1667710800,
#            'precip': 5.8,
#            'precip_gpm': 5.8,
#            'pres': 1005,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 116,
#            't_dhi': 740,
#            't_dni': 6297,
#            't_ghi': 3084,
#            't_solar_rad': 2794,
#            'temp': 14.7,
#            'ts': 1667689200,
#            'wind_dir': 191,
#            'wind_gust_spd': 12,
#            'wind_spd': 2.2},
#           {'clouds': 83,
#            'datetime': '2022-11-07',
#            'dewpt': 12.4,
#            'dhi': 31,
#            'dni': 260,
#            'ghi': 127,
#            'max_dhi': 97,
#            'max_dni': 805,
#            'max_ghi': 504,
#            'max_temp': 17.2,
#            'max_temp_ts': 1667797200,
#            'max_uv': 1.9,
#            'max_wind_dir': 174,
#            'max_wind_spd': 5.6,
#            'max_wind_spd_ts': 1667797200,
#            'min_temp': 14.1,
#            'min_temp_ts': 1667804400,
#            'precip': 0.5,
#            'precip_gpm': 0.5,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 82,
#            'slp': 1013,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 99,
#            't_dhi': 735,
#            't_dni': 6252,
#            't_ghi': 3042,
#            't_solar_rad': 2386,
#            'temp': 15.5,
#            'ts': 1667775600,
#            'wind_dir': 174,
#            'wind_gust_spd': 20.8,
#            'wind_spd': 4.2},
#           {'clouds': 91,
#            'datetime': '2022-11-08',
#            'dewpt': 13.2,
#            'dhi': 30,
#            'dni': 259,
#            'ghi': 125,
#            'max_dhi': 97,
#            'max_dni': 803,
#            'max_ghi': 499,
#            'max_temp': 17,
#            'max_temp_ts': 1667912400,
#            'max_uv': 1.5,
#            'max_wind_dir': 187,
#            'max_wind_spd': 3.1,
#            'max_wind_spd_ts': 1667930400,
#            'min_temp': 13,
#            'min_temp_ts': 1667887200,
#            'precip': 4.8,
#            'precip_gpm': 4.8,
#            'pres': 997,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1010,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 69,
#            't_dhi': 729,
#            't_dni': 6206,
#            't_ghi': 3001,
#            't_solar_rad': 1666,
#            'temp': 14.6,
#            'ts': 1667862000,
#            'wind_dir': 187,
#            'wind_gust_spd': 18.8,
#            'wind_spd': 2},
#           {'clouds': 91,
#            'datetime': '2022-11-09',
#            'dewpt': 13.6,
#            'dhi': 30,
#            'dni': 257,
#            'ghi': 123,
#            'max_dhi': 96,
#            'max_dni': 801,
#            'max_ghi': 495,
#            'max_temp': 17.9,
#            'max_temp_ts': 1668002400,
#            'max_uv': 1.7,
#            'max_wind_dir': 131,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1667998800,
#            'min_temp': 12.2,
#            'min_temp_ts': 1667966400,
#            'precip': 2.5,
#            'precip_gpm': 2.5,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 94,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 79,
#            't_dhi': 724,
#            't_dni': 6161,
#            't_ghi': 2960,
#            't_solar_rad': 1902,
#            'temp': 14.6,
#            'ts': 1667948400,
#            'wind_dir': 131,
#            'wind_gust_spd': 10.4,
#            'wind_spd': 1.1},
#           {'clouds': 63,
#            'datetime': '2022-11-10',
#            'dewpt': 13.9,
#            'dhi': 30,
#            'dni': 255,
#            'ghi': 122,
#            'max_dhi': 96,
#            'max_dni': 799,
#            'max_ghi': 490,
#            'max_temp': 19.6,
#            'max_temp_ts': 1668078000,
#            'max_uv': 2.1,
#            'max_wind_dir': 143,
#            'max_wind_spd': 3.6,
#            'max_wind_spd_ts': 1668117600,
#            'min_temp': 13,
#            'min_temp_ts': 1668117600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1009,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 91,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 98,
#            't_dhi': 718,
#            't_dni': 6116,
#            't_ghi': 2920,
#            't_solar_rad': 2345,
#            'temp': 15.5,
#            'ts': 1668034800,
#            'wind_dir': 143,
#            'wind_gust_spd': 8.8,
#            'wind_spd': 1.4},
#           {'clouds': 21,
#            'datetime': '2022-11-11',
#            'dewpt': 11,
#            'dhi': 30,
#            'dni': 253,
#            'ghi': 120,
#            'max_dhi': 96,
#            'max_dni': 797,
#            'max_ghi': 485,
#            'max_temp': 20.8,
#            'max_temp_ts': 1668171600,
#            'max_uv': 3.2,
#            'max_wind_dir': 137,
#            'max_wind_spd': 3,
#            'max_wind_spd_ts': 1668121200,
#            'min_temp': 11.1,
#            'min_temp_ts': 1668150000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1008,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 120,
#            't_dhi': 713,
#            't_dni': 6070,
#            't_ghi': 2881,
#            't_solar_rad': 2881,
#            'temp': 14.9,
#            'ts': 1668121200,
#            'wind_dir': 137,
#            'wind_gust_spd': 5.6,
#            'wind_spd': 1.6},
#           {'clouds': 56,
#            'datetime': '2022-11-12',
#            'dewpt': 10.4,
#            'dhi': 29,
#            'dni': 251,
#            'ghi': 118,
#            'max_dhi': 95,
#            'max_dni': 795,
#            'max_ghi': 480,
#            'max_temp': 21.7,
#            'max_temp_ts': 1668283200,
#            'max_uv': 1.9,
#            'max_wind_dir': 130,
#            'max_wind_spd': 3.9,
#            'max_wind_spd_ts': 1668283200,
#            'min_temp': 11.5,
#            'min_temp_ts': 1668225600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 73,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 96,
#            't_dhi': 707,
#            't_dni': 6025,
#            't_ghi': 2843,
#            't_solar_rad': 2306,
#            'temp': 15.2,
#            'ts': 1668207600,
#            'wind_dir': 130,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.8},
#           {'clouds': 63,
#            'datetime': '2022-11-13',
#            'dewpt': 12.7,
#            'dhi': 29,
#            'dni': 249,
#            'ghi': 117,
#            'max_dhi': 95,
#            'max_dni': 793,
#            'max_ghi': 476,
#            'max_temp': 18.1,
#            'max_temp_ts': 1668358800,
#            'max_uv': 1.7,
#            'max_wind_dir': 191,
#            'max_wind_spd': 8.4,
#            'max_wind_spd_ts': 1668294000,
#            'min_temp': 13.7,
#            'min_temp_ts': 1668358800,
#            'precip': 24.8,
#            'precip_gpm': 24.8,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 70,
#            't_dhi': 702,
#            't_dni': 5981,
#            't_ghi': 2805,
#            't_solar_rad': 1688,
#            'temp': 15.5,
#            'ts': 1668294000,
#            'wind_dir': 191,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 5.1},
#           {'clouds': 85,
#            'datetime': '2022-11-14',
#            'dewpt': 11.1,
#            'dhi': 29,
#            'dni': 247,
#            'ghi': 115,
#            'max_dhi': 95,
#            'max_dni': 791,
#            'max_ghi': 471,
#            'max_temp': 15.8,
#            'max_temp_ts': 1668384000,
#            'max_uv': 1,
#            'max_wind_dir': 162,
#            'max_wind_spd': 3.9,
#            'max_wind_spd_ts': 1668387600,
#            'min_temp': 9.1,
#            'min_temp_ts': 1668409200,
#            'precip': 4.8,
#            'precip_gpm': 4.8,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 87,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 32,
#            't_dhi': 697,
#            't_dni': 5936,
#            't_ghi': 2768,
#            't_solar_rad': 770,
#            'temp': 13.2,
#            'ts': 1668380400,
#            'wind_dir': 162,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 2.4}],
#  'lat': 42.431,
#  'lon': -8.64435,
#  'sources': ['080440-99999', 'imerg', 'era5', 'sat', 'radar', 'snodas'],
#  'state_code': '58',
#  'station_id': '080440-99999',
#  'timezone': 'Europe/Madrid'}

# %%
ciudad = data["city_name"]
ciudad
# Out:
# 'Pontevedra'

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

pontevedra =  pd.DataFrame(datos)

pontevedra.head()

pontevedra.to_csv("pontevedra_2021-11-15_2022-11-15.csv")
