# %% [markdown]
# # Extracción de datos

# %% [markdown]
# # Link web API:
#
#  **https://www.weatherbit.io/api?utm_source=chatgpt.com**
#
# # Normas generales.
#  - Todos los parámetros que pongamos en la llamada a la **API (URL)** van separados por **'&'**. **"lat=35.7796&lon=-78.6382&key=API_KEY&include=minutely"**
#
#  - Todos los links ACABAN con **key=API_KEY**
#
#  - El idioma por defecto de las respuestas será en **Inglés**
#
#         - Se pueden cambiar a Español ocn este parametro: &lang=es
#
#
#  - **Todos** los datos obtenidos por defecto serán:
#
#
#         - Metric : Celsius, m/s, l/m²
#
#
#
# # Utilidades del API:
#
# ## Geocodificación:
#    1. Con **zip**: https://api.weatherbit.io/v2.0/geocode?postal_code=08188&country=US&key=API_KEY
#
#            - Muestra un dict{} (No siempre exacto con la ciudad):
#
#            {'country_code': 'ES',
#             'geo_id': '08188-ES',
#             'lat': 41.5333,
#             'lon': 2.3,
#             'name': 'Barcelona',
#             'state_code': 'CT',
#             'timezone': 'Europe/Madrid'}
#
#
#
#    2. Con **nombre de ciudad**: https://api.weatherbit.io/v2.0/geocode?&city=vallromanes&country=ES&key=9a25028e04c943f5b50689bfd5db49b7
#
#            - Muestra un dict{} (Siempre exacto con la ciudad):
#
#            {'country_code': 'ES',
#             'geo_id': 'VALLROMANES--ES',
#             'lat': 41.53333,
#             'lon': 2.3,
#             'name': 'Vallromanes',
#             'state_code': '56',
#             'timezone': 'Europe/Madrid'}
#
#              - Mejor con el nombre de la ciudad/pueblo para que sea más preciso.
#
#  - Creo que estos són los métodos más sencillos, las otras dos són con el id de la ciudad (Que no he sabido encontrar) y con la estación meteorológica (Que no se encontrar exactamente qué es lo que pide)
#
#
#
# # Clima Actual.
#
#
# ## Clima actual (Literal):
#     De una ubicación exacta y en el momento actual. Lat y Lon que le demos (Recomendable con nombre de ciudad en Geocodificación) y datetime de la petición
#
#     Opcionales: include=minutely (minuto a minuto, 1 hora en adelante desde la petición)
#
#     alerts (Alertas en el momento de la petición)
#
#     lightning (Rayos en el momento de la petición)
#
#     Da info de:
#
#         Nombre de la ciudad
#         Tiempo de la última actualización
#         Salida y puesta del sol
#         Zona horaria
#         Radiación solar
#         Calidad del aire
#         Tasa de precipitación
#         Velocidad del viento
#         Prevision de la hora siguiente a la que estamos en 'minutely' (asignado en la url) de la próxima hora minuto a minuto
#         Etc...
#
# ## Alertas de clima adverso:
#  - Solo aplicable a alertas actuales, se puede trabajar poco con esto...
#
# ## Calidad del aire actual:
#  - Solo aplicable a alertas actuales, se puede trabajar poco con esto...
#
# ## Api de rayos (actual):
#  - Solo aplicable a alertas actuales, se puede trabajar poco con esto...
#
#
# ## Mapas del tiempo:
# Se puede usar para complementar gráficas, a la funcion 'subplot' tambien se le pueden añadir imagenes.p
#
#
#     fig, ax = plt.subplots(3, 3, figsize=(8, 4))
#
#     ax[0].imshow(img)
#     ax[0].set_title("Imagen original")
#     ax[0].axis('off')
#
#
# # Histórico de climas.
#
#
# ## Diario:
#  - URL: https://api.weatherbit.io/v2.0/history/daily?lat=41.5333&lon=2.2667&start_date=2025-11-08&end_date=2025-11-10&key=9a25028e04c943f5b50689bfd5db49b7
#
#    1. lat=41.5333
#
#    2. lon=2.2667
#
#    3. start_date=2025-11-08                     Formato Datetime: %Y-%m-%d
#
#    4. end_date=2025-11-10                       Formato Datetime: %Y-%m-%d
#
# ## Por horas:
#  - URL: https://api.weatherbit.io/v2.0/history/hourly?lat=41.5333&lon=2.2667&start_date=2025-11-08:20&end_date=2025-11-10:20&tz=local&key=9a25028e04c943f5b50689bfd5db49b7
#
#    1. lat=41.5333
#
#    2. lon=2.2667
#
#    3. start_date=2025-11-08 / 2025-11-08:20    Formato Datetime: %Y-%m-%d:%H
#
#    4. end_date=2025-11-10 / 2025-11-10:20      Formato Datetime: %Y-%m-%d:%H
#
# ## Por sub-horas (ej. 15 min):
#  - URL: https://api.weatherbit.io/v2.0/history/subhourly?lat=41.5333&lon=2.2667&start_date=2025-11-08:20&end_date=2025-11-10:20&tz=local&key=9a25028e04c943f5b50689bfd5db49b7
#
#    1. lat=41.5333
#
#    2. lon=2.2667
#
#    3. start_date=2025-11-08 / 2025-11-08:20    Formato Datetime: %Y-%m-%d:%H
#
#    4. end_date=2025-11-10 / 2025-11-10:20      Formato Datetime: %Y-%m-%d:%H
#
#
# ## Normales climáticas:
#
#
# ## Histórico de la calidad del aire:
#
#
# ## Histórico del clima agricola:
#
#
# ## Histórico de grados día de refrigeración y calefacción:
#
#
# ## Histórico de rayos:
#  - Esta para mi es complicada de entender, pero se pueden acabar sacando datos como: cantidad de rayos por paises, frequencia de rayos por paises, longitud de rayos...
#
# # Pronóstico del tiempo:
#
# ## 16 días vista:
#
# Se puede usar para comparar al cabo de unos dias con el histórico
#
#
# ## 240 horas / por hora:
#
#
# ## 1 hora / por minuto:
#
#
# ## Pronóstico grados día de calefacción y refrigeración:
#
#
# ## Pronóstico calidad aire:
#
#
# ## Pronóstico meteorológico agrícola:
#
#
# # Utilidades del API:
#
# ## Geocodificación:

# %%
import requests
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# Geocodificación
# En este caso uso el zip

data = {}

url = "https://api.weatherbit.io/v2.0/geocode?postal_code=08140&country=ES&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'ES',
#  'geo_id': '08140-ES',
#  'lat': 41.2667,
#  'lon': 1.9667,
#  'name': 'Barcelona',
#  'state_code': 'CT',
#  'timezone': 'Europe/Madrid'}

# %%
# Geocodificación
# En este caso uso el nombre de la ciudad/pueblo

data = {}

url = "https://api.weatherbit.io/v2.0/geocode?&city=palma+del+rio&country=ES&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'ES',
#  'geo_id': 'PALMA DEL RIO--ES',
#  'lat': 37.70024,
#  'lon': -5.28121,
#  'name': 'Palma del Rio',
#  'state_code': '51',
#  'timezone': 'Europe/Madrid'}

# %%
data = {}

url = "https://api.weatherbit.io/v2.0/geocode?&city=guatire&country=VE&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'VE',
#  'geo_id': 'GUATIRE--VE',
#  'lat': 10.4762,
#  'lon': -66.54266,
#  'name': 'Guatire',
#  'state_code': '15',
#  'timezone': 'America/Caracas'}

# %%
# Clima actual

data = {}

url = "https://api.weatherbit.io/v2.0/current?lat=41.5333&lon=2.2667&key=9a25028e04c943f5b50689bfd5db49b7&include=minutely"
response = requests.get(url)
data.update(response.json())

pprint(data)

# data["data"][0]["city_name"]      # Nombre de la ciudad (No muy exacto a veces con Lon y Lat, da ciudad equivocada)
# data["data"][0]["ob_time"]        # Datetime de LA ÚLTIMA OBSERVACIÓN (se aplica a toda la llave 'data') en formato (UTC) %Y-%m-%d %H:%M
# data["data"][0]["sunrise"]        # Hora salida del sol
# data["data"][0]["sunset"]         # Hora puesta de sol
# data["data"][0]["timezone"]       # Zona horaria
# data["data"][0]["clouds"]         # % de nubes
# data["data"][0]["solar_rad"]      # Radiación solar estimada (W/m^2)
# data["data"][0]["aqi"]            # Índice de calidad de aire (Cuanto más cercano a 0 mejor calidad de aire - EPA standard)
# data["data"][0]["precip"]         # Tasa de precipitación (default mm/hr)
# data["data"][0]["wind_spd"]       # Velocidad del viento (m/s)

# data["minutely"][0]["precip"]
# data["minutely"][0]["temp"]
# data["minutely"][0]["timestamp_utc"]
# data["minutely"][0]["ts"]                # Tiempo en segundos desde en 1 de Enero de 1970 :D

# hora = datetime.fromtimestamp(data["minutely"][0]["ts"])
# print(hora)

# datetime.utcfromtimestamp(1762990200)


# for x in data["minutely"]:
#     print(f"{x["timestamp_local"]} -> {x["temp"]}")

# %%
# Alerta de clima adbersos
# Solo actuales, te puedes morir buscando (No sirve para hacer tablas ninguna de las actuales)

data = {}

url = "https://api.weatherbit.io/v2.0/alerts?lat=35.5043&lon=-97.6399&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)

# %%
# Hay que trabajar con los históricos

# %%
# Histórico de clima (diario)

data = {}
url = "https://api.weatherbit.io/v2.0/history/daily?lat=41.5333&lon=2.2667&start_date=2025-11-08&end_date=2025-11-10&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

# pprint(data)

for x in data["data"]:
    print(f"{data["city_name"]}")
    print(f"A fecha de: {x["datetime"]} temperatura media: {x["temp"]} Temperatura máxima: {x["max_temp"]} Temperatura máxima: {x["min_temp"]}")
    print(f"Humedad: {x["rh"]}%")
    print(f"Precipitaciones: {x["precip"]}")
    print(f"Área cubierta por nubes en %: {x["clouds"]}%")
    print()
# Out:
# Montornès del Vallès
# A fecha de: 2025-11-08 temperatura media: 11.2 Temperatura máxima: 14.4 Temperatura máxima: 8.5
# Humedad: 85%
# Precipitaciones: 3.8
# Área cubierta por nubes en %: 69%
#
# Montornès del Vallès
# A fecha de: 2025-11-09 temperatura media: 11.5 Temperatura máxima: 17 Temperatura máxima: 7.8
# Humedad: 78%
# Precipitaciones: 0
# Área cubierta por nubes en %: 1%

# %%
# Histórico de clima (Por horas)

data = {}
url = "https://api.weatherbit.io/v2.0/history/hourly?lat=41.5333&lon=2.2667&start_date=2025-11-08:20&end_date=2025-11-10:20&tz=local&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# for x in data:
#     print(f"Lugar de la búsqueda: {data["city_name"]}")
#     print()
#     for x in data["data"]:
#         print(f"A fecha y hora: {x["datetime"]}")
#         print(f"Temperatura: {x["temp"]}")
#         print(f"Sensación térmica: {x["app_temp"]}")
#         print(f"Punto de rocío (Celsius): {x["dewpt"]}")
#         print(f"Presión atmosférica: {x["pres"]}")
#         print(f"Humedad: {x["rh"]}%")
#         print(f"Precipitaciones: {x["precip"]} l/m²")
#         print(f"Área cubierta por nubes en %: {x["clouds"]}%")
#         print(f"Dirección del viento: {x["wind_dir"]}º")
#         print(f"Velocidad del viento: {x["wind_spd"]}")
#         print(f"Radiación solar estimada: {x["solar_rad"]} W/m²")
#         print(f"Índice UV: {x["uv"]} (Escala: 0-11+)")
#         print()



# for x in data["data"]:
#     print(f"Lugar de la búsqueda: {data["city_name"]}")
#     print(f"A fecha y hora: {x["datetime"]}")
#     print(f"Temperatura: {x["temp"]}")
#     print(f"Sensación térmica: {x["app_temp"]}")
#     print(f"Punto de rocío (Celsius): {x["dewpt"]}")
#     print(f"Presión atmosférica: {x["pres"]}")
#     print(f"Humedad: {x["rh"]}%")
#     print(f"Precipitaciones: {x["precip"]} l/m²")
#     print(f"Área cubierta por nubes en %: {x["clouds"]}%")
#     print(f"Dirección del viento: {x["wind_dir"]}º")
#     print(f"Velocidad del viento: {x["wind_spd"]}")
#     print(f"Radiación solar estimada: {x["solar_rad"]} W/m²")
#     print(f"Índice UV: {x["uv"]} (Escala: 0-11+)")
#     print()
# Out:
# {'city_id': '3116262',
#  'city_name': 'Montornès del Vallès',
#  'country_code': 'ES',
#  'data': [{'app_temp': 10.7,
#            'azimuth': 270.8,
#            'clouds': 0,
#            'datetime': '2025-11-08:19',
#            'dewpt': 8.8,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -26.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 10.7,
#            'timestamp_local': '2025-11-08T20:00:00',
#            'timestamp_utc': '2025-11-08T19:00:00',
#            'ts': 1762628400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 350,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 10,
#            'azimuth': 281.5,
#            'clouds': 0,
#            'datetime': '2025-11-08:20',
#            'dewpt': 8.1,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -38,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 10,
#            'timestamp_local': '2025-11-08T21:00:00',
#            'timestamp_utc': '2025-11-08T20:00:00',
#            'ts': 1762632000,
#            'uv': 0,
#            'vis': 13,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 358,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 294.7,
#            'clouds': 0,
#            'datetime': '2025-11-08:21',
#            'dewpt': 7.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -48.6,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-08T22:00:00',
#            'timestamp_utc': '2025-11-08T21:00:00',
#            'ts': 1762635600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 352,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 313.1,
#            'clouds': 0,
#            'datetime': '2025-11-08:22',
#            'dewpt': 7.4,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -58,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-08T23:00:00',
#            'timestamp_utc': '2025-11-08T22:00:00',
#            'ts': 1762639200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 350,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 9.3,
#            'azimuth': 340.2,
#            'clouds': 0,
#            'datetime': '2025-11-08:23',
#            'dewpt': 7.1,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -64.2,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.3,
#            'timestamp_local': '2025-11-09T00:00:00',
#            'timestamp_utc': '2025-11-08T23:00:00',
#            'ts': 1762642800,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 354,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 13.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:00',
#            'dewpt': 6.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -64.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T01:00:00',
#            'timestamp_utc': '2025-11-09T00:00:00',
#            'ts': 1762646400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 2,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 42.7,
#            'clouds': 0,
#            'datetime': '2025-11-09:01',
#            'dewpt': 6.3,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -59.4,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T02:00:00',
#            'timestamp_utc': '2025-11-09T01:00:00',
#            'ts': 1762650000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 354,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 62.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:02',
#            'dewpt': 6.3,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -50.5,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T03:00:00',
#            'timestamp_utc': '2025-11-09T02:00:00',
#            'ts': 1762653600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 352,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 76.4,
#            'clouds': 0,
#            'datetime': '2025-11-09:03',
#            'dewpt': 6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -40,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-09T04:00:00',
#            'timestamp_utc': '2025-11-09T03:00:00',
#            'ts': 1762657200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 87.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:04',
#            'dewpt': 5.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -28.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 82,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-09T05:00:00',
#            'timestamp_utc': '2025-11-09T04:00:00',
#            'ts': 1762660800,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 354,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 97.3,
#            'clouds': 0,
#            'datetime': '2025-11-09:05',
#            'dewpt': 5.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -17.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 82,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-09T06:00:00',
#            'timestamp_utc': '2025-11-09T05:00:00',
#            'ts': 1762664400,
#            'uv': 0,
#            'vis': 12,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 2,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 7.8,
#            'azimuth': 106.8,
#            'clouds': 0,
#            'datetime': '2025-11-09:06',
#            'dewpt': 5.3,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -6.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.8,
#            'timestamp_local': '2025-11-09T07:00:00',
#            'timestamp_utc': '2025-11-09T06:00:00',
#            'ts': 1762668000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 8,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 0.8},
#           {'app_temp': 7.8,
#            'azimuth': 116.6,
#            'clouds': 0,
#            'datetime': '2025-11-09:07',
#            'dewpt': 5.3,
#            'dhi': 29,
#            'dni': 233,
#            'elev_angle': 3.7,
#            'ghi': 35,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 35,
#            'temp': 7.8,
#            'timestamp_local': '2025-11-09T08:00:00',
#            'timestamp_utc': '2025-11-09T07:00:00',
#            'ts': 1762671600,
#            'uv': 1.8,
#            'vis': 13,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 350,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 127.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:08',
#            'dewpt': 6.3,
#            'dhi': 63,
#            'dni': 567,
#            'elev_angle': 13.2,
#            'ghi': 185,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 80,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 185,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-09T09:00:00',
#            'timestamp_utc': '2025-11-09T08:00:00',
#            'ts': 1762675200,
#            'uv': 1.9,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 348,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 0.8},
#           {'app_temp': 12.6,
#            'azimuth': 139.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:09',
#            'dewpt': 8.5,
#            'dhi': 81,
#            'dni': 706,
#            'elev_angle': 21.3,
#            'ghi': 331,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 76,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 331,
#            'temp': 12.6,
#            'timestamp_local': '2025-11-09T10:00:00',
#            'timestamp_utc': '2025-11-09T09:00:00',
#            'ts': 1762678800,
#            'uv': 2.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 310,
#            'wind_gust_spd': 2,
#            'wind_spd': 0.4},
#           {'app_temp': 14.8,
#            'azimuth': 154.2,
#            'clouds': 0,
#            'datetime': '2025-11-09:10',
#            'dewpt': 9,
#            'dhi': 92,
#            'dni': 775,
#            'elev_angle': 27.4,
#            'ghi': 442,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 68,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 442,
#            'temp': 14.8,
#            'timestamp_local': '2025-11-09T11:00:00',
#            'timestamp_utc': '2025-11-09T10:00:00',
#            'ts': 1762682400,
#            'uv': 3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 268,
#            'wind_gust_spd': 2,
#            'wind_spd': 0.4},
#           {'app_temp': 15.9,
#            'azimuth': 170.1,
#            'clouds': 0,
#            'datetime': '2025-11-09:11',
#            'dewpt': 8.9,
#            'dhi': 97,
#            'dni': 806,
#            'elev_angle': 30.9,
#            'ghi': 504,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 504,
#            'temp': 15.9,
#            'timestamp_local': '2025-11-09T12:00:00',
#            'timestamp_utc': '2025-11-09T11:00:00',
#            'ts': 1762686000,
#            'uv': 3.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 152,
#            'wind_gust_spd': 2,
#            'wind_spd': 0},
#           {'app_temp': 16.7,
#            'azimuth': 186.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:12',
#            'dewpt': 9.6,
#            'dhi': 97,
#            'dni': 808,
#            'elev_angle': 31.1,
#            'ghi': 509,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1038,
#            'snow': 0,
#            'solar_rad': 509,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-09T13:00:00',
#            'timestamp_utc': '2025-11-09T12:00:00',
#            'ts': 1762689600,
#            'uv': 3.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 164,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 17,
#            'azimuth': 203,
#            'clouds': 0,
#            'datetime': '2025-11-09:13',
#            'dewpt': 9.7,
#            'dhi': 93,
#            'dni': 783,
#            'elev_angle': 28.2,
#            'ghi': 457,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 62,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 457,
#            'temp': 17,
#            'timestamp_local': '2025-11-09T14:00:00',
#            'timestamp_utc': '2025-11-09T13:00:00',
#            'ts': 1762693200,
#            'uv': 3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 178,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 17,
#            'azimuth': 217.6,
#            'clouds': 0,
#            'datetime': '2025-11-09:14',
#            'dewpt': 9.9,
#            'dhi': 84,
#            'dni': 721,
#            'elev_angle': 22.5,
#            'ghi': 353,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 353,
#            'temp': 17,
#            'timestamp_local': '2025-11-09T15:00:00',
#            'timestamp_utc': '2025-11-09T14:00:00',
#            'ts': 1762696800,
#            'uv': 2.5,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 190,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 16.7,
#            'azimuth': 230.3,
#            'clouds': 0,
#            'datetime': '2025-11-09:15',
#            'dewpt': 9.6,
#            'dhi': 67,
#            'dni': 599,
#            'elev_angle': 14.7,
#            'ghi': 212,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 212,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-09T16:00:00',
#            'timestamp_utc': '2025-11-09T15:00:00',
#            'ts': 1762700400,
#            'uv': 2,
#            'vis': 16,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 188,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 15.9,
#            'azimuth': 241.4,
#            'clouds': 0,
#            'datetime': '2025-11-09:16',
#            'dewpt': 9.6,
#            'dhi': 37,
#            'dni': 321,
#            'elev_angle': 5.4,
#            'ghi': 58,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 66,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 58,
#            'temp': 15.9,
#            'timestamp_local': '2025-11-09T17:00:00',
#            'timestamp_utc': '2025-11-09T16:00:00',
#            'ts': 1762704000,
#            'uv': 1.8,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 184,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 13.7,
#            'azimuth': 251.4,
#            'clouds': 0,
#            'datetime': '2025-11-09:17',
#            'dewpt': 9.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -4.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 76,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 13.7,
#            'timestamp_local': '2025-11-09T18:00:00',
#            'timestamp_utc': '2025-11-09T17:00:00',
#            'ts': 1762707600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 164,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.4},
#           {'app_temp': 12.6,
#            'azimuth': 260.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:18',
#            'dewpt': 8.9,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -15.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 78,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 12.6,
#            'timestamp_local': '2025-11-09T19:00:00',
#            'timestamp_utc': '2025-11-09T18:00:00',
#            'ts': 1762711200,
#            'uv': 0,
#            'vis': 12,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 348,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 0},
#           {'app_temp': 10.7,
#            'azimuth': 270.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:19',
#            'dewpt': 8.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -27,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 10.7,
#            'timestamp_local': '2025-11-09T20:00:00',
#            'timestamp_utc': '2025-11-09T19:00:00',
#            'ts': 1762714800,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 338,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 281.2,
#            'clouds': 0,
#            'datetime': '2025-11-09:20',
#            'dewpt': 7.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -38.1,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-09T21:00:00',
#            'timestamp_utc': '2025-11-09T20:00:00',
#            'ts': 1762718400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 294.4,
#            'clouds': 16,
#            'datetime': '2025-11-09:21',
#            'dewpt': 7.4,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -48.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 90,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T22:00:00',
#            'timestamp_utc': '2025-11-09T21:00:00',
#            'ts': 1762722000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7.8,
#            'azimuth': 312.8,
#            'clouds': 0,
#            'datetime': '2025-11-09:22',
#            'dewpt': 5.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -58.2,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.8,
#            'timestamp_local': '2025-11-09T23:00:00',
#            'timestamp_utc': '2025-11-09T22:00:00',
#            'ts': 1762725600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7.4,
#            'azimuth': 340,
#            'clouds': 33,
#            'datetime': '2025-11-09:23',
#            'dewpt': 5.2,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -64.5,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.4,
#            'timestamp_local': '2025-11-10T00:00:00',
#            'timestamp_utc': '2025-11-09T23:00:00',
#            'ts': 1762729200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 802,
#                        'description': 'Scattered clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 6.6,
#            'azimuth': 14,
#            'clouds': 55,
#            'datetime': '2025-11-10:00',
#            'dewpt': 4.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -65.1,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7,
#            'timestamp_local': '2025-11-10T01:00:00',
#            'timestamp_utc': '2025-11-10T00:00:00',
#            'ts': 1762732800,
#            'uv': 0,
#            'vis': 14,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03n'},
#            'wind_dir': 344,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7.4,
#            'azimuth': 43,
#            'clouds': 56,
#            'datetime': '2025-11-10:01',
#            'dewpt': 4,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -59.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 79,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.4,
#            'timestamp_local': '2025-11-10T02:00:00',
#            'timestamp_utc': '2025-11-10T01:00:00',
#            'ts': 1762736400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 6.6,
#            'azimuth': 62.8,
#            'clouds': 48,
#            'datetime': '2025-11-10:02',
#            'dewpt': 3.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -50.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 79,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7,
#            'timestamp_local': '2025-11-10T03:00:00',
#            'timestamp_utc': '2025-11-10T02:00:00',
#            'ts': 1762740000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03n'},
#            'wind_dir': 344,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 6.3,
#            'azimuth': 76.7,
#            'clouds': 21,
#            'datetime': '2025-11-10:03',
#            'dewpt': 3.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -40.2,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 81,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T04:00:00',
#            'timestamp_utc': '2025-11-10T03:00:00',
#            'ts': 1762743600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 802,
#                        'description': 'Scattered clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7,
#            'azimuth': 87.8,
#            'clouds': 4,
#            'datetime': '2025-11-10:04',
#            'dewpt': 3.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -29.1,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0.5,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 81,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T05:00:00',
#            'timestamp_utc': '2025-11-10T04:00:00',
#            'ts': 1762747200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 301, 'description': 'Drizzle', 'icon': 'd02n'},
#            'wind_dir': 338,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 7.3,
#            'azimuth': 97.5,
#            'clouds': 0,
#            'datetime': '2025-11-10:05',
#            'dewpt': 4.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -17.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7,
#            'timestamp_local': '2025-11-10T06:00:00',
#            'timestamp_utc': '2025-11-10T05:00:00',
#            'ts': 1762750800,
#            'uv': 0,
#            'vis': 16,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 330,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 7,
#            'azimuth': 107,
#            'clouds': 0,
#            'datetime': '2025-11-10:06',
#            'dewpt': 4.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -6.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T07:00:00',
#            'timestamp_utc': '2025-11-10T06:00:00',
#            'ts': 1762754400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 328,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 6.3,
#            'azimuth': 116.8,
#            'clouds': 5,
#            'datetime': '2025-11-10:07',
#            'dewpt': 4.5,
#            'dhi': 28,
#            'dni': 221,
#            'elev_angle': 3.5,
#            'ghi': 32,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 32,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T08:00:00',
#            'timestamp_utc': '2025-11-10T07:00:00',
#            'ts': 1762758000,
#            'uv': 1.7,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 338,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 127.7,
#            'clouds': 0,
#            'datetime': '2025-11-10:08',
#            'dewpt': 5.6,
#            'dhi': 63,
#            'dni': 562,
#            'elev_angle': 13,
#            'ghi': 181,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 82,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 181,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-10T09:00:00',
#            'timestamp_utc': '2025-11-10T08:00:00',
#            'ts': 1762761600,
#            'uv': 1.9,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 336,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 11.9,
#            'azimuth': 140,
#            'clouds': 0,
#            'datetime': '2025-11-10:09',
#            'dewpt': 7.8,
#            'dhi': 81,
#            'dni': 702,
#            'elev_angle': 21.1,
#            'ghi': 326,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 76,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 326,
#            'temp': 11.9,
#            'timestamp_local': '2025-11-10T10:00:00',
#            'timestamp_utc': '2025-11-10T09:00:00',
#            'ts': 1762765200,
#            'uv': 2.3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 264,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 0.4},
#           {'app_temp': 14.1,
#            'azimuth': 154.3,
#            'clouds': 0,
#            'datetime': '2025-11-10:10',
#            'dewpt': 7.9,
#            'dhi': 91,
#            'dni': 773,
#            'elev_angle': 27.1,
#            'ghi': 437,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 66,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 437,
#            'temp': 14.1,
#            'timestamp_local': '2025-11-10T11:00:00',
#            'timestamp_utc': '2025-11-10T10:00:00',
#            'ts': 1762768800,
#            'uv': 2.9,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 240,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.2},
#           {'app_temp': 15.6,
#            'azimuth': 170.1,
#            'clouds': 0,
#            'datetime': '2025-11-10:11',
#            'dewpt': 8.6,
#            'dhi': 97,
#            'dni': 804,
#            'elev_angle': 30.6,
#            'ghi': 499,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 499,
#            'temp': 15.6,
#            'timestamp_local': '2025-11-10T12:00:00',
#            'timestamp_utc': '2025-11-10T11:00:00',
#            'ts': 1762772400,
#            'uv': 3.3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 240,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 2},
#           {'app_temp': 16.7,
#            'azimuth': 186.8,
#            'clouds': 0,
#            'datetime': '2025-11-10:12',
#            'dewpt': 8.7,
#            'dhi': 97,
#            'dni': 806,
#            'elev_angle': 30.9,
#            'ghi': 504,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 59,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 504,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-10T13:00:00',
#            'timestamp_utc': '2025-11-10T12:00:00',
#            'ts': 1762776000,
#            'uv': 3.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 244,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.8},
#           {'app_temp': 17.4,
#            'azimuth': 202.9,
#            'clouds': 19,
#            'datetime': '2025-11-10:13',
#            'dewpt': 8.3,
#            'dhi': 93,
#            'dni': 781,
#            'elev_angle': 28,
#            'ghi': 452,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 55,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 451,
#            'temp': 17.4,
#            'timestamp_local': '2025-11-10T14:00:00',
#            'timestamp_utc': '2025-11-10T13:00:00',
#            'ts': 1762779600,
#            'uv': 2.6,
#            'vis': 13,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_dir': 250,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.8},
#           {'app_temp': 17.4,
#            'azimuth': 217.4,
#            'clouds': 49,
#            'datetime': '2025-11-10:14',
#            'dewpt': 8.3,
#            'dhi': 83,
#            'dni': 719,
#            'elev_angle': 22.3,
#            'ghi': 349,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 55,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 321,
#            'temp': 17.4,
#            'timestamp_local': '2025-11-10T15:00:00',
#            'timestamp_utc': '2025-11-10T14:00:00',
#            'ts': 1762783200,
#            'uv': 1.6,
#            'vis': 10,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03d'},
#            'wind_dir': 254,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.8},
#           {'app_temp': 17.4,
#            'azimuth': 230.1,
#            'clouds': 15,
#            'datetime': '2025-11-10:15',
#            'dewpt': 7.7,
#            'dhi': 67,
#            'dni': 595,
#            'elev_angle': 14.5,
#            'ghi': 208,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 53,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 208,
#            'temp': 17.4,
#            'timestamp_local': '2025-11-10T16:00:00',
#            'timestamp_utc': '2025-11-10T15:00:00',
#            'ts': 1762786800,
#            'uv': 1.8,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_dir': 260,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.4},
#           {'app_temp': 16.7,
#            'azimuth': 241.2,
#            'clouds': 6,
#            'datetime': '2025-11-10:16',
#            'dewpt': 7.9,
#            'dhi': 36,
#            'dni': 313,
#            'elev_angle': 5.2,
#            'ghi': 56,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 56,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 56,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-10T17:00:00',
#            'timestamp_utc': '2025-11-10T16:00:00',
#            'ts': 1762790400,
#            'uv': 1.7,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_dir': 252,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.2},
#           {'app_temp': 14.4,
#            'azimuth': 251.2,
#            'clouds': 0,
#            'datetime': '2025-11-10:17',
#            'dewpt': 8.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -5,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 68,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 14.4,
#            'timestamp_local': '2025-11-10T18:00:00',
#            'timestamp_utc': '2025-11-10T17:00:00',
#            'ts': 1762794000,
#            'uv': 0,
#            'vis': 13,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 278,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 0},
#           {'app_temp': 11.9,
#            'azimuth': 260.6,
#            'clouds': 0,
#            'datetime': '2025-11-10:18',
#            'dewpt': 8.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -15.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 80,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 11.9,
#            'timestamp_local': '2025-11-10T19:00:00',
#            'timestamp_utc': '2025-11-10T18:00:00',
#            'ts': 1762797600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 4,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2}],
#  'lat': 41.5333,
#  'lon': 2.2667,
#  'sources': ['imerg', 'era5', 'sat', 'radar'],
#  'state_code': '56',
#  'station_id': '081763-99999',
#  'timezone': 'Europe/Madrid'}

# %%
data = {}
url = "https://api.weatherbit.io/v2.0/history/daily?lat=41.63333&lon=2.16667&start_date=2025-11-08&end_date=2025-11-10&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []


for x in data["data"]:
    city_name.append(x["city_name"])
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_ts.append(x["max_wind_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])



    
for llave, valor in [("Ciudad", city_name), 
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
    datos[llave] = valor


# datos

caldes_de_montbui =  pd.DataFrame(datos)

caldes_de_montbui.head()

# ubicacion
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\anaconda3\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 4
#       2 url = "https://api.weatherbit.io/v2.0/history/daily?lat=41.63333&lon=2.16667&start_date=2025-11-08&end_date=2025-11-10&key=9a25028e04c943f5b50689bfd5db49b7"
#       3 response = requests.get(url)
# ----> 4 data.update(response.json())
#       6 datos = {}
#       7 city_name = []
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
X = caldes_de_montbui["datetime"]
Y1 = caldes_de_montbui["temp"]
Y2 = caldes_de_montbui["max_temp"]
Y3 = caldes_de_montbui["min_temp"]

colores = ["red", "blue", "green"]

plt.figure(figsize = (15, 8))

plt.plot(X,
         Y1, 
         color       = "red",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temperatura ℃") 

plt.plot(X,
         Y2, 
         color       = "blue",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. máxima ℃") 

plt.plot(X,
         Y3, 
         color       = "green",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. mínima ℃") 



plt.legend()
plt.xticks(rotation = 90)
plt.grid()
plt.show()
