# %% [markdown]
# # Extracción de datos

# %% [markdown]
# # Link web API:
#
#  **https://www.weatherbit.io/api?utm_source=chatgpt.com**
#
# # Normas generales.
#  - Todos los parámetros que pongamos en la llamada a la **API (URL)** van separados por **'&'**. **"lat=35.7796&lon=-78.6382&key=API_KEY&include=minutely"**
#
#  - Todos los links ACABAN con **key=API_KEY**
#
#  - El idioma por defecto de las respuestas será en **Inglés**
#
#         - Se pueden cambiar a Español ocn este parametro: &lang=es
#
#
#  - **Todos** los datos obtenidos por defecto serán:
#
#
#         - Metric : Celsius, m/s, l/m²
#
#
#
# # Utilidades del API:
#
# ## Geocodificación:
#    1. Con **zip**: https://api.weatherbit.io/v2.0/geocode?postal_code=08188&country=US&key=API_KEY
#
#            - Muestra un dict{} (No siempre exacto con la ciudad):
#
#            {'country_code': 'ES',
#             'geo_id': '08188-ES',
#             'lat': 41.5333,
#             'lon': 2.3,
#             'name': 'Barcelona',
#             'state_code': 'CT',
#             'timezone': 'Europe/Madrid'}
#
#
#
#    2. Con **nombre de ciudad**: https://api.weatherbit.io/v2.0/geocode?&city=vallromanes&country=ES&key=9a25028e04c943f5b50689bfd5db49b7
#
#            - Muestra un dict{} (Siempre exacto con la ciudad):
#
#            {'country_code': 'ES',
#             'geo_id': 'VALLROMANES--ES',
#             'lat': 41.53333,
#             'lon': 2.3,
#             'name': 'Vallromanes',
#             'state_code': '56',
#             'timezone': 'Europe/Madrid'}
#
#              - Mejor con el nombre de la ciudad/pueblo para que sea más preciso.
#
#  - Creo que estos són los métodos más sencillos, las otras dos són con el id de la ciudad (Que no he sabido encontrar) y con la estación meteorológica (Que no se encontrar exactamente qué es lo que pide)
#
#
#
# # Clima Actual.
#
#
# ## Clima actual (Literal):
#     De una ubicación exacta y en el momento actual. Lat y Lon que le demos (Recomendable con nombre de ciudad en Geocodificación) y datetime de la petición
#
#     Opcionales: include=minutely (minuto a minuto, 1 hora en adelante desde la petición)
#
#     alerts (Alertas en el momento de la petición)
#
#     lightning (Rayos en el momento de la petición)
#
#     Da info de:
#
#         Nombre de la ciudad
#         Tiempo de la última actualización
#         Salida y puesta del sol
#         Zona horaria
#         Radiación solar
#         Calidad del aire
#         Tasa de precipitación
#         Velocidad del viento
#         Prevision de la hora siguiente a la que estamos en 'minutely' (asignado en la url) de la próxima hora minuto a minuto
#         Etc...
#
# ## Alertas de clima adverso:
#  - Solo aplicable a alertas actuales, se puede trabajar poco con esto...
#
# ## Calidad del aire actual:
#  - Solo aplicable a alertas actuales, se puede trabajar poco con esto...
#
# ## Api de rayos (actual):
#  - Solo aplicable a alertas actuales, se puede trabajar poco con esto...
#
#
# ## Mapas del tiempo:
# Se puede usar para complementar gráficas, a la funcion 'subplot' tambien se le pueden añadir imagenes.p
#
#
#     fig, ax = plt.subplots(3, 3, figsize=(8, 4))
#
#     ax[0].imshow(img)
#     ax[0].set_title("Imagen original")
#     ax[0].axis('off')
#
#
# # Histórico de climas.
#
#
# ## Diario:
#  - URL: https://api.weatherbit.io/v2.0/history/daily?lat=41.5333&lon=2.2667&start_date=2025-11-08&end_date=2025-11-10&key=9a25028e04c943f5b50689bfd5db49b7
#
#    1. lat=41.5333
#
#    2. lon=2.2667
#
#    3. start_date=2025-11-08                     Formato Datetime: %Y-%m-%d
#
#    4. end_date=2025-11-10                       Formato Datetime: %Y-%m-%d
#
# ## Por horas:
#  - URL: https://api.weatherbit.io/v2.0/history/hourly?lat=41.5333&lon=2.2667&start_date=2025-11-08:20&end_date=2025-11-10:20&tz=local&key=9a25028e04c943f5b50689bfd5db49b7
#
#    1. lat=41.5333
#
#    2. lon=2.2667
#
#    3. start_date=2025-11-08 / 2025-11-08:20    Formato Datetime: %Y-%m-%d:%H
#
#    4. end_date=2025-11-10 / 2025-11-10:20      Formato Datetime: %Y-%m-%d:%H
#
# ## Por sub-horas (ej. 15 min):
#  - URL: https://api.weatherbit.io/v2.0/history/subhourly?lat=41.5333&lon=2.2667&start_date=2025-11-08:20&end_date=2025-11-10:20&tz=local&key=9a25028e04c943f5b50689bfd5db49b7
#
#    1. lat=41.5333
#
#    2. lon=2.2667
#
#    3. start_date=2025-11-08 / 2025-11-08:20    Formato Datetime: %Y-%m-%d:%H
#
#    4. end_date=2025-11-10 / 2025-11-10:20      Formato Datetime: %Y-%m-%d:%H
#
#
# ## Normales climáticas:
#
#
# ## Histórico de la calidad del aire:
#
#
# ## Histórico del clima agricola:
#
#
# ## Histórico de grados día de refrigeración y calefacción:
#
#
# ## Histórico de rayos:
#  - Esta para mi es complicada de entender, pero se pueden acabar sacando datos como: cantidad de rayos por paises, frequencia de rayos por paises, longitud de rayos...
#
# # Pronóstico del tiempo:
#
# ## 16 días vista:
#
# Se puede usar para comparar al cabo de unos dias con el histórico
#
#
# ## 240 horas / por hora:
#
#
# ## 1 hora / por minuto:
#
#
# ## Pronóstico grados día de calefacción y refrigeración:
#
#
# ## Pronóstico calidad aire:
#
#
# ## Pronóstico meteorológico agrícola:
#
#
# # Utilidades del API:
#
# ## Geocodificación:

# %%
import requests
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# Geocodificación
# En este caso uso el zip

data = {}

url = "https://api.weatherbit.io/v2.0/geocode?postal_code=08140&country=ES&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'ES',
#  'geo_id': '08140-ES',
#  'lat': 41.2667,
#  'lon': 1.9667,
#  'name': 'Barcelona',
#  'state_code': 'CT',
#  'timezone': 'Europe/Madrid'}

# %%
# Geocodificación
# En este caso uso el nombre de la ciudad/pueblo

data = {}

url = "https://api.weatherbit.io/v2.0/geocode?&city=palma+del+rio&country=ES&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'ES',
#  'geo_id': 'PALMA DEL RIO--ES',
#  'lat': 37.70024,
#  'lon': -5.28121,
#  'name': 'Palma del Rio',
#  'state_code': '51',
#  'timezone': 'Europe/Madrid'}

# %%
data = {}

url = "https://api.weatherbit.io/v2.0/geocode?&city=guatire&country=VE&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'VE',
#  'geo_id': 'GUATIRE--VE',
#  'lat': 10.4762,
#  'lon': -66.54266,
#  'name': 'Guatire',
#  'state_code': '15',
#  'timezone': 'America/Caracas'}

# %%
# Clima actual

data = {}

url = "https://api.weatherbit.io/v2.0/current?lat=41.5333&lon=2.2667&key=9a25028e04c943f5b50689bfd5db49b7&include=minutely"
response = requests.get(url)
data.update(response.json())

pprint(data)

# data["data"][0]["city_name"]      # Nombre de la ciudad (No muy exacto a veces con Lon y Lat, da ciudad equivocada)
# data["data"][0]["ob_time"]        # Datetime de LA ÚLTIMA OBSERVACIÓN (se aplica a toda la llave 'data') en formato (UTC) %Y-%m-%d %H:%M
# data["data"][0]["sunrise"]        # Hora salida del sol
# data["data"][0]["sunset"]         # Hora puesta de sol
# data["data"][0]["timezone"]       # Zona horaria
# data["data"][0]["clouds"]         # % de nubes
# data["data"][0]["solar_rad"]      # Radiación solar estimada (W/m^2)
# data["data"][0]["aqi"]            # Índice de calidad de aire (Cuanto más cercano a 0 mejor calidad de aire - EPA standard)
# data["data"][0]["precip"]         # Tasa de precipitación (default mm/hr)
# data["data"][0]["wind_spd"]       # Velocidad del viento (m/s)

# data["minutely"][0]["precip"]
# data["minutely"][0]["temp"]
# data["minutely"][0]["timestamp_utc"]
# data["minutely"][0]["ts"]                # Tiempo en segundos desde en 1 de Enero de 1970 :D

# hora = datetime.fromtimestamp(data["minutely"][0]["ts"])
# print(hora)

# datetime.utcfromtimestamp(1762990200)


# for x in data["minutely"]:
#     print(f"{x["timestamp_local"]} -> {x["temp"]}")

# %%
# Alerta de clima adbersos
# Solo actuales, te puedes morir buscando (No sirve para hacer tablas ninguna de las actuales)

data = {}

url = "https://api.weatherbit.io/v2.0/alerts?lat=35.5043&lon=-97.6399&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)

# %%
# Hay que trabajar con los históricos

# %%
# Histórico de clima (diario)

data = {}
url = "https://api.weatherbit.io/v2.0/history/daily?lat=41.5333&lon=2.2667&start_date=2025-11-08&end_date=2025-11-10&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

# pprint(data)

for x in data["data"]:
    print(f"{data["city_name"]}")
    print(f"A fecha de: {x["datetime"]} temperatura media: {x["temp"]} Temperatura máxima: {x["max_temp"]} Temperatura máxima: {x["min_temp"]}")
    print(f"Humedad: {x["rh"]}%")
    print(f"Precipitaciones: {x["precip"]}")
    print(f"Área cubierta por nubes en %: {x["clouds"]}%")
    print()
# Out:
# Montornès del Vallès
# A fecha de: 2025-11-08 temperatura media: 11.2 Temperatura máxima: 14.4 Temperatura máxima: 8.5
# Humedad: 85%
# Precipitaciones: 3.8
# Área cubierta por nubes en %: 69%
#
# Montornès del Vallès
# A fecha de: 2025-11-09 temperatura media: 11.5 Temperatura máxima: 17 Temperatura máxima: 7.8
# Humedad: 78%
# Precipitaciones: 0
# Área cubierta por nubes en %: 1%

# %%
# Histórico de clima (Por horas)

data = {}
url = "https://api.weatherbit.io/v2.0/history/hourly?lat=41.5333&lon=2.2667&start_date=2025-11-08:20&end_date=2025-11-10:20&tz=local&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# for x in data:
#     print(f"Lugar de la búsqueda: {data["city_name"]}")
#     print()
#     for x in data["data"]:
#         print(f"A fecha y hora: {x["datetime"]}")
#         print(f"Temperatura: {x["temp"]}")
#         print(f"Sensación térmica: {x["app_temp"]}")
#         print(f"Punto de rocío (Celsius): {x["dewpt"]}")
#         print(f"Presión atmosférica: {x["pres"]}")
#         print(f"Humedad: {x["rh"]}%")
#         print(f"Precipitaciones: {x["precip"]} l/m²")
#         print(f"Área cubierta por nubes en %: {x["clouds"]}%")
#         print(f"Dirección del viento: {x["wind_dir"]}º")
#         print(f"Velocidad del viento: {x["wind_spd"]}")
#         print(f"Radiación solar estimada: {x["solar_rad"]} W/m²")
#         print(f"Índice UV: {x["uv"]} (Escala: 0-11+)")
#         print()



# for x in data["data"]:
#     print(f"Lugar de la búsqueda: {data["city_name"]}")
#     print(f"A fecha y hora: {x["datetime"]}")
#     print(f"Temperatura: {x["temp"]}")
#     print(f"Sensación térmica: {x["app_temp"]}")
#     print(f"Punto de rocío (Celsius): {x["dewpt"]}")
#     print(f"Presión atmosférica: {x["pres"]}")
#     print(f"Humedad: {x["rh"]}%")
#     print(f"Precipitaciones: {x["precip"]} l/m²")
#     print(f"Área cubierta por nubes en %: {x["clouds"]}%")
#     print(f"Dirección del viento: {x["wind_dir"]}º")
#     print(f"Velocidad del viento: {x["wind_spd"]}")
#     print(f"Radiación solar estimada: {x["solar_rad"]} W/m²")
#     print(f"Índice UV: {x["uv"]} (Escala: 0-11+)")
#     print()
# Out:
# {'city_id': '3116262',
#  'city_name': 'Montornès del Vallès',
#  'country_code': 'ES',
#  'data': [{'app_temp': 10.7,
#            'azimuth': 270.8,
#            'clouds': 0,
#            'datetime': '2025-11-08:19',
#            'dewpt': 8.8,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -26.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 10.7,
#            'timestamp_local': '2025-11-08T20:00:00',
#            'timestamp_utc': '2025-11-08T19:00:00',
#            'ts': 1762628400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 350,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 10,
#            'azimuth': 281.5,
#            'clouds': 0,
#            'datetime': '2025-11-08:20',
#            'dewpt': 8.1,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -38,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 10,
#            'timestamp_local': '2025-11-08T21:00:00',
#            'timestamp_utc': '2025-11-08T20:00:00',
#            'ts': 1762632000,
#            'uv': 0,
#            'vis': 13,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 358,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 294.7,
#            'clouds': 0,
#            'datetime': '2025-11-08:21',
#            'dewpt': 7.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -48.6,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-08T22:00:00',
#            'timestamp_utc': '2025-11-08T21:00:00',
#            'ts': 1762635600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 352,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 313.1,
#            'clouds': 0,
#            'datetime': '2025-11-08:22',
#            'dewpt': 7.4,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -58,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-08T23:00:00',
#            'timestamp_utc': '2025-11-08T22:00:00',
#            'ts': 1762639200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 350,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 9.3,
#            'azimuth': 340.2,
#            'clouds': 0,
#            'datetime': '2025-11-08:23',
#            'dewpt': 7.1,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -64.2,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.3,
#            'timestamp_local': '2025-11-09T00:00:00',
#            'timestamp_utc': '2025-11-08T23:00:00',
#            'ts': 1762642800,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 354,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 13.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:00',
#            'dewpt': 6.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -64.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T01:00:00',
#            'timestamp_utc': '2025-11-09T00:00:00',
#            'ts': 1762646400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 2,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 42.7,
#            'clouds': 0,
#            'datetime': '2025-11-09:01',
#            'dewpt': 6.3,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -59.4,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T02:00:00',
#            'timestamp_utc': '2025-11-09T01:00:00',
#            'ts': 1762650000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 354,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 62.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:02',
#            'dewpt': 6.3,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -50.5,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T03:00:00',
#            'timestamp_utc': '2025-11-09T02:00:00',
#            'ts': 1762653600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 352,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 76.4,
#            'clouds': 0,
#            'datetime': '2025-11-09:03',
#            'dewpt': 6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -40,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-09T04:00:00',
#            'timestamp_utc': '2025-11-09T03:00:00',
#            'ts': 1762657200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 87.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:04',
#            'dewpt': 5.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -28.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 82,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-09T05:00:00',
#            'timestamp_utc': '2025-11-09T04:00:00',
#            'ts': 1762660800,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 354,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 97.3,
#            'clouds': 0,
#            'datetime': '2025-11-09:05',
#            'dewpt': 5.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -17.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 82,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-09T06:00:00',
#            'timestamp_utc': '2025-11-09T05:00:00',
#            'ts': 1762664400,
#            'uv': 0,
#            'vis': 12,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 2,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 7.8,
#            'azimuth': 106.8,
#            'clouds': 0,
#            'datetime': '2025-11-09:06',
#            'dewpt': 5.3,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -6.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.8,
#            'timestamp_local': '2025-11-09T07:00:00',
#            'timestamp_utc': '2025-11-09T06:00:00',
#            'ts': 1762668000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 8,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 0.8},
#           {'app_temp': 7.8,
#            'azimuth': 116.6,
#            'clouds': 0,
#            'datetime': '2025-11-09:07',
#            'dewpt': 5.3,
#            'dhi': 29,
#            'dni': 233,
#            'elev_angle': 3.7,
#            'ghi': 35,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 35,
#            'temp': 7.8,
#            'timestamp_local': '2025-11-09T08:00:00',
#            'timestamp_utc': '2025-11-09T07:00:00',
#            'ts': 1762671600,
#            'uv': 1.8,
#            'vis': 13,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 350,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 127.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:08',
#            'dewpt': 6.3,
#            'dhi': 63,
#            'dni': 567,
#            'elev_angle': 13.2,
#            'ghi': 185,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 80,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 185,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-09T09:00:00',
#            'timestamp_utc': '2025-11-09T08:00:00',
#            'ts': 1762675200,
#            'uv': 1.9,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 348,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 0.8},
#           {'app_temp': 12.6,
#            'azimuth': 139.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:09',
#            'dewpt': 8.5,
#            'dhi': 81,
#            'dni': 706,
#            'elev_angle': 21.3,
#            'ghi': 331,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 76,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 331,
#            'temp': 12.6,
#            'timestamp_local': '2025-11-09T10:00:00',
#            'timestamp_utc': '2025-11-09T09:00:00',
#            'ts': 1762678800,
#            'uv': 2.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 310,
#            'wind_gust_spd': 2,
#            'wind_spd': 0.4},
#           {'app_temp': 14.8,
#            'azimuth': 154.2,
#            'clouds': 0,
#            'datetime': '2025-11-09:10',
#            'dewpt': 9,
#            'dhi': 92,
#            'dni': 775,
#            'elev_angle': 27.4,
#            'ghi': 442,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 68,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 442,
#            'temp': 14.8,
#            'timestamp_local': '2025-11-09T11:00:00',
#            'timestamp_utc': '2025-11-09T10:00:00',
#            'ts': 1762682400,
#            'uv': 3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 268,
#            'wind_gust_spd': 2,
#            'wind_spd': 0.4},
#           {'app_temp': 15.9,
#            'azimuth': 170.1,
#            'clouds': 0,
#            'datetime': '2025-11-09:11',
#            'dewpt': 8.9,
#            'dhi': 97,
#            'dni': 806,
#            'elev_angle': 30.9,
#            'ghi': 504,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 504,
#            'temp': 15.9,
#            'timestamp_local': '2025-11-09T12:00:00',
#            'timestamp_utc': '2025-11-09T11:00:00',
#            'ts': 1762686000,
#            'uv': 3.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 152,
#            'wind_gust_spd': 2,
#            'wind_spd': 0},
#           {'app_temp': 16.7,
#            'azimuth': 186.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:12',
#            'dewpt': 9.6,
#            'dhi': 97,
#            'dni': 808,
#            'elev_angle': 31.1,
#            'ghi': 509,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1038,
#            'snow': 0,
#            'solar_rad': 509,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-09T13:00:00',
#            'timestamp_utc': '2025-11-09T12:00:00',
#            'ts': 1762689600,
#            'uv': 3.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 164,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 17,
#            'azimuth': 203,
#            'clouds': 0,
#            'datetime': '2025-11-09:13',
#            'dewpt': 9.7,
#            'dhi': 93,
#            'dni': 783,
#            'elev_angle': 28.2,
#            'ghi': 457,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 62,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 457,
#            'temp': 17,
#            'timestamp_local': '2025-11-09T14:00:00',
#            'timestamp_utc': '2025-11-09T13:00:00',
#            'ts': 1762693200,
#            'uv': 3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 178,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 17,
#            'azimuth': 217.6,
#            'clouds': 0,
#            'datetime': '2025-11-09:14',
#            'dewpt': 9.9,
#            'dhi': 84,
#            'dni': 721,
#            'elev_angle': 22.5,
#            'ghi': 353,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 353,
#            'temp': 17,
#            'timestamp_local': '2025-11-09T15:00:00',
#            'timestamp_utc': '2025-11-09T14:00:00',
#            'ts': 1762696800,
#            'uv': 2.5,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 190,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 16.7,
#            'azimuth': 230.3,
#            'clouds': 0,
#            'datetime': '2025-11-09:15',
#            'dewpt': 9.6,
#            'dhi': 67,
#            'dni': 599,
#            'elev_angle': 14.7,
#            'ghi': 212,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 212,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-09T16:00:00',
#            'timestamp_utc': '2025-11-09T15:00:00',
#            'ts': 1762700400,
#            'uv': 2,
#            'vis': 16,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 188,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 15.9,
#            'azimuth': 241.4,
#            'clouds': 0,
#            'datetime': '2025-11-09:16',
#            'dewpt': 9.6,
#            'dhi': 37,
#            'dni': 321,
#            'elev_angle': 5.4,
#            'ghi': 58,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 66,
#            'slp': 1036,
#            'snow': 0,
#            'solar_rad': 58,
#            'temp': 15.9,
#            'timestamp_local': '2025-11-09T17:00:00',
#            'timestamp_utc': '2025-11-09T16:00:00',
#            'ts': 1762704000,
#            'uv': 1.8,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 184,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 1.2},
#           {'app_temp': 13.7,
#            'azimuth': 251.4,
#            'clouds': 0,
#            'datetime': '2025-11-09:17',
#            'dewpt': 9.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -4.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 76,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 13.7,
#            'timestamp_local': '2025-11-09T18:00:00',
#            'timestamp_utc': '2025-11-09T17:00:00',
#            'ts': 1762707600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 164,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.4},
#           {'app_temp': 12.6,
#            'azimuth': 260.9,
#            'clouds': 0,
#            'datetime': '2025-11-09:18',
#            'dewpt': 8.9,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -15.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 78,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 12.6,
#            'timestamp_local': '2025-11-09T19:00:00',
#            'timestamp_utc': '2025-11-09T18:00:00',
#            'ts': 1762711200,
#            'uv': 0,
#            'vis': 12,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 348,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 0},
#           {'app_temp': 10.7,
#            'azimuth': 270.5,
#            'clouds': 0,
#            'datetime': '2025-11-09:19',
#            'dewpt': 8.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -27,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 10.7,
#            'timestamp_local': '2025-11-09T20:00:00',
#            'timestamp_utc': '2025-11-09T19:00:00',
#            'ts': 1762714800,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 338,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 9.6,
#            'azimuth': 281.2,
#            'clouds': 0,
#            'datetime': '2025-11-09:20',
#            'dewpt': 7.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -38.1,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 88,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 9.6,
#            'timestamp_local': '2025-11-09T21:00:00',
#            'timestamp_utc': '2025-11-09T20:00:00',
#            'ts': 1762718400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 8.9,
#            'azimuth': 294.4,
#            'clouds': 16,
#            'datetime': '2025-11-09:21',
#            'dewpt': 7.4,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -48.8,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 90,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 8.9,
#            'timestamp_local': '2025-11-09T22:00:00',
#            'timestamp_utc': '2025-11-09T21:00:00',
#            'ts': 1762722000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7.8,
#            'azimuth': 312.8,
#            'clouds': 0,
#            'datetime': '2025-11-09:22',
#            'dewpt': 5.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -58.2,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1018,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1039,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.8,
#            'timestamp_local': '2025-11-09T23:00:00',
#            'timestamp_utc': '2025-11-09T22:00:00',
#            'ts': 1762725600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7.4,
#            'azimuth': 340,
#            'clouds': 33,
#            'datetime': '2025-11-09:23',
#            'dewpt': 5.2,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -64.5,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.4,
#            'timestamp_local': '2025-11-10T00:00:00',
#            'timestamp_utc': '2025-11-09T23:00:00',
#            'ts': 1762729200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 802,
#                        'description': 'Scattered clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 6.6,
#            'azimuth': 14,
#            'clouds': 55,
#            'datetime': '2025-11-10:00',
#            'dewpt': 4.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -65.1,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7,
#            'timestamp_local': '2025-11-10T01:00:00',
#            'timestamp_utc': '2025-11-10T00:00:00',
#            'ts': 1762732800,
#            'uv': 0,
#            'vis': 14,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03n'},
#            'wind_dir': 344,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7.4,
#            'azimuth': 43,
#            'clouds': 56,
#            'datetime': '2025-11-10:01',
#            'dewpt': 4,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -59.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 79,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7.4,
#            'timestamp_local': '2025-11-10T02:00:00',
#            'timestamp_utc': '2025-11-10T01:00:00',
#            'ts': 1762736400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 6.6,
#            'azimuth': 62.8,
#            'clouds': 48,
#            'datetime': '2025-11-10:02',
#            'dewpt': 3.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -50.7,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 79,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7,
#            'timestamp_local': '2025-11-10T03:00:00',
#            'timestamp_utc': '2025-11-10T02:00:00',
#            'ts': 1762740000,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03n'},
#            'wind_dir': 344,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 6.3,
#            'azimuth': 76.7,
#            'clouds': 21,
#            'datetime': '2025-11-10:03',
#            'dewpt': 3.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -40.2,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 81,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T04:00:00',
#            'timestamp_utc': '2025-11-10T03:00:00',
#            'ts': 1762743600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 802,
#                        'description': 'Scattered clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 346,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2},
#           {'app_temp': 7,
#            'azimuth': 87.8,
#            'clouds': 4,
#            'datetime': '2025-11-10:04',
#            'dewpt': 3.7,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -29.1,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0.5,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 81,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T05:00:00',
#            'timestamp_utc': '2025-11-10T04:00:00',
#            'ts': 1762747200,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 301, 'description': 'Drizzle', 'icon': 'd02n'},
#            'wind_dir': 338,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 7.3,
#            'azimuth': 97.5,
#            'clouds': 0,
#            'datetime': '2025-11-10:05',
#            'dewpt': 4.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -17.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 84,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 7,
#            'timestamp_local': '2025-11-10T06:00:00',
#            'timestamp_utc': '2025-11-10T05:00:00',
#            'ts': 1762750800,
#            'uv': 0,
#            'vis': 16,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 330,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 7,
#            'azimuth': 107,
#            'clouds': 0,
#            'datetime': '2025-11-10:06',
#            'dewpt': 4.5,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -6.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T07:00:00',
#            'timestamp_utc': '2025-11-10T06:00:00',
#            'ts': 1762754400,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 328,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 6.3,
#            'azimuth': 116.8,
#            'clouds': 5,
#            'datetime': '2025-11-10:07',
#            'dewpt': 4.5,
#            'dhi': 28,
#            'dni': 221,
#            'elev_angle': 3.5,
#            'ghi': 32,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 86,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 32,
#            'temp': 6.7,
#            'timestamp_local': '2025-11-10T08:00:00',
#            'timestamp_utc': '2025-11-10T07:00:00',
#            'ts': 1762758000,
#            'uv': 1.7,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02n'},
#            'wind_dir': 338,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 1.2},
#           {'app_temp': 8.5,
#            'azimuth': 127.7,
#            'clouds': 0,
#            'datetime': '2025-11-10:08',
#            'dewpt': 5.6,
#            'dhi': 63,
#            'dni': 562,
#            'elev_angle': 13,
#            'ghi': 181,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 82,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 181,
#            'temp': 8.5,
#            'timestamp_local': '2025-11-10T09:00:00',
#            'timestamp_utc': '2025-11-10T08:00:00',
#            'ts': 1762761600,
#            'uv': 1.9,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 336,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 0.8},
#           {'app_temp': 11.9,
#            'azimuth': 140,
#            'clouds': 0,
#            'datetime': '2025-11-10:09',
#            'dewpt': 7.8,
#            'dhi': 81,
#            'dni': 702,
#            'elev_angle': 21.1,
#            'ghi': 326,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 76,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 326,
#            'temp': 11.9,
#            'timestamp_local': '2025-11-10T10:00:00',
#            'timestamp_utc': '2025-11-10T09:00:00',
#            'ts': 1762765200,
#            'uv': 2.3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 264,
#            'wind_gust_spd': 3.2,
#            'wind_spd': 0.4},
#           {'app_temp': 14.1,
#            'azimuth': 154.3,
#            'clouds': 0,
#            'datetime': '2025-11-10:10',
#            'dewpt': 7.9,
#            'dhi': 91,
#            'dni': 773,
#            'elev_angle': 27.1,
#            'ghi': 437,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 66,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 437,
#            'temp': 14.1,
#            'timestamp_local': '2025-11-10T11:00:00',
#            'timestamp_utc': '2025-11-10T10:00:00',
#            'ts': 1762768800,
#            'uv': 2.9,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 240,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.2},
#           {'app_temp': 15.6,
#            'azimuth': 170.1,
#            'clouds': 0,
#            'datetime': '2025-11-10:11',
#            'dewpt': 8.6,
#            'dhi': 97,
#            'dni': 804,
#            'elev_angle': 30.6,
#            'ghi': 499,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 63,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 499,
#            'temp': 15.6,
#            'timestamp_local': '2025-11-10T12:00:00',
#            'timestamp_utc': '2025-11-10T11:00:00',
#            'ts': 1762772400,
#            'uv': 3.3,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 240,
#            'wind_gust_spd': 4.8,
#            'wind_spd': 2},
#           {'app_temp': 16.7,
#            'azimuth': 186.8,
#            'clouds': 0,
#            'datetime': '2025-11-10:12',
#            'dewpt': 8.7,
#            'dhi': 97,
#            'dni': 806,
#            'elev_angle': 30.9,
#            'ghi': 504,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 59,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 504,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-10T13:00:00',
#            'timestamp_utc': '2025-11-10T12:00:00',
#            'ts': 1762776000,
#            'uv': 3.4,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#            'wind_dir': 244,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.8},
#           {'app_temp': 17.4,
#            'azimuth': 202.9,
#            'clouds': 19,
#            'datetime': '2025-11-10:13',
#            'dewpt': 8.3,
#            'dhi': 93,
#            'dni': 781,
#            'elev_angle': 28,
#            'ghi': 452,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 55,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 451,
#            'temp': 17.4,
#            'timestamp_local': '2025-11-10T14:00:00',
#            'timestamp_utc': '2025-11-10T13:00:00',
#            'ts': 1762779600,
#            'uv': 2.6,
#            'vis': 13,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_dir': 250,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.8},
#           {'app_temp': 17.4,
#            'azimuth': 217.4,
#            'clouds': 49,
#            'datetime': '2025-11-10:14',
#            'dewpt': 8.3,
#            'dhi': 83,
#            'dni': 719,
#            'elev_angle': 22.3,
#            'ghi': 349,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 55,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 321,
#            'temp': 17.4,
#            'timestamp_local': '2025-11-10T15:00:00',
#            'timestamp_utc': '2025-11-10T14:00:00',
#            'ts': 1762783200,
#            'uv': 1.6,
#            'vis': 10,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03d'},
#            'wind_dir': 254,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.8},
#           {'app_temp': 17.4,
#            'azimuth': 230.1,
#            'clouds': 15,
#            'datetime': '2025-11-10:15',
#            'dewpt': 7.7,
#            'dhi': 67,
#            'dni': 595,
#            'elev_angle': 14.5,
#            'ghi': 208,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 53,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 208,
#            'temp': 17.4,
#            'timestamp_local': '2025-11-10T16:00:00',
#            'timestamp_utc': '2025-11-10T15:00:00',
#            'ts': 1762786800,
#            'uv': 1.8,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_dir': 260,
#            'wind_gust_spd': 6,
#            'wind_spd': 2.4},
#           {'app_temp': 16.7,
#            'azimuth': 241.2,
#            'clouds': 6,
#            'datetime': '2025-11-10:16',
#            'dewpt': 7.9,
#            'dhi': 36,
#            'dni': 313,
#            'elev_angle': 5.2,
#            'ghi': 56,
#            'h_angle': None,
#            'pod': 'd',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 56,
#            'slp': 1034,
#            'snow': 0,
#            'solar_rad': 56,
#            'temp': 16.7,
#            'timestamp_local': '2025-11-10T17:00:00',
#            'timestamp_utc': '2025-11-10T16:00:00',
#            'ts': 1762790400,
#            'uv': 1.7,
#            'vis': 10,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_dir': 252,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 1.2},
#           {'app_temp': 14.4,
#            'azimuth': 251.2,
#            'clouds': 0,
#            'datetime': '2025-11-10:17',
#            'dewpt': 8.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -5,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1014,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 68,
#            'slp': 1035,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 14.4,
#            'timestamp_local': '2025-11-10T18:00:00',
#            'timestamp_utc': '2025-11-10T17:00:00',
#            'ts': 1762794000,
#            'uv': 0,
#            'vis': 13,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 278,
#            'wind_gust_spd': 2.4,
#            'wind_spd': 0},
#           {'app_temp': 11.9,
#            'azimuth': 260.6,
#            'clouds': 0,
#            'datetime': '2025-11-10:18',
#            'dewpt': 8.6,
#            'dhi': 0,
#            'dni': 0,
#            'elev_angle': -15.9,
#            'ghi': 0,
#            'h_angle': None,
#            'pod': 'n',
#            'precip': 0,
#            'pres': 1016,
#            'revision_status': 'interim',
#            'revision_version': '0.0',
#            'rh': 80,
#            'slp': 1037,
#            'snow': 0,
#            'solar_rad': 0,
#            'temp': 11.9,
#            'timestamp_local': '2025-11-10T19:00:00',
#            'timestamp_utc': '2025-11-10T18:00:00',
#            'ts': 1762797600,
#            'uv': 0,
#            'vis': 10,
#            'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#            'wind_dir': 4,
#            'wind_gust_spd': 2.8,
#            'wind_spd': 1.2}],
#  'lat': 41.5333,
#  'lon': 2.2667,
#  'sources': ['imerg', 'era5', 'sat', 'radar'],
#  'state_code': '56',
#  'station_id': '081763-99999',
#  'timezone': 'Europe/Madrid'}

# %%
data = {}
url = "https://api.weatherbit.io/v2.0/history/daily?lat=41.63333&lon=2.16667&start_date=2024-11-15&end_date=2025-11-15&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())
data
# Out:
# {'city_id': '3127035',
#  'city_name': 'Caldes de Montbui',
#  'country_code': 'ES',
#  'data': [{'clouds': 85,
#    'datetime': '2024-11-15',
#    'dewpt': 9.1,
#    'dhi': 30,
#    'dni': 252,
#    'ghi': 119,
#    'max_dhi': 95,
#    'max_dni': 797,
#    'max_ghi': 482,
#    'max_temp': 17,
#    'max_temp_ts': 1731682800,
#    'max_uv': 1.6,
#    'max_wind_dir': 231,
#    'max_wind_spd': 2.8,
#    'max_wind_spd_ts': 1731675600,
#    'min_temp': 11,
#    'min_temp_ts': 1731650400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 78,
#    'slp': 1023,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 76,
#    't_dhi': 709,
#    't_dni': 6058,
#    't_ghi': 2856,
#    't_solar_rad': 1820,
#    'temp': 12.9,
#    'ts': 1731625200,
#    'wind_dir': 231,
#    'wind_gust_spd': 5.6,
#    'wind_spd': 1.2},
#   {'clouds': 53,
#    'datetime': '2024-11-16',
#    'dewpt': 10.2,
#    'dhi': 29,
#    'dni': 251,
#    'ghi': 118,
#    'max_dhi': 95,
#    'max_dni': 795,
#    'max_ghi': 478,
#    'max_temp': 19,
#    'max_temp_ts': 1731762000,
#    'max_uv': 2.2,
#    'max_wind_dir': 253,
#    'max_wind_spd': 2.4,
#    'max_wind_spd_ts': 1731769200,
#    'min_temp': 9,
#    'min_temp_ts': 1731736800,
#    'precip': 1.8,
#    'precip_gpm': 1.8,
#    'pres': 994,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 81,
#    'slp': 1022,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 89,
#    't_dhi': 704,
#    't_dni': 6014,
#    't_ghi': 2821,
#    't_solar_rad': 2146,
#    'temp': 13.6,
#    'ts': 1731711600,
#    'wind_dir': 253,
#    'wind_gust_spd': 5.6,
#    'wind_spd': 1.1},
#   {'clouds': 27,
#    'datetime': '2024-11-17',
#    'dewpt': 9.1,
#    'dhi': 29,
#    'dni': 249,
#    'ghi': 116,
#    'max_dhi': 95,
#    'max_dni': 793,
#    'max_ghi': 474,
#    'max_temp': 20,
#    'max_temp_ts': 1731880800,
#    'max_uv': 3.1,
#    'max_wind_dir': 267,
#    'max_wind_spd': 2.4,
#    'max_wind_spd_ts': 1731880800,
#    'min_temp': 8,
#    'min_temp_ts': 1731823200,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 81,
#    'slp': 1018,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 116,
#    't_dhi': 699,
#    't_dni': 5971,
#    't_ghi': 2786,
#    't_solar_rad': 2786,
#    'temp': 12.5,
#    'ts': 1731798000,
#    'wind_dir': 267,
#    'wind_gust_spd': 4.6,
#    'wind_spd': 1.2},
#   {'clouds': 87,
#    'datetime': '2024-11-18',
#    'dewpt': 11.6,
#    'dhi': 29,
#    'dni': 247,
#    'ghi': 115,
#    'max_dhi': 94,
#    'max_dni': 792,
#    'max_ghi': 470,
#    'max_temp': 15.6,
#    'max_temp_ts': 1731895200,
#    'max_uv': 1.1,
#    'max_wind_dir': 149,
#    'max_wind_spd': 3.2,
#    'max_wind_spd_ts': 1731891600,
#    'min_temp': 11.9,
#    'min_temp_ts': 1731898800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 88,
#    'slp': 1018,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 29,
#    't_dhi': 694,
#    't_dni': 5928,
#    't_ghi': 2753,
#    't_solar_rad': 705,
#    'temp': 13.6,
#    'ts': 1731884400,
#    'wind_dir': 149,
#    'wind_gust_spd': 7.2,
#    'wind_spd': 2.1},
#   {'clouds': 47,
#    'datetime': '2024-11-19',
#    'dewpt': 10.7,
#    'dhi': 29,
#    'dni': 245,
#    'ghi': 113,
#    'max_dhi': 94,
#    'max_dni': 790,
#    'max_ghi': 466,
#    'max_temp': 18.1,
#    'max_temp_ts': 1731970800,
#    'max_uv': 3.1,
#    'max_wind_dir': 280,
#    'max_wind_spd': 4,
#    'max_wind_spd_ts': 1731970800,
#    'min_temp': 10.7,
#    'min_temp_ts': 1731970800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 988,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 82,
#    'slp': 1015,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 113,
#    't_dhi': 689,
#    't_dni': 5885,
#    't_ghi': 2720,
#    't_solar_rad': 2720,
#    'temp': 13.9,
#    'ts': 1731970800,
#    'wind_dir': 280,
#    'wind_gust_spd': 8.4,
#    'wind_spd': 2.5},
#   {'clouds': 93,
#    'datetime': '2024-11-20',
#    'dewpt': 9.5,
#    'dhi': 29,
#    'dni': 243,
#    'ghi': 112,
#    'max_dhi': 94,
#    'max_dni': 788,
#    'max_ghi': 462,
#    'max_temp': 17.8,
#    'max_temp_ts': 1732104000,
#    'max_uv': 1.1,
#    'max_wind_dir': 269,
#    'max_wind_spd': 6.8,
#    'max_wind_spd_ts': 1732104000,
#    'min_temp': 13,
#    'min_temp_ts': 1732104000,
#    'precip': 6.3,
#    'precip_gpm': 6.3,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 67,
#    'slp': 1011,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 36,
#    't_dhi': 684,
#    't_dni': 5843,
#    't_ghi': 2689,
#    't_solar_rad': 857,
#    'temp': 15.7,
#    'ts': 1732057200,
#    'wind_dir': 269,
#    'wind_gust_spd': 13.2,
#    'wind_spd': 3.8},
#   {'clouds': 78,
#    'datetime': '2024-11-21',
#    'dewpt': 9.3,
#    'dhi': 28,
#    'dni': 242,
#    'ghi': 111,
#    'max_dhi': 94,
#    'max_dni': 786,
#    'max_ghi': 459,
#    'max_temp': 17,
#    'max_temp_ts': 1732186800,
#    'max_uv': 1.3,
#    'max_wind_dir': 226,
#    'max_wind_spd': 8.4,
#    'max_wind_spd_ts': 1732186800,
#    'min_temp': 11.9,
#    'min_temp_ts': 1732226400,
#    'precip': 3.3,
#    'precip_gpm': 3.3,
#    'pres': 981,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 1008,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 46,
#    't_dhi': 679,
#    't_dni': 5801,
#    't_ghi': 2658,
#    't_solar_rad': 1111,
#    'temp': 14.6,
#    'ts': 1732143600,
#    'wind_dir': 226,
#    'wind_gust_spd': 15.2,
#    'wind_spd': 5.4},
#   {'clouds': 45,
#    'datetime': '2024-11-22',
#    'dewpt': 5,
#    'dhi': 28,
#    'dni': 240,
#    'ghi': 109,
#    'max_dhi': 93,
#    'max_dni': 785,
#    'max_ghi': 455,
#    'max_temp': 17,
#    'max_temp_ts': 1732284000,
#    'max_uv': 2.7,
#    'max_wind_dir': 252,
#    'max_wind_spd': 5.4,
#    'max_wind_spd_ts': 1732240800,
#    'min_temp': 10,
#    'min_temp_ts': 1732298400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 56,
#    'slp': 1012,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 107,
#    't_dhi': 675,
#    't_dni': 5761,
#    't_ghi': 2628,
#    't_solar_rad': 2569,
#    'temp': 13.9,
#    'ts': 1732230000,
#    'wind_dir': 252,
#    'wind_gust_spd': 14.4,
#    'wind_spd': 3.6},
#   {'clouds': 67,
#    'datetime': '2024-11-23',
#    'dewpt': 8.1,
#    'dhi': 28,
#    'dni': 238,
#    'ghi': 108,
#    'max_dhi': 93,
#    'max_dni': 783,
#    'max_ghi': 452,
#    'max_temp': 17,
#    'max_temp_ts': 1732366800,
#    'max_uv': 2.7,
#    'max_wind_dir': 248,
#    'max_wind_spd': 4.7,
#    'max_wind_spd_ts': 1732374000,
#    'min_temp': 9,
#    'min_temp_ts': 1732341600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 74,
#    'slp': 1026,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 99,
#    't_dhi': 670,
#    't_dni': 5721,
#    't_ghi': 2599,
#    't_solar_rad': 2370,
#    'temp': 12.8,
#    'ts': 1732316400,
#    'wind_dir': 248,
#    'wind_gust_spd': 8.8,
#    'wind_spd': 1.6},
#   {'clouds': 67,
#    'datetime': '2024-11-24',
#    'dewpt': 12.4,
#    'dhi': 28,
#    'dni': 237,
#    'ghi': 107,
#    'max_dhi': 93,
#    'max_dni': 782,
#    'max_ghi': 448,
#    'max_temp': 19,
#    'max_temp_ts': 1732453200,
#    'max_uv': 2.3,
#    'max_wind_dir': 199,
#    'max_wind_spd': 2.7,
#    'max_wind_spd_ts': 1732402800,
#    'min_temp': 11.5,
#    'min_temp_ts': 1732485600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 87,
#    'slp': 1025,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 102,
#    't_dhi': 665,
#    't_dni': 5683,
#    't_ghi': 2571,
#    't_solar_rad': 2440,
#    'temp': 14.8,
#    'ts': 1732402800,
#    'wind_dir': 199,
#    'wind_gust_spd': 6,
#    'wind_spd': 1.4},
#   {'clouds': 62,
#    'datetime': '2024-11-25',
#    'dewpt': 12.1,
#    'dhi': 28,
#    'dni': 235,
#    'ghi': 106,
#    'max_dhi': 92,
#    'max_dni': 780,
#    'max_ghi': 445,
#    'max_temp': 18,
#    'max_temp_ts': 1732546800,
#    'max_uv': 1.5,
#    'max_wind_dir': 215,
#    'max_wind_spd': 2.5,
#    'max_wind_spd_ts': 1732550400,
#    'min_temp': 10,
#    'min_temp_ts': 1732496400,
#    'precip': 1.3,
#    'precip_gpm': 1.3,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 88,
#    'slp': 1020,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 68,
#    't_dhi': 660,
#    't_dni': 5647,
#    't_ghi': 2545,
#    't_solar_rad': 1625,
#    'temp': 14,
#    'ts': 1732489200,
#    'wind_dir': 215,
#    'wind_gust_spd': 9.2,
#    'wind_spd': 1.1},
#   {'clouds': 70,
#    'datetime': '2024-11-26',
#    'dewpt': 8.1,
#    'dhi': 27,
#    'dni': 234,
#    'ghi': 105,
#    'max_dhi': 92,
#    'max_dni': 779,
#    'max_ghi': 442,
#    'max_temp': 16,
#    'max_temp_ts': 1732618800,
#    'max_uv': 1.4,
#    'max_wind_dir': 270,
#    'max_wind_spd': 2.7,
#    'max_wind_spd_ts': 1732597200,
#    'min_temp': 9,
#    'min_temp_ts': 1732658400,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 995,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 1022,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 65,
#    't_dhi': 656,
#    't_dni': 5613,
#    't_ghi': 2519,
#    't_solar_rad': 1561,
#    'temp': 12.5,
#    'ts': 1732575600,
#    'wind_dir': 270,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.6},
#   {'clouds': 20,
#    'datetime': '2024-11-27',
#    'dewpt': 6.3,
#    'dhi': 27,
#    'dni': 233,
#    'ghi': 104,
#    'max_dhi': 92,
#    'max_dni': 777,
#    'max_ghi': 439,
#    'max_temp': 17,
#    'max_temp_ts': 1732712400,
#    'max_uv': 2.9,
#    'max_wind_dir': 266,
#    'max_wind_spd': 2.5,
#    'max_wind_spd_ts': 1732730400,
#    'min_temp': 6,
#    'min_temp_ts': 1732744800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 77,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 103,
#    't_dhi': 651,
#    't_dni': 5581,
#    't_ghi': 2494,
#    't_solar_rad': 2483,
#    'temp': 10.5,
#    'ts': 1732662000,
#    'wind_dir': 266,
#    'wind_gust_spd': 3.6,
#    'wind_spd': 1.4},
#   {'clouds': 7,
#    'datetime': '2024-11-28',
#    'dewpt': 5,
#    'dhi': 27,
#    'dni': 231,
#    'ghi': 103,
#    'max_dhi': 92,
#    'max_dni': 776,
#    'max_ghi': 436,
#    'max_temp': 19,
#    'max_temp_ts': 1732802400,
#    'max_uv': 2.9,
#    'max_wind_dir': 249,
#    'max_wind_spd': 2,
#    'max_wind_spd_ts': 1732795200,
#    'min_temp': 3,
#    'min_temp_ts': 1732773600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 997,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1025,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 103,
#    't_dhi': 646,
#    't_dni': 5553,
#    't_ghi': 2471,
#    't_solar_rad': 2471,
#    'temp': 9.4,
#    'ts': 1732748400,
#    'wind_dir': 249,
#    'wind_gust_spd': 4,
#    'wind_spd': 1},
#   {'clouds': 19,
#    'datetime': '2024-11-29',
#    'dewpt': 5.7,
#    'dhi': 27,
#    'dni': 230,
#    'ghi': 102,
#    'max_dhi': 92,
#    'max_dni': 774,
#    'max_ghi': 433,
#    'max_temp': 18,
#    'max_temp_ts': 1732885200,
#    'max_uv': 2.9,
#    'max_wind_dir': 218,
#    'max_wind_spd': 3.5,
#    'max_wind_spd_ts': 1732892400,
#    'min_temp': 4,
#    'min_temp_ts': 1732852800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 78,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 102,
#    't_dhi': 642,
#    't_dni': 5528,
#    't_ghi': 2448,
#    't_solar_rad': 2448,
#    'temp': 9.7,
#    'ts': 1732834800,
#    'wind_dir': 218,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.1},
#   {'clouds': 43,
#    'datetime': '2024-11-30',
#    'dewpt': 8.2,
#    'dhi': 27,
#    'dni': 229,
#    'ghi': 101,
#    'max_dhi': 91,
#    'max_dni': 773,
#    'max_ghi': 430,
#    'max_temp': 17,
#    'max_temp_ts': 1733004000,
#    'max_uv': 2.8,
#    'max_wind_dir': 248,
#    'max_wind_spd': 3.2,
#    'max_wind_spd_ts': 1733004000,
#    'min_temp': 6,
#    'min_temp_ts': 1732942800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 999,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 85,
#    'slp': 1027,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 101,
#    't_dhi': 638,
#    't_dni': 5506,
#    't_ghi': 2427,
#    't_solar_rad': 2427,
#    'temp': 10.8,
#    'ts': 1732921200,
#    'wind_dir': 248,
#    'wind_gust_spd': 4,
#    'wind_spd': 1.2},
#   {'clouds': 62,
#    'datetime': '2024-12-01',
#    'dewpt': 11.1,
#    'dhi': 26,
#    'dni': 229,
#    'ghi': 100,
#    'max_dhi': 91,
#    'max_dni': 772,
#    'max_ghi': 428,
#    'max_temp': 15.9,
#    'max_temp_ts': 1733086800,
#    'max_uv': 1.4,
#    'max_wind_dir': 301,
#    'max_wind_spd': 2.8,
#    'max_wind_spd_ts': 1733065200,
#    'min_temp': 10,
#    'min_temp_ts': 1733090400,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 88,
#    'slp': 1025,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 77,
#    't_dhi': 635,
#    't_dni': 5485,
#    't_ghi': 2407,
#    't_solar_rad': 1847,
#    'temp': 13,
#    'ts': 1733007600,
#    'wind_dir': 301,
#    'wind_gust_spd': 4.4,
#    'wind_spd': 1.8},
#   {'clouds': 70,
#    'datetime': '2024-12-02',
#    'dewpt': 7.7,
#    'dhi': 26,
#    'dni': 228,
#    'ghi': 99,
#    'max_dhi': 91,
#    'max_dni': 771,
#    'max_ghi': 425,
#    'max_temp': 19,
#    'max_temp_ts': 1733144400,
#    'max_uv': 0.8,
#    'max_wind_dir': 210,
#    'max_wind_spd': 5.8,
#    'max_wind_spd_ts': 1733140800,
#    'min_temp': 8,
#    'min_temp_ts': 1733097600,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 994,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 77,
#    'slp': 1021,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 34,
#    't_dhi': 632,
#    't_dni': 5466,
#    't_ghi': 2387,
#    't_solar_rad': 817,
#    'temp': 11.9,
#    'ts': 1733094000,
#    'wind_dir': 210,
#    'wind_gust_spd': 6.6,
#    'wind_spd': 1.6},
#   {'clouds': 60,
#    'datetime': '2024-12-03',
#    'dewpt': 6.5,
#    'dhi': 26,
#    'dni': 227,
#    'ghi': 99,
#    'max_dhi': 91,
#    'max_dni': 769,
#    'max_ghi': 423,
#    'max_temp': 15,
#    'max_temp_ts': 1733230800,
#    'max_uv': 1.5,
#    'max_wind_dir': 221,
#    'max_wind_spd': 5,
#    'max_wind_spd_ts': 1733234400,
#    'min_temp': 6,
#    'min_temp_ts': 1733194800,
#    'precip': 0.8,
#    'precip_gpm': 0.8,
#    'pres': 992,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 79,
#    'slp': 1020,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 77,
#    't_dhi': 630,
#    't_dni': 5447,
#    't_ghi': 2369,
#    't_solar_rad': 1837,
#    'temp': 10.1,
#    'ts': 1733180400,
#    'wind_dir': 221,
#    'wind_gust_spd': 7.2,
#    'wind_spd': 1.6},
#   {'clouds': 36,
#    'datetime': '2024-12-04',
#    'dewpt': 6,
#    'dhi': 26,
#    'dni': 226,
#    'ghi': 98,
#    'max_dhi': 91,
#    'max_dni': 768,
#    'max_ghi': 421,
#    'max_temp': 14,
#    'max_temp_ts': 1733317200,
#    'max_uv': 1.6,
#    'max_wind_dir': 249,
#    'max_wind_spd': 3.4,
#    'max_wind_spd_ts': 1733324400,
#    'min_temp': 7,
#    'min_temp_ts': 1733295600,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 77,
#    'slp': 1021,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 86,
#    't_dhi': 628,
#    't_dni': 5429,
#    't_ghi': 2352,
#    't_solar_rad': 2061,
#    'temp': 10,
#    'ts': 1733266800,
#    'wind_dir': 249,
#    'wind_gust_spd': 7.2,
#    'wind_spd': 1.8},
#   {'clouds': 54,
#    'datetime': '2024-12-05',
#    'dewpt': 3.6,
#    'dhi': 26,
#    'dni': 226,
#    'ghi': 97,
#    'max_dhi': 90,
#    'max_dni': 767,
#    'max_ghi': 419,
#    'max_temp': 16,
#    'max_temp_ts': 1733407200,
#    'max_uv': 1.5,
#    'max_wind_dir': 275,
#    'max_wind_spd': 2.7,
#    'max_wind_spd_ts': 1733396400,
#    'min_temp': 4,
#    'min_temp_ts': 1733367600,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 70,
#    'slp': 1026,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 57,
#    't_dhi': 626,
#    't_dni': 5413,
#    't_ghi': 2335,
#    't_solar_rad': 1375,
#    'temp': 9,
#    'ts': 1733353200,
#    'wind_dir': 275,
#    'wind_gust_spd': 6,
#    'wind_spd': 1.3},
#   {'clouds': 78,
#    'datetime': '2024-12-06',
#    'dewpt': 7,
#    'dhi': 26,
#    'dni': 225,
#    'ghi': 97,
#    'max_dhi': 90,
#    'max_dni': 766,
#    'max_ghi': 417,
#    'max_temp': 16,
#    'max_temp_ts': 1733490000,
#    'max_uv': 0.8,
#    'max_wind_dir': 257,
#    'max_wind_spd': 3.1,
#    'max_wind_spd_ts': 1733450400,
#    'min_temp': 7,
#    'min_temp_ts': 1733439600,
#    'precip': 1.3,
#    'precip_gpm': 1.3,
#    'pres': 995,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1022,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 31,
#    't_dhi': 624,
#    't_dni': 5397,
#    't_ghi': 2320,
#    't_solar_rad': 736,
#    'temp': 11.2,
#    'ts': 1733439600,
#    'wind_dir': 257,
#    'wind_gust_spd': 5.6,
#    'wind_spd': 1.4},
#   {'clouds': 44,
#    'datetime': '2024-12-07',
#    'dewpt': 6.2,
#    'dhi': 26,
#    'dni': 224,
#    'ghi': 96,
#    'max_dhi': 90,
#    'max_dni': 765,
#    'max_ghi': 415,
#    'max_temp': 18,
#    'max_temp_ts': 1733580000,
#    'max_uv': 1.6,
#    'max_wind_dir': 258,
#    'max_wind_spd': 12.4,
#    'max_wind_spd_ts': 1733587200,
#    'min_temp': 8,
#    'min_temp_ts': 1733533200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 68,
#    'slp': 1017,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 69,
#    't_dhi': 622,
#    't_dni': 5382,
#    't_ghi': 2306,
#    't_solar_rad': 1655,
#    'temp': 12.5,
#    'ts': 1733526000,
#    'wind_dir': 258,
#    'wind_gust_spd': 19.2,
#    'wind_spd': 4.3},
#   {'clouds': 43,
#    'datetime': '2024-12-08',
#    'dewpt': 0.6,
#    'dhi': 26,
#    'dni': 224,
#    'ghi': 96,
#    'max_dhi': 90,
#    'max_dni': 765,
#    'max_ghi': 413,
#    'max_temp': 13,
#    'max_temp_ts': 1733662800,
#    'max_uv': 2,
#    'max_wind_dir': 260,
#    'max_wind_spd': 8.2,
#    'max_wind_spd_ts': 1733652000,
#    'min_temp': 4,
#    'min_temp_ts': 1733637600,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 59,
#    'slp': 1012,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 81,
#    't_dhi': 620,
#    't_dni': 5369,
#    't_ghi': 2292,
#    't_solar_rad': 1934,
#    'temp': 8.3,
#    'ts': 1733612400,
#    'wind_dir': 260,
#    'wind_gust_spd': 13.2,
#    'wind_spd': 4.5},
#   {'clouds': 47,
#    'datetime': '2024-12-09',
#    'dewpt': 0.9,
#    'dhi': 26,
#    'dni': 223,
#    'ghi': 95,
#    'max_dhi': 90,
#    'max_dni': 764,
#    'max_ghi': 412,
#    'max_temp': 12,
#    'max_temp_ts': 1733745600,
#    'max_uv': 1.9,
#    'max_wind_dir': 251,
#    'max_wind_spd': 5,
#    'max_wind_spd_ts': 1733749200,
#    'min_temp': 3,
#    'min_temp_ts': 1733727600,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 64,
#    'slp': 1011,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 78,
#    't_dhi': 619,
#    't_dni': 5357,
#    't_ghi': 2280,
#    't_solar_rad': 1869,
#    'temp': 7.6,
#    'ts': 1733698800,
#    'wind_dir': 251,
#    'wind_gust_spd': 8.8,
#    'wind_spd': 2.1},
#   {'clouds': 67,
#    'datetime': '2024-12-10',
#    'dewpt': 2.5,
#    'dhi': 26,
#    'dni': 223,
#    'ghi': 95,
#    'max_dhi': 90,
#    'max_dni': 763,
#    'max_ghi': 410,
#    'max_temp': 11,
#    'max_temp_ts': 1733832000,
#    'max_uv': 1.4,
#    'max_wind_dir': 270,
#    'max_wind_spd': 2.2,
#    'max_wind_spd_ts': 1733814000,
#    'min_temp': 3,
#    'min_temp_ts': 1733810400,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 73,
#    'slp': 1017,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 62,
#    't_dhi': 617,
#    't_dni': 5346,
#    't_ghi': 2268,
#    't_solar_rad': 1490,
#    'temp': 7.1,
#    'ts': 1733785200,
#    'wind_dir': 270,
#    'wind_gust_spd': 6.8,
#    'wind_spd': 1.3},
#   {'clouds': 84,
#    'datetime': '2024-12-11',
#    'dewpt': 5,
#    'dhi': 26,
#    'dni': 222,
#    'ghi': 94,
#    'max_dhi': 90,
#    'max_dni': 762,
#    'max_ghi': 409,
#    'max_temp': 9,
#    'max_temp_ts': 1733918400,
#    'max_uv': 1,
#    'max_wind_dir': 260,
#    'max_wind_spd': 4.8,
#    'max_wind_spd_ts': 1733882400,
#    'min_temp': 6,
#    'min_temp_ts': 1733893200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 84,
#    'slp': 1021,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 51,
#    't_dhi': 616,
#    't_dni': 5336,
#    't_ghi': 2258,
#    't_solar_rad': 1221,
#    'temp': 7.4,
#    'ts': 1733871600,
#    'wind_dir': 260,
#    'wind_gust_spd': 9.2,
#    'wind_spd': 1.5},
#   {'clouds': 79,
#    'datetime': '2024-12-12',
#    'dewpt': 6.6,
#    'dhi': 26,
#    'dni': 222,
#    'ghi': 94,
#    'max_dhi': 89,
#    'max_dni': 762,
#    'max_ghi': 408,
#    'max_temp': 12,
#    'max_temp_ts': 1734012000,
#    'max_uv': 0.9,
#    'max_wind_dir': 174,
#    'max_wind_spd': 2.9,
#    'max_wind_spd_ts': 1734012000,
#    'min_temp': 6,
#    'min_temp_ts': 1733965200,
#    'precip': 37.3,
#    'precip_gpm': 37.3,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 84,
#    'slp': 1021,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 39,
#    't_dhi': 615,
#    't_dni': 5327,
#    't_ghi': 2249,
#    't_solar_rad': 944,
#    'temp': 9.2,
#    'ts': 1733958000,
#    'wind_dir': 174,
#    'wind_gust_spd': 13.2,
#    'wind_spd': 2.1},
#   {'clouds': 50,
#    'datetime': '2024-12-13',
#    'dewpt': 6.2,
#    'dhi': 26,
#    'dni': 222,
#    'ghi': 93,
#    'max_dhi': 89,
#    'max_dni': 761,
#    'max_ghi': 407,
#    'max_temp': 15,
#    'max_temp_ts': 1734091200,
#    'max_uv': 1.6,
#    'max_wind_dir': 230,
#    'max_wind_spd': 2.7,
#    'max_wind_spd_ts': 1734123600,
#    'min_temp': 4,
#    'min_temp_ts': 1734069600,
#    'precip': 2.5,
#    'precip_gpm': 2.5,
#    'pres': 994,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 84,
#    'slp': 1022,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 88,
#    't_dhi': 614,
#    't_dni': 5319,
#    't_ghi': 2240,
#    't_solar_rad': 2121,
#    'temp': 8.9,
#    'ts': 1734044400,
#    'wind_dir': 230,
#    'wind_gust_spd': 8,
#    'wind_spd': 1.6},
#   {'clouds': 21,
#    'datetime': '2024-12-14',
#    'dewpt': 3.9,
#    'dhi': 26,
#    'dni': 221,
#    'ghi': 93,
#    'max_dhi': 89,
#    'max_dni': 761,
#    'max_ghi': 406,
#    'max_temp': 12,
#    'max_temp_ts': 1734184800,
#    'max_uv': 2.2,
#    'max_wind_dir': 271,
#    'max_wind_spd': 5.8,
#    'max_wind_spd_ts': 1734177600,
#    'min_temp': 4,
#    'min_temp_ts': 1734213600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 79,
#    'slp': 1026,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 93,
#    't_dhi': 613,
#    't_dni': 5313,
#    't_ghi': 2233,
#    't_solar_rad': 2233,
#    'temp': 7.5,
#    'ts': 1734130800,
#    'wind_dir': 271,
#    'wind_gust_spd': 6.7,
#    'wind_spd': 2.5},
#   {'clouds': 25,
#    'datetime': '2024-12-15',
#    'dewpt': 2.5,
#    'dhi': 26,
#    'dni': 221,
#    'ghi': 93,
#    'max_dhi': 89,
#    'max_dni': 761,
#    'max_ghi': 405,
#    'max_temp': 12,
#    'max_temp_ts': 1734267600,
#    'max_uv': 2,
#    'max_wind_dir': 261,
#    'max_wind_spd': 2.7,
#    'max_wind_spd_ts': 1734274800,
#    'min_temp': 1,
#    'min_temp_ts': 1734246000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1004,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 81,
#    'slp': 1032,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 91,
#    't_dhi': 612,
#    't_dni': 5308,
#    't_ghi': 2227,
#    't_solar_rad': 2192,
#    'temp': 5.6,
#    'ts': 1734217200,
#    'wind_dir': 261,
#    'wind_gust_spd': 4.4,
#    'wind_spd': 1.6},
#   {'clouds': 10,
#    'datetime': '2024-12-16',
#    'dewpt': 2.6,
#    'dhi': 25,
#    'dni': 221,
#    'ghi': 93,
#    'max_dhi': 89,
#    'max_dni': 760,
#    'max_ghi': 405,
#    'max_temp': 13,
#    'max_temp_ts': 1734357600,
#    'max_uv': 2.2,
#    'max_wind_dir': 255,
#    'max_wind_spd': 3.7,
#    'max_wind_spd_ts': 1734379200,
#    'min_temp': 1,
#    'min_temp_ts': 1734328800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1009,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 78,
#    'slp': 1038,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 93,
#    't_dhi': 612,
#    't_dni': 5304,
#    't_ghi': 2222,
#    't_solar_rad': 2222,
#    'temp': 6.5,
#    'ts': 1734303600,
#    'wind_dir': 255,
#    'wind_gust_spd': 6.8,
#    'wind_spd': 1.9},
#   {'clouds': 35,
#    'datetime': '2024-12-17',
#    'dewpt': 3.4,
#    'dhi': 25,
#    'dni': 221,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 760,
#    'max_ghi': 404,
#    'max_temp': 14,
#    'max_temp_ts': 1734440400,
#    'max_uv': 1.7,
#    'max_wind_dir': 222,
#    'max_wind_spd': 5,
#    'max_wind_spd_ts': 1734440400,
#    'min_temp': 2,
#    'min_temp_ts': 1734411600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1004,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 1033,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 86,
#    't_dhi': 611,
#    't_dni': 5301,
#    't_ghi': 2217,
#    't_solar_rad': 2075,
#    'temp': 7.9,
#    'ts': 1734390000,
#    'wind_dir': 222,
#    'wind_gust_spd': 8.8,
#    'wind_spd': 2.2},
#   {'clouds': 18,
#    'datetime': '2024-12-18',
#    'dewpt': 3.7,
#    'dhi': 25,
#    'dni': 221,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 760,
#    'max_ghi': 404,
#    'max_temp': 16,
#    'max_temp_ts': 1734530400,
#    'max_uv': 2.2,
#    'max_wind_dir': 207,
#    'max_wind_spd': 2,
#    'max_wind_spd_ts': 1734555600,
#    'min_temp': 3,
#    'min_temp_ts': 1734501600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 999,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 1027,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 92,
#    't_dhi': 611,
#    't_dni': 5300,
#    't_ghi': 2214,
#    't_solar_rad': 2214,
#    'temp': 8.8,
#    'ts': 1734476400,
#    'wind_dir': 207,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.3},
#   {'clouds': 30,
#    'datetime': '2024-12-19',
#    'dewpt': 5.1,
#    'dhi': 25,
#    'dni': 221,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 760,
#    'max_ghi': 404,
#    'max_temp': 18,
#    'max_temp_ts': 1734616800,
#    'max_uv': 2.2,
#    'max_wind_dir': 245,
#    'max_wind_spd': 9,
#    'max_wind_spd_ts': 1734609600,
#    'min_temp': 8,
#    'min_temp_ts': 1734645600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 56,
#    'slp': 1017,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 88,
#    't_dhi': 611,
#    't_dni': 5300,
#    't_ghi': 2212,
#    't_solar_rad': 2116,
#    'temp': 13.8,
#    'ts': 1734562800,
#    'wind_dir': 245,
#    'wind_gust_spd': 15.5,
#    'wind_spd': 3.8},
#   {'clouds': 14,
#    'datetime': '2024-12-20',
#    'dewpt': 1.3,
#    'dhi': 25,
#    'dni': 221,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 760,
#    'max_ghi': 404,
#    'max_temp': 13,
#    'max_temp_ts': 1734699600,
#    'max_uv': 2.2,
#    'max_wind_dir': 268,
#    'max_wind_spd': 4.8,
#    'max_wind_spd_ts': 1734692400,
#    'min_temp': 2,
#    'min_temp_ts': 1734674400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 68,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 92,
#    't_dhi': 611,
#    't_dni': 5301,
#    't_ghi': 2211,
#    't_solar_rad': 2208,
#    'temp': 7.3,
#    'ts': 1734649200,
#    'wind_dir': 268,
#    'wind_gust_spd': 8.8,
#    'wind_spd': 2.5},
#   {'clouds': 18,
#    'datetime': '2024-12-21',
#    'dewpt': 1.3,
#    'dhi': 25,
#    'dni': 221,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 760,
#    'max_ghi': 404,
#    'max_temp': 13,
#    'max_temp_ts': 1734793200,
#    'max_uv': 2.2,
#    'max_wind_dir': 260,
#    'max_wind_spd': 4.7,
#    'max_wind_spd_ts': 1734789600,
#    'min_temp': 1,
#    'min_temp_ts': 1734764400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 999,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 73,
#    'slp': 1028,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 92,
#    't_dhi': 611,
#    't_dni': 5303,
#    't_ghi': 2211,
#    't_solar_rad': 2205,
#    'temp': 6.2,
#    'ts': 1734735600,
#    'wind_dir': 260,
#    'wind_gust_spd': 5.3,
#    'wind_spd': 1.8},
#   {'clouds': 20,
#    'datetime': '2024-12-22',
#    'dewpt': 4.8,
#    'dhi': 25,
#    'dni': 221,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 760,
#    'max_ghi': 404,
#    'max_temp': 15,
#    'max_temp_ts': 1734879600,
#    'max_uv': 1.2,
#    'max_wind_dir': 271,
#    'max_wind_spd': 8.6,
#    'max_wind_spd_ts': 1734876000,
#    'min_temp': 5,
#    'min_temp_ts': 1734825600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 69,
#    'slp': 1021,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 47,
#    't_dhi': 612,
#    't_dni': 5307,
#    't_ghi': 2212,
#    't_solar_rad': 1129,
#    'temp': 10.4,
#    'ts': 1734822000,
#    'wind_dir': 271,
#    'wind_gust_spd': 14.6,
#    'wind_spd': 4.3},
#   {'clouds': 25,
#    'datetime': '2024-12-23',
#    'dewpt': -0.1,
#    'dhi': 26,
#    'dni': 221,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 761,
#    'max_ghi': 404,
#    'max_temp': 14,
#    'max_temp_ts': 1734962400,
#    'max_uv': 1.8,
#    'max_wind_dir': 233,
#    'max_wind_spd': 3,
#    'max_wind_spd_ts': 1734908400,
#    'min_temp': 2,
#    'min_temp_ts': 1734991200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 992,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 62,
#    'slp': 1020,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 90,
#    't_dhi': 612,
#    't_dni': 5312,
#    't_ghi': 2214,
#    't_solar_rad': 2155,
#    'temp': 7.5,
#    'ts': 1734908400,
#    'wind_dir': 233,
#    'wind_gust_spd': 7.7,
#    'wind_spd': 1.9},
#   {'clouds': 32,
#    'datetime': '2024-12-24',
#    'dewpt': 1.3,
#    'dhi': 26,
#    'dni': 222,
#    'ghi': 92,
#    'max_dhi': 89,
#    'max_dni': 761,
#    'max_ghi': 405,
#    'max_temp': 12,
#    'max_temp_ts': 1735045200,
#    'max_uv': 1.3,
#    'max_wind_dir': 293,
#    'max_wind_spd': 2.4,
#    'max_wind_spd_ts': 1734994800,
#    'min_temp': 0,
#    'min_temp_ts': 1735023600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 74,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 74,
#    't_dhi': 613,
#    't_dni': 5318,
#    't_ghi': 2218,
#    't_solar_rad': 1784,
#    'temp': 5.7,
#    'ts': 1734994800,
#    'wind_dir': 293,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.4},
#   {'clouds': 49,
#    'datetime': '2024-12-25',
#    'dewpt': 5.8,
#    'dhi': 26,
#    'dni': 222,
#    'ghi': 93,
#    'max_dhi': 89,
#    'max_dni': 761,
#    'max_ghi': 405,
#    'max_temp': 15,
#    'max_temp_ts': 1735128000,
#    'max_uv': 2,
#    'max_wind_dir': 244,
#    'max_wind_spd': 2,
#    'max_wind_spd_ts': 1735131600,
#    'min_temp': 3,
#    'min_temp_ts': 1735102800,
#    'precip': 0.8,
#    'precip_gpm': 0.8,
#    'pres': 1000,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 84,
#    'slp': 1028,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 92,
#    't_dhi': 614,
#    't_dni': 5325,
#    't_ghi': 2222,
#    't_solar_rad': 2207,
#    'temp': 8.4,
#    'ts': 1735081200,
#    'wind_dir': 244,
#    'wind_gust_spd': 6,
#    'wind_spd': 1.2},
#   {'clouds': 86,
#    'datetime': '2024-12-26',
#    'dewpt': 8.6,
#    'dhi': 26,
#    'dni': 222,
#    'ghi': 93,
#    'max_dhi': 89,
#    'max_dni': 762,
#    'max_ghi': 406,
#    'max_temp': 13,
#    'max_temp_ts': 1735221600,
#    'max_uv': 1.3,
#    'max_wind_dir': 183,
#    'max_wind_spd': 3.1,
#    'max_wind_spd_ts': 1735225200,
#    'min_temp': 7,
#    'min_temp_ts': 1735250400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1002,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 90,
#    'slp': 1030,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 64,
#    't_dhi': 615,
#    't_dni': 5334,
#    't_ghi': 2227,
#    't_solar_rad': 1525,
#    'temp': 10.3,
#    'ts': 1735167600,
#    'wind_dir': 183,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.4},
#   {'clouds': 26,
#    'datetime': '2024-12-27',
#    'dewpt': 2.5,
#    'dhi': 26,
#    'dni': 223,
#    'ghi': 93,
#    'max_dhi': 89,
#    'max_dni': 762,
#    'max_ghi': 407,
#    'max_temp': 15,
#    'max_temp_ts': 1735308000,
#    'max_uv': 2.2,
#    'max_wind_dir': 259,
#    'max_wind_spd': 3.1,
#    'max_wind_spd_ts': 1735322400,
#    'min_temp': 2,
#    'min_temp_ts': 1735282800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1003,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1031,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 93,
#    't_dhi': 616,
#    't_dni': 5344,
#    't_ghi': 2234,
#    't_solar_rad': 2234,
#    'temp': 7.2,
#    'ts': 1735254000,
#    'wind_dir': 259,
#    'wind_gust_spd': 5.6,
#    'wind_spd': 1.4},
#   {'clouds': 11,
#    'datetime': '2024-12-28',
#    'dewpt': 0.9,
#    'dhi': 26,
#    'dni': 223,
#    'ghi': 93,
#    'max_dhi': 90,
#    'max_dni': 763,
#    'max_ghi': 408,
#    'max_temp': 15,
#    'max_temp_ts': 1735394400,
#    'max_uv': 2.2,
#    'max_wind_dir': 249,
#    'max_wind_spd': 2.7,
#    'max_wind_spd_ts': 1735408800,
#    'min_temp': -1,
#    'min_temp_ts': 1735369200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1001,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 1030,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 93,
#    't_dhi': 617,
#    't_dni': 5355,
#    't_ghi': 2241,
#    't_solar_rad': 2241,
#    'temp': 5.5,
#    'ts': 1735340400,
#    'wind_dir': 249,
#    'wind_gust_spd': 3.6,
#    'wind_spd': 1.4},
#   {'clouds': 0,
#    'datetime': '2024-12-29',
#    'dewpt': 0.9,
#    'dhi': 26,
#    'dni': 224,
#    'ghi': 94,
#    'max_dhi': 90,
#    'max_dni': 764,
#    'max_ghi': 409,
#    'max_temp': 15,
#    'max_temp_ts': 1735477200,
#    'max_uv': 2.2,
#    'max_wind_dir': 255,
#    'max_wind_spd': 3,
#    'max_wind_spd_ts': 1735498800,
#    'min_temp': 0,
#    'min_temp_ts': 1735455600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1001,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 1029,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 94,
#    't_dhi': 618,
#    't_dni': 5367,
#    't_ghi': 2249,
#    't_solar_rad': 2249,
#    'temp': 5.5,
#    'ts': 1735426800,
#    'wind_dir': 255,
#    'wind_gust_spd': 4.4,
#    'wind_spd': 1.4},
#   {'clouds': 7,
#    'datetime': '2024-12-30',
#    'dewpt': 0.5,
#    'dhi': 26,
#    'dni': 224,
#    'ghi': 94,
#    'max_dhi': 90,
#    'max_dni': 765,
#    'max_ghi': 410,
#    'max_temp': 14,
#    'max_temp_ts': 1735567200,
#    'max_uv': 2.2,
#    'max_wind_dir': 249,
#    'max_wind_spd': 2.9,
#    'max_wind_spd_ts': 1735581600,
#    'min_temp': -1,
#    'min_temp_ts': 1735538400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1002,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1030,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 94,
#    't_dhi': 620,
#    't_dni': 5380,
#    't_ghi': 2259,
#    't_solar_rad': 2259,
#    'temp': 4.8,
#    'ts': 1735513200,
#    'wind_dir': 249,
#    'wind_gust_spd': 3.6,
#    'wind_spd': 1.4},
#   {'clouds': 24,
#    'datetime': '2024-12-31',
#    'dewpt': 2.4,
#    'dhi': 26,
#    'dni': 225,
#    'ghi': 95,
#    'max_dhi': 90,
#    'max_dni': 765,
#    'max_ghi': 412,
#    'max_temp': 14,
#    'max_temp_ts': 1735650000,
#    'max_uv': 1.9,
#    'max_wind_dir': 249,
#    'max_wind_spd': 2.3,
#    'max_wind_spd_ts': 1735671600,
#    'min_temp': 0,
#    'min_temp_ts': 1735628400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1003,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 84,
#    'slp': 1031,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 94,
#    't_dhi': 621,
#    't_dni': 5394,
#    't_ghi': 2270,
#    't_solar_rad': 2248,
#    'temp': 5.1,
#    'ts': 1735599600,
#    'wind_dir': 249,
#    'wind_gust_spd': 4.4,
#    'wind_spd': 1},
#   {'clouds': 42,
#    'datetime': '2025-01-01',
#    'dewpt': 3.1,
#    'dhi': 26,
#    'dni': 225,
#    'ghi': 95,
#    'max_dhi': 90,
#    'max_dni': 766,
#    'max_ghi': 412,
#    'max_temp': 13,
#    'max_temp_ts': 1735740000,
#    'max_uv': 1.7,
#    'max_wind_dir': 244,
#    'max_wind_spd': 2.4,
#    'max_wind_spd_ts': 1735736400,
#    'min_temp': 0,
#    'min_temp_ts': 1735714800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1002,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 82,
#    'slp': 1031,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 92,
#    't_dhi': 622,
#    't_dni': 5398,
#    't_ghi': 2272,
#    't_solar_rad': 2210,
#    'temp': 6.2,
#    'ts': 1735686000,
#    'wind_dir': 244,
#    'wind_gust_spd': 3.6,
#    'wind_spd': 1.2},
#   {'clouds': 44,
#    'datetime': '2025-01-02',
#    'dewpt': 1.2,
#    'dhi': 26,
#    'dni': 226,
#    'ghi': 95,
#    'max_dhi': 90,
#    'max_dni': 767,
#    'max_ghi': 414,
#    'max_temp': 13,
#    'max_temp_ts': 1735826400,
#    'max_uv': 1.8,
#    'max_wind_dir': 224,
#    'max_wind_spd': 6.4,
#    'max_wind_spd_ts': 1735830000,
#    'min_temp': 1,
#    'min_temp_ts': 1735783200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 997,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 1026,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 86,
#    't_dhi': 624,
#    't_dni': 5413,
#    't_ghi': 2284,
#    't_solar_rad': 2075,
#    'temp': 6.2,
#    'ts': 1735772400,
#    'wind_dir': 224,
#    'wind_gust_spd': 8.4,
#    'wind_spd': 3},
#   {'clouds': 60,
#    'datetime': '2025-01-03',
#    'dewpt': 2.2,
#    'dhi': 26,
#    'dni': 226,
#    'ghi': 96,
#    'max_dhi': 90,
#    'max_dni': 768,
#    'max_ghi': 416,
#    'max_temp': 13,
#    'max_temp_ts': 1735912800,
#    'max_uv': 1.6,
#    'max_wind_dir': 265,
#    'max_wind_spd': 5.3,
#    'max_wind_spd_ts': 1735898400,
#    'min_temp': 5,
#    'min_temp_ts': 1735876800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 67,
#    'slp': 1021,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 62,
#    't_dhi': 626,
#    't_dni': 5430,
#    't_ghi': 2297,
#    't_solar_rad': 1495,
#    'temp': 8.1,
#    'ts': 1735858800,
#    'wind_dir': 265,
#    'wind_gust_spd': 6,
#    'wind_spd': 2.5},
#   {'clouds': 39,
#    'datetime': '2025-01-04',
#    'dewpt': 6.1,
#    'dhi': 26,
#    'dni': 227,
#    'ghi': 96,
#    'max_dhi': 90,
#    'max_dni': 769,
#    'max_ghi': 417,
#    'max_temp': 15,
#    'max_temp_ts': 1735999200,
#    'max_uv': 1.2,
#    'max_wind_dir': 298,
#    'max_wind_spd': 4.5,
#    'max_wind_spd_ts': 1735963200,
#    'min_temp': 6,
#    'min_temp_ts': 1735948800,
#    'precip': 3.5,
#    'precip_gpm': 3.5,
#    'pres': 992,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1020,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 58,
#    't_dhi': 628,
#    't_dni': 5448,
#    't_ghi': 2311,
#    't_solar_rad': 1401,
#    'temp': 10.2,
#    'ts': 1735945200,
#    'wind_dir': 298,
#    'wind_gust_spd': 5.2,
#    'wind_spd': 2},
#   {'clouds': 84,
#    'datetime': '2025-01-05',
#    'dewpt': 5.3,
#    'dhi': 26,
#    'dni': 228,
#    'ghi': 97,
#    'max_dhi': 91,
#    'max_dni': 770,
#    'max_ghi': 419,
#    'max_temp': 15,
#    'max_temp_ts': 1736082000,
#    'max_uv': 1,
#    'max_wind_dir': 212,
#    'max_wind_spd': 4.8,
#    'max_wind_spd_ts': 1736100000,
#    'min_temp': 4,
#    'min_temp_ts': 1736035200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1013,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 42,
#    't_dhi': 630,
#    't_dni': 5466,
#    't_ghi': 2326,
#    't_solar_rad': 1015,
#    'temp': 9.6,
#    'ts': 1736031600,
#    'wind_dir': 212,
#    'wind_gust_spd': 10.4,
#    'wind_spd': 2.4},
#   {'clouds': 46,
#    'datetime': '2025-01-06',
#    'dewpt': 6.3,
#    'dhi': 26,
#    'dni': 229,
#    'ghi': 98,
#    'max_dhi': 91,
#    'max_dni': 771,
#    'max_ghi': 422,
#    'max_temp': 17,
#    'max_temp_ts': 1736172000,
#    'max_uv': 1.6,
#    'max_wind_dir': 206,
#    'max_wind_spd': 3.6,
#    'max_wind_spd_ts': 1736175600,
#    'min_temp': 6,
#    'min_temp_ts': 1736139600,
#    'precip': 12.8,
#    'precip_gpm': 12.8,
#    'pres': 978,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 73,
#    'slp': 1006,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 64,
#    't_dhi': 632,
#    't_dni': 5486,
#    't_ghi': 2342,
#    't_solar_rad': 1543,
#    'temp': 11.3,
#    'ts': 1736118000,
#    'wind_dir': 206,
#    'wind_gust_spd': 7.6,
#    'wind_spd': 1.8},
#   {'clouds': 26,
#    'datetime': '2025-01-07',
#    'dewpt': 2.3,
#    'dhi': 26,
#    'dni': 229,
#    'ghi': 98,
#    'max_dhi': 91,
#    'max_dni': 772,
#    'max_ghi': 424,
#    'max_temp': 13,
#    'max_temp_ts': 1736280000,
#    'max_uv': 2.3,
#    'max_wind_dir': 270,
#    'max_wind_spd': 7.4,
#    'max_wind_spd_ts': 1736287200,
#    'min_temp': 3,
#    'min_temp_ts': 1736226000,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 987,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 64,
#    'slp': 1015,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 98,
#    't_dhi': 635,
#    't_dni': 5506,
#    't_ghi': 2359,
#    't_solar_rad': 2357,
#    'temp': 8.9,
#    'ts': 1736204400,
#    'wind_dir': 270,
#    'wind_gust_spd': 9.6,
#    'wind_spd': 4.1},
#   {'clouds': 45,
#    'datetime': '2025-01-08',
#    'dewpt': 4.6,
#    'dhi': 27,
#    'dni': 230,
#    'ghi': 99,
#    'max_dhi': 91,
#    'max_dni': 774,
#    'max_ghi': 426,
#    'max_temp': 18,
#    'max_temp_ts': 1736301600,
#    'max_uv': 1.9,
#    'max_wind_dir': 264,
#    'max_wind_spd': 8.9,
#    'max_wind_spd_ts': 1736308800,
#    'min_temp': 6.7,
#    'min_temp_ts': 1736319600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 988,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 62,
#    'slp': 1015,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 88,
#    't_dhi': 637,
#    't_dni': 5528,
#    't_ghi': 2377,
#    't_solar_rad': 2115,
#    'temp': 11.8,
#    'ts': 1736290800,
#    'wind_dir': 264,
#    'wind_gust_spd': 12.4,
#    'wind_spd': 5},
#   {'clouds': 12,
#    'datetime': '2025-01-09',
#    'dewpt': 5.1,
#    'dhi': 27,
#    'dni': 231,
#    'ghi': 100,
#    'max_dhi': 91,
#    'max_dni': 775,
#    'max_ghi': 429,
#    'max_temp': 18,
#    'max_temp_ts': 1736427600,
#    'max_uv': 2.3,
#    'max_wind_dir': 257,
#    'max_wind_spd': 7.9,
#    'max_wind_spd_ts': 1736420400,
#    'min_temp': 8,
#    'min_temp_ts': 1736460000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 988,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 56,
#    'slp': 1015,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 100,
#    't_dhi': 640,
#    't_dni': 5550,
#    't_ghi': 2396,
#    't_solar_rad': 2396,
#    'temp': 14,
#    'ts': 1736377200,
#    'wind_dir': 257,
#    'wind_gust_spd': 14.9,
#    'wind_spd': 4.3},
#   {'clouds': 33,
#    'datetime': '2025-01-10',
#    'dewpt': 5.8,
#    'dhi': 27,
#    'dni': 232,
#    'ghi': 101,
#    'max_dhi': 92,
#    'max_dni': 776,
#    'max_ghi': 431,
#    'max_temp': 18,
#    'max_temp_ts': 1736514000,
#    'max_uv': 2.2,
#    'max_wind_dir': 264,
#    'max_wind_spd': 5.9,
#    'max_wind_spd_ts': 1736514000,
#    'min_temp': 5,
#    'min_temp_ts': 1736492400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 1020,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 98,
#    't_dhi': 643,
#    't_dni': 5573,
#    't_ghi': 2416,
#    't_solar_rad': 2345,
#    'temp': 11,
#    'ts': 1736463600,
#    'wind_dir': 264,
#    'wind_gust_spd': 7.2,
#    'wind_spd': 2},
#   {'clouds': 38,
#    'datetime': '2025-01-11',
#    'dewpt': 6,
#    'dhi': 27,
#    'dni': 233,
#    'ghi': 102,
#    'max_dhi': 92,
#    'max_dni': 778,
#    'max_ghi': 434,
#    'max_temp': 19,
#    'max_temp_ts': 1736604000,
#    'max_uv': 1.8,
#    'max_wind_dir': 264,
#    'max_wind_spd': 5.4,
#    'max_wind_spd_ts': 1736575200,
#    'min_temp': 9,
#    'min_temp_ts': 1736632800,
#    'precip': 5.3,
#    'precip_gpm': 5.3,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 60,
#    'slp': 1018,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 72,
#    't_dhi': 645,
#    't_dni': 5597,
#    't_ghi': 2437,
#    't_solar_rad': 1726,
#    'temp': 14,
#    'ts': 1736550000,
#    'wind_dir': 264,
#    'wind_gust_spd': 8,
#    'wind_spd': 2.5},
#   {'clouds': 9,
#    'datetime': '2025-01-12',
#    'dewpt': -4.5,
#    'dhi': 27,
#    'dni': 234,
#    'ghi': 102,
#    'max_dhi': 92,
#    'max_dni': 779,
#    'max_ghi': 437,
#    'max_temp': 14,
#    'max_temp_ts': 1736679600,
#    'max_uv': 2.3,
#    'max_wind_dir': 216,
#    'max_wind_spd': 4.8,
#    'max_wind_spd_ts': 1736683200,
#    'min_temp': 1,
#    'min_temp_ts': 1736719200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 44,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 102,
#    't_dhi': 648,
#    't_dni': 5621,
#    't_ghi': 2459,
#    't_solar_rad': 2459,
#    'temp': 7.7,
#    'ts': 1736636400,
#    'wind_dir': 216,
#    'wind_gust_spd': 6,
#    'wind_spd': 2.3},
#   {'clouds': 8,
#    'datetime': '2025-01-13',
#    'dewpt': -3.4,
#    'dhi': 27,
#    'dni': 235,
#    'ghi': 103,
#    'max_dhi': 92,
#    'max_dni': 781,
#    'max_ghi': 440,
#    'max_temp': 11,
#    'max_temp_ts': 1736780400,
#    'max_uv': 2.4,
#    'max_wind_dir': 256,
#    'max_wind_spd': 3.5,
#    'max_wind_spd_ts': 1736794800,
#    'min_temp': -2,
#    'min_temp_ts': 1736748000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1000,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 62,
#    'slp': 1028,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 103,
#    't_dhi': 652,
#    't_dni': 5647,
#    't_ghi': 2482,
#    't_solar_rad': 2482,
#    'temp': 3.6,
#    'ts': 1736722800,
#    'wind_dir': 256,
#    'wind_gust_spd': 5.2,
#    'wind_spd': 1.4},
#   {'clouds': 18,
#    'datetime': '2025-01-14',
#    'dewpt': -3.9,
#    'dhi': 27,
#    'dni': 236,
#    'ghi': 104,
#    'max_dhi': 93,
#    'max_dni': 783,
#    'max_ghi': 443,
#    'max_temp': 11,
#    'max_temp_ts': 1736863200,
#    'max_uv': 2.4,
#    'max_wind_dir': 233,
#    'max_wind_spd': 2.6,
#    'max_wind_spd_ts': 1736881200,
#    'min_temp': -3,
#    'min_temp_ts': 1736834400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1001,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 65,
#    'slp': 1030,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 104,
#    't_dhi': 655,
#    't_dni': 5673,
#    't_ghi': 2506,
#    't_solar_rad': 2506,
#    'temp': 2.8,
#    'ts': 1736809200,
#    'wind_dir': 233,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.6},
#   {'clouds': 20,
#    'datetime': '2025-01-15',
#    'dewpt': -3.6,
#    'dhi': 27,
#    'dni': 237,
#    'ghi': 105,
#    'max_dhi': 93,
#    'max_dni': 784,
#    'max_ghi': 446,
#    'max_temp': 13,
#    'max_temp_ts': 1736949600,
#    'max_uv': 2.4,
#    'max_wind_dir': 252,
#    'max_wind_spd': 4.2,
#    'max_wind_spd_ts': 1736953200,
#    'min_temp': -3,
#    'min_temp_ts': 1736924400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 64,
#    'slp': 1026,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 103,
#    't_dhi': 658,
#    't_dni': 5699,
#    't_ghi': 2531,
#    't_solar_rad': 2482,
#    'temp': 3.3,
#    'ts': 1736895600,
#    'wind_dir': 252,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.5},
#   {'clouds': 29,
#    'datetime': '2025-01-16',
#    'dewpt': -0.9,
#    'dhi': 28,
#    'dni': 239,
#    'ghi': 107,
#    'max_dhi': 93,
#    'max_dni': 786,
#    'max_ghi': 450,
#    'max_temp': 12,
#    'max_temp_ts': 1737028800,
#    'max_uv': 1.7,
#    'max_wind_dir': 163,
#    'max_wind_spd': 5.7,
#    'max_wind_spd_ts': 1737039600,
#    'min_temp': -2,
#    'min_temp_ts': 1736989200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 997,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 67,
#    'slp': 1026,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 91,
#    't_dhi': 661,
#    't_dni': 5726,
#    't_ghi': 2557,
#    't_solar_rad': 2181,
#    'temp': 4.9,
#    'ts': 1736982000,
#    'wind_dir': 163,
#    'wind_gust_spd': 15.6,
#    'wind_spd': 2.5},
#   {'clouds': 46,
#    'datetime': '2025-01-17',
#    'dewpt': 1.5,
#    'dhi': 28,
#    'dni': 240,
#    'ghi': 108,
#    'max_dhi': 93,
#    'max_dni': 788,
#    'max_ghi': 453,
#    'max_temp': 14,
#    'max_temp_ts': 1737122400,
#    'max_uv': 2.3,
#    'max_wind_dir': 159,
#    'max_wind_spd': 5.4,
#    'max_wind_spd_ts': 1737111600,
#    'min_temp': 2,
#    'min_temp_ts': 1737151200,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 1001,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 64,
#    'slp': 1029,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 107,
#    't_dhi': 665,
#    't_dni': 5754,
#    't_ghi': 2584,
#    't_solar_rad': 2559,
#    'temp': 8.4,
#    'ts': 1737068400,
#    'wind_dir': 159,
#    'wind_gust_spd': 14.8,
#    'wind_spd': 2.6},
#   {'clouds': 30,
#    'datetime': '2025-01-18',
#    'dewpt': -1.2,
#    'dhi': 28,
#    'dni': 241,
#    'ghi': 109,
#    'max_dhi': 94,
#    'max_dni': 790,
#    'max_ghi': 457,
#    'max_temp': 14,
#    'max_temp_ts': 1737212400,
#    'max_uv': 2.4,
#    'max_wind_dir': 256,
#    'max_wind_spd': 2.4,
#    'max_wind_spd_ts': 1737208800,
#    'min_temp': -1,
#    'min_temp_ts': 1737183600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 65,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 109,
#    't_dhi': 668,
#    't_dni': 5782,
#    't_ghi': 2612,
#    't_solar_rad': 2606,
#    'temp': 5.5,
#    'ts': 1737154800,
#    'wind_dir': 256,
#    'wind_gust_spd': 5.6,
# ...
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 157,
#    't_dhi': 823,
#    't_dni': 6966,
#    't_ghi': 3808,
#    't_solar_rad': 3779,
#    'temp': 15.4,
#    'ts': 1761256800,
#    'wind_dir': 268,
#    'wind_gust_spd': 8.2,
#    'wind_spd': 2.9},
#   {'clouds': 47,
#    'datetime': '2025-10-25',
#    'dewpt': 10.5,
#    'dhi': 34,
#    'dni': 289,
#    'ghi': 157,
#    'max_dhi': 103,
#    'max_dni': 837,
#    'max_ghi': 586,
#    'max_temp': 21.8,
#    'max_temp_ts': 1761397200,
#    'max_uv': 3,
#    'max_wind_dir': 252,
#    'max_wind_spd': 3.9,
#    'max_wind_spd_ts': 1761397200,
#    'min_temp': 13,
#    'min_temp_ts': 1761361200,
#    'precip': 1.8,
#    'precip_gpm': 1.8,
#    'pres': 986,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 66,
#    'slp': 1013,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 128,
#    't_dhi': 818,
#    't_dni': 6928,
#    't_ghi': 3759,
#    't_solar_rad': 3078,
#    'temp': 17,
#    'ts': 1761343200,
#    'wind_dir': 252,
#    'wind_gust_spd': 4.8,
#    'wind_spd': 1.7},
#   {'clouds': 59,
#    'datetime': '2025-10-26',
#    'dewpt': 10.6,
#    'dhi': 33,
#    'dni': 276,
#    'ghi': 148,
#    'max_dhi': 102,
#    'max_dni': 835,
#    'max_ghi': 581,
#    'max_temp': 18,
#    'max_temp_ts': 1761429600,
#    'max_uv': 2,
#    'max_wind_dir': 223,
#    'max_wind_spd': 3,
#    'max_wind_spd_ts': 1761480000,
#    'min_temp': 10,
#    'min_temp_ts': 1761516000,
#    'precip': 17,
#    'precip_gpm': 17,
#    'pres': 988,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1016,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 64,
#    't_dhi': 813,
#    't_dni': 6891,
#    't_ghi': 3710,
#    't_solar_rad': 1610,
#    'temp': 14.9,
#    'ts': 1761429600,
#    'wind_dir': 223,
#    'wind_gust_spd': 5.1,
#    'wind_spd': 1.8},
#   {'clouds': 71,
#    'datetime': '2025-10-27',
#    'dewpt': 6.2,
#    'dhi': 34,
#    'dni': 286,
#    'ghi': 153,
#    'max_dhi': 102,
#    'max_dni': 833,
#    'max_ghi': 575,
#    'max_temp': 18.3,
#    'max_temp_ts': 1761577200,
#    'max_uv': 3.5,
#    'max_wind_dir': 262,
#    'max_wind_spd': 5.7,
#    'max_wind_spd_ts': 1761559200,
#    'min_temp': 7,
#    'min_temp_ts': 1761544800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 994,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 66,
#    'slp': 1020,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 152,
#    't_dhi': 808,
#    't_dni': 6853,
#    't_ghi': 3663,
#    't_solar_rad': 3638,
#    'temp': 12.7,
#    'ts': 1761519600,
#    'wind_dir': 262,
#    'wind_gust_spd': 6.5,
#    'wind_spd': 2.9},
#   {'clouds': 56,
#    'datetime': '2025-10-28',
#    'dewpt': 8.8,
#    'dhi': 33,
#    'dni': 284,
#    'ghi': 151,
#    'max_dhi': 102,
#    'max_dni': 831,
#    'max_ghi': 570,
#    'max_temp': 21.1,
#    'max_temp_ts': 1761660000,
#    'max_uv': 3.7,
#    'max_wind_dir': 201,
#    'max_wind_spd': 2.8,
#    'max_wind_spd_ts': 1761634800,
#    'min_temp': 10,
#    'min_temp_ts': 1761624000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 995,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 70,
#    'slp': 1019,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 147,
#    't_dhi': 803,
#    't_dni': 6814,
#    't_ghi': 3615,
#    't_solar_rad': 3524,
#    'temp': 14.5,
#    'ts': 1761606000,
#    'wind_dir': 201,
#    'wind_gust_spd': 5,
#    'wind_spd': 1.4},
#   {'clouds': 67,
#    'datetime': '2025-10-29',
#    'dewpt': 12.7,
#    'dhi': 33,
#    'dni': 282,
#    'ghi': 149,
#    'max_dhi': 101,
#    'max_dni': 829,
#    'max_ghi': 564,
#    'max_temp': 20,
#    'max_temp_ts': 1761746400,
#    'max_uv': 2.2,
#    'max_wind_dir': 170,
#    'max_wind_spd': 2,
#    'max_wind_spd_ts': 1761746400,
#    'min_temp': 9,
#    'min_temp_ts': 1761706800,
#    'precip': 5.8,
#    'precip_gpm': 5.8,
#    'pres': 983,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 88,
#    'slp': 1012,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 79,
#    't_dhi': 798,
#    't_dni': 6775,
#    't_ghi': 3568,
#    't_solar_rad': 1903,
#    'temp': 14.7,
#    'ts': 1761692400,
#    'wind_dir': 170,
#    'wind_gust_spd': 4.6,
#    'wind_spd': 0.9},
#   {'clouds': 60,
#    'datetime': '2025-10-30',
#    'dewpt': 13.1,
#    'dhi': 33,
#    'dni': 281,
#    'ghi': 147,
#    'max_dhi': 101,
#    'max_dni': 827,
#    'max_ghi': 559,
#    'max_temp': 23.6,
#    'max_temp_ts': 1761829200,
#    'max_uv': 2.8,
#    'max_wind_dir': 250,
#    'max_wind_spd': 4.6,
#    'max_wind_spd_ts': 1761822000,
#    'min_temp': 12,
#    'min_temp_ts': 1761861600,
#    'precip': 3.5,
#    'precip_gpm': 3.5,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 81,
#    'slp': 1012,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 140,
#    't_dhi': 793,
#    't_dni': 6736,
#    't_ghi': 3521,
#    't_solar_rad': 3356,
#    'temp': 16.7,
#    'ts': 1761778800,
#    'wind_dir': 250,
#    'wind_gust_spd': 7.2,
#    'wind_spd': 2.1},
#   {'clouds': 54,
#    'datetime': '2025-10-31',
#    'dewpt': 10.9,
#    'dhi': 33,
#    'dni': 279,
#    'ghi': 145,
#    'max_dhi': 100,
#    'max_dni': 825,
#    'max_ghi': 554,
#    'max_temp': 23,
#    'max_temp_ts': 1761922800,
#    'max_uv': 1.2,
#    'max_wind_dir': 244,
#    'max_wind_spd': 4.4,
#    'max_wind_spd_ts': 1761919200,
#    'min_temp': 11,
#    'min_temp_ts': 1761894000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 987,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 1016,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 46,
#    't_dhi': 788,
#    't_dni': 6696,
#    't_ghi': 3475,
#    't_solar_rad': 1102,
#    'temp': 15.7,
#    'ts': 1761865200,
#    'wind_dir': 244,
#    'wind_gust_spd': 7.3,
#    'wind_spd': 2.1},
#   {'clouds': 72,
#    'datetime': '2025-11-01',
#    'dewpt': 11.8,
#    'dhi': 33,
#    'dni': 277,
#    'ghi': 143,
#    'max_dhi': 100,
#    'max_dni': 823,
#    'max_ghi': 549,
#    'max_temp': 24,
#    'max_temp_ts': 1762009200,
#    'max_uv': 1.5,
#    'max_wind_dir': 193,
#    'max_wind_spd': 3.6,
#    'max_wind_spd_ts': 1761998400,
#    'min_temp': 11,
#    'min_temp_ts': 1761980400,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1017,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 55,
#    't_dhi': 782,
#    't_dni': 6655,
#    't_ghi': 3429,
#    't_solar_rad': 1308,
#    'temp': 16.5,
#    'ts': 1761951600,
#    'wind_dir': 193,
#    'wind_gust_spd': 6.9,
#    'wind_spd': 1.3},
#   {'clouds': 50,
#    'datetime': '2025-11-02',
#    'dewpt': 11.2,
#    'dhi': 32,
#    'dni': 276,
#    'ghi': 141,
#    'max_dhi': 100,
#    'max_dni': 822,
#    'max_ghi': 543,
#    'max_temp': 22,
#    'max_temp_ts': 1762084800,
#    'max_uv': 2.3,
#    'max_wind_dir': 183,
#    'max_wind_spd': 5.7,
#    'max_wind_spd_ts': 1762081200,
#    'min_temp': 12,
#    'min_temp_ts': 1762120800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 73,
#    'slp': 1018,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 70,
#    't_dhi': 777,
#    't_dni': 6615,
#    't_ghi': 3384,
#    't_solar_rad': 1681,
#    'temp': 16.6,
#    'ts': 1762038000,
#    'wind_dir': 183,
#    'wind_gust_spd': 6.4,
#    'wind_spd': 2.1},
#   {'clouds': 73,
#    'datetime': '2025-11-03',
#    'dewpt': 9.9,
#    'dhi': 32,
#    'dni': 274,
#    'ghi': 139,
#    'max_dhi': 99,
#    'max_dni': 820,
#    'max_ghi': 538,
#    'max_temp': 20.3,
#    'max_temp_ts': 1762178400,
#    'max_uv': 2.4,
#    'max_wind_dir': 225,
#    'max_wind_spd': 3.2,
#    'max_wind_spd_ts': 1762185600,
#    'min_temp': 9,
#    'min_temp_ts': 1762146000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 78,
#    'slp': 1023,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 115,
#    't_dhi': 772,
#    't_dni': 6573,
#    't_ghi': 3340,
#    't_solar_rad': 2759,
#    'temp': 13.9,
#    'ts': 1762124400,
#    'wind_dir': 225,
#    'wind_gust_spd': 4.6,
#    'wind_spd': 1.8},
#   {'clouds': 61,
#    'datetime': '2025-11-04',
#    'dewpt': 9.8,
#    'dhi': 32,
#    'dni': 272,
#    'ghi': 137,
#    'max_dhi': 99,
#    'max_dni': 818,
#    'max_ghi': 533,
#    'max_temp': 20.1,
#    'max_temp_ts': 1762257600,
#    'max_uv': 3.4,
#    'max_wind_dir': 162,
#    'max_wind_spd': 3.6,
#    'max_wind_spd_ts': 1762268400,
#    'min_temp': 8,
#    'min_temp_ts': 1762232400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 995,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 79,
#    'slp': 1023,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 133,
#    't_dhi': 767,
#    't_dni': 6532,
#    't_ghi': 3296,
#    't_solar_rad': 3197,
#    'temp': 13.7,
#    'ts': 1762210800,
#    'wind_dir': 162,
#    'wind_gust_spd': 4.4,
#    'wind_spd': 1.2},
#   {'clouds': 78,
#    'datetime': '2025-11-05',
#    'dewpt': 12.1,
#    'dhi': 32,
#    'dni': 270,
#    'ghi': 136,
#    'max_dhi': 99,
#    'max_dni': 816,
#    'max_ghi': 528,
#    'max_temp': 19,
#    'max_temp_ts': 1762347600,
#    'max_uv': 1.9,
#    'max_wind_dir': 165,
#    'max_wind_spd': 2.1,
#    'max_wind_spd_ts': 1762311600,
#    'min_temp': 9,
#    'min_temp_ts': 1762308000,
#    'precip': 0.3,
#    'precip_gpm': 0.3,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 89,
#    'slp': 1020,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 99,
#    't_dhi': 762,
#    't_dni': 6490,
#    't_ghi': 3252,
#    't_solar_rad': 2378,
#    'temp': 13.9,
#    'ts': 1762297200,
#    'wind_dir': 165,
#    'wind_gust_spd': 5.1,
#    'wind_spd': 0.9},
#   {'clouds': 58,
#    'datetime': '2025-11-06',
#    'dewpt': 11.8,
#    'dhi': 32,
#    'dni': 269,
#    'ghi': 134,
#    'max_dhi': 98,
#    'max_dni': 814,
#    'max_ghi': 523,
#    'max_temp': 17.8,
#    'max_temp_ts': 1762437600,
#    'max_uv': 2.6,
#    'max_wind_dir': 216,
#    'max_wind_spd': 6,
#    'max_wind_spd_ts': 1762434000,
#    'min_temp': 12,
#    'min_temp_ts': 1762466400,
#    'precip': 20.5,
#    'precip_gpm': 20.5,
#    'pres': 982,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 82,
#    'slp': 1010,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 74,
#    't_dhi': 756,
#    't_dni': 6447,
#    't_ghi': 3209,
#    't_solar_rad': 1785,
#    'temp': 15,
#    'ts': 1762383600,
#    'wind_dir': 216,
#    'wind_gust_spd': 9,
#    'wind_spd': 2.5},
#   {'clouds': 50,
#    'datetime': '2025-11-07',
#    'dewpt': 8.3,
#    'dhi': 31,
#    'dni': 267,
#    'ghi': 132,
#    'max_dhi': 98,
#    'max_dni': 812,
#    'max_ghi': 518,
#    'max_temp': 18.2,
#    'max_temp_ts': 1762531200,
#    'max_uv': 2.9,
#    'max_wind_dir': 265,
#    'max_wind_spd': 4.6,
#    'max_wind_spd_ts': 1762524000,
#    'min_temp': 9,
#    'min_temp_ts': 1762484400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 73,
#    'slp': 1012,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 126,
#    't_dhi': 751,
#    't_dni': 6405,
#    't_ghi': 3167,
#    't_solar_rad': 3027,
#    'temp': 13.2,
#    'ts': 1762470000,
#    'wind_dir': 265,
#    'wind_gust_spd': 6.7,
#    'wind_spd': 2.4},
#   {'clouds': 68,
#    'datetime': '2025-11-08',
#    'dewpt': 8.9,
#    'dhi': 31,
#    'dni': 265,
#    'ghi': 130,
#    'max_dhi': 98,
#    'max_dni': 810,
#    'max_ghi': 514,
#    'max_temp': 16.2,
#    'max_temp_ts': 1762606800,
#    'max_uv': 1.2,
#    'max_wind_dir': 231,
#    'max_wind_spd': 3.6,
#    'max_wind_spd_ts': 1762614000,
#    'min_temp': 9,
#    'min_temp_ts': 1762639200,
#    'precip': 3.5,
#    'precip_gpm': 3.5,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 82,
#    'slp': 1013,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 26,
#    't_dhi': 746,
#    't_dni': 6362,
#    't_ghi': 3126,
#    't_solar_rad': 630,
#    'temp': 11.9,
#    'ts': 1762556400,
#    'wind_dir': 231,
#    'wind_gust_spd': 6,
#    'wind_spd': 1.7},
#   {'clouds': 75,
#    'datetime': '2025-11-09',
#    'dewpt': 7.1,
#    'dhi': 31,
#    'dni': 263,
#    'ghi': 129,
#    'max_dhi': 97,
#    'max_dni': 808,
#    'max_ghi': 509,
#    'max_temp': 18.4,
#    'max_temp_ts': 1762696800,
#    'max_uv': 3.4,
#    'max_wind_dir': 267,
#    'max_wind_spd': 3.6,
#    'max_wind_spd_ts': 1762678800,
#    'min_temp': 7,
#    'min_temp_ts': 1762668000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'interim',
#    'revision_version': '0.0',
#    'rh': 72,
#    'slp': 1018,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 129,
#    't_dhi': 741,
#    't_dni': 6319,
#    't_ghi': 3085,
#    't_solar_rad': 3085,
#    'temp': 12.2,
#    'ts': 1762642800,
#    'wind_dir': 267,
#    'wind_gust_spd': 6.7,
#    'wind_spd': 2.1},
#   {'clouds': 47,
#    'datetime': '2025-11-10',
#    'dewpt': 6.9,
#    'dhi': 31,
#    'dni': 261,
#    'ghi': 127,
#    'max_dhi': 97,
#    'max_dni': 806,
#    'max_ghi': 504,
#    'max_temp': 18.4,
#    'max_temp_ts': 1762783200,
#    'max_uv': 2.8,
#    'max_wind_dir': 222,
#    'max_wind_spd': 4.9,
#    'max_wind_spd_ts': 1762776000,
#    'min_temp': 6,
#    'min_temp_ts': 1762743600,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 989,
#    'revision_status': 'interim',
#    'revision_version': '0.0',
#    'rh': 76,
#    'slp': 1017,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 124,
#    't_dhi': 735,
#    't_dni': 6276,
#    't_ghi': 3045,
#    't_solar_rad': 2978,
#    'temp': 11.3,
#    'ts': 1762729200,
#    'wind_dir': 222,
#    'wind_gust_spd': 5.7,
#    'wind_spd': 1.9},
#   {'clouds': 70,
#    'datetime': '2025-11-11',
#    'dewpt': 7.7,
#    'dhi': 30,
#    'dni': 260,
#    'ghi': 125,
#    'max_dhi': 97,
#    'max_dni': 804,
#    'max_ghi': 500,
#    'max_temp': 20,
#    'max_temp_ts': 1762869600,
#    'max_uv': 2.6,
#    'max_wind_dir': 246,
#    'max_wind_spd': 3.4,
#    'max_wind_spd_ts': 1762869600,
#    'min_temp': 6,
#    'min_temp_ts': 1762837200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 991,
#    'revision_status': 'interim',
#    'revision_version': '0.0',
#    'rh': 76,
#    'slp': 1018,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 115,
#    't_dhi': 730,
#    't_dni': 6232,
#    't_ghi': 3006,
#    't_solar_rad': 2754,
#    'temp': 12.2,
#    'ts': 1762815600,
#    'wind_dir': 246,
#    'wind_gust_spd': 5.1,
#    'wind_spd': 1.6},
#   {'clouds': 64,
#    'datetime': '2025-11-12',
#    'dewpt': 10.1,
#    'dhi': 30,
#    'dni': 258,
#    'ghi': 124,
#    'max_dhi': 96,
#    'max_dni': 803,
#    'max_ghi': 495,
#    'max_temp': 20,
#    'max_temp_ts': 1762952400,
#    'max_uv': 2.3,
#    'max_wind_dir': 183,
#    'max_wind_spd': 2.9,
#    'max_wind_spd_ts': 1762963200,
#    'min_temp': 7,
#    'min_temp_ts': 1762912800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'interim',
#    'revision_version': '0.0',
#    'rh': 84,
#    'slp': 1019,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 116,
#    't_dhi': 725,
#    't_dni': 6189,
#    't_ghi': 2967,
#    't_solar_rad': 2776,
#    'temp': 13,
#    'ts': 1762902000,
#    'wind_dir': 183,
#    'wind_gust_spd': 5.1,
#    'wind_spd': 1.1},
#   {'clouds': 81,
#    'datetime': '2025-11-13',
#    'dewpt': 13.8,
#    'dhi': 30,
#    'dni': 256,
#    'ghi': 122,
#    'max_dhi': 96,
#    'max_dni': 801,
#    'max_ghi': 491,
#    'max_temp': 20.2,
#    'max_temp_ts': 1763038800,
#    'max_uv': 1.8,
#    'max_wind_dir': 91,
#    'max_wind_spd': 3.7,
#    'max_wind_spd_ts': 1763038800,
#    'min_temp': 11.8,
#    'min_temp_ts': 1762999200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'interim',
#    'revision_version': '0.0',
#    'rh': 86,
#    'slp': 1018,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 94,
#    't_dhi': 720,
#    't_dni': 6145,
#    't_ghi': 2929,
#    't_solar_rad': 2258,
#    'temp': 16.2,
#    'ts': 1762988400,
#    'wind_dir': 91,
#    'wind_gust_spd': 7.7,
#    'wind_spd': 1.8},
#   {'clouds': 79,
#    'datetime': '2025-11-14',
#    'dewpt': 14.9,
#    'dhi': 30,
#    'dni': 254,
#    'ghi': 121,
#    'max_dhi': 96,
#    'max_dni': 799,
#    'max_ghi': 486,
#    'max_temp': 21,
#    'max_temp_ts': 1763121600,
#    'max_uv': 1.3,
#    'max_wind_dir': 120,
#    'max_wind_spd': 3.4,
#    'max_wind_spd_ts': 1763125200,
#    'min_temp': 15,
#    'min_temp_ts': 1763154000,
#    'precip': 1.3,
#    'precip_gpm': 1.3,
#    'pres': 983,
#    'revision_status': 'interim',
#    'revision_version': '0.0',
#    'rh': 84,
#    'slp': 1011,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 57,
#    't_dhi': 715,
#    't_dni': 6101,
#    't_ghi': 2892,
#    't_solar_rad': 1362,
#    'temp': 17.7,
#    'ts': 1763074800,
#    'wind_dir': 120,
#    'wind_gust_spd': 6.3,
#    'wind_spd': 1.7}],
#  'lat': 41.63333,
#  'lon': 2.16667,
#  'sources': ['081763-99999', 'imerg', 'era5', 'sat', 'radar', 'snodas'],
#  'state_code': '56',
#  'station_id': '081763-99999',
#  'timezone': 'Europe/Madrid'}

# %%
ciudad = data["city_name"]

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []


for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

n = len(city_name)

listas = {"city_name": city_name,
          "datetime": datetime,
          "ts": ts,
          "pres": pres,
          "slp": slp,
          "wind_spd": wind_spd,
          "wind_gust_spd": wind_gust_spd,
          "max_wind_spd": max_wind_spd,
          "max_wind_spd_ts": max_wind_spd_ts,
          "wind_dir": wind_dir,
          "temp": temp,
          "max_temp": max_temp,
          "min_temp": min_temp,
          "max_temp_ts": max_temp_ts,
          "min_temp_ts": min_temp_ts,
          "rh": rh,
          "dewpt": dewpt,
          "clouds": clouds,
          "precip": precip,
          "precip_gpm": precip_gpm,
          "snow": snow,
          "snow_depth": snow_depth,
          "solar_rad": solar_rad,
          "t_solar_rad": t_solar_rad,
          "ghi": ghi,
          "t_ghi": t_ghi,
          "max_ghi": max_ghi,
          "dni": dni,
          "t_dni": t_dni,
          "max_dni": max_dni,
          "dhi": dhi,
          "t_dhi": t_dhi,
          "max_dhi": max_dhi,
          "max_uv": max_uv,}

# for k, v in listas.items():
#     print(k, len(v))

# for nombre, lista in listas.items():
#     if len(lista) < n:
#         lista.extend([np.nan] * (n - len(lista)))

#     if len(lista) > n:
#         print(f"⚠️ La lista '{nombre}' tiene MÁS elementos que city_name: {len(lista)} vs {n}")
    
for llave, valor in [("Ciudad", city_name), 
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
    datos[llave] = valor


# pprint(datos)

caldes_de_montbui =  pd.DataFrame(datos)

caldes_de_montbui.head()

# city_name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 161
#     156     datos[llave] = valor
#     159 # pprint(datos)
# --> 161 caldes_de_montbui =  pd.DataFrame(datos)
#     163 caldes_de_montbui.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
X = caldes_de_montbui["datetime"]
Y1 = caldes_de_montbui["temp"]
Y2 = caldes_de_montbui["max_temp"]
Y3 = caldes_de_montbui["min_temp"]

colores = ["red", "blue", "green"]

plt.figure(figsize = (15, 8))

plt.plot(X,
         Y1, 
         color       = "red",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temperatura ℃") 

plt.plot(X,
         Y2, 
         color       = "blue",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. máxima ℃") 

plt.plot(X,
         Y3, 
         color       = "green",
         markersize  = 3,
         linestyle   = ":",
         linewidth   = 1,
         alpha       = 0.9,
         label       = "Temp. mínima ℃") 



plt.legend()
plt.xticks(rotation = 90)
plt.grid()
plt.show()
