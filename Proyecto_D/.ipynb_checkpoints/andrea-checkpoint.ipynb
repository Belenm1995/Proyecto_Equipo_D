# %%
import requests
from pprint import pprint
from datetime import datetime

# %%
# Geocodificación
# En este caso uso el zip

data = {}

url = "https://api.weatherbit.io/v2.0/geocode?postal_code=08140&country=ES&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'ES',
#  'geo_id': '08140-ES',
#  'lat': 41.2667,
#  'lon': 1.9667,
#  'name': 'Barcelona',
#  'state_code': 'CT',
#  'timezone': 'Europe/Madrid'}

# %%
# ANÁLISIS DE LOS DATOS 

# ¿Cuál es el mes más caluroso?

# ¿Qué porcentaje supera la humedad media?

# Se podría comparar nieve por zonas, en que unidad está la info de nieve?

# Punto de rocío
