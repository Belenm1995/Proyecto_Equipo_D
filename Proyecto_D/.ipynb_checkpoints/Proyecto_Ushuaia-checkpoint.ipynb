# %%
import requests
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data = {}

url = "https://api.weatherbit.io/v2.0/geocode?&city=ushuaia&country=ar&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'AR',
#  'geo_id': 'USHUAIA--AR',
#  'lat': -54.8,
#  'lon': -68.3,
#  'name': 'Ushuaia',
#  'state_code': '23',
#  'timezone': 'America/Argentina/Ushuaia'}

# %%
data = {}
url = "https://api.weatherbit.io/v2.0/history/daily?lat=-54.8&lon=-68.3&start_date=2021-11-15&end_date=2022-11-15&key=9a25028e04c943f5b50689bfd5db49b7"
response = requests.get(url)
data.update(response.json())

# %%
data
# Out:
# {'city_id': '3833367',
#  'city_name': 'Ushuaia',
#  'country_code': 'AR',
#  'data': [{'clouds': 67,
#    'datetime': '2023-11-15',
#    'dewpt': -1.6,
#    'dhi': 59,
#    'dni': 479,
#    'ghi': 327,
#    'max_dhi': 121,
#    'max_dni': 931,
#    'max_ghi': 863,
#    'max_temp': 5.2,
#    'max_temp_ts': 1700071200,
#    'max_uv': 3.5,
#    'max_wind_dir': 237,
#    'max_wind_spd': 10.1,
#    'max_wind_spd_ts': 1700074800,
#    'min_temp': 0,
#    'min_temp_ts': 1700038800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 990,
#    'snow': 0,
#    'snow_depth': 13,
#    'solar_rad': 213,
#    't_dhi': 1420,
#    't_dni': 11496,
#    't_ghi': 7853,
#    't_solar_rad': 5102,
#    'temp': 3.3,
#    'ts': 1700017200,
#    'wind_dir': 237,
#    'wind_gust_spd': 12.9,
#    'wind_spd': 6.9},
#   {'clouds': 77,
#    'datetime': '2023-11-16',
#    'dewpt': -1.7,
#    'dhi': 59,
#    'dni': 481,
#    'ghi': 330,
#    'max_dhi': 121,
#    'max_dni': 932,
#    'max_ghi': 867,
#    'max_temp': 10,
#    'max_temp_ts': 1700157600,
#    'max_uv': 2.7,
#    'max_wind_dir': 290,
#    'max_wind_spd': 8.5,
#    'max_wind_spd_ts': 1700146800,
#    'min_temp': 1.2,
#    'min_temp_ts': 1700110800,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 972,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 57,
#    'slp': 979,
#    'snow': 0,
#    'snow_depth': 9,
#    'solar_rad': 105,
#    't_dhi': 1427,
#    't_dni': 11555,
#    't_ghi': 7909,
#    't_solar_rad': 2528,
#    'temp': 6.3,
#    'ts': 1700103600,
#    'wind_dir': 290,
#    'wind_gust_spd': 17.6,
#    'wind_spd': 5.9},
#   {'clouds': 98,
#    'datetime': '2023-11-17',
#    'dewpt': 3.6,
#    'dhi': 60,
#    'dni': 484,
#    'ghi': 332,
#    'max_dhi': 121,
#    'max_dni': 934,
#    'max_ghi': 870,
#    'max_temp': 7,
#    'max_temp_ts': 1700190000,
#    'max_uv': 2.4,
#    'max_wind_dir': 234,
#    'max_wind_spd': 9.4,
#    'max_wind_spd_ts': 1700272800,
#    'min_temp': 4,
#    'min_temp_ts': 1700211600,
#    'precip': 11,
#    'precip_gpm': 11,
#    'pres': 972,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 88,
#    'slp': 979,
#    'snow': 0,
#    'snow_depth': 8,
#    'solar_rad': 54,
#    't_dhi': 1434,
#    't_dni': 11612,
#    't_ghi': 7964,
#    't_solar_rad': 1295,
#    'temp': 5.5,
#    'ts': 1700190000,
#    'wind_dir': 234,
#    'wind_gust_spd': 11.7,
#    'wind_spd': 6},
#   {'clouds': 90,
#    'datetime': '2023-11-18',
#    'dewpt': -0.9,
#    'dhi': 60,
#    'dni': 486,
#    'ghi': 334,
#    'max_dhi': 122,
#    'max_dni': 935,
#    'max_ghi': 874,
#    'max_temp': 5.7,
#    'max_temp_ts': 1700276400,
#    'max_uv': 3.8,
#    'max_wind_dir': 195,
#    'max_wind_spd': 9.9,
#    'max_wind_spd_ts': 1700359200,
#    'min_temp': 1.9,
#    'min_temp_ts': 1700348400,
#    'precip': 2,
#    'precip_gpm': 2,
#    'pres': 987,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 73,
#    'slp': 994,
#    'snow': 15,
#    'snow_depth': 23,
#    'solar_rad': 187,
#    't_dhi': 1441,
#    't_dni': 11667,
#    't_ghi': 8018,
#    't_solar_rad': 4492,
#    'temp': 3.5,
#    'ts': 1700276400,
#    'wind_dir': 195,
#    'wind_gust_spd': 14,
#    'wind_spd': 7.6},
#   {'clouds': 92,
#    'datetime': '2023-11-19',
#    'dewpt': -2.1,
#    'dhi': 60,
#    'dni': 488,
#    'ghi': 336,
#    'max_dhi': 122,
#    'max_dni': 936,
#    'max_ghi': 877,
#    'max_temp': 5,
#    'max_temp_ts': 1700416800,
#    'max_uv': 2.8,
#    'max_wind_dir': 193,
#    'max_wind_spd': 14,
#    'max_wind_spd_ts': 1700388000,
#    'min_temp': 0,
#    'min_temp_ts': 1700373600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 25,
#    'solar_rad': 135,
#    't_dhi': 1448,
#    't_dni': 11721,
#    't_ghi': 8070,
#    't_solar_rad': 3232,
#    'temp': 2.5,
#    'ts': 1700362800,
#    'wind_dir': 193,
#    'wind_gust_spd': 18.9,
#    'wind_spd': 8.9},
#   {'clouds': 88,
#    'datetime': '2023-11-20',
#    'dewpt': -0.3,
#    'dhi': 61,
#    'dni': 490,
#    'ghi': 338,
#    'max_dhi': 122,
#    'max_dni': 937,
#    'max_ghi': 880,
#    'max_temp': 6.8,
#    'max_temp_ts': 1700496000,
#    'max_uv': 3.1,
#    'max_wind_dir': 77,
#    'max_wind_spd': 7.8,
#    'max_wind_spd_ts': 1700474400,
#    'min_temp': 2.3,
#    'min_temp_ts': 1700460000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 982,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 74,
#    'slp': 989,
#    'snow': 0,
#    'snow_depth': 18,
#    'solar_rad': 127,
#    't_dhi': 1454,
#    't_dni': 11772,
#    't_ghi': 8122,
#    't_solar_rad': 3059,
#    'temp': 4,
#    'ts': 1700449200,
#    'wind_dir': 77,
#    'wind_gust_spd': 9.3,
#    'wind_spd': 4.6},
#   {'clouds': 87,
#    'datetime': '2023-11-21',
#    'dewpt': 0.9,
#    'dhi': 61,
#    'dni': 493,
#    'ghi': 340,
#    'max_dhi': 122,
#    'max_dni': 938,
#    'max_ghi': 883,
#    'max_temp': 5.7,
#    'max_temp_ts': 1700604000,
#    'max_uv': 3.4,
#    'max_wind_dir': 148,
#    'max_wind_spd': 8.5,
#    'max_wind_spd_ts': 1700604000,
#    'min_temp': 2.2,
#    'min_temp_ts': 1700560800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 82,
#    'slp': 992,
#    'snow': 0,
#    'snow_depth': 12,
#    'solar_rad': 125,
#    't_dhi': 1460,
#    't_dni': 11821,
#    't_ghi': 8171,
#    't_solar_rad': 2996,
#    'temp': 3.7,
#    'ts': 1700535600,
#    'wind_dir': 148,
#    'wind_gust_spd': 10.3,
#    'wind_spd': 4.5},
#   {'clouds': 63,
#    'datetime': '2023-11-22',
#    'dewpt': 0.7,
#    'dhi': 61,
#    'dni': 495,
#    'ghi': 343,
#    'max_dhi': 122,
#    'max_dni': 939,
#    'max_ghi': 886,
#    'max_temp': 7.5,
#    'max_temp_ts': 1700672400,
#    'max_uv': 5.2,
#    'max_wind_dir': 239,
#    'max_wind_spd': 16,
#    'max_wind_spd_ts': 1700679600,
#    'min_temp': 2.5,
#    'min_temp_ts': 1700640000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 5,
#    'solar_rad': 320,
#    't_dhi': 1466,
#    't_dni': 11869,
#    't_ghi': 8220,
#    't_solar_rad': 7683,
#    'temp': 4.8,
#    'ts': 1700622000,
#    'wind_dir': 239,
#    'wind_gust_spd': 22.5,
#    'wind_spd': 9.7},
#   {'clouds': 70,
#    'datetime': '2023-11-23',
#    'dewpt': 2.6,
#    'dhi': 61,
#    'dni': 496,
#    'ghi': 344,
#    'max_dhi': 123,
#    'max_dni': 940,
#    'max_ghi': 889,
#    'max_temp': 11.6,
#    'max_temp_ts': 1700769600,
#    'max_uv': 4.5,
#    'max_wind_dir': 230,
#    'max_wind_spd': 14.5,
#    'max_wind_spd_ts': 1700780400,
#    'min_temp': 3.7,
#    'min_temp_ts': 1700708400,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 995,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 1002,
#    'snow': 0,
#    'snow_depth': 3,
#    'solar_rad': 202,
#    't_dhi': 1472,
#    't_dni': 11914,
#    't_ghi': 8267,
#    't_solar_rad': 4857,
#    'temp': 7.3,
#    'ts': 1700708400,
#    'wind_dir': 230,
#    'wind_gust_spd': 19.8,
#    'wind_spd': 8.4},
#   {'clouds': 75,
#    'datetime': '2023-11-24',
#    'dewpt': 5.3,
#    'dhi': 62,
#    'dni': 498,
#    'ghi': 346,
#    'max_dhi': 123,
#    'max_dni': 941,
#    'max_ghi': 892,
#    'max_temp': 13.5,
#    'max_temp_ts': 1700845200,
#    'max_uv': 4.5,
#    'max_wind_dir': 260,
#    'max_wind_spd': 11.6,
#    'max_wind_spd_ts': 1700794800,
#    'min_temp': 8.3,
#    'min_temp_ts': 1700809200,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 997,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 1004,
#    'snow': 0,
#    'snow_depth': 1,
#    'solar_rad': 221,
#    't_dhi': 1477,
#    't_dni': 11958,
#    't_ghi': 8313,
#    't_solar_rad': 5294,
#    'temp': 10.5,
#    'ts': 1700794800,
#    'wind_dir': 260,
#    'wind_gust_spd': 14.9,
#    'wind_spd': 6.4},
#   {'clouds': 66,
#    'datetime': '2023-11-25',
#    'dewpt': 2,
#    'dhi': 62,
#    'dni': 500,
#    'ghi': 348,
#    'max_dhi': 123,
#    'max_dni': 942,
#    'max_ghi': 894,
#    'max_temp': 16.4,
#    'max_temp_ts': 1700928000,
#    'max_uv': 6.1,
#    'max_wind_dir': 217,
#    'max_wind_spd': 11.7,
#    'max_wind_spd_ts': 1700964000,
#    'min_temp': 6.2,
#    'min_temp_ts': 1700964000,
#    'precip': 1,
#    'precip_gpm': 1,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 57,
#    'slp': 990,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 327,
#    't_dhi': 1482,
#    't_dni': 11999,
#    't_ghi': 8358,
#    't_solar_rad': 7857,
#    'temp': 10.9,
#    'ts': 1700881200,
#    'wind_dir': 217,
#    'wind_gust_spd': 21.2,
#    'wind_spd': 7.2},
#   {'clouds': 64,
#    'datetime': '2023-11-26',
#    'dewpt': 0.8,
#    'dhi': 62,
#    'dni': 502,
#    'ghi': 350,
#    'max_dhi': 123,
#    'max_dni': 943,
#    'max_ghi': 897,
#    'max_temp': 8.4,
#    'max_temp_ts': 1701025200,
#    'max_uv': 5.5,
#    'max_wind_dir': 231,
#    'max_wind_spd': 12.2,
#    'max_wind_spd_ts': 1701007200,
#    'min_temp': 3,
#    'min_temp_ts': 1700985600,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 1000,
#    'snow': 2,
#    'snow_depth': 2,
#    'solar_rad': 266,
#    't_dhi': 1487,
#    't_dni': 12040,
#    't_ghi': 8400,
#    't_solar_rad': 6388,
#    'temp': 5.7,
#    'ts': 1700967600,
#    'wind_dir': 231,
#    'wind_gust_spd': 15.9,
#    'wind_spd': 10.2},
#   {'clouds': 56,
#    'datetime': '2023-11-27',
#    'dewpt': 0.1,
#    'dhi': 62,
#    'dni': 503,
#    'ghi': 352,
#    'max_dhi': 123,
#    'max_dni': 944,
#    'max_ghi': 899,
#    'max_temp': 15.2,
#    'max_temp_ts': 1701111600,
#    'max_uv': 4.9,
#    'max_wind_dir': 285,
#    'max_wind_spd': 8.1,
#    'max_wind_spd_ts': 1701118800,
#    'min_temp': 3.7,
#    'min_temp_ts': 1701072000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 55,
#    'slp': 1003,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 188,
#    't_dhi': 1492,
#    't_dni': 12078,
#    't_ghi': 8442,
#    't_solar_rad': 4507,
#    'temp': 9.2,
#    'ts': 1701054000,
#    'wind_dir': 285,
#    'wind_gust_spd': 17.2,
#    'wind_spd': 4.9},
#   {'clouds': 55,
#    'datetime': '2023-11-28',
#    'dewpt': 2.6,
#    'dhi': 62,
#    'dni': 505,
#    'ghi': 353,
#    'max_dhi': 123,
#    'max_dni': 945,
#    'max_ghi': 902,
#    'max_temp': 16.5,
#    'max_temp_ts': 1701190800,
#    'max_uv': 5.8,
#    'max_wind_dir': 239,
#    'max_wind_spd': 10.3,
#    'max_wind_spd_ts': 1701194400,
#    'min_temp': 6.4,
#    'min_temp_ts': 1701219600,
#    'precip': 2,
#    'precip_gpm': 2,
#    'pres': 978,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 61,
#    'slp': 984,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 284,
#    't_dhi': 1497,
#    't_dni': 12114,
#    't_ghi': 8482,
#    't_solar_rad': 6827,
#    'temp': 10.2,
#    'ts': 1701140400,
#    'wind_dir': 239,
#    'wind_gust_spd': 24.8,
#    'wind_spd': 4.6},
#   {'clouds': 65,
#    'datetime': '2023-11-29',
#    'dewpt': -0.2,
#    'dhi': 63,
#    'dni': 506,
#    'ghi': 355,
#    'max_dhi': 123,
#    'max_dni': 946,
#    'max_ghi': 904,
#    'max_temp': 10.2,
#    'max_temp_ts': 1701284400,
#    'max_uv': 6.1,
#    'max_wind_dir': 265,
#    'max_wind_spd': 12.4,
#    'max_wind_spd_ts': 1701248400,
#    'min_temp': 3.4,
#    'min_temp_ts': 1701248400,
#    'precip': 4,
#    'precip_gpm': 4,
#    'pres': 976,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 61,
#    'slp': 982,
#    'snow': 4,
#    'snow_depth': 4,
#    'solar_rad': 289,
#    't_dhi': 1501,
#    't_dni': 12149,
#    't_ghi': 8520,
#    't_solar_rad': 6932,
#    'temp': 7.2,
#    'ts': 1701226800,
#    'wind_dir': 265,
#    'wind_gust_spd': 16.2,
#    'wind_spd': 6.7},
#   {'clouds': 68,
#    'datetime': '2023-11-30',
#    'dewpt': 1,
#    'dhi': 63,
#    'dni': 508,
#    'ghi': 357,
#    'max_dhi': 124,
#    'max_dni': 946,
#    'max_ghi': 906,
#    'max_temp': 7.5,
#    'max_temp_ts': 1701367200,
#    'max_uv': 5.7,
#    'max_wind_dir': 238,
#    'max_wind_spd': 14.2,
#    'max_wind_spd_ts': 1701334800,
#    'min_temp': 2.8,
#    'min_temp_ts': 1701396000,
#    'precip': 6.5,
#    'precip_gpm': 6.5,
#    'pres': 977,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 984,
#    'snow': 5,
#    'snow_depth': 9,
#    'solar_rad': 319,
#    't_dhi': 1506,
#    't_dni': 12182,
#    't_ghi': 8557,
#    't_solar_rad': 7663,
#    'temp': 5.1,
#    'ts': 1701313200,
#    'wind_dir': 238,
#    'wind_gust_spd': 19.7,
#    'wind_spd': 8.7},
#   {'clouds': 40,
#    'datetime': '2023-12-01',
#    'dewpt': -1.3,
#    'dhi': 63,
#    'dni': 509,
#    'ghi': 358,
#    'max_dhi': 124,
#    'max_dni': 947,
#    'max_ghi': 908,
#    'max_temp': 11.8,
#    'max_temp_ts': 1701453600,
#    'max_uv': 4.9,
#    'max_wind_dir': 205,
#    'max_wind_spd': 9.1,
#    'max_wind_spd_ts': 1701460800,
#    'min_temp': 2.8,
#    'min_temp_ts': 1701410400,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 59,
#    'slp': 992,
#    'snow': 0,
#    'snow_depth': 3,
#    'solar_rad': 307,
#    't_dhi': 1511,
#    't_dni': 12214,
#    't_ghi': 8593,
#    't_solar_rad': 7358,
#    'temp': 6.6,
#    'ts': 1701399600,
#    'wind_dir': 205,
#    'wind_gust_spd': 15.6,
#    'wind_spd': 4.4},
#   {'clouds': 54,
#    'datetime': '2023-12-02',
#    'dewpt': 1,
#    'dhi': 63,
#    'dni': 510,
#    'ghi': 359,
#    'max_dhi': 124,
#    'max_dni': 948,
#    'max_ghi': 910,
#    'max_temp': 8.1,
#    'max_temp_ts': 1701529200,
#    'max_uv': 4.3,
#    'max_wind_dir': 239,
#    'max_wind_spd': 14.7,
#    'max_wind_spd_ts': 1701529200,
#    'min_temp': 1.5,
#    'min_temp_ts': 1701496800,
#    'precip': 3,
#    'precip_gpm': 3,
#    'pres': 992,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 999,
#    'snow': 0,
#    'snow_depth': 3,
#    'solar_rad': 242,
#    't_dhi': 1516,
#    't_dni': 12244,
#    't_ghi': 8627,
#    't_solar_rad': 5800,
#    'temp': 5.3,
#    'ts': 1701486000,
#    'wind_dir': 239,
#    'wind_gust_spd': 20,
#    'wind_spd': 8.7},
#   {'clouds': 80,
#    'datetime': '2023-12-03',
#    'dewpt': 1.5,
#    'dhi': 63,
#    'dni': 511,
#    'ghi': 361,
#    'max_dhi': 124,
#    'max_dni': 948,
#    'max_ghi': 912,
#    'max_temp': 10.1,
#    'max_temp_ts': 1701622800,
#    'max_uv': 2.6,
#    'max_wind_dir': 232,
#    'max_wind_spd': 17.8,
#    'max_wind_spd_ts': 1701648000,
#    'min_temp': 4.3,
#    'min_temp_ts': 1701576000,
#    'precip': 1,
#    'precip_gpm': 1,
#    'pres': 997,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 67,
#    'slp': 1004,
#    'snow': 0,
#    'snow_depth': 1,
#    'solar_rad': 113,
#    't_dhi': 1520,
#    't_dni': 12274,
#    't_ghi': 8659,
#    't_solar_rad': 2711,
#    'temp': 7.3,
#    'ts': 1701572400,
#    'wind_dir': 232,
#    'wind_gust_spd': 25.7,
#    'wind_spd': 11.4},
#   {'clouds': 68,
#    'datetime': '2023-12-04',
#    'dewpt': 5.1,
#    'dhi': 64,
#    'dni': 513,
#    'ghi': 362,
#    'max_dhi': 124,
#    'max_dni': 949,
#    'max_ghi': 914,
#    'max_temp': 13.6,
#    'max_temp_ts': 1701702000,
#    'max_uv': 3.7,
#    'max_wind_dir': 239,
#    'max_wind_spd': 15,
#    'max_wind_spd_ts': 1701658800,
#    'min_temp': 7.7,
#    'min_temp_ts': 1701662400,
#    'precip': 2.5,
#    'precip_gpm': 2.5,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 70,
#    'slp': 997,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 191,
#    't_dhi': 1524,
#    't_dni': 12302,
#    't_ghi': 8690,
#    't_solar_rad': 4579,
#    'temp': 10.5,
#    'ts': 1701658800,
#    'wind_dir': 239,
#    'wind_gust_spd': 20.6,
#    'wind_spd': 8.6},
#   {'clouds': 74,
#    'datetime': '2023-12-05',
#    'dewpt': 0.9,
#    'dhi': 64,
#    'dni': 514,
#    'ghi': 363,
#    'max_dhi': 124,
#    'max_dni': 950,
#    'max_ghi': 915,
#    'max_temp': 9.6,
#    'max_temp_ts': 1701745200,
#    'max_uv': 5.6,
#    'max_wind_dir': 232,
#    'max_wind_spd': 20.9,
#    'max_wind_spd_ts': 1701820800,
#    'min_temp': 1,
#    'min_temp_ts': 1701774000,
#    'precip': 8,
#    'precip_gpm': 8,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 74,
#    'slp': 997,
#    'snow': 4,
#    'snow_depth': 4,
#    'solar_rad': 282,
#    't_dhi': 1528,
#    't_dni': 12329,
#    't_ghi': 8719,
#    't_solar_rad': 6764,
#    'temp': 5.3,
#    'ts': 1701745200,
#    'wind_dir': 232,
#    'wind_gust_spd': 31,
#    'wind_spd': 15.7},
#   {'clouds': 59,
#    'datetime': '2023-12-06',
#    'dewpt': 2.5,
#    'dhi': 64,
#    'dni': 515,
#    'ghi': 364,
#    'max_dhi': 124,
#    'max_dni': 950,
#    'max_ghi': 917,
#    'max_temp': 11,
#    'max_temp_ts': 1701885600,
#    'max_uv': 2.8,
#    'max_wind_dir': 231,
#    'max_wind_spd': 21.2,
#    'max_wind_spd_ts': 1701838800,
#    'min_temp': 5,
#    'min_temp_ts': 1701849600,
#    'precip': 3.5,
#    'precip_gpm': 3.5,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 1005,
#    'snow': 0,
#    'snow_depth': 2,
#    'solar_rad': 141,
#    't_dhi': 1532,
#    't_dni': 12354,
#    't_ghi': 8747,
#    't_solar_rad': 3382,
#    'temp': 7.5,
#    'ts': 1701831600,
#    'wind_dir': 231,
#    'wind_gust_spd': 31.4,
#    'wind_spd': 15.3},
#   {'clouds': 48,
#    'datetime': '2023-12-07',
#    'dewpt': 3.8,
#    'dhi': 64,
#    'dni': 516,
#    'ghi': 366,
#    'max_dhi': 124,
#    'max_dni': 951,
#    'max_ghi': 918,
#    'max_temp': 12,
#    'max_temp_ts': 1701975600,
#    'max_uv': 6.1,
#    'max_wind_dir': 229,
#    'max_wind_spd': 16.1,
#    'max_wind_spd_ts': 1701936000,
#    'min_temp': 6.6,
#    'min_temp_ts': 1702000800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1008,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 70,
#    'slp': 1015,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 306,
#    't_dhi': 1535,
#    't_dni': 12378,
#    't_ghi': 8773,
#    't_solar_rad': 7350,
#    'temp': 9,
#    'ts': 1701918000,
#    'wind_dir': 229,
#    'wind_gust_spd': 22.5,
#    'wind_spd': 10.4},
#   {'clouds': 56,
#    'datetime': '2023-12-08',
#    'dewpt': 5.1,
#    'dhi': 64,
#    'dni': 517,
#    'ghi': 367,
#    'max_dhi': 125,
#    'max_dni': 951,
#    'max_ghi': 920,
#    'max_temp': 14.9,
#    'max_temp_ts': 1702062000,
#    'max_uv': 6,
#    'max_wind_dir': 190,
#    'max_wind_spd': 5.8,
#    'max_wind_spd_ts': 1702087200,
#    'min_temp': 4.4,
#    'min_temp_ts': 1702018800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1003,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 76,
#    'slp': 1010,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 244,
#    't_dhi': 1538,
#    't_dni': 12400,
#    't_ghi': 8797,
#    't_solar_rad': 5861,
#    'temp': 9.3,
#    'ts': 1702004400,
#    'wind_dir': 190,
#    'wind_gust_spd': 6.6,
#    'wind_spd': 3.3},
#   {'clouds': 87,
#    'datetime': '2023-12-09',
#    'dewpt': 4.7,
#    'dhi': 64,
#    'dni': 518,
#    'ghi': 367,
#    'max_dhi': 125,
#    'max_dni': 952,
#    'max_ghi': 921,
#    'max_temp': 15.5,
#    'max_temp_ts': 1702144800,
#    'max_uv': 3.6,
#    'max_wind_dir': 168,
#    'max_wind_spd': 11.1,
#    'max_wind_spd_ts': 1702166400,
#    'min_temp': 7.2,
#    'min_temp_ts': 1702101600,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 996,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 1003,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 171,
#    't_dhi': 1541,
#    't_dni': 12421,
#    't_ghi': 8820,
#    't_solar_rad': 4104,
#    'temp': 9.9,
#    'ts': 1702090800,
#    'wind_dir': 168,
#    'wind_gust_spd': 14.1,
#    'wind_spd': 4.5},
#   {'clouds': 71,
#    'datetime': '2023-12-10',
#    'dewpt': 1.9,
#    'dhi': 64,
#    'dni': 518,
#    'ghi': 368,
#    'max_dhi': 125,
#    'max_dni': 952,
#    'max_ghi': 922,
#    'max_temp': 10.6,
#    'max_temp_ts': 1702238400,
#    'max_uv': 4.6,
#    'max_wind_dir': 233,
#    'max_wind_spd': 14.4,
#    'max_wind_spd_ts': 1702220400,
#    'min_temp': 5.2,
#    'min_temp_ts': 1702198800,
#    'precip': 2,
#    'precip_gpm': 2,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 68,
#    'slp': 996,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 298,
#    't_dhi': 1544,
#    't_dni': 12440,
#    't_ghi': 8840,
#    't_solar_rad': 7153,
#    'temp': 7.9,
#    'ts': 1702177200,
#    'wind_dir': 233,
#    'wind_gust_spd': 19.6,
#    'wind_spd': 7.9},
#   {'clouds': 78,
#    'datetime': '2023-12-11',
#    'dewpt': 0.9,
#    'dhi': 64,
#    'dni': 519,
#    'ghi': 369,
#    'max_dhi': 125,
#    'max_dni': 953,
#    'max_ghi': 923,
#    'max_temp': 12.4,
#    'max_temp_ts': 1702332000,
#    'max_uv': 2.6,
#    'max_wind_dir': 235,
#    'max_wind_spd': 4.5,
#    'max_wind_spd_ts': 1702346400,
#    'min_temp': 2.6,
#    'min_temp_ts': 1702278000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 61,
#    'slp': 997,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 127,
#    't_dhi': 1547,
#    't_dni': 12457,
#    't_ghi': 8860,
#    't_solar_rad': 3039,
#    'temp': 8.5,
#    'ts': 1702263600,
#    'wind_dir': 235,
#    'wind_gust_spd': 14.8,
#    'wind_spd': 3.1},
#   {'clouds': 60,
#    'datetime': '2023-12-12',
#    'dewpt': 1.8,
#    'dhi': 65,
#    'dni': 520,
#    'ghi': 370,
#    'max_dhi': 125,
#    'max_dni': 953,
#    'max_ghi': 924,
#    'max_temp': 12.6,
#    'max_temp_ts': 1702407600,
#    'max_uv': 5.1,
#    'max_wind_dir': 251,
#    'max_wind_spd': 7.7,
#    'max_wind_spd_ts': 1702407600,
#    'min_temp': 5.9,
#    'min_temp_ts': 1702368000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 59,
#    'slp': 990,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 240,
#    't_dhi': 1550,
#    't_dni': 12473,
#    't_ghi': 8877,
#    't_solar_rad': 5768,
#    'temp': 9.8,
#    'ts': 1702350000,
#    'wind_dir': 251,
#    'wind_gust_spd': 16.4,
#    'wind_spd': 3.9},
#   {'clouds': 66,
#    'datetime': '2023-12-13',
#    'dewpt': 1.3,
#    'dhi': 65,
#    'dni': 520,
#    'ghi': 371,
#    'max_dhi': 125,
#    'max_dni': 953,
#    'max_ghi': 925,
#    'max_temp': 9.7,
#    'max_temp_ts': 1702436400,
#    'max_uv': 5.4,
#    'max_wind_dir': 223,
#    'max_wind_spd': 12.2,
#    'max_wind_spd_ts': 1702454400,
#    'min_temp': 5.6,
#    'min_temp_ts': 1702454400,
#    'precip': 2.5,
#    'precip_gpm': 2.5,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 66,
#    'slp': 991,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 345,
#    't_dhi': 1553,
#    't_dni': 12488,
#    't_ghi': 8893,
#    't_solar_rad': 8270,
#    'temp': 7.3,
#    'ts': 1702436400,
#    'wind_dir': 223,
#    'wind_gust_spd': 20,
#    'wind_spd': 8.6},
#   {'clouds': 67,
#    'datetime': '2023-12-14',
#    'dewpt': 0.1,
#    'dhi': 65,
#    'dni': 521,
#    'ghi': 371,
#    'max_dhi': 125,
#    'max_dni': 954,
#    'max_ghi': 925,
#    'max_temp': 12.6,
#    'max_temp_ts': 1702580400,
#    'max_uv': 3.1,
#    'max_wind_dir': 298,
#    'max_wind_spd': 7.6,
#    'max_wind_spd_ts': 1702558800,
#    'min_temp': 5.2,
#    'min_temp_ts': 1702522800,
#    'precip': 3.5,
#    'precip_gpm': 3.5,
#    'pres': 980,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 53,
#    'slp': 987,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 114,
#    't_dhi': 1555,
#    't_dni': 12501,
#    't_ghi': 8907,
#    't_solar_rad': 2737,
#    'temp': 9.6,
#    'ts': 1702522800,
#    'wind_dir': 298,
#    'wind_gust_spd': 18,
#    'wind_spd': 5.3},
#   {'clouds': 58,
#    'datetime': '2023-12-15',
#    'dewpt': 3.5,
#    'dhi': 65,
#    'dni': 521,
#    'ghi': 372,
#    'max_dhi': 125,
#    'max_dni': 954,
#    'max_ghi': 926,
#    'max_temp': 14.4,
#    'max_temp_ts': 1702663200,
#    'max_uv': 4.3,
#    'max_wind_dir': 206,
#    'max_wind_spd': 9.7,
#    'max_wind_spd_ts': 1702684800,
#    'min_temp': 5.8,
#    'min_temp_ts': 1702623600,
#    'precip': 3,
#    'precip_gpm': 3,
#    'pres': 976,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 68,
#    'slp': 983,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 245,
#    't_dhi': 1558,
#    't_dni': 12514,
#    't_ghi': 8919,
#    't_solar_rad': 5888,
#    'temp': 9.6,
#    'ts': 1702609200,
#    'wind_dir': 206,
#    'wind_gust_spd': 12.8,
#    'wind_spd': 3.4},
#   {'clouds': 67,
#    'datetime': '2023-12-16',
#    'dewpt': 1.1,
#    'dhi': 65,
#    'dni': 522,
#    'ghi': 372,
#    'max_dhi': 125,
#    'max_dni': 954,
#    'max_ghi': 926,
#    'max_temp': 8.6,
#    'max_temp_ts': 1702731600,
#    'max_uv': 6.3,
#    'max_wind_dir': 229,
#    'max_wind_spd': 14.8,
#    'max_wind_spd_ts': 1702753200,
#    'min_temp': 4.5,
#    'min_temp_ts': 1702778400,
#    'precip': 2,
#    'precip_gpm': 2,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 996,
#    'snow': 1,
#    'snow_depth': 1,
#    'solar_rad': 347,
#    't_dhi': 1559,
#    't_dni': 12525,
#    't_ghi': 8930,
#    't_solar_rad': 8332,
#    'temp': 6.3,
#    'ts': 1702695600,
#    'wind_dir': 229,
#    'wind_gust_spd': 20.2,
#    'wind_spd': 9.2},
#   {'clouds': 71,
#    'datetime': '2023-12-17',
#    'dewpt': 0.8,
#    'dhi': 65,
#    'dni': 522,
#    'ghi': 372,
#    'max_dhi': 125,
#    'max_dni': 954,
#    'max_ghi': 927,
#    'max_temp': 11,
#    'max_temp_ts': 1702839600,
#    'max_uv': 3.4,
#    'max_wind_dir': 244,
#    'max_wind_spd': 6.7,
#    'max_wind_spd_ts': 1702782000,
#    'min_temp': 2.9,
#    'min_temp_ts': 1702800000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1004,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 63,
#    'slp': 1011,
#    'snow': 0,
#    'snow_depth': 1,
#    'solar_rad': 197,
#    't_dhi': 1561,
#    't_dni': 12535,
#    't_ghi': 8939,
#    't_solar_rad': 4730,
#    'temp': 7.7,
#    'ts': 1702782000,
#    'wind_dir': 244,
#    'wind_gust_spd': 8.2,
#    'wind_spd': 3.9},
#   {'clouds': 72,
#    'datetime': '2023-12-18',
#    'dewpt': 5.2,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 927,
#    'max_temp': 15,
#    'max_temp_ts': 1702915200,
#    'max_uv': 5.7,
#    'max_wind_dir': 250,
#    'max_wind_spd': 12.2,
#    'max_wind_spd_ts': 1702922400,
#    'min_temp': 7.9,
#    'min_temp_ts': 1702872000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1006,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 65,
#    'slp': 1013,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 299,
#    't_dhi': 1562,
#    't_dni': 12543,
#    't_ghi': 8946,
#    't_solar_rad': 7166,
#    'temp': 11.6,
#    'ts': 1702868400,
#    'wind_dir': 250,
#    'wind_gust_spd': 15.9,
#    'wind_spd': 7.7},
#   {'clouds': 80,
#    'datetime': '2023-12-19',
#    'dewpt': 7.3,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 928,
#    'max_temp': 15.9,
#    'max_temp_ts': 1703012400,
#    'max_uv': 3.3,
#    'max_wind_dir': 252,
#    'max_wind_spd': 8.5,
#    'max_wind_spd_ts': 1702954800,
#    'min_temp': 10.7,
#    'min_temp_ts': 1702976400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1004,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 69,
#    'slp': 1011,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 137,
#    't_dhi': 1563,
#    't_dni': 12549,
#    't_ghi': 8951,
#    't_solar_rad': 3289,
#    'temp': 12.9,
#    'ts': 1702954800,
#    'wind_dir': 252,
#    'wind_gust_spd': 12.4,
#    'wind_spd': 6},
#   {'clouds': 71,
#    'datetime': '2023-12-20',
#    'dewpt': 6.5,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 928,
#    'max_temp': 20.4,
#    'max_temp_ts': 1703091600,
#    'max_uv': 6.7,
#    'max_wind_dir': 186,
#    'max_wind_spd': 17.7,
#    'max_wind_spd_ts': 1703116800,
#    'min_temp': 7.3,
#    'min_temp_ts': 1703124000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 70,
#    'slp': 1000,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 248,
#    't_dhi': 1563,
#    't_dni': 12553,
#    't_ghi': 8955,
#    't_solar_rad': 5963,
#    'temp': 12.2,
#    'ts': 1703041200,
#    'wind_dir': 186,
#    'wind_gust_spd': 25.4,
#    'wind_spd': 6.3},
#   {'clouds': 55,
#    'datetime': '2023-12-21',
#    'dewpt': 1.7,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 928,
#    'max_temp': 13,
#    'max_temp_ts': 1703188800,
#    'max_uv': 3.9,
#    'max_wind_dir': 234,
#    'max_wind_spd': 13.8,
#    'max_wind_spd_ts': 1703127600,
#    'min_temp': 6.1,
#    'min_temp_ts': 1703142000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 997,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 60,
#    'slp': 1004,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 215,
#    't_dhi': 1564,
#    't_dni': 12556,
#    't_ghi': 8956,
#    't_solar_rad': 5168,
#    'temp': 9.4,
#    'ts': 1703127600,
#    'wind_dir': 234,
#    'wind_gust_spd': 18.6,
#    'wind_spd': 6.8},
#   {'clouds': 74,
#    'datetime': '2023-12-22',
#    'dewpt': 2.5,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 929,
#    'max_temp': 13.2,
#    'max_temp_ts': 1703246400,
#    'max_uv': 6,
#    'max_wind_dir': 231,
#    'max_wind_spd': 14.6,
#    'max_wind_spd_ts': 1703271600,
#    'min_temp': 5.6,
#    'min_temp_ts': 1703293200,
#    'precip': 3,
#    'precip_gpm': 3,
#    'pres': 988,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 65,
#    'slp': 995,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 308,
#    't_dhi': 1564,
#    't_dni': 12557,
#    't_ghi': 8956,
#    't_solar_rad': 7401,
#    'temp': 9,
#    'ts': 1703214000,
#    'wind_dir': 231,
#    'wind_gust_spd': 21.6,
#    'wind_spd': 8.4},
#   {'clouds': 86,
#    'datetime': '2023-12-23',
#    'dewpt': 3,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 956,
#    'max_ghi': 929,
#    'max_temp': 12.1,
#    'max_temp_ts': 1703358000,
#    'max_uv': 2.7,
#    'max_wind_dir': 228,
#    'max_wind_spd': 15.9,
#    'max_wind_spd_ts': 1703300400,
#    'min_temp': 4.4,
#    'min_temp_ts': 1703314800,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 70,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 104,
#    't_dhi': 1563,
#    't_dni': 12557,
#    't_ghi': 8954,
#    't_solar_rad': 2486,
#    'temp': 8.2,
#    'ts': 1703300400,
#    'wind_dir': 228,
#    'wind_gust_spd': 22.2,
#    'wind_spd': 9.5},
#   {'clouds': 64,
#    'datetime': '2023-12-24',
#    'dewpt': 2.8,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 956,
#    'max_ghi': 929,
#    'max_temp': 12,
#    'max_temp_ts': 1703448000,
#    'max_uv': 3.9,
#    'max_wind_dir': 232,
#    'max_wind_spd': 17.3,
#    'max_wind_spd_ts': 1703422800,
#    'min_temp': 5.6,
#    'min_temp_ts': 1703412000,
#    'precip': 1,
#    'precip_gpm': 1,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 68,
#    'slp': 1000,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 172,
#    't_dhi': 1563,
#    't_dni': 12554,
#    't_ghi': 8950,
#    't_solar_rad': 4134,
#    'temp': 8.7,
#    'ts': 1703386800,
#    'wind_dir': 232,
#    'wind_gust_spd': 24.8,
#    'wind_spd': 12},
#   {'clouds': 76,
#    'datetime': '2023-12-25',
#    'dewpt': 4.3,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 373,
#    'max_dhi': 125,
#    'max_dni': 956,
#    'max_ghi': 929,
#    'max_temp': 13,
#    'max_temp_ts': 1703505600,
#    'max_uv': 4.2,
#    'max_wind_dir': 214,
#    'max_wind_spd': 18.7,
#    'max_wind_spd_ts': 1703538000,
#    'min_temp': 5.9,
#    'min_temp_ts': 1703548800,
#    'precip': 6,
#    'precip_gpm': 6,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 72,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 227,
#    't_dhi': 1562,
#    't_dni': 12550,
#    't_ghi': 8945,
#    't_solar_rad': 5439,
#    'temp': 9.2,
#    'ts': 1703473200,
#    'wind_dir': 214,
#    'wind_gust_spd': 27.3,
#    'wind_spd': 10},
#   {'clouds': 39,
#    'datetime': '2023-12-26',
#    'dewpt': 0.8,
#    'dhi': 65,
#    'dni': 523,
#    'ghi': 372,
#    'max_dhi': 125,
#    'max_dni': 956,
#    'max_ghi': 928,
#    'max_temp': 12.7,
#    'max_temp_ts': 1703606400,
#    'max_uv': 7.7,
#    'max_wind_dir': 218,
#    'max_wind_spd': 20.6,
#    'max_wind_spd_ts': 1703592000,
#    'min_temp': 7,
#    'min_temp_ts': 1703559600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 53,
#    'slp': 1000,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 342,
#    't_dhi': 1560,
#    't_dni': 12545,
#    't_ghi': 8938,
#    't_solar_rad': 8201,
#    'temp': 10.1,
#    'ts': 1703559600,
#    'wind_dir': 218,
#    'wind_gust_spd': 30.7,
#    'wind_spd': 16.3},
#   {'clouds': 67,
#    'datetime': '2023-12-27',
#    'dewpt': 2.8,
#    'dhi': 65,
#    'dni': 522,
#    'ghi': 372,
#    'max_dhi': 125,
#    'max_dni': 956,
#    'max_ghi': 928,
#    'max_temp': 8.9,
#    'max_temp_ts': 1703689200,
#    'max_uv': 4.1,
#    'max_wind_dir': 228,
#    'max_wind_spd': 17.4,
#    'max_wind_spd_ts': 1703685600,
#    'min_temp': 3,
#    'min_temp_ts': 1703728800,
#    'precip': 5.5,
#    'precip_gpm': 5.5,
#    'pres': 983,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 77,
#    'slp': 990,
#    'snow': 1,
#    'snow_depth': 1,
#    'solar_rad': 276,
#    't_dhi': 1559,
#    't_dni': 12539,
#    't_ghi': 8929,
#    't_solar_rad': 6622,
#    'temp': 6.5,
#    'ts': 1703646000,
#    'wind_dir': 228,
#    'wind_gust_spd': 25,
#    'wind_spd': 14.4},
#   {'clouds': 78,
#    'datetime': '2023-12-28',
#    'dewpt': 0.6,
#    'dhi': 65,
#    'dni': 522,
#    'ghi': 372,
#    'max_dhi': 125,
#    'max_dni': 956,
#    'max_ghi': 928,
#    'max_temp': 7,
#    'max_temp_ts': 1703790000,
#    'max_uv': 3.5,
#    'max_wind_dir': 230,
#    'max_wind_spd': 14.7,
#    'max_wind_spd_ts': 1703746800,
#    'min_temp': 2.1,
#    'min_temp_ts': 1703757600,
#    'precip': 1,
#    'precip_gpm': 1,
#    'pres': 995,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 79,
#    'slp': 1002,
#    'snow': 3,
#    'snow_depth': 4,
#    'solar_rad': 204,
#    't_dhi': 1557,
#    't_dni': 12530,
#    't_ghi': 8918,
#    't_solar_rad': 4888,
#    'temp': 3.9,
#    'ts': 1703732400,
#    'wind_dir': 230,
#    'wind_gust_spd': 23.2,
#    'wind_spd': 11.4},
#   {'clouds': 69,
#    'datetime': '2023-12-29',
#    'dewpt': 2.9,
#    'dhi': 65,
#    'dni': 522,
#    'ghi': 371,
#    'max_dhi': 125,
#    'max_dni': 956,
#    'max_ghi': 927,
#    'max_temp': 10.5,
#    'max_temp_ts': 1703858400,
#    'max_uv': 2.6,
#    'max_wind_dir': 242,
#    'max_wind_spd': 14.2,
#    'max_wind_spd_ts': 1703847600,
#    'min_temp': 4.4,
#    'min_temp_ts': 1703818800,
#    'precip': 2.5,
#    'precip_gpm': 2.5,
#    'pres': 1001,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 73,
#    'slp': 1008,
#    'snow': 0,
#    'snow_depth': 2,
#    'solar_rad': 99,
#    't_dhi': 1555,
#    't_dni': 12521,
#    't_ghi': 8905,
#    't_solar_rad': 2368,
#    'temp': 7.6,
#    'ts': 1703818800,
#    'wind_dir': 242,
#    'wind_gust_spd': 19.3,
#    'wind_spd': 8.8},
#   {'clouds': 55,
#    'datetime': '2023-12-30',
#    'dewpt': 3.8,
#    'dhi': 65,
#    'dni': 521,
#    'ghi': 370,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 927,
#    'max_temp': 13.3,
#    'max_temp_ts': 1703955600,
#    'max_uv': 5.1,
#    'max_wind_dir': 227,
#    'max_wind_spd': 14.4,
#    'max_wind_spd_ts': 1703934000,
#    'min_temp': 7.5,
#    'min_temp_ts': 1703926800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 67,
#    'slp': 1004,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 275,
#    't_dhi': 1553,
#    't_dni': 12509,
#    't_ghi': 8891,
#    't_solar_rad': 6611,
#    'temp': 9.8,
#    'ts': 1703905200,
#    'wind_dir': 227,
#    'wind_gust_spd': 19.6,
#    'wind_spd': 10.9},
#   {'clouds': 34,
#    'datetime': '2023-12-31',
#    'dewpt': 1.4,
#    'dhi': 65,
#    'dni': 521,
#    'ghi': 370,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 926,
#    'max_temp': 12,
#    'max_temp_ts': 1704049200,
#    'max_uv': 6.1,
#    'max_wind_dir': 229,
#    'max_wind_spd': 16.1,
#    'max_wind_spd_ts': 1704031200,
#    'min_temp': 7.9,
#    'min_temp_ts': 1704009600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 998,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 56,
#    'slp': 1004,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 354,
#    't_dhi': 1552,
#    't_dni': 12496,
#    't_ghi': 8875,
#    't_solar_rad': 8500,
#    'temp': 10,
#    'ts': 1703991600,
#    'wind_dir': 229,
#    'wind_gust_spd': 22.5,
#    'wind_spd': 11.5},
#   {'clouds': 80,
#    'datetime': '2024-01-01',
#    'dewpt': 5.6,
#    'dhi': 65,
#    'dni': 520,
#    'ghi': 370,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 926,
#    'max_temp': 17.6,
#    'max_temp_ts': 1704142800,
#    'max_uv': 2.8,
#    'max_wind_dir': 169,
#    'max_wind_spd': 8.7,
#    'max_wind_spd_ts': 1704078000,
#    'min_temp': 7.3,
#    'min_temp_ts': 1704099600,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 1000,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 70,
#    'slp': 1007,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 114,
#    't_dhi': 1551,
#    't_dni': 12491,
#    't_ghi': 8871,
#    't_solar_rad': 2725,
#    'temp': 11,
#    'ts': 1704078000,
#    'wind_dir': 169,
#    'wind_gust_spd': 10.6,
#    'wind_spd': 3.6},
#   {'clouds': 55,
#    'datetime': '2024-01-02',
#    'dewpt': 5.4,
#    'dhi': 65,
#    'dni': 520,
#    'ghi': 369,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 925,
#    'max_temp': 16.7,
#    'max_temp_ts': 1704229200,
#    'max_uv': 6.2,
#    'max_wind_dir': 174,
#    'max_wind_spd': 8.2,
#    'max_wind_spd_ts': 1704214800,
#    'min_temp': 8.3,
#    'min_temp_ts': 1704175200,
#    'precip': 1,
#    'precip_gpm': 1,
#    'pres': 997,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 68,
#    'slp': 1004,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 253,
#    't_dhi': 1549,
#    't_dni': 12475,
#    't_ghi': 8852,
#    't_solar_rad': 6065,
#    'temp': 12.1,
#    'ts': 1704164400,
#    'wind_dir': 174,
#    'wind_gust_spd': 10,
#    'wind_spd': 4.6},
#   {'clouds': 79,
#    'datetime': '2024-01-03',
#    'dewpt': 4.1,
#    'dhi': 64,
#    'dni': 519,
#    'ghi': 368,
#    'max_dhi': 125,
#    'max_dni': 955,
#    'max_ghi': 924,
#    'max_temp': 17.6,
#    'max_temp_ts': 1704301200,
#    'max_uv': 3.1,
#    'max_wind_dir': 214,
#    'max_wind_spd': 7.6,
#    'max_wind_spd_ts': 1704301200,
#    'min_temp': 8.7,
#    'min_temp_ts': 1704268800,
#    'precip': 3,
#    'precip_gpm': 3,
#    'pres': 995,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 60,
#    'slp': 1002,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 117,
#    't_dhi': 1546,
#    't_dni': 12458,
#    't_ghi': 8832,
#    't_solar_rad': 2817,
#    'temp': 12.3,
#    'ts': 1704250800,
#    'wind_dir': 214,
#    'wind_gust_spd': 17.2,
#    'wind_spd': 3.5},
#   {'clouds': 80,
#    'datetime': '2024-01-04',
#    'dewpt': 6.1,
#    'dhi': 64,
#    'dni': 518,
#    'ghi': 367,
#    'max_dhi': 125,
#    'max_dni': 954,
#    'max_ghi': 923,
#    'max_temp': 11.3,
#    'max_temp_ts': 1704337200,
#    'max_uv': 2.6,
#    'max_wind_dir': 183,
#    'max_wind_spd': 12.2,
#    'max_wind_spd_ts': 1704348000,
#    'min_temp': 7.2,
#    'min_temp_ts': 1704420000,
#    'precip': 2.5,
#    'precip_gpm': 2.5,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 82,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 112,
#    't_dhi': 1544,
#    't_dni': 12438,
#    't_ghi': 8811,
#    't_solar_rad': 2679,
#    'temp': 8.9,
#    'ts': 1704337200,
#    'wind_dir': 183,
#    'wind_gust_spd': 15.9,
#    'wind_spd': 7.1},
#   {'clouds': 89,
#    'datetime': '2024-01-05',
#    'dewpt': 3.5,
#    'dhi': 64,
#    'dni': 517,
#    'ghi': 366,
#    'max_dhi': 125,
#    'max_dni': 954,
#    'max_ghi': 922,
#    'max_temp': 10.8,
#    'max_temp_ts': 1704477600,
#    'max_uv': 2.9,
#    'max_wind_dir': 187,
#    'max_wind_spd': 9.7,
#    'max_wind_spd_ts': 1704481200,
#    'min_temp': 6,
#    'min_temp_ts': 1704445200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 137,
#    't_dhi': 1541,
#    't_dni': 12416,
#    't_ghi': 8787,
#    't_solar_rad': 3300,
#    'temp': 7.9,
#    'ts': 1704423600,
#    'wind_dir': 187,
#    'wind_gust_spd': 12.1,
#    'wind_spd': 5.3},
#   {'clouds': 67,
#    'datetime': '2024-01-06',
#    'dewpt': 3.1,
#    'dhi': 64,
#    'dni': 516,
#    'ghi': 365,
#    'max_dhi': 125,
#    'max_dni': 954,
#    'max_ghi': 920,
#    'max_temp': 14.7,
#    'max_temp_ts': 1704567600,
#    'max_uv': 2.6,
#    'max_wind_dir': 255,
#    'max_wind_spd': 8.8,
#    'max_wind_spd_ts': 1704571200,
#    'min_temp': 5.4,
#    'min_temp_ts': 1704524400,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 64,
#    'slp': 997,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 101,
#    't_dhi': 1538,
#    't_dni': 12393,
#    't_ghi': 8762,
#    't_solar_rad': 2430,
#    'temp': 10.2,
#    'ts': 1704510000,
#    'wind_dir': 255,
#    'wind_gust_spd': 16,
#    'wind_spd': 4.3},
#   {'clouds': 69,
#    'datetime': '2024-01-07',
#    'dewpt': 2.2,
#    'dhi': 64,
#    'dni': 515,
#    'ghi': 364,
#    'max_dhi': 125,
#    'max_dni': 953,
#    'max_ghi': 919,
#    'max_temp': 12.6,
#    'max_temp_ts': 1704654000,
#    'max_uv': 5.6,
#    'max_wind_dir': 219,
#    'max_wind_spd': 12.8,
#    'max_wind_spd_ts': 1704646800,
#    'min_temp': 8,
#    'min_temp_ts': 1704618000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 987,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 60,
#    'slp': 994,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 312,
#    't_dhi': 1534,
#    't_dni': 12367,
#    't_ghi': 8735,
#    't_solar_rad': 7478,
#    'temp': 9.8,
#    'ts': 1704596400,
#    'wind_dir': 219,
#    'wind_gust_spd': 16.9,
#    'wind_spd': 8.6},
#   {'clouds': 69,
#    'datetime': '2024-01-08',
#    'dewpt': 2.5,
#    'dhi': 64,
#    'dni': 514,
#    'ghi': 363,
#    'max_dhi': 125,
#    'max_dni': 953,
#    'max_ghi': 917,
#    'max_temp': 11,
#    'max_temp_ts': 1704718800,
#    'max_uv': 4.9,
#    'max_wind_dir': 231,
#    'max_wind_spd': 14.1,
#    'max_wind_spd_ts': 1704744000,
#    'min_temp': 5.3,
#    'min_temp_ts': 1704765600,
#    'precip': 5,
#    'precip_gpm': 5,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 65,
#    'slp': 991,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 299,
#    't_dhi': 1531,
#    't_dni': 12340,
#    't_ghi': 8706,
#    't_solar_rad': 7178,
#    'temp': 8.8,
#    'ts': 1704682800,
#    'wind_dir': 231,
#    'wind_gust_spd': 19.2,
#    'wind_spd': 6.9},
#   {'clouds': 73,
#    'datetime': '2024-01-09',
#    'dewpt': 1.3,
#    'dhi': 64,
#    'dni': 513,
#    'ghi': 361,
#    'max_dhi': 125,
#    'max_dni': 953,
#    'max_ghi': 916,
#    'max_temp': 9,
#    'max_temp_ts': 1704823200,
#    'max_uv': 4.7,
#    'max_wind_dir': 229,
#    'max_wind_spd': 14.2,
#    'max_wind_spd_ts': 1704808800,
#    'min_temp': 3,
#    'min_temp_ts': 1704844800,
#    'precip': 2,
#    'precip_gpm': 2,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 79,
#    'slp': 998,
#    'snow': 2,
#    'snow_depth': 2,
#    'solar_rad': 284,
#    't_dhi': 1527,
#    't_dni': 12312,
#    't_ghi': 8676,
#    't_solar_rad': 6807,
#    'temp': 4.7,
#    'ts': 1704769200,
#    'wind_dir': 229,
#    'wind_gust_spd': 19.2,
#    'wind_spd': 10.5},
#   {'clouds': 73,
#    'datetime': '2024-01-10',
#    'dewpt': 1.7,
#    'dhi': 63,
#    'dni': 512,
#    'ghi': 360,
#    'max_dhi': 124,
#    'max_dni': 952,
#    'max_ghi': 914,
#    'max_temp': 12,
#    'max_temp_ts': 1704920400,
#    'max_uv': 4.4,
#    'max_wind_dir': 230,
#    'max_wind_spd': 16.9,
#    'max_wind_spd_ts': 1704934800,
#    'min_temp': 3.5,
#    'min_temp_ts': 1704855600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1001,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 69,
#    'slp': 1008,
#    'snow': 0,
#    'snow_depth': 2,
#    'solar_rad': 170,
#    't_dhi': 1522,
#    't_dni': 12282,
#    't_ghi': 8644,
#    't_solar_rad': 4084,
#    'temp': 7.2,
#    'ts': 1704855600,
#    'wind_dir': 230,
#    'wind_gust_spd': 24.1,
#    'wind_spd': 11.6},
#   {'clouds': 26,
#    'datetime': '2024-01-11',
#    'dewpt': 0.7,
#    'dhi': 63,
#    'dni': 510,
#    'ghi': 359,
#    'max_dhi': 124,
#    'max_dni': 952,
#    'max_ghi': 912,
#    'max_temp': 11.4,
#    'max_temp_ts': 1704999600,
#    'max_uv': 5.5,
#    'max_wind_dir': 235,
#    'max_wind_spd': 15.2,
#    'max_wind_spd_ts': 1704978000,
#    'min_temp': 6.6,
#    'min_temp_ts': 1704963600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 1004,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 57,
#    'slp': 1011,
#    'snow': 0,
#    'snow_depth': 1,
#    'solar_rad': 299,
#    't_dhi': 1518,
#    't_dni': 12250,
#    't_ghi': 8610,
#    't_solar_rad': 7182,
#    'temp': 8.8,
#    'ts': 1704942000,
#    'wind_dir': 235,
#    'wind_gust_spd': 21,
#    'wind_spd': 12.1},
#   {'clouds': 77,
#    'datetime': '2024-01-12',
#    'dewpt': 3.2,
#    'dhi': 63,
#    'dni': 509,
#    'ghi': 357,
#    'max_dhi': 124,
#    'max_dni': 951,
#    'max_ghi': 910,
#    'max_temp': 12.8,
#    'max_temp_ts': 1705071600,
#    'max_uv': 3.3,
#    'max_wind_dir': 251,
#    'max_wind_spd': 18.1,
#    'max_wind_spd_ts': 1705078800,
#    'min_temp': 7.3,
#    'min_temp_ts': 1705111200,
#    'precip': 1.5,
#    'precip_gpm': 1.5,
#    'pres': 992,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 64,
#    'slp': 999,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 133,
#    't_dhi': 1513,
#    't_dni': 12218,
#    't_ghi': 8575,
#    't_solar_rad': 3203,
#    'temp': 9.7,
#    'ts': 1705028400,
#    'wind_dir': 251,
#    'wind_gust_spd': 26.2,
#    'wind_spd': 11.1},
#   {'clouds': 86,
#    'datetime': '2024-01-13',
#    'dewpt': 2.1,
#    'dhi': 63,
#    'dni': 508,
#    'ghi': 356,
#    'max_dhi': 124,
#    'max_dni': 951,
#    'max_ghi': 908,
#    'max_temp': 9.3,
#    'max_temp_ts': 1705161600,
#    'max_uv': 3.5,
#    'max_wind_dir': 228,
#    'max_wind_spd': 15.4,
#    'max_wind_spd_ts': 1705165200,
#    'min_temp': 2,
#    'min_temp_ts': 1705197600,
#    'precip': 9.5,
#    'precip_gpm': 9.5,
#    'pres': 984,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 78,
#    'slp': 991,
#    'snow': 3,
#    'snow_depth': 3,
#    'solar_rad': 211,
#    't_dhi': 1508,
#    't_dni': 12184,
#    't_ghi': 8538,
#    't_solar_rad': 5068,
#    'temp': 5.7,
#    'ts': 1705114800,
#    'wind_dir': 228,
#    'wind_gust_spd': 21.3,
#    'wind_spd': 11.9},
#   {'clouds': 62,
#    'datetime': '2024-01-14',
#    'dewpt': 1,
#    'dhi': 63,
#    'dni': 506,
#    'ghi': 354,
#    'max_dhi': 124,
#    'max_dni': 950,
#    'max_ghi': 906,
#    'max_temp': 8.8,
#    'max_temp_ts': 1705258800,
#    'max_uv': 3.1,
#    'max_wind_dir': 231,
#    'max_wind_spd': 13.5,
#    'max_wind_spd_ts': 1705215600,
#    'min_temp': 2,
#    'min_temp_ts': 1705201200,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 992,
#    'snow': 0,
#    'snow_depth': 3,
#    'solar_rad': 174,
#    't_dhi': 1503,
#    't_dni': 12149,
#    't_ghi': 8500,
#    't_solar_rad': 4186,
#    'temp': 5.1,
#    'ts': 1705201200,
#    'wind_dir': 231,
#    'wind_gust_spd': 18.1,
#    'wind_spd': 11.5},
#   {'clouds': 93,
#    'datetime': '2024-01-15',
#    'dewpt': 2.2,
#    'dhi': 62,
#    'dni': 505,
#    'ghi': 353,
#    'max_dhi': 124,
#    'max_dni': 949,
#    'max_ghi': 904,
#    'max_temp': 7.8,
#    'max_temp_ts': 1705341600,
#    'max_uv': 3.5,
#    'max_wind_dir': 250,
#    'max_wind_spd': 11.8,
#    'max_wind_spd_ts': 1705294800,
#    'min_temp': 1,
#    'min_temp_ts': 1705359600,
#    'precip': 10.5,
#    'precip_gpm': 10.5,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 86,
#    'slp': 996,
#    'snow': 9,
#    'snow_depth': 11,
#    'solar_rad': 146,
#    't_dhi': 1497,
#    't_dni': 12113,
#    't_ghi': 8460,
#    't_solar_rad': 3493,
#    'temp': 4.4,
#    'ts': 1705287600,
#    'wind_dir': 250,
#    'wind_gust_spd': 15.3,
#    'wind_spd': 6.8},
#   {'clouds': 82,
#    'datetime': '2024-01-16',
#    'dewpt': 4.3,
#    'dhi': 62,
#    'dni': 503,
#    'ghi': 351,
#    'max_dhi': 124,
#    'max_dni': 949,
#    'max_ghi': 902,
#    'max_temp': 13,
#    'max_temp_ts': 1705438800,
#    'max_uv': 2.5,
#    'max_wind_dir': 218,
#    'max_wind_spd': 7.2,
#    'max_wind_spd_ts': 1705438800,
#    'min_temp': 3.8,
#    'min_temp_ts': 1705374000,
#    'precip': 3.5,
#    'precip_gpm': 3.5,
#    'pres': 992,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 78,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 6,
#    'solar_rad': 72,
#    't_dhi': 1492,
#    't_dni': 12076,
#    't_ghi': 8419,
#    't_solar_rad': 1730,
#    'temp': 8.1,
#    'ts': 1705374000,
#    'wind_dir': 218,
#    'wind_gust_spd': 15.2,
#    'wind_spd': 3.6},
#   {'clouds': 64,
#    'datetime': '2024-01-17',
#    'dewpt': 6.2,
#    'dhi': 62,
#    'dni': 501,
#    'ghi': 349,
#    'max_dhi': 124,
#    'max_dni': 948,
#    'max_ghi': 899,
#    'max_temp': 14.4,
#    'max_temp_ts': 1705518000,
#    'max_uv': 2.5,
#    'max_wind_dir': 210,
#    'max_wind_spd': 12,
#    'max_wind_spd_ts': 1705500000,
#    'min_temp': 8.6,
#    'min_temp_ts': 1705482000,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 74,
#    'slp': 992,
#    'snow': 0,
#    'snow_depth': 1,
#    'solar_rad': 101,
#    't_dhi': 1487,
#    't_dni': 12036,
#    't_ghi': 8376,
#    't_solar_rad': 2426,
#    'temp': 10.8,
#    'ts': 1705460400,
#    'wind_dir': 210,
#    'wind_gust_spd': 15.6,
#    'wind_spd': 5.7},
#   {'clouds': 59,
#    'datetime': '2024-01-18',
#    'dewpt': 4.3,
#    'dhi': 62,
#    'dni': 500,
#    'ghi': 347,
#    'max_dhi': 123,
#    'max_dni': 947,
#    'max_ghi': 897,
#    'max_temp': 17,
#    'max_temp_ts': 1705604400,
#    'max_uv': 2.7,
# ...
#    't_dhi': 1225,
#    't_dni': 10057,
#    't_ghi': 6408,
#    't_solar_rad': 3275,
#    'temp': 5.5,
#    'ts': 1729738800,
#    'wind_dir': 224,
#    'wind_gust_spd': 24.3,
#    'wind_spd': 8.6},
#   {'clouds': 82,
#    'datetime': '2024-10-25',
#    'dewpt': 1.1,
#    'dhi': 51,
#    'dni': 422,
#    'ghi': 270,
#    'max_dhi': 115,
#    'max_dni': 897,
#    'max_ghi': 768,
#    'max_temp': 8.9,
#    'max_temp_ts': 1729872000,
#    'max_uv': 4.4,
#    'max_wind_dir': 242,
#    'max_wind_spd': 20.6,
#    'max_wind_spd_ts': 1729875600,
#    'min_temp': 0.9,
#    'min_temp_ts': 1729900800,
#    'precip': 5.5,
#    'precip_gpm': 5.5,
#    'pres': 982,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 80,
#    'slp': 988,
#    'snow': 0.5,
#    'snow_depth': 0,
#    'solar_rad': 192,
#    't_dhi': 1233,
#    't_dni': 10121,
#    't_ghi': 6480,
#    't_solar_rad': 4604,
#    'temp': 4.3,
#    'ts': 1729825200,
#    'wind_dir': 242,
#    'wind_gust_spd': 30.7,
#    'wind_spd': 10},
#   {'clouds': 75,
#    'datetime': '2024-10-26',
#    'dewpt': 0.9,
#    'dhi': 52,
#    'dni': 424,
#    'ghi': 273,
#    'max_dhi': 115,
#    'max_dni': 899,
#    'max_ghi': 774,
#    'max_temp': 10.6,
#    'max_temp_ts': 1729969200,
#    'max_uv': 2.6,
#    'max_wind_dir': 227,
#    'max_wind_spd': 15.5,
#    'max_wind_spd_ts': 1729922400,
#    'min_temp': 2.7,
#    'min_temp_ts': 1729918800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 987,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 69,
#    'slp': 994,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 130,
#    't_dhi': 1243,
#    't_dni': 10182,
#    't_ghi': 6551,
#    't_solar_rad': 3130,
#    'temp': 6.3,
#    'ts': 1729911600,
#    'wind_dir': 227,
#    'wind_gust_spd': 21.4,
#    'wind_spd': 10.1},
#   {'clouds': 70,
#    'datetime': '2024-10-27',
#    'dewpt': 2.6,
#    'dhi': 52,
#    'dni': 427,
#    'ghi': 276,
#    'max_dhi': 115,
#    'max_dni': 901,
#    'max_ghi': 779,
#    'max_temp': 9,
#    'max_temp_ts': 1730041200,
#    'max_uv': 3.6,
#    'max_wind_dir': 207,
#    'max_wind_spd': 12.6,
#    'max_wind_spd_ts': 1730052000,
#    'min_temp': 5.3,
#    'min_temp_ts': 1730080800,
#    'precip': 2,
#    'precip_gpm': 2,
#    'pres': 977,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 984,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 200,
#    't_dhi': 1253,
#    't_dni': 10246,
#    't_ghi': 6622,
#    't_solar_rad': 4806,
#    'temp': 6.7,
#    'ts': 1729998000,
#    'wind_dir': 207,
#    'wind_gust_spd': 22.8,
#    'wind_spd': 5.9},
#   {'clouds': 64,
#    'datetime': '2024-10-28',
#    'dewpt': 3.2,
#    'dhi': 53,
#    'dni': 430,
#    'ghi': 279,
#    'max_dhi': 116,
#    'max_dni': 903,
#    'max_ghi': 784,
#    'max_temp': 9.7,
#    'max_temp_ts': 1730145600,
#    'max_uv': 3.7,
#    'max_wind_dir': 218,
#    'max_wind_spd': 13,
#    'max_wind_spd_ts': 1730152800,
#    'min_temp': 5.2,
#    'min_temp_ts': 1730098800,
#    'precip': 7,
#    'precip_gpm': 7,
#    'pres': 980,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 77,
#    'slp': 987,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 172,
#    't_dhi': 1263,
#    't_dni': 10315,
#    't_ghi': 6693,
#    't_solar_rad': 4116,
#    'temp': 7,
#    'ts': 1730084400,
#    'wind_dir': 218,
#    'wind_gust_spd': 22.8,
#    'wind_spd': 7.6},
#   {'clouds': 68,
#    'datetime': '2024-10-29',
#    'dewpt': 2.2,
#    'dhi': 53,
#    'dni': 433,
#    'ghi': 282,
#    'max_dhi': 116,
#    'max_dni': 905,
#    'max_ghi': 789,
#    'max_temp': 10.2,
#    'max_temp_ts': 1730192400,
#    'max_uv': 3.8,
#    'max_wind_dir': 230,
#    'max_wind_spd': 15.7,
#    'max_wind_spd_ts': 1730228400,
#    'min_temp': 4,
#    'min_temp_ts': 1730246400,
#    'precip': 6,
#    'precip_gpm': 6,
#    'pres': 983,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 990,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 239,
#    't_dhi': 1273,
#    't_dni': 10386,
#    't_ghi': 6763,
#    't_solar_rad': 5738,
#    'temp': 7.2,
#    'ts': 1730170800,
#    'wind_dir': 230,
#    'wind_gust_spd': 27.6,
#    'wind_spd': 8.6},
#   {'clouds': 45,
#    'datetime': '2024-10-30',
#    'dewpt': -0.5,
#    'dhi': 53,
#    'dni': 436,
#    'ghi': 285,
#    'max_dhi': 116,
#    'max_dni': 907,
#    'max_ghi': 794,
#    'max_temp': 12,
#    'max_temp_ts': 1730307600,
#    'max_uv': 4.8,
#    'max_wind_dir': 232,
#    'max_wind_spd': 16.6,
#    'max_wind_spd_ts': 1730322000,
#    'min_temp': 3.5,
#    'min_temp_ts': 1730264400,
#    'precip': 1,
#    'precip_gpm': 1,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 56,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 210,
#    't_dhi': 1283,
#    't_dni': 10458,
#    't_ghi': 6833,
#    't_solar_rad': 5038,
#    'temp': 8,
#    'ts': 1730257200,
#    'wind_dir': 232,
#    'wind_gust_spd': 23.5,
#    'wind_spd': 7.7},
#   {'clouds': 64,
#    'datetime': '2024-10-31',
#    'dewpt': 3.6,
#    'dhi': 54,
#    'dni': 439,
#    'ghi': 288,
#    'max_dhi': 117,
#    'max_dni': 909,
#    'max_ghi': 799,
#    'max_temp': 19,
#    'max_temp_ts': 1730404800,
#    'max_uv': 3.6,
#    'max_wind_dir': 254,
#    'max_wind_spd': 11.8,
#    'max_wind_spd_ts': 1730386800,
#    'min_temp': 5.8,
#    'min_temp_ts': 1730358000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 990,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 58,
#    'slp': 997,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 170,
#    't_dhi': 1292,
#    't_dni': 10530,
#    't_ghi': 6903,
#    't_solar_rad': 4070,
#    'temp': 11.8,
#    'ts': 1730343600,
#    'wind_dir': 254,
#    'wind_gust_spd': 18,
#    'wind_spd': 4.8},
#   {'clouds': 69,
#    'datetime': '2024-11-01',
#    'dewpt': 4.3,
#    'dhi': 54,
#    'dni': 442,
#    'ghi': 290,
#    'max_dhi': 117,
#    'max_dni': 910,
#    'max_ghi': 804,
#    'max_temp': 17,
#    'max_temp_ts': 1730480400,
#    'max_uv': 2.1,
#    'max_wind_dir': 232,
#    'max_wind_spd': 10.7,
#    'max_wind_spd_ts': 1730498400,
#    'min_temp': 3,
#    'min_temp_ts': 1730505600,
#    'precip': 6,
#    'precip_gpm': 6,
#    'pres': 978,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 984,
#    'snow': 3,
#    'snow_depth': 3,
#    'solar_rad': 82,
#    't_dhi': 1301,
#    't_dni': 10600,
#    't_ghi': 6972,
#    't_solar_rad': 1973,
#    'temp': 9.8,
#    'ts': 1730430000,
#    'wind_dir': 232,
#    'wind_gust_spd': 13.6,
#    'wind_spd': 5},
#   {'clouds': 60,
#    'datetime': '2024-11-02',
#    'dewpt': 0,
#    'dhi': 55,
#    'dni': 445,
#    'ghi': 293,
#    'max_dhi': 117,
#    'max_dni': 912,
#    'max_ghi': 809,
#    'max_temp': 9,
#    'max_temp_ts': 1730570400,
#    'max_uv': 4.2,
#    'max_wind_dir': 224,
#    'max_wind_spd': 13.2,
#    'max_wind_spd_ts': 1730548800,
#    'min_temp': 2.3,
#    'min_temp_ts': 1730538000,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 987,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 68,
#    'slp': 994,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 265,
#    't_dhi': 1310,
#    't_dni': 10669,
#    't_ghi': 7040,
#    't_solar_rad': 6370,
#    'temp': 5.7,
#    'ts': 1730516400,
#    'wind_dir': 224,
#    'wind_gust_spd': 17.5,
#    'wind_spd': 8.7},
#   {'clouds': 58,
#    'datetime': '2024-11-03',
#    'dewpt': 1.6,
#    'dhi': 55,
#    'dni': 447,
#    'ghi': 296,
#    'max_dhi': 118,
#    'max_dni': 914,
#    'max_ghi': 814,
#    'max_temp': 13,
#    'max_temp_ts': 1730649600,
#    'max_uv': 3,
#    'max_wind_dir': 223,
#    'max_wind_spd': 7.8,
#    'max_wind_spd_ts': 1730610000,
#    'min_temp': 6.4,
#    'min_temp_ts': 1730682000,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 977,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 56,
#    'slp': 984,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 118,
#    't_dhi': 1318,
#    't_dni': 10736,
#    't_ghi': 7107,
#    't_solar_rad': 2836,
#    'temp': 10.2,
#    'ts': 1730602800,
#    'wind_dir': 223,
#    'wind_gust_spd': 21.2,
#    'wind_spd': 5.3},
#   {'clouds': 55,
#    'datetime': '2024-11-04',
#    'dewpt': 1.1,
#    'dhi': 55,
#    'dni': 450,
#    'ghi': 299,
#    'max_dhi': 118,
#    'max_dni': 915,
#    'max_ghi': 818,
#    'max_temp': 10.8,
#    'max_temp_ts': 1730725200,
#    'max_uv': 5.1,
#    'max_wind_dir': 237,
#    'max_wind_spd': 11.2,
#    'max_wind_spd_ts': 1730754000,
#    'min_temp': 5,
#    'min_temp_ts': 1730696400,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 975,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 63,
#    'slp': 982,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 267,
#    't_dhi': 1326,
#    't_dni': 10802,
#    't_ghi': 7174,
#    't_solar_rad': 6402,
#    'temp': 8,
#    'ts': 1730689200,
#    'wind_dir': 237,
#    'wind_gust_spd': 15.6,
#    'wind_spd': 6.2},
#   {'clouds': 86,
#    'datetime': '2024-11-05',
#    'dewpt': 0.9,
#    'dhi': 56,
#    'dni': 453,
#    'ghi': 302,
#    'max_dhi': 118,
#    'max_dni': 917,
#    'max_ghi': 823,
#    'max_temp': 6.4,
#    'max_temp_ts': 1730822400,
#    'max_uv': 3.5,
#    'max_wind_dir': 130,
#    'max_wind_spd': 10.8,
#    'max_wind_spd_ts': 1730779200,
#    'min_temp': 2,
#    'min_temp_ts': 1730800800,
#    'precip': 12,
#    'precip_gpm': 12,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 83,
#    'slp': 992,
#    'snow': 4.5,
#    'snow_depth': 1,
#    'solar_rad': 153,
#    't_dhi': 1334,
#    't_dni': 10865,
#    't_ghi': 7240,
#    't_solar_rad': 3669,
#    'temp': 3.5,
#    'ts': 1730775600,
#    'wind_dir': 130,
#    'wind_gust_spd': 13.7,
#    'wind_spd': 5.1},
#   {'clouds': 69,
#    'datetime': '2024-11-06',
#    'dewpt': -0.1,
#    'dhi': 56,
#    'dni': 455,
#    'ghi': 304,
#    'max_dhi': 119,
#    'max_dni': 919,
#    'max_ghi': 827,
#    'max_temp': 9,
#    'max_temp_ts': 1730916000,
#    'max_uv': 6.3,
#    'max_wind_dir': 222,
#    'max_wind_spd': 11,
#    'max_wind_spd_ts': 1730926800,
#    'min_temp': 2,
#    'min_temp_ts': 1730876400,
#    'precip': 2.5,
#    'precip_gpm': 2.5,
#    'pres': 994,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 71,
#    'slp': 1001,
#    'snow': 1,
#    'snow_depth': 0,
#    'solar_rad': 277,
#    't_dhi': 1342,
#    't_dni': 10926,
#    't_ghi': 7304,
#    't_solar_rad': 6656,
#    'temp': 5,
#    'ts': 1730862000,
#    'wind_dir': 222,
#    'wind_gust_spd': 14,
#    'wind_spd': 6.2},
#   {'clouds': 70,
#    'datetime': '2024-11-07',
#    'dewpt': 1.2,
#    'dhi': 56,
#    'dni': 458,
#    'ghi': 307,
#    'max_dhi': 119,
#    'max_dni': 920,
#    'max_ghi': 832,
#    'max_temp': 10.3,
#    'max_temp_ts': 1730995200,
#    'max_uv': 2.2,
#    'max_wind_dir': 196,
#    'max_wind_spd': 7.5,
#    'max_wind_spd_ts': 1730998800,
#    'min_temp': 3.5,
#    'min_temp_ts': 1730966400,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 991,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 67,
#    'slp': 998,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 77,
#    't_dhi': 1351,
#    't_dni': 10986,
#    't_ghi': 7368,
#    't_solar_rad': 1854,
#    'temp': 7.2,
#    'ts': 1730948400,
#    'wind_dir': 196,
#    'wind_gust_spd': 8.9,
#    'wind_spd': 3.8},
#   {'clouds': 81,
#    'datetime': '2024-11-08',
#    'dewpt': 2.7,
#    'dhi': 57,
#    'dni': 460,
#    'ghi': 310,
#    'max_dhi': 119,
#    'max_dni': 922,
#    'max_ghi': 836,
#    'max_temp': 8.6,
#    'max_temp_ts': 1731092400,
#    'max_uv': 2.2,
#    'max_wind_dir': 129,
#    'max_wind_spd': 8.8,
#    'max_wind_spd_ts': 1731103200,
#    'min_temp': 3.6,
#    'min_temp_ts': 1731063600,
#    'precip': 3,
#    'precip_gpm': 3,
#    'pres': 993,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 81,
#    'slp': 1000,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 51,
#    't_dhi': 1361,
#    't_dni': 11047,
#    't_ghi': 7432,
#    't_solar_rad': 1223,
#    'temp': 5.7,
#    'ts': 1731034800,
#    'wind_dir': 129,
#    'wind_gust_spd': 10.7,
#    'wind_spd': 4.4},
#   {'clouds': 66,
#    'datetime': '2024-11-09',
#    'dewpt': 2.7,
#    'dhi': 57,
#    'dni': 463,
#    'ghi': 312,
#    'max_dhi': 119,
#    'max_dni': 923,
#    'max_ghi': 840,
#    'max_temp': 8.4,
#    'max_temp_ts': 1731189600,
#    'max_uv': 2.2,
#    'max_wind_dir': 198,
#    'max_wind_spd': 9.2,
#    'max_wind_spd_ts': 1731124800,
#    'min_temp': 4.8,
#    'min_temp_ts': 1731135600,
#    'precip': 9,
#    'precip_gpm': 9,
#    'pres': 988,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 79,
#    'slp': 995,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 52,
#    't_dhi': 1370,
#    't_dni': 11111,
#    't_ghi': 7495,
#    't_solar_rad': 1256,
#    'temp': 6.1,
#    'ts': 1731121200,
#    'wind_dir': 198,
#    'wind_gust_spd': 11.3,
#    'wind_spd': 5},
#   {'clouds': 60,
#    'datetime': '2024-11-10',
#    'dewpt': 3.3,
#    'dhi': 57,
#    'dni': 466,
#    'ghi': 315,
#    'max_dhi': 120,
#    'max_dni': 925,
#    'max_ghi': 844,
#    'max_temp': 10.3,
#    'max_temp_ts': 1731250800,
#    'max_uv': 3.9,
#    'max_wind_dir': 232,
#    'max_wind_spd': 10.3,
#    'max_wind_spd_ts': 1731272400,
#    'min_temp': 2.7,
#    'min_temp_ts': 1731214800,
#    'precip': 0.5,
#    'precip_gpm': 0.5,
#    'pres': 986,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 82,
#    'slp': 993,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 226,
#    't_dhi': 1379,
#    't_dni': 11176,
#    't_ghi': 7557,
#    't_solar_rad': 5422,
#    'temp': 6.2,
#    'ts': 1731207600,
#    'wind_dir': 232,
#    'wind_gust_spd': 16.4,
#    'wind_spd': 5.4},
#   {'clouds': 83,
#    'datetime': '2024-11-11',
#    'dewpt': 2.8,
#    'dhi': 58,
#    'dni': 468,
#    'ghi': 317,
#    'max_dhi': 120,
#    'max_dni': 926,
#    'max_ghi': 848,
#    'max_temp': 10,
#    'max_temp_ts': 1731348000,
#    'max_uv': 2.3,
#    'max_wind_dir': 242,
#    'max_wind_spd': 7.8,
#    'max_wind_spd_ts': 1731294000,
#    'min_temp': 4,
#    'min_temp_ts': 1731312000,
#    'precip': 4,
#    'precip_gpm': 4,
#    'pres': 989,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 75,
#    'slp': 996,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 86,
#    't_dhi': 1388,
#    't_dni': 11242,
#    't_ghi': 7618,
#    't_solar_rad': 2070,
#    'temp': 7,
#    'ts': 1731294000,
#    'wind_dir': 242,
#    'wind_gust_spd': 9.3,
#    'wind_spd': 3.5},
#   {'clouds': 73,
#    'datetime': '2024-11-12',
#    'dewpt': 5.6,
#    'dhi': 58,
#    'dni': 471,
#    'ghi': 320,
#    'max_dhi': 120,
#    'max_dni': 927,
#    'max_ghi': 852,
#    'max_temp': 14.3,
#    'max_temp_ts': 1731434400,
#    'max_uv': 2.3,
#    'max_wind_dir': 187,
#    'max_wind_spd': 13.4,
#    'max_wind_spd_ts': 1731409200,
#    'min_temp': 6.8,
#    'min_temp_ts': 1731387600,
#    'precip': 2,
#    'precip_gpm': 2,
#    'pres': 987,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 78,
#    'slp': 994,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 99,
#    't_dhi': 1396,
#    't_dni': 11308,
#    't_ghi': 7678,
#    't_solar_rad': 2376,
#    'temp': 9.4,
#    'ts': 1731380400,
#    'wind_dir': 187,
#    'wind_gust_spd': 17.9,
#    'wind_spd': 6.5},
#   {'clouds': 69,
#    'datetime': '2024-11-13',
#    'dewpt': 1.8,
#    'dhi': 59,
#    'dni': 474,
#    'ghi': 322,
#    'max_dhi': 120,
#    'max_dni': 929,
#    'max_ghi': 856,
#    'max_temp': 14.2,
#    'max_temp_ts': 1731524400,
#    'max_uv': 5.6,
#    'max_wind_dir': 246,
#    'max_wind_spd': 13.1,
#    'max_wind_spd_ts': 1731481200,
#    'min_temp': 5,
#    'min_temp_ts': 1731549600,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 988,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 63,
#    'slp': 995,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 278,
#    't_dhi': 1405,
#    't_dni': 11372,
#    't_ghi': 7738,
#    't_solar_rad': 6674,
#    'temp': 9.5,
#    'ts': 1731466800,
#    'wind_dir': 246,
#    'wind_gust_spd': 17.6,
#    'wind_spd': 6},
#   {'clouds': 52,
#    'datetime': '2024-11-14',
#    'dewpt': 2.2,
#    'dhi': 59,
#    'dni': 476,
#    'ghi': 325,
#    'max_dhi': 121,
#    'max_dni': 930,
#    'max_ghi': 860,
#    'max_temp': 13.4,
#    'max_temp_ts': 1731614400,
#    'max_uv': 3.7,
#    'max_wind_dir': 244,
#    'max_wind_spd': 7.7,
#    'max_wind_spd_ts': 1731610800,
#    'min_temp': 3.1,
#    'min_temp_ts': 1731556800,
#    'precip': 0,
#    'precip_gpm': 0,
#    'pres': 985,
#    'revision_status': 'final',
#    'revision_version': '2.1',
#    'rh': 65,
#    'slp': 992,
#    'snow': 0,
#    'snow_depth': 0,
#    'solar_rad': 208,
#    't_dhi': 1412,
#    't_dni': 11435,
#    't_ghi': 7796,
#    't_solar_rad': 4988,
#    'temp': 9.1,
#    'ts': 1731553200,
#    'wind_dir': 244,
#    'wind_gust_spd': 15.6,
#    'wind_spd': 3.8}],
#  'lat': -54.8,
#  'lon': -68.3,
#  'sources': ['879380-99999', 'imerg', 'era5', 'sat', 'radar', 'snodas'],
#  'state_code': '23',
#  'station_id': '879380-99999',
#  'timezone': 'America/Argentina/Ushuaia'}

# %%
ciudad = data["city_name"]
ciudad
# Out:
# 'Ushuaia'

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []


for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])



    
for llave, valor in [("Ciudad", city_name), 
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
    datos[llave] = valor


# datos

ushuaia =  pd.DataFrame(datos)

ushuaia.head()

# city_name

ushuaia.to_csv("ushuaia_2021_11_15_2022_11_15.csv")

# %%
df_ushuaia_21 = pd.read_csv("ushuaia_2021_11_15_2022_11_15.csv")
df_ushuaia_22 = pd.read_csv("ushuaia_2022_11_15_2023_11_15.csv")
df_ushuaia_23 = pd.read_csv("ushuaia_2023_11_15_2024_11_15.csv")
df_ushuaia_24 = pd.read_csv("ushuaia_2024_11_15_2025_11_15.csv")

# %%
df_ushuaia = pd.concat([df_ushuaia_21, df_ushuaia_22, df_ushuaia_23, df_ushuaia_24], axis = 0, ignore_index = True)
df_ushuaia = df_ushuaia.drop("Unnamed: 0", axis = 1)

# %%
df_ushuaia
# Out:
#        Ciudad       Fecha  Fecha (UNIX)  Presión atmosférica  \
# 0     Ushuaia  2021-11-15    1636945200                  998
# 1     Ushuaia  2021-11-16    1637031600                  992
# 2     Ushuaia  2021-11-17    1637118000                  987
# 3     Ushuaia  2021-11-18    1637204400                  993
# 4     Ushuaia  2021-11-19    1637290800                  982
# ...       ...         ...           ...                  ...
# 1456  Ushuaia  2025-11-10    1762743600                  994
# 1457  Ushuaia  2025-11-11    1762830000                  985
# 1458  Ushuaia  2025-11-12    1762916400                  981
# 1459  Ushuaia  2025-11-13    1763002800                  978
# 1460  Ushuaia  2025-11-14    1763089200                  976
#
#       Presión Atm. sobre Nvl. del mar  Media de la vel. del viento (m/s)  \
# 0                                1005                               10.2
# 1                                 998                                7.5
# 2                                 994                               10.3
# 3                                1000                                9.5
# 4                                 989                               12.6
# ...                               ...                                ...
# 1456                             1005                                7.4
# 1457                              998                                5.8
# 1458                              989                                7.8
# 1459                              989                                5.1
# 1460                              985                                8.4
#
#       Vel. ráfaga de viento max.  Máx. vel. del viento /2min  \
# 0                           18.0                        13.2
# 1                           22.0                        15.8
# 2                           25.7                        14.5
# 3                           21.3                        15.4
# 4                           24.9                        17.4
# ...                          ...                         ...
# 1456                        13.3                        10.6
# 1457                        12.6                        10.0
# 1458                        19.3                        14.2
# 1459                         8.6                         7.3
# 1460                        17.6                        13.3
#
#       Momento (UNIX) de la vel. máx. del veinto  \
# 0                                    1636999200
# 1                                    1637114400
# 2                                    1637118000
# 3                                    1637233200
# 4                                    1637352000
# ...                                         ...
# 1456                                 1762794000
# 1457                                 1762898400
# 1458                                 1762963200
# 1459                                 1763038800
# 1460                                 1763136000
#
#       Media de la dirección del viento  ...  \
# 0                                  228  ...
# 1                                  269  ...
# 2                                  231  ...
# 3                                  217  ...
# 4                                  239  ...
# ...                                ...  ...
# 1456                               248  ...
# 1457                               235  ...
# 1458                               209  ...
# 1459                               226  ...
# 1460                               213  ...
#
#       Media de la radiación solar horizontal  \
# 0                                        327
# 1                                        330
# 2                                        332
# 3                                        334
# 4                                        336
# ...                                      ...
# 1456                                     315
# 1457                                     317
# 1458                                     320
# 1459                                     322
# 1460                                     325
#
#       Total de la radiación solar horizontal  \
# 0                                       7853
# 1                                       7909
# 2                                       7964
# 3                                       8018
# 4                                       8070
# ...                                      ...
# 1456                                    7557
# 1457                                    7618
# 1458                                    7678
# 1459                                    7738
# 1460                                    7796
#
#       Máximo de la radiación solar horizontal  \
# 0                                         863
# 1                                         867
# 2                                         870
# 3                                         874
# 4                                         877
# ...                                       ...
# 1456                                      844
# 1457                                      848
# 1458                                      852
# 1459                                      856
# 1460                                      860
#
#       Media de la radiación solar concentrada  \
# 0                                         479
# 1                                         481
# 2                                         484
# 3                                         486
# 4                                         488
# ...                                       ...
# 1456                                      466
# 1457                                      468
# 1458                                      471
# 1459                                      474
# 1460                                      476
#
#       Total de la radiación solar concentrada  \
# 0                                       11496
# 1                                       11555
# 2                                       11612
# 3                                       11667
# 4                                       11721
# ...                                       ...
# 1456                                    11176
# 1457                                    11242
# 1458                                    11308
# 1459                                    11372
# 1460                                    11435
#
#       Máximo de la radiación solar concentrada  \
# 0                                          931
# 1                                          932
# 2                                          934
# 3                                          935
# 4                                          936
# ...                                        ...
# 1456                                       925
# 1457                                       926
# 1458                                       927
# 1459                                       929
# 1460                                       930
#
#       Media de la radiación solar horizontal difusa  \
# 0                                                59
# 1                                                59
# 2                                                60
# 3                                                60
# 4                                                60
# ...                                             ...
# 1456                                             57
# 1457                                             58
# 1458                                             58
# 1459                                             59
# 1460                                             59
#
#       Total de la radiación solar horizontal difusa  \
# 0                                              1420
# 1                                              1427
# 2                                              1434
# 3                                              1441
# 4                                              1448
# ...                                             ...
# 1456                                           1379
# 1457                                           1388
# 1458                                           1396
# 1459                                           1405
# 1460                                           1412
#
#       Máximo de la radiación solar horizontal difusa  \
# 0                                                121
# 1                                                121
# 2                                                121
# 3                                                122
# 4                                                122
# ...                                              ...
# 1456                                             120
# 1457                                             120
# 1458                                             120
# 1459                                             120
# 1460                                             121
#
#       Índice máximo de rayos ultravioleta
# 0                                     4.5
# 1                                     2.4
# 2                                     5.4
# 3                                     3.0
# 4                                     5.2
# ...                                   ...
# 1456                                  2.3
# 1457                                  4.4
# 1458                                  4.0
# 1459                                  3.3
# 1460                                  4.3
#
# [1461 rows x 34 columns]
