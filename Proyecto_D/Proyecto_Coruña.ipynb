# %%
import requests
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data = {}

url = "https://api.weatherbit.io/v2.0/geocode?&city=a+coruña&country=ES&key=ac89c8c428e94ce68180c1a3a65dec3f"
response = requests.get(url)
data.update(response.json())

pprint(data)
# Out:
# {'country_code': 'ES',
#  'geo_id': 'A CORUñA--ES',
#  'lat': 43.37135,
#  'lon': -8.396,
#  'name': 'A Coruña',
#  'state_code': '58',
#  'timezone': 'Europe/Madrid'}

# %%
# Datos Coruña 2024/2025
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=43.37135&lon=8.396&start_date=2024-11-15&end_date=2025-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
data.update(response.json())

# %%
pprint(data)
# Out:
# {'city_id': '3178987',
#  'city_name': 'Cervo',
#  'country_code': 'IT',
#  'data': [{'clouds': 0,
#            'datetime': '2024-11-15',
#            'dewpt': 5.8,
#            'dhi': 28,
#            'dni': 239,
#            'ghi': 109,
#            'max_dhi': 93,
#            'max_dni': 780,
#            'max_ghi': 451,
#            'max_temp': 15.9,
#            'max_temp_ts': 1731679200,
#            'max_uv': 3,
#            'max_wind_dir': 132,
#            'max_wind_spd': 6.4,
#            'max_wind_spd_ts': 1731625200,
#            'min_temp': 15.2,
#            'min_temp_ts': 1731625200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1023,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 52,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 109,
#            't_dhi': 669,
#            't_dni': 5729,
#            't_ghi': 2608,
#            't_solar_rad': 2608,
#            'temp': 15.6,
#            'ts': 1731625200,
#            'wind_dir': 132,
#            'wind_gust_spd': 7.4,
#            'wind_spd': 3.1},
#           {'clouds': 10,
#            'datetime': '2024-11-16',
#            'dewpt': 9.3,
#            'dhi': 28,
#            'dni': 237,
#            'ghi': 107,
#            'max_dhi': 93,
#            'max_dni': 778,
#            'max_ghi': 447,
#            'max_temp': 16.7,
#            'max_temp_ts': 1731762000,
#            'max_uv': 2.7,
#            'max_wind_dir': 167,
#            'max_wind_spd': 8.8,
#            'max_wind_spd_ts': 1731794400,
#            'min_temp': 15.6,
#            'min_temp_ts': 1731715200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 65,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 107,
#            't_dhi': 663,
#            't_dni': 5693,
#            't_ghi': 2573,
#            't_solar_rad': 2571,
#            'temp': 15.8,
#            'ts': 1731711600,
#            'wind_dir': 167,
#            'wind_gust_spd': 12,
#            'wind_spd': 3.1},
#           {'clouds': 59,
#            'datetime': '2024-11-17',
#            'dewpt': 12.8,
#            'dhi': 27,
#            'dni': 236,
#            'ghi': 106,
#            'max_dhi': 92,
#            'max_dni': 776,
#            'max_ghi': 442,
#            'max_temp': 17,
#            'max_temp_ts': 1731880800,
#            'max_uv': 1.7,
#            'max_wind_dir': 248,
#            'max_wind_spd': 10.8,
#            'max_wind_spd_ts': 1731880800,
#            'min_temp': 16.3,
#            'min_temp_ts': 1731801600,
#            'precip': 2.3,
#            'precip_gpm': 2.3,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 77,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 68,
#            't_dhi': 658,
#            't_dni': 5658,
#            't_ghi': 2540,
#            't_solar_rad': 1624,
#            'temp': 16.8,
#            'ts': 1731798000,
#            'wind_dir': 248,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 8.1},
#           {'clouds': 53,
#            'datetime': '2024-11-18',
#            'dewpt': 10.9,
#            'dhi': 27,
#            'dni': 234,
#            'ghi': 104,
#            'max_dhi': 92,
#            'max_dni': 774,
#            'max_ghi': 438,
#            'max_temp': 16.7,
#            'max_temp_ts': 1731891600,
#            'max_uv': 2.4,
#            'max_wind_dir': 220,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1731888000,
#            'min_temp': 15.9,
#            'min_temp_ts': 1731895200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 71,
#            'slp': 1011,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 95,
#            't_dhi': 653,
#            't_dni': 5623,
#            't_ghi': 2508,
#            't_solar_rad': 2289,
#            'temp': 16.1,
#            'ts': 1731884400,
#            'wind_dir': 220,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 1.8},
#           {'clouds': 40,
#            'datetime': '2024-11-19',
#            'dewpt': 11.1,
#            'dhi': 27,
#            'dni': 233,
#            'ghi': 103,
#            'max_dhi': 92,
#            'max_dni': 772,
#            'max_ghi': 434,
#            'max_temp': 17,
#            'max_temp_ts': 1731970800,
#            'max_uv': 2.8,
#            'max_wind_dir': 247,
#            'max_wind_spd': 18,
#            'max_wind_spd_ts': 1731970800,
#            'min_temp': 15.6,
#            'min_temp_ts': 1731970800,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 72,
#            'slp': 1010,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 79,
#            't_dhi': 649,
#            't_dni': 5588,
#            't_ghi': 2476,
#            't_solar_rad': 1903,
#            'temp': 16.2,
#            'ts': 1731970800,
#            'wind_dir': 247,
#            'wind_gust_spd': 26.1,
#            'wind_spd': 9.5},
#           {'clouds': 84,
#            'datetime': '2024-11-20',
#            'dewpt': 9.1,
#            'dhi': 27,
#            'dni': 231,
#            'ghi': 102,
#            'max_dhi': 91,
#            'max_dni': 770,
#            'max_ghi': 430,
#            'max_temp': 17,
#            'max_temp_ts': 1732125600,
#            'max_uv': 1.7,
#            'max_wind_dir': 259,
#            'max_wind_spd': 20,
#            'max_wind_spd_ts': 1732125600,
#            'min_temp': 13.7,
#            'min_temp_ts': 1732125600,
#            'precip': 3.8,
#            'precip_gpm': 3.8,
#            'pres': 1001,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 65,
#            'slp': 1001,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 51,
#            't_dhi': 645,
#            't_dni': 5554,
#            't_ghi': 2445,
#            't_solar_rad': 1215,
#            'temp': 15.9,
#            'ts': 1732057200,
#            'wind_dir': 259,
#            'wind_gust_spd': 30,
#            'wind_spd': 16.7},
#           {'clouds': 64,
#            'datetime': '2024-11-21',
#            'dewpt': 7.3,
#            'dhi': 27,
#            'dni': 230,
#            'ghi': 101,
#            'max_dhi': 91,
#            'max_dni': 768,
#            'max_ghi': 426,
#            'max_temp': 17.4,
#            'max_temp_ts': 1732186800,
#            'max_uv': 1.7,
#            'max_wind_dir': 258,
#            'max_wind_spd': 18.4,
#            'max_wind_spd_ts': 1732186800,
#            'min_temp': 12.6,
#            'min_temp_ts': 1732226400,
#            'precip': 5,
#            'precip_gpm': 5,
#            'pres': 1003,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 64,
#            'slp': 1003,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 47,
#            't_dhi': 641,
#            't_dni': 5520,
#            't_ghi': 2415,
#            't_solar_rad': 1133,
#            'temp': 14.3,
#            'ts': 1732143600,
#            'wind_dir': 258,
#            'wind_gust_spd': 26.9,
#            'wind_spd': 10.6},
#           {'clouds': 35,
#            'datetime': '2024-11-22',
#            'dewpt': 5.3,
#            'dhi': 27,
#            'dni': 229,
#            'ghi': 99,
#            'max_dhi': 91,
#            'max_dni': 766,
#            'max_ghi': 423,
#            'max_temp': 17.4,
#            'max_temp_ts': 1732233600,
#            'max_uv': 2.8,
#            'max_wind_dir': 209,
#            'max_wind_spd': 18.4,
#            'max_wind_spd_ts': 1732233600,
#            'min_temp': 13,
#            'min_temp_ts': 1732312800,
#            'precip': 1.8,
#            'precip_gpm': 1.8,
#            'pres': 1004,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 55,
#            'slp': 1004,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 99,
#            't_dhi': 637,
#            't_dni': 5486,
#            't_ghi': 2386,
#            't_solar_rad': 2370,
#            'temp': 14.2,
#            'ts': 1732230000,
#            'wind_dir': 209,
#            'wind_gust_spd': 26.9,
#            'wind_spd': 11},
#           {'clouds': 20,
#            'datetime': '2024-11-23',
#            'dewpt': 1.8,
#            'dhi': 26,
#            'dni': 227,
#            'ghi': 98,
#            'max_dhi': 90,
#            'max_dni': 764,
#            'max_ghi': 419,
#            'max_temp': 14.4,
#            'max_temp_ts': 1732370400,
#            'max_uv': 2.8,
#            'max_wind_dir': 167,
#            'max_wind_spd': 6,
#            'max_wind_spd_ts': 1732384800,
#            'min_temp': 13,
#            'min_temp_ts': 1732323600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1027,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 46,
#            'slp': 1027,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 98,
#            't_dhi': 633,
#            't_dni': 5452,
#            't_ghi': 2358,
#            't_solar_rad': 2358,
#            'temp': 13.4,
#            'ts': 1732316400,
#            'wind_dir': 167,
#            'wind_gust_spd': 8.4,
#            'wind_spd': 4.9},
#           {'clouds': 46,
#            'datetime': '2024-11-24',
#            'dewpt': 8.9,
#            'dhi': 26,
#            'dni': 226,
#            'ghi': 97,
#            'max_dhi': 90,
#            'max_dni': 762,
#            'max_ghi': 415,
#            'max_temp': 15.6,
#            'max_temp_ts': 1732442400,
#            'max_uv': 2.2,
#            'max_wind_dir': 153,
#            'max_wind_spd': 6,
#            'max_wind_spd_ts': 1732453200,
#            'min_temp': 14.4,
#            'min_temp_ts': 1732424400,
#            'precip': 1.5,
#            'precip_gpm': 1.5,
#            'pres': 1032,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 66,
#            'slp': 1032,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 95,
#            't_dhi': 629,
#            't_dni': 5419,
#            't_ghi': 2330,
#            't_solar_rad': 2286,
#            'temp': 15.1,
#            'ts': 1732402800,
#            'wind_dir': 153,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 4.8},
#           {'clouds': 35,
#            'datetime': '2024-11-25',
#            'dewpt': 11.9,
#            'dhi': 26,
#            'dni': 224,
#            'ghi': 96,
#            'max_dhi': 90,
#            'max_dni': 760,
#            'max_ghi': 412,
#            'max_temp': 15.2,
#            'max_temp_ts': 1732532400,
#            'max_uv': 2.5,
#            'max_wind_dir': 45,
#            'max_wind_spd': 6.4,
#            'max_wind_spd_ts': 1732550400,
#            'min_temp': 14.1,
#            'min_temp_ts': 1732496400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1026,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 96,
#            't_dhi': 625,
#            't_dni': 5386,
#            't_ghi': 2304,
#            't_solar_rad': 2299,
#            'temp': 14.5,
#            'ts': 1732489200,
#            'wind_dir': 45,
#            'wind_gust_spd': 8,
#            'wind_spd': 4.2},
#           {'clouds': 76,
#            'datetime': '2024-11-26',
#            'dewpt': 14,
#            'dhi': 26,
#            'dni': 223,
#            'ghi': 95,
#            'max_dhi': 90,
#            'max_dni': 758,
#            'max_ghi': 408,
#            'max_temp': 16.7,
#            'max_temp_ts': 1732622400,
#            'max_uv': 1.1,
#            'max_wind_dir': 149,
#            'max_wind_spd': 10,
#            'max_wind_spd_ts': 1732651200,
#            'min_temp': 14.8,
#            'min_temp_ts': 1732658400,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1021,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 90,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 37,
#            't_dhi': 621,
#            't_dni': 5354,
#            't_ghi': 2278,
#            't_solar_rad': 885,
#            'temp': 15.6,
#            'ts': 1732575600,
#            'wind_dir': 149,
#            'wind_gust_spd': 13.2,
#            'wind_spd': 4},
#           {'clouds': 66,
#            'datetime': '2024-11-27',
#            'dewpt': 11.6,
#            'dhi': 26,
#            'dni': 222,
#            'ghi': 94,
#            'max_dhi': 89,
#            'max_dni': 757,
#            'max_ghi': 405,
#            'max_temp': 14.8,
#            'max_temp_ts': 1732705200,
#            'max_uv': 1.7,
#            'max_wind_dir': 93,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1732712400,
#            'min_temp': 14.4,
#            'min_temp_ts': 1732687200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1023,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 55,
#            't_dhi': 617,
#            't_dni': 5322,
#            't_ghi': 2253,
#            't_solar_rad': 1322,
#            'temp': 14.5,
#            'ts': 1732662000,
#            'wind_dir': 93,
#            'wind_gust_spd': 5.6,
#            'wind_spd': 2.4},
#           {'clouds': 50,
#            'datetime': '2024-11-28',
#            'dewpt': 11.9,
#            'dhi': 26,
#            'dni': 220,
#            'ghi': 93,
#            'max_dhi': 89,
#            'max_dni': 755,
#            'max_ghi': 402,
#            'max_temp': 15.6,
#            'max_temp_ts': 1732827600,
#            'max_uv': 1.9,
#            'max_wind_dir': 226,
#            'max_wind_spd': 8.8,
#            'max_wind_spd_ts': 1732824000,
#            'min_temp': 14.4,
#            'min_temp_ts': 1732770000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 81,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 58,
#            't_dhi': 614,
#            't_dni': 5290,
#            't_ghi': 2230,
#            't_solar_rad': 1381,
#            'temp': 15.1,
#            'ts': 1732748400,
#            'wind_dir': 226,
#            'wind_gust_spd': 11.6,
#            'wind_spd': 5.1},
#           {'clouds': 25,
#            'datetime': '2024-11-29',
#            'dewpt': 12.1,
#            'dhi': 25,
#            'dni': 219,
#            'ghi': 92,
#            'max_dhi': 89,
#            'max_dni': 753,
#            'max_ghi': 399,
#            'max_temp': 15.6,
#            'max_temp_ts': 1732874400,
#            'max_uv': 2.1,
#            'max_wind_dir': 47,
#            'max_wind_spd': 9.2,
#            'max_wind_spd_ts': 1732834800,
#            'min_temp': 14.4,
#            'min_temp_ts': 1732917600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1023,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 87,
#            't_dhi': 610,
#            't_dni': 5259,
#            't_ghi': 2207,
#            't_solar_rad': 2092,
#            'temp': 15,
#            'ts': 1732834800,
#            'wind_dir': 47,
#            'wind_gust_spd': 12.4,
#            'wind_spd': 6.8},
#           {'clouds': 7,
#            'datetime': '2024-11-30',
#            'dewpt': 5.3,
#            'dhi': 25,
#            'dni': 218,
#            'ghi': 91,
#            'max_dhi': 88,
#            'max_dni': 752,
#            'max_ghi': 396,
#            'max_temp': 15.2,
#            'max_temp_ts': 1733004000,
#            'max_uv': 2.2,
#            'max_wind_dir': 62,
#            'max_wind_spd': 7.6,
#            'max_wind_spd_ts': 1733004000,
#            'min_temp': 13.3,
#            'min_temp_ts': 1732993200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1028,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 55,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 90,
#            't_dhi': 607,
#            't_dni': 5229,
#            't_ghi': 2185,
#            't_solar_rad': 2165,
#            'temp': 14.2,
#            'ts': 1732921200,
#            'wind_dir': 62,
#            'wind_gust_spd': 9.6,
#            'wind_spd': 5.9},
#           {'clouds': 3,
#            'datetime': '2024-12-01',
#            'dewpt': 6.6,
#            'dhi': 25,
#            'dni': 217,
#            'ghi': 90,
#            'max_dhi': 88,
#            'max_dni': 750,
#            'max_ghi': 393,
#            'max_temp': 14.1,
#            'max_temp_ts': 1733086800,
#            'max_uv': 2.2,
#            'max_wind_dir': 170,
#            'max_wind_spd': 8.4,
#            'max_wind_spd_ts': 1733086800,
#            'min_temp': 13.3,
#            'min_temp_ts': 1733090400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1025,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 62,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 90,
#            't_dhi': 603,
#            't_dni': 5200,
#            't_ghi': 2164,
#            't_solar_rad': 2164,
#            'temp': 13.7,
#            'ts': 1733007600,
#            'wind_dir': 170,
#            'wind_gust_spd': 10.2,
#            'wind_spd': 4.7},
#           {'clouds': 21,
#            'datetime': '2024-12-02',
#            'dewpt': 9.8,
#            'dhi': 25,
#            'dni': 215,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 749,
#            'max_ghi': 391,
#            'max_temp': 14.8,
#            'max_temp_ts': 1733133600,
#            'max_uv': 2.1,
#            'max_wind_dir': 243,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1733155200,
#            'min_temp': 13.7,
#            'min_temp_ts': 1733101200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1020,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 76,
#            'slp': 1020,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 89,
#            't_dhi': 600,
#            't_dni': 5171,
#            't_ghi': 2144,
#            't_solar_rad': 2144,
#            'temp': 14.1,
#            'ts': 1733094000,
#            'wind_dir': 243,
#            'wind_gust_spd': 6,
#            'wind_spd': 2},
#           {'clouds': 50,
#            'datetime': '2024-12-03',
#            'dewpt': 11.4,
#            'dhi': 25,
#            'dni': 214,
#            'ghi': 89,
#            'max_dhi': 88,
#            'max_dni': 747,
#            'max_ghi': 388,
#            'max_temp': 14.8,
#            'max_temp_ts': 1733216400,
#            'max_uv': 1.5,
#            'max_wind_dir': 93,
#            'max_wind_spd': 7.2,
#            'max_wind_spd_ts': 1733234400,
#            'min_temp': 13.7,
#            'min_temp_ts': 1733259600,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 78,
#            't_dhi': 597,
#            't_dni': 5144,
#            't_ghi': 2126,
#            't_solar_rad': 1878,
#            'temp': 14.1,
#            'ts': 1733180400,
#            'wind_dir': 93,
#            'wind_gust_spd': 9.6,
#            'wind_spd': 3.9},
#           {'clouds': 39,
#            'datetime': '2024-12-04',
#            'dewpt': 7.1,
#            'dhi': 25,
#            'dni': 213,
#            'ghi': 88,
#            'max_dhi': 88,
#            'max_dni': 746,
#            'max_ghi': 386,
#            'max_temp': 13.7,
#            'max_temp_ts': 1733310000,
#            'max_uv': 2,
#            'max_wind_dir': 28,
#            'max_wind_spd': 12.4,
#            'max_wind_spd_ts': 1733313600,
#            'min_temp': 12.6,
#            'min_temp_ts': 1733349600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1017,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 68,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 75,
#            't_dhi': 594,
#            't_dni': 5117,
#            't_ghi': 2108,
#            't_solar_rad': 1799,
#            'temp': 13,
#            'ts': 1733266800,
#            'wind_dir': 28,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 11.1},
#           {'clouds': 25,
#            'datetime': '2024-12-05',
#            'dewpt': 4.8,
#            'dhi': 25,
#            'dni': 212,
#            'ghi': 87,
#            'max_dhi': 87,
#            'max_dni': 745,
#            'max_ghi': 383,
#            'max_temp': 13.3,
#            'max_temp_ts': 1733396400,
#            'max_uv': 2.1,
#            'max_wind_dir': 23,
#            'max_wind_spd': 12.8,
#            'max_wind_spd_ts': 1733382000,
#            'min_temp': 12.6,
#            'min_temp_ts': 1733356800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1023,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 58,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 81,
#            't_dhi': 591,
#            't_dni': 5091,
#            't_ghi': 2091,
#            't_solar_rad': 1952,
#            'temp': 12.9,
#            'ts': 1733353200,
#            'wind_dir': 23,
#            'wind_gust_spd': 16.9,
#            'wind_spd': 7.6},
#           {'clouds': 55,
#            'datetime': '2024-12-06',
#            'dewpt': 9,
#            'dhi': 24,
#            'dni': 211,
#            'ghi': 86,
#            'max_dhi': 87,
#            'max_dni': 743,
#            'max_ghi': 381,
#            'max_temp': 14.8,
#            'max_temp_ts': 1733493600,
#            'max_uv': 1.1,
#            'max_wind_dir': 147,
#            'max_wind_spd': 10.8,
#            'max_wind_spd_ts': 1733490000,
#            'min_temp': 13,
#            'min_temp_ts': 1733454000,
#            'precip': 1,
#            'precip_gpm': 1,
#            'pres': 1016,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 72,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 68,
#            't_dhi': 588,
#            't_dni': 5067,
#            't_ghi': 2075,
#            't_solar_rad': 1643,
#            'temp': 14,
#            'ts': 1733439600,
#            'wind_dir': 147,
#            'wind_gust_spd': 16,
#            'wind_spd': 6.5},
#           {'clouds': 66,
#            'datetime': '2024-12-07',
#            'dewpt': 10.5,
#            'dhi': 24,
#            'dni': 210,
#            'ghi': 86,
#            'max_dhi': 87,
#            'max_dni': 742,
#            'max_ghi': 379,
#            'max_temp': 14.8,
#            'max_temp_ts': 1733572800,
#            'max_uv': 0.9,
#            'max_wind_dir': 170,
#            'max_wind_spd': 11.6,
#            'max_wind_spd_ts': 1733587200,
#            'min_temp': 11.5,
#            'min_temp_ts': 1733605200,
#            'precip': 2.8,
#            'precip_gpm': 2.8,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1010,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 28,
#            't_dhi': 585,
#            't_dni': 5044,
#            't_ghi': 2060,
#            't_solar_rad': 676,
#            'temp': 14.1,
#            'ts': 1733526000,
#            'wind_dir': 170,
#            'wind_gust_spd': 17.2,
#            'wind_spd': 5.9},
#           {'clouds': 95,
#            'datetime': '2024-12-08',
#            'dewpt': 5.1,
#            'dhi': 24,
#            'dni': 209,
#            'ghi': 85,
#            'max_dhi': 87,
#            'max_dni': 741,
#            'max_ghi': 377,
#            'max_temp': 12.6,
#            'max_temp_ts': 1733612400,
#            'max_uv': 1.1,
#            'max_wind_dir': 192,
#            'max_wind_spd': 12.8,
#            'max_wind_spd_ts': 1733626800,
#            'min_temp': 10,
#            'min_temp_ts': 1733634000,
#            'precip': 1,
#            'precip_gpm': 1,
#            'pres': 999,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 65,
#            'slp': 999,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 36,
#            't_dhi': 582,
#            't_dni': 5022,
#            't_ghi': 2047,
#            't_solar_rad': 865,
#            'temp': 11.5,
#            'ts': 1733612400,
#            'wind_dir': 192,
#            'wind_gust_spd': 18.4,
#            'wind_spd': 8.7},
#           {'clouds': 70,
#            'datetime': '2024-12-09',
#            'dewpt': 5.6,
#            'dhi': 24,
#            'dni': 208,
#            'ghi': 85,
#            'max_dhi': 87,
#            'max_dni': 740,
#            'max_ghi': 375,
#            'max_temp': 11.9,
#            'max_temp_ts': 1733742000,
#            'max_uv': 1.7,
#            'max_wind_dir': 28,
#            'max_wind_spd': 11.6,
#            'max_wind_spd_ts': 1733770800,
#            'min_temp': 10.7,
#            'min_temp_ts': 1733724000,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1007,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 67,
#            'slp': 1007,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 83,
#            't_dhi': 580,
#            't_dni': 5002,
#            't_ghi': 2034,
#            't_solar_rad': 1991,
#            'temp': 11.5,
#            'ts': 1733698800,
#            'wind_dir': 28,
#            'wind_gust_spd': 16.4,
#            'wind_spd': 10.2},
#           {'clouds': 82,
#            'datetime': '2024-12-10',
#            'dewpt': 6.6,
#            'dhi': 24,
#            'dni': 208,
#            'ghi': 84,
#            'max_dhi': 86,
#            'max_dni': 739,
#            'max_ghi': 374,
#            'max_temp': 11.5,
#            'max_temp_ts': 1733824800,
#            'max_uv': 0.9,
#            'max_wind_dir': 33,
#            'max_wind_spd': 12,
#            'max_wind_spd_ts': 1733860800,
#            'min_temp': 11.1,
#            'min_temp_ts': 1733799600,
#            'precip': 1.3,
#            'precip_gpm': 1.3,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 73,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 46,
#            't_dhi': 577,
#            't_dni': 4983,
#            't_ghi': 2022,
#            't_solar_rad': 1104,
#            'temp': 11.4,
#            'ts': 1733785200,
#            'wind_dir': 33,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 11.4},
#           {'clouds': 66,
#            'datetime': '2024-12-11',
#            'dewpt': 7.1,
#            'dhi': 24,
#            'dni': 207,
#            'ghi': 84,
#            'max_dhi': 86,
#            'max_dni': 738,
#            'max_ghi': 372,
#            'max_temp': 13.7,
#            'max_temp_ts': 1733918400,
#            'max_uv': 1.3,
#            'max_wind_dir': 57,
#            'max_wind_spd': 12.8,
#            'max_wind_spd_ts': 1733871600,
#            'min_temp': 11.5,
#            'min_temp_ts': 1733893200,
#            'precip': 4.3,
#            'precip_gpm': 4.3,
#            'pres': 1021,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 71,
#            'slp': 1021,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 68,
#            't_dhi': 575,
#            't_dni': 4966,
#            't_ghi': 2012,
#            't_solar_rad': 1641,
#            'temp': 12.3,
#            'ts': 1733871600,
#            'wind_dir': 57,
#            'wind_gust_spd': 16.9,
#            'wind_spd': 9.2},
#           {'clouds': 41,
#            'datetime': '2024-12-12',
#            'dewpt': 7.5,
#            'dhi': 24,
#            'dni': 206,
#            'ghi': 83,
#            'max_dhi': 86,
#            'max_dni': 737,
#            'max_ghi': 371,
#            'max_temp': 13.7,
#            'max_temp_ts': 1734004800,
#            'max_uv': 1.9,
#            'max_wind_dir': 59,
#            'max_wind_spd': 12,
#            'max_wind_spd_ts': 1734037200,
#            'min_temp': 12.6,
#            'min_temp_ts': 1733986800,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1025,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 68,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 83,
#            't_dhi': 573,
#            't_dni': 4950,
#            't_ghi': 2002,
#            't_solar_rad': 1996,
#            'temp': 13.3,
#            'ts': 1733958000,
#            'wind_dir': 59,
#            'wind_gust_spd': 16.8,
#            'wind_spd': 9},
#           {'clouds': 92,
#            'datetime': '2024-12-13',
#            'dewpt': 8.2,
#            'dhi': 24,
#            'dni': 206,
#            'ghi': 83,
#            'max_dhi': 86,
#            'max_dni': 736,
#            'max_ghi': 369,
#            'max_temp': 12.6,
#            'max_temp_ts': 1734084000,
#            'max_uv': 0.9,
#            'max_wind_dir': 40,
#            'max_wind_spd': 14,
#            'max_wind_spd_ts': 1734051600,
#            'min_temp': 11.1,
#            'min_temp_ts': 1734127200,
#            'precip': 8.8,
#            'precip_gpm': 8.8,
#            'pres': 1025,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 45,
#            't_dhi': 571,
#            't_dni': 4937,
#            't_ghi': 1994,
#            't_solar_rad': 1083,
#            'temp': 11.7,
#            'ts': 1734044400,
#            'wind_dir': 40,
#            'wind_gust_spd': 20,
#            'wind_spd': 13},
#           {'clouds': 51,
#            'datetime': '2024-12-14',
#            'dewpt': 7.4,
#            'dhi': 24,
#            'dni': 205,
#            'ghi': 83,
#            'max_dhi': 86,
#            'max_dni': 736,
#            'max_ghi': 368,
#            'max_temp': 13.7,
#            'max_temp_ts': 1734174000,
#            'max_uv': 1.7,
#            'max_wind_dir': 154,
#            'max_wind_spd': 9.6,
#            'max_wind_spd_ts': 1734199200,
#            'min_temp': 11.1,
#            'min_temp_ts': 1734145200,
#            'precip': 0.3,
#            'precip_gpm': 0.3,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 73,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 73,
#            't_dhi': 569,
#            't_dni': 4925,
#            't_ghi': 1986,
#            't_solar_rad': 1751,
#            'temp': 12.1,
#            'ts': 1734130800,
#            'wind_dir': 154,
#            'wind_gust_spd': 13.6,
#            'wind_spd': 6},
#           {'clouds': 1,
#            'datetime': '2024-12-15',
#            'dewpt': 6.8,
#            'dhi': 24,
#            'dni': 205,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 735,
#            'max_ghi': 367,
#            'max_temp': 14.1,
#            'max_temp_ts': 1734260400,
#            'max_uv': 2,
#            'max_wind_dir': 195,
#            'max_wind_spd': 4.8,
#            'max_wind_spd_ts': 1734220800,
#            'min_temp': 13,
#            'min_temp_ts': 1734242400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1025,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 64,
#            'slp': 1025,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 567,
#            't_dni': 4916,
#            't_ghi': 1980,
#            't_solar_rad': 1980,
#            'temp': 13.4,
#            'ts': 1734217200,
#            'wind_dir': 195,
#            'wind_gust_spd': 5.4,
#            'wind_spd': 2.8},
#           {'clouds': 0,
#            'datetime': '2024-12-16',
#            'dewpt': 9.1,
#            'dhi': 24,
#            'dni': 205,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 735,
#            'max_ghi': 366,
#            'max_temp': 14.4,
#            'max_temp_ts': 1734354000,
#            'max_uv': 2,
#            'max_wind_dir': 243,
#            'max_wind_spd': 8.8,
#            'max_wind_spd_ts': 1734368400,
#            'min_temp': 13.3,
#            'min_temp_ts': 1734303600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1035,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 73,
#            'slp': 1035,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 566,
#            't_dni': 4908,
#            't_ghi': 1975,
#            't_solar_rad': 1975,
#            'temp': 14,
#            'ts': 1734303600,
#            'wind_dir': 243,
#            'wind_gust_spd': 11.6,
#            'wind_spd': 5.6},
#           {'clouds': 73,
#            'datetime': '2024-12-17',
#            'dewpt': 9.6,
#            'dhi': 24,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 366,
#            'max_temp': 14.4,
#            'max_temp_ts': 1734433200,
#            'max_uv': 0.7,
#            'max_wind_dir': 235,
#            'max_wind_spd': 10.8,
#            'max_wind_spd_ts': 1734440400,
#            'min_temp': 13.3,
#            'min_temp_ts': 1734415200,
#            'precip': 1,
#            'precip_gpm': 1,
#            'pres': 1033,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 75,
#            'slp': 1033,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 35,
#            't_dhi': 564,
#            't_dni': 4903,
#            't_ghi': 1970,
#            't_solar_rad': 829,
#            'temp': 13.9,
#            'ts': 1734390000,
#            'wind_dir': 235,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 9.6},
#           {'clouds': 72,
#            'datetime': '2024-12-18',
#            'dewpt': 10.6,
#            'dhi': 23,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 365,
#            'max_temp': 14.4,
#            'max_temp_ts': 1734526800,
#            'max_uv': 1.4,
#            'max_wind_dir': 225,
#            'max_wind_spd': 9.6,
#            'max_wind_spd_ts': 1734534000,
#            'min_temp': 14.1,
#            'min_temp_ts': 1734541200,
#            'precip': 7,
#            'precip_gpm': 7,
#            'pres': 1028,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 69,
#            't_dhi': 563,
#            't_dni': 4900,
#            't_ghi': 1967,
#            't_solar_rad': 1655,
#            'temp': 14.3,
#            'ts': 1734476400,
#            'wind_dir': 225,
#            'wind_gust_spd': 12,
#            'wind_spd': 7.9},
#           {'clouds': 66,
#            'datetime': '2024-12-19',
#            'dewpt': 12.3,
#            'dhi': 23,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 364,
#            'max_temp': 15.2,
#            'max_temp_ts': 1734631200,
#            'max_uv': 1,
#            'max_wind_dir': 216,
#            'max_wind_spd': 14,
#            'max_wind_spd_ts': 1734642000,
#            'min_temp': 13.7,
#            'min_temp_ts': 1734588000,
#            'precip': 10.5,
#            'precip_gpm': 10.5,
#            'pres': 1014,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 86,
#            'slp': 1014,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 35,
#            't_dhi': 562,
#            't_dni': 4898,
#            't_ghi': 1965,
#            't_solar_rad': 835,
#            'temp': 14.7,
#            'ts': 1734562800,
#            'wind_dir': 216,
#            'wind_gust_spd': 18.9,
#            'wind_spd': 9.1},
#           {'clouds': 43,
#            'datetime': '2024-12-20',
#            'dewpt': 1.9,
#            'dhi': 23,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 364,
#            'max_temp': 14.1,
#            'max_temp_ts': 1734717600,
#            'max_uv': 1.8,
#            'max_wind_dir': 188,
#            'max_wind_spd': 15.2,
#            'max_wind_spd_ts': 1734663600,
#            'min_temp': 10.4,
#            'min_temp_ts': 1734670800,
#            'precip': 0.8,
#            'precip_gpm': 0.8,
#            'pres': 1010,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 50,
#            'slp': 1010,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 57,
#            't_dhi': 561,
#            't_dni': 4897,
#            't_ghi': 1964,
#            't_solar_rad': 1369,
#            'temp': 12.8,
#            'ts': 1734649200,
#            'wind_dir': 188,
#            'wind_gust_spd': 21,
#            'wind_spd': 9.5},
#           {'clouds': 4,
#            'datetime': '2024-12-21',
#            'dewpt': 1.4,
#            'dhi': 23,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 364,
#            'max_temp': 13.3,
#            'max_temp_ts': 1734775200,
#            'max_uv': 2,
#            'max_wind_dir': 130,
#            'max_wind_spd': 6.4,
#            'max_wind_spd_ts': 1734753600,
#            'min_temp': 12.6,
#            'min_temp_ts': 1734818400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 46,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 561,
#            't_dni': 4898,
#            't_ghi': 1964,
#            't_solar_rad': 1964,
#            'temp': 12.9,
#            'ts': 1734735600,
#            'wind_dir': 130,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 2.5},
#           {'clouds': 43,
#            'datetime': '2024-12-22',
#            'dewpt': 7.9,
#            'dhi': 23,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 364,
#            'max_temp': 14.8,
#            'max_temp_ts': 1734876000,
#            'max_uv': 1.3,
#            'max_wind_dir': 249,
#            'max_wind_spd': 18.4,
#            'max_wind_spd_ts': 1734890400,
#            'min_temp': 11.9,
#            'min_temp_ts': 1734825600,
#            'precip': 2,
#            'precip_gpm': 2,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 71,
#            'slp': 1011,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 49,
#            't_dhi': 561,
#            't_dni': 4899,
#            't_ghi': 1965,
#            't_solar_rad': 1177,
#            'temp': 13.1,
#            'ts': 1734822000,
#            'wind_dir': 249,
#            'wind_gust_spd': 26.9,
#            'wind_spd': 11.7},
#           {'clouds': 22,
#            'datetime': '2024-12-23',
#            'dewpt': 1.1,
#            'dhi': 23,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 364,
#            'max_temp': 14.1,
#            'max_temp_ts': 1734987600,
#            'max_uv': 2,
#            'max_wind_dir': 310,
#            'max_wind_spd': 11.2,
#            'max_wind_spd_ts': 1734930000,
#            'min_temp': 11.9,
#            'min_temp_ts': 1734915600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1006,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 46,
#            'slp': 1006,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 80,
#            't_dhi': 561,
#            't_dni': 4902,
#            't_ghi': 1966,
#            't_solar_rad': 1913,
#            'temp': 12.6,
#            'ts': 1734908400,
#            'wind_dir': 310,
#            'wind_gust_spd': 17.6,
#            'wind_spd': 7.6},
#           {'clouds': 3,
#            'datetime': '2024-12-24',
#            'dewpt': 0.3,
#            'dhi': 23,
#            'dni': 204,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 364,
#            'max_temp': 13.7,
#            'max_temp_ts': 1735038000,
#            'max_uv': 2,
#            'max_wind_dir': 20,
#            'max_wind_spd': 11.6,
#            'max_wind_spd_ts': 1734994800,
#            'min_temp': 12.6,
#            'min_temp_ts': 1735059600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1017,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 42,
#            'slp': 1017,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 562,
#            't_dni': 4906,
#            't_ghi': 1969,
#            't_solar_rad': 1968,
#            'temp': 13,
#            'ts': 1734994800,
#            'wind_dir': 20,
#            'wind_gust_spd': 16.4,
#            'wind_spd': 9.2},
#           {'clouds': 0,
#            'datetime': '2024-12-25',
#            'dewpt': 3.5,
#            'dhi': 23,
#            'dni': 205,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 364,
#            'max_temp': 14.1,
#            'max_temp_ts': 1735128000,
#            'max_uv': 2,
#            'max_wind_dir': 89,
#            'max_wind_spd': 9.6,
#            'max_wind_spd_ts': 1735120800,
#            'min_temp': 13.3,
#            'min_temp_ts': 1735106400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1026,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 51,
#            'slp': 1026,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 562,
#            't_dni': 4910,
#            't_ghi': 1973,
#            't_solar_rad': 1973,
#            'temp': 13.6,
#            'ts': 1735081200,
#            'wind_dir': 89,
#            'wind_gust_spd': 12.8,
#            'wind_spd': 7.9},
#           {'clouds': 0,
#            'datetime': '2024-12-26',
#            'dewpt': 3.8,
#            'dhi': 23,
#            'dni': 205,
#            'ghi': 82,
#            'max_dhi': 86,
#            'max_dni': 734,
#            'max_ghi': 365,
#            'max_temp': 14.1,
#            'max_temp_ts': 1735210800,
#            'max_uv': 2,
#            'max_wind_dir': 38,
#            'max_wind_spd': 12,
#            'max_wind_spd_ts': 1735174800,
#            'min_temp': 13.3,
#            'min_temp_ts': 1735239600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1029,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 51,
#            'slp': 1029,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 82,
#            't_dhi': 563,
#            't_dni': 4916,
#            't_ghi': 1978,
#            't_solar_rad': 1978,
#            'temp': 13.7,
#            'ts': 1735167600,
#            'wind_dir': 38,
#            'wind_gust_spd': 15.6,
#            'wind_spd': 10.2},
#           {'clouds': 0,
#            'datetime': '2024-12-27',
#            'dewpt': 6,
#            'dhi': 23,
#            'dni': 205,
#            'ghi': 83,
#            'max_dhi': 86,
#            'max_dni': 735,
#            'max_ghi': 366,
#            'max_temp': 14.1,
#            'max_temp_ts': 1735304400,
#            'max_uv': 2,
#            'max_wind_dir': 42,
#            'max_wind_spd': 10.8,
#            'max_wind_spd_ts': 1735308000,
#            'min_temp': 13.3,
#            'min_temp_ts': 1735282800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1030,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 60,
#            'slp': 1030,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 83,
#            't_dhi': 564,
#            't_dni': 4923,
#            't_ghi': 1984,
#            't_solar_rad': 1984,
#            'temp': 13.7,
#            'ts': 1735254000,
#            'wind_dir': 42,
#            'wind_gust_spd': 13.7,
#            'wind_spd': 7.5},
#           {'clouds': 9,
#            'datetime': '2024-12-28',
#            'dewpt': 8.8,
#            'dhi': 24,
#            'dni': 205,
#            'ghi': 83,
#            'max_dhi': 86,
#            'max_dni': 736,
#            'max_ghi': 367,
#            'max_temp': 13.7,
#            'max_temp_ts': 1735390800,
#            'max_uv': 2,
#            'max_wind_dir': 239,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1735394400,
#            'min_temp': 13.3,
#            'min_temp_ts': 1735354800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1028,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 74,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 81,
#            't_dhi': 565,
#            't_dni': 4930,
#            't_ghi': 1990,
#            't_solar_rad': 1951,
#            'temp': 13.5,
#            'ts': 1735340400,
#            'wind_dir': 239,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 2.8},
#           {'clouds': 1,
#            'datetime': '2024-12-29',
#            'dewpt': 10.5,
#            'dhi': 24,
#            'dni': 206,
#            'ghi': 83,
#            'max_dhi': 86,
#            'max_dni': 737,
#            'max_ghi': 368,
#            'max_temp': 13.3,
#            'max_temp_ts': 1735477200,
#            'max_uv': 2,
#            'max_wind_dir': 229,
#            'max_wind_spd': 4.4,
#            'max_wind_spd_ts': 1735477200,
#            'min_temp': 13,
#            'min_temp_ts': 1735509600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1028,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 83,
#            'slp': 1028,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 83,
#            't_dhi': 566,
#            't_dni': 4939,
#            't_ghi': 1998,
#            't_solar_rad': 1998,
#            'temp': 13.3,
#            'ts': 1735426800,
#            'wind_dir': 229,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 3.6},
#           {'clouds': 5,
#            'datetime': '2024-12-30',
#            'dewpt': 9.3,
#            'dhi': 24,
#            'dni': 206,
#            'ghi': 84,
#            'max_dhi': 86,
#            'max_dni': 738,
#            'max_ghi': 369,
#            'max_temp': 13,
#            'max_temp_ts': 1735560000,
#            'max_uv': 2,
#            'max_wind_dir': 200,
#            'max_wind_spd': 3.2,
#            'max_wind_spd_ts': 1735585200,
#            'min_temp': 11.9,
#            'min_temp_ts': 1735538400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1030,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1030,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 84,
#            't_dhi': 567,
#            't_dni': 4949,
#            't_ghi': 2007,
#            't_solar_rad': 2006,
#            'temp': 12.6,
#            'ts': 1735513200,
#            'wind_dir': 200,
#            'wind_gust_spd': 5.2,
#            'wind_spd': 2.1},
#           {'clouds': 6,
#            'datetime': '2024-12-31',
#            'dewpt': 6.2,
#            'dhi': 24,
#            'dni': 207,
#            'ghi': 84,
#            'max_dhi': 86,
#            'max_dni': 739,
#            'max_ghi': 371,
#            'max_temp': 12.6,
#            'max_temp_ts': 1735639200,
#            'max_uv': 2,
#            'max_wind_dir': 168,
#            'max_wind_spd': 1.2,
#            'max_wind_spd_ts': 1735678800,
#            'min_temp': 11.5,
#            'min_temp_ts': 1735621200,
#            'precip': 0,
#            'precip_gpm': 0,
# ...
#            'slp': 1011,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 15,
#            't_dhi': 763,
#            't_dni': 6459,
#            't_ghi': 3268,
#            't_solar_rad': 366,
#            'temp': 18,
#            'ts': 1761778800,
#            'wind_dir': 104,
#            'wind_gust_spd': 15.2,
#            'wind_spd': 7.9},
#           {'clouds': 72,
#            'datetime': '2025-10-31',
#            'dewpt': 15.5,
#            'dhi': 32,
#            'dni': 267,
#            'ghi': 134,
#            'max_dhi': 99,
#            'max_dni': 811,
#            'max_ghi': 525,
#            'max_temp': 18.9,
#            'max_temp_ts': 1761915600,
#            'max_uv': 2.4,
#            'max_wind_dir': 41,
#            'max_wind_spd': 11.2,
#            'max_wind_spd_ts': 1761904800,
#            'min_temp': 17.4,
#            'min_temp_ts': 1761886800,
#            'precip': 4.3,
#            'precip_gpm': 4.3,
#            'pres': 1016,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 84,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 85,
#            't_dhi': 757,
#            't_dni': 6412,
#            't_ghi': 3221,
#            't_solar_rad': 2035,
#            'temp': 18.3,
#            'ts': 1761865200,
#            'wind_dir': 41,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 8},
#           {'clouds': 91,
#            'datetime': '2025-11-01',
#            'dewpt': 16.9,
#            'dhi': 31,
#            'dni': 265,
#            'ghi': 132,
#            'max_dhi': 98,
#            'max_dni': 809,
#            'max_ghi': 519,
#            'max_temp': 18.5,
#            'max_temp_ts': 1762002000,
#            'max_uv': 1.1,
#            'max_wind_dir': 171,
#            'max_wind_spd': 6.4,
#            'max_wind_spd_ts': 1762012800,
#            'min_temp': 18.1,
#            'min_temp_ts': 1761973200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1019,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 92,
#            'slp': 1019,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 19,
#            't_dhi': 751,
#            't_dni': 6365,
#            't_ghi': 3175,
#            't_solar_rad': 450,
#            'temp': 18.3,
#            'ts': 1761951600,
#            'wind_dir': 171,
#            'wind_gust_spd': 8.4,
#            'wind_spd': 3.3},
#           {'clouds': 78,
#            'datetime': '2025-11-02',
#            'dewpt': 16.1,
#            'dhi': 31,
#            'dni': 263,
#            'ghi': 130,
#            'max_dhi': 98,
#            'max_dni': 807,
#            'max_ghi': 514,
#            'max_temp': 18.5,
#            'max_temp_ts': 1762092000,
#            'max_uv': 2.3,
#            'max_wind_dir': 226,
#            'max_wind_spd': 10.8,
#            'max_wind_spd_ts': 1762095600,
#            'min_temp': 18.1,
#            'min_temp_ts': 1762120800,
#            'precip': 8.3,
#            'precip_gpm': 8.3,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 47,
#            't_dhi': 746,
#            't_dni': 6318,
#            't_ghi': 3130,
#            't_solar_rad': 1131,
#            'temp': 18.3,
#            'ts': 1762038000,
#            'wind_dir': 226,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 7.8},
#           {'clouds': 3,
#            'datetime': '2025-11-03',
#            'dewpt': 12.2,
#            'dhi': 31,
#            'dni': 261,
#            'ghi': 129,
#            'max_dhi': 97,
#            'max_dni': 805,
#            'max_ghi': 509,
#            'max_temp': 18.9,
#            'max_temp_ts': 1762174800,
#            'max_uv': 3.4,
#            'max_wind_dir': 134,
#            'max_wind_spd': 7.2,
#            'max_wind_spd_ts': 1762128000,
#            'min_temp': 17.8,
#            'min_temp_ts': 1762207200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 68,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 129,
#            't_dhi': 740,
#            't_dni': 6270,
#            't_ghi': 3085,
#            't_solar_rad': 3085,
#            'temp': 18.3,
#            'ts': 1762124400,
#            'wind_dir': 134,
#            'wind_gust_spd': 9.2,
#            'wind_spd': 3.7},
#           {'clouds': 0,
#            'datetime': '2025-11-04',
#            'dewpt': 11.5,
#            'dhi': 31,
#            'dni': 259,
#            'ghi': 127,
#            'max_dhi': 97,
#            'max_dni': 803,
#            'max_ghi': 504,
#            'max_temp': 18.5,
#            'max_temp_ts': 1762261200,
#            'max_uv': 3.4,
#            'max_wind_dir': 62,
#            'max_wind_spd': 6,
#            'max_wind_spd_ts': 1762264800,
#            'min_temp': 17.8,
#            'min_temp_ts': 1762228800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1024,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 66,
#            'slp': 1024,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 127,
#            't_dhi': 734,
#            't_dni': 6222,
#            't_ghi': 3041,
#            't_solar_rad': 3041,
#            'temp': 18.1,
#            'ts': 1762210800,
#            'wind_dir': 62,
#            'wind_gust_spd': 8,
#            'wind_spd': 4.9},
#           {'clouds': 0,
#            'datetime': '2025-11-05',
#            'dewpt': 9.7,
#            'dhi': 30,
#            'dni': 257,
#            'ghi': 125,
#            'max_dhi': 97,
#            'max_dni': 801,
#            'max_ghi': 498,
#            'max_temp': 17.4,
#            'max_temp_ts': 1762347600,
#            'max_uv': 3.3,
#            'max_wind_dir': 60,
#            'max_wind_spd': 4.8,
#            'max_wind_spd_ts': 1762344000,
#            'min_temp': 16.7,
#            'min_temp_ts': 1762315200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 63,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 125,
#            't_dhi': 728,
#            't_dni': 6174,
#            't_ghi': 2998,
#            't_solar_rad': 2998,
#            'temp': 16.9,
#            'ts': 1762297200,
#            'wind_dir': 60,
#            'wind_gust_spd': 6.4,
#            'wind_spd': 3.2},
#           {'clouds': 64,
#            'datetime': '2025-11-06',
#            'dewpt': 11.6,
#            'dhi': 30,
#            'dni': 255,
#            'ghi': 123,
#            'max_dhi': 96,
#            'max_dni': 799,
#            'max_ghi': 493,
#            'max_temp': 17.8,
#            'max_temp_ts': 1762434000,
#            'max_uv': 1.5,
#            'max_wind_dir': 70,
#            'max_wind_spd': 8,
#            'max_wind_spd_ts': 1762434000,
#            'min_temp': 16.7,
#            'min_temp_ts': 1762401600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 70,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 57,
#            't_dhi': 722,
#            't_dni': 6126,
#            't_ghi': 2955,
#            't_solar_rad': 1373,
#            'temp': 17,
#            'ts': 1762383600,
#            'wind_dir': 70,
#            'wind_gust_spd': 10.8,
#            'wind_spd': 6.3},
#           {'clouds': 98,
#            'datetime': '2025-11-07',
#            'dewpt': 12.1,
#            'dhi': 30,
#            'dni': 253,
#            'ghi': 121,
#            'max_dhi': 96,
#            'max_dni': 797,
#            'max_ghi': 488,
#            'max_temp': 17.4,
#            'max_temp_ts': 1762520400,
#            'max_uv': 1.1,
#            'max_wind_dir': 37,
#            'max_wind_spd': 12.8,
#            'max_wind_spd_ts': 1762520400,
#            'min_temp': 14.8,
#            'min_temp_ts': 1762488000,
#            'precip': 17,
#            'precip_gpm': 17,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 79,
#            'slp': 1011,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 25,
#            't_dhi': 716,
#            't_dni': 6079,
#            't_ghi': 2914,
#            't_solar_rad': 609,
#            'temp': 15.8,
#            'ts': 1762470000,
#            'wind_dir': 37,
#            'wind_gust_spd': 16.9,
#            'wind_spd': 9.8},
#           {'clouds': 40,
#            'datetime': '2025-11-08',
#            'dewpt': 11,
#            'dhi': 30,
#            'dni': 251,
#            'ghi': 120,
#            'max_dhi': 96,
#            'max_dni': 794,
#            'max_ghi': 483,
#            'max_temp': 16.7,
#            'max_temp_ts': 1762606800,
#            'max_uv': 2.2,
#            'max_wind_dir': 45,
#            'max_wind_spd': 10.8,
#            'max_wind_spd_ts': 1762606800,
#            'min_temp': 15.2,
#            'min_temp_ts': 1762639200,
#            'precip': 8,
#            'precip_gpm': 8,
#            'pres': 1011,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 73,
#            'slp': 1011,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 114,
#            't_dhi': 710,
#            't_dni': 6031,
#            't_ghi': 2872,
#            't_solar_rad': 2744,
#            'temp': 15.9,
#            'ts': 1762556400,
#            'wind_dir': 45,
#            'wind_gust_spd': 13.7,
#            'wind_spd': 8.4},
#           {'clouds': 1,
#            'datetime': '2025-11-09',
#            'dewpt': 9.9,
#            'dhi': 29,
#            'dni': 249,
#            'ghi': 118,
#            'max_dhi': 95,
#            'max_dni': 792,
#            'max_ghi': 479,
#            'max_temp': 16.7,
#            'max_temp_ts': 1762693200,
#            'max_uv': 3.2,
#            'max_wind_dir': 33,
#            'max_wind_spd': 10.4,
#            'max_wind_spd_ts': 1762689600,
#            'min_temp': 15.2,
#            'min_temp_ts': 1762660800,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1015,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 68,
#            'slp': 1015,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 118,
#            't_dhi': 704,
#            't_dni': 5985,
#            't_ghi': 2832,
#            't_solar_rad': 2832,
#            'temp': 15.9,
#            'ts': 1762642800,
#            'wind_dir': 33,
#            'wind_gust_spd': 13.1,
#            'wind_spd': 7.2},
#           {'clouds': 41,
#            'datetime': '2025-11-10',
#            'dewpt': 11.1,
#            'dhi': 29,
#            'dni': 247,
#            'ghi': 116,
#            'max_dhi': 95,
#            'max_dni': 790,
#            'max_ghi': 474,
#            'max_temp': 17,
#            'max_temp_ts': 1762779600,
#            'max_uv': 1.4,
#            'max_wind_dir': 242,
#            'max_wind_spd': 6,
#            'max_wind_spd_ts': 1762790400,
#            'min_temp': 15.6,
#            'min_temp_ts': 1762747200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1016,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 72,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 65,
#            't_dhi': 698,
#            't_dni': 5939,
#            't_ghi': 2793,
#            't_solar_rad': 1572,
#            'temp': 16.3,
#            'ts': 1762729200,
#            'wind_dir': 242,
#            'wind_gust_spd': 7.6,
#            'wind_spd': 3.5},
#           {'clouds': 33,
#            'datetime': '2025-11-11',
#            'dewpt': 13.3,
#            'dhi': 29,
#            'dni': 246,
#            'ghi': 115,
#            'max_dhi': 94,
#            'max_dni': 788,
#            'max_ghi': 469,
#            'max_temp': 17,
#            'max_temp_ts': 1762866000,
#            'max_uv': 2.7,
#            'max_wind_dir': 219,
#            'max_wind_spd': 5.2,
#            'max_wind_spd_ts': 1762869600,
#            'min_temp': 16.3,
#            'min_temp_ts': 1762833600,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 80,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 109,
#            't_dhi': 692,
#            't_dni': 5894,
#            't_ghi': 2754,
#            't_solar_rad': 2624,
#            'temp': 16.8,
#            'ts': 1762815600,
#            'wind_dir': 219,
#            'wind_gust_spd': 7.2,
#            'wind_spd': 2.1},
#           {'clouds': 32,
#            'datetime': '2025-11-12',
#            'dewpt': 15.3,
#            'dhi': 29,
#            'dni': 244,
#            'ghi': 113,
#            'max_dhi': 94,
#            'max_dni': 786,
#            'max_ghi': 464,
#            'max_temp': 17.8,
#            'max_temp_ts': 1762952400,
#            'max_uv': 2.2,
#            'max_wind_dir': 142,
#            'max_wind_spd': 2.4,
#            'max_wind_spd_ts': 1762952400,
#            'min_temp': 16.7,
#            'min_temp_ts': 1762909200,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1022,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 88,
#            'slp': 1022,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 103,
#            't_dhi': 687,
#            't_dni': 5850,
#            't_ghi': 2716,
#            't_solar_rad': 2465,
#            'temp': 17.2,
#            'ts': 1762902000,
#            'wind_dir': 142,
#            'wind_gust_spd': 3.6,
#            'wind_spd': 1.9},
#           {'clouds': 12,
#            'datetime': '2025-11-13',
#            'dewpt': 15.5,
#            'dhi': 28,
#            'dni': 242,
#            'ghi': 112,
#            'max_dhi': 94,
#            'max_dni': 784,
#            'max_ghi': 460,
#            'max_temp': 17.8,
#            'max_temp_ts': 1763038800,
#            'max_uv': 2.8,
#            'max_wind_dir': 52,
#            'max_wind_spd': 5.2,
#            'max_wind_spd_ts': 1763042400,
#            'min_temp': 17,
#            'min_temp_ts': 1763006400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1023,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1023,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 107,
#            't_dhi': 681,
#            't_dni': 5808,
#            't_ghi': 2679,
#            't_solar_rad': 2564,
#            'temp': 17.3,
#            'ts': 1762988400,
#            'wind_dir': 52,
#            'wind_gust_spd': 6,
#            'wind_spd': 3.6},
#           {'clouds': 53,
#            'datetime': '2025-11-14',
#            'dewpt': 16.2,
#            'dhi': 28,
#            'dni': 240,
#            'ghi': 110,
#            'max_dhi': 93,
#            'max_dni': 782,
#            'max_ghi': 455,
#            'max_temp': 18.5,
#            'max_temp_ts': 1763132400,
#            'max_uv': 2.3,
#            'max_wind_dir': 72,
#            'max_wind_spd': 5.6,
#            'max_wind_spd_ts': 1763121600,
#            'min_temp': 17.8,
#            'min_temp_ts': 1763096400,
#            'precip': 0,
#            'precip_gpm': 0,
#            'pres': 1018,
#            'revision_status': 'final',
#            'revision_version': '2.1',
#            'rh': 89,
#            'slp': 1018,
#            'snow': 0,
#            'snow_depth': 0,
#            'solar_rad': 62,
#            't_dhi': 675,
#            't_dni': 5767,
#            't_ghi': 2643,
#            't_solar_rad': 1481,
#            'temp': 18,
#            'ts': 1763074800,
#            'wind_dir': 72,
#            'wind_gust_spd': 6.8,
#            'wind_spd': 4.8}],
#  'lat': 43.37135,
#  'lon': 8.396,
#  'sources': ['imerg', 'era5', 'sat', 'radar', 'snodas'],
#  'state_code': '08',
#  'station_id': '077530-99999',
#  'timezone': 'Europe/Rome'}

# %%
ciudad = data["city_name"]
ciudad

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

coruña =  pd.DataFrame(datos)

coruña.head()

coruña.to_csv("coruña_2024-11-15_2025-11-15.csv")

# %%
# Datos Coruña 2023/2024
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=43.37135&lon=8.396&start_date=2023-11-15&end_date=2024-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response

# %%
data.update(response.json())

# %%
pprint(data)

# %%
ciudad = data["city_name"]
ciudad

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

coruña =  pd.DataFrame(datos)

coruña.head()

coruña.to_csv("coruña_2023-11-15_2024-11-15.csv")

# %%
# Datos Coruña 2022/2023
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=43.37135&lon=8.396&start_date=2022-11-15&end_date=2023-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response

# %%
data.update(response.json())

# %%
pprint(data)

# %%
ciudad = data["city_name"]
ciudad

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

coruña =  pd.DataFrame(datos)

coruña.head()

coruña.to_csv("coruña_2022-11-15_2023-11-15.csv")

# %%
# Datos Coruña 2021/2022
data = {}

url = "https://api.weatherbit.io/v2.0/history/daily?lat=43.37135&lon=8.396&start_date=2021-11-15&end_date=2022-11-15&key=9eff7a274b02431bbc87d0660dbabd60"
response = requests.get(url)

response

# %%
data.update(response.json())

# %%
pprint(data)

# %%
ciudad = data["city_name"]
ciudad

# %%
datos = {}
city_name = []
datetime = []
ts = []
pres = []
slp = []
wind_spd = []
wind_gust_spd = []
max_wind_spd = []
wind_dir = []
max_wind_dir = []
max_wind_spd_ts = []
temp = []
max_temp = []
min_temp = []
max_temp_ts = []
min_temp_ts = []
rh = []
dewpt = []
clouds = []
precip = []
precip_gpm = []
snow = []
snow_depth = []
solar_rad = []
t_solar_rad = []
ghi = []
t_ghi = []
max_ghi = []
dni = []
t_dni = []
max_dni = []
dhi = []
t_dhi = []
max_dhi = []
max_uv = []

for x in data["data"]:
    city_name.append(ciudad)
    datetime.append(x["datetime"])
    ts.append(x["ts"])
    pres.append(x["pres"])
    slp.append(x["slp"])
    wind_spd.append(x["wind_spd"])
    wind_gust_spd.append(x["wind_gust_spd"])
    max_wind_spd.append(x["max_wind_spd"])
    max_wind_spd_ts.append(x["max_wind_spd_ts"])
    wind_dir.append(x["wind_dir"])
    temp.append(x["temp"])
    max_temp.append(x["max_temp"])
    min_temp.append(x["min_temp"])
    max_temp_ts.append(x["max_temp_ts"])
    min_temp_ts.append(x["min_temp_ts"])
    rh.append(x["rh"])
    dewpt.append(x["dewpt"])
    clouds.append(x["clouds"])
    precip.append(x["precip"])
    precip_gpm.append(x["precip_gpm"])
    snow.append(x["snow"])
    snow_depth.append(x["snow_depth"])
    solar_rad.append(x["solar_rad"])
    t_solar_rad.append(x["t_solar_rad"])
    ghi.append(x["ghi"])
    t_ghi.append(x["t_ghi"])
    max_ghi.append(x["max_ghi"])
    dni.append(x["dni"])
    t_dni.append(x["t_dni"])
    max_dni.append(x["max_dni"])
    dhi.append(x["dhi"])
    t_dhi.append(x["t_dhi"])
    max_dhi.append(x["max_dhi"])
    max_uv.append(x["max_uv"])

    for llave, valor in [("Ciudad", city_name),
                     ("Fecha", datetime), 
                     ("Fecha (UNIX)", ts), 
                     ("Presión atmosférica", pres), 
                     ("Presión Atm. sobre Nvl. del mar", slp), 
                     ("Media de la vel. del viento (m/s)", wind_spd), 
                     ("Vel. ráfaga de viento max.", wind_gust_spd),
                     ("Máx. vel. del viento /2min", max_wind_spd), 
                     ("Momento (UNIX) de la vel. máx. del veinto", max_wind_spd_ts), 
                     ("Media de la dirección del viento", wind_dir), 
                     ("Media de la temperatura", temp), 
                     ("Temperatura máxima", max_temp), 
                     ("Temperatura mínima", min_temp), 
                     ("Momento temperatura máxima (UNIX)", max_temp_ts), 
                     ("Momento temperatura mínima (UNIX)", min_temp_ts), 
                     ("Media humedad", rh), 
                     ("Media punto de rocío", dewpt), 
                     ("Media de % de nubes en la zona", clouds), 
                     ("Acumulación de precipitaciones (l/m2)", precip), 
                     ("Acumulación de precipitaciones (l/m2) (NASA)", precip_gpm), 
                     ("Acumulación de nieve (l/m2)", snow), 
                     ("Profundidad de la neive", snow_depth), 
                     ("Media de radiación solar (W/m2)", solar_rad), 
                     ("Total de radiación solar (W/m2)", t_solar_rad), 
                     ("Media de la radiación solar horizontal", ghi), 
                     ("Total de la radiación solar horizontal", t_ghi), 
                     ("Máximo de la radiación solar horizontal", max_ghi), 
                     ("Media de la radiación solar concentrada", dni), 
                     ("Total de la radiación solar concentrada", t_dni), 
                     ("Máximo de la radiación solar concentrada", max_dni), 
                     ("Media de la radiación solar horizontal difusa", dhi), 
                     ("Total de la radiación solar horizontal difusa", t_dhi), 
                     ("Máximo de la radiación solar horizontal difusa", max_dhi),
                     ("Índice máximo de rayos ultravioleta", max_uv)]:
        datos[llave] = valor

coruña =  pd.DataFrame(datos)

coruña.head()

coruña.to_csv("coruña_2021-11-15_2022-11-15.csv")
