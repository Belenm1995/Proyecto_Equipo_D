# %%
import requests
from pprint import pprint
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data = {}

url = "https://api.weatherbit.io/v2.0/geocode?postal_code=08140&country=ES&key=aba2dfe467aa49edb50fd2b3a9937f37"
response = requests.get(url)
data.update(response.json())

pprint(data)
